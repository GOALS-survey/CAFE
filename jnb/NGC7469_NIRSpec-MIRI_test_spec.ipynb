# %%
import os
os._exit(00)

# %%
#%matplotlib widget

import sys
sys.path.insert(0, '../../CAFE')
sys.path.insert(0, '../../CRETA')

import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.ticker
from matplotlib.backends.backend_pdf import PdfPages

#import creta
#import cafe_io
import CAFE
import CRETA
from CAFE.cafe_io import *
#import cafe_helper
from CAFE.cafe_helper import *
import CAFE.cafe as cafe

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# SPECTRAL EXTRACTION

# %%
# Read parameter file with extraction keywords
creta_dir = '../../CRETA/'
pf = open(creta_dir+'param_files/NGC7469_single_params.txt','r')
print(pf.read())
pf.close()
# Out:
# cubes = g140h, g235h, g395h, ch1-short, ch1-medium, ch1-long, ch2-short, ch2-medium, ch2-long, ch3-short, ch3-medium, ch3-long, ch4-short, ch4-medium, ch4-long
# user_r_ap = 0.3                 # [arcsec] Aperture size
# user_ra = 23h03m15.614s         # RA of the extraction location
# user_dec = 08d52m26.23s         # Dec of the extraction location
# point_source = False            # [True/False] True = Cone extraction. False = Cylinder extraction
# lambda_ap = 5.4                 # [microns] The user-specified aperture size (user_r_ap) will be defined at this wavelength (ignored if point_source=False; cylinder extraction)
# aperture_correction = False     # [True/False]
# centering = True                # [True/False] At lambda_cent, this will update user_ra,user_dec to recenter the extraction location
# lambda_cent = 5.4               # [microns] The wavelength at which to perform the centering (ignored if centering=False)
# background_sub = False          # [True/False]
# r_ann_in = 0.0                  # [arcsec] When background_sub=True, this defines the inner annulus size. This size will NOT scale with aperture size even when point_source=True
# ann_width = 0.0                 # [arcsec] When background_sub=True, this defines the annulus width. This size will NOT scale with aperture size even when point_source=True

# %%
# Load the extraction tool (CRETA)
c = creta.creta(creta_dir)
# Out:
# CAFE Region Extraction Tool Automaton (CRETA) initialized

# %%
# Perform the extraction
c.singleExtraction(parameter_file=True, perband_cent=True, parfile_name='NGC7469_single_params.txt', data_path='../CRETA/data/NGC7469/', output_filebase_name='NGC7469')
# Out:
# User API Created
# PSFs: ../CRETA/PSFs/
# Data: ../CRETA/data/NGC7469/
# ########################################
#      Load User Parameters
# ########################################
# Cubes: ['g140h', 'g235h', 'g395h', 'ch1-short', 'ch1-medium', 'ch1-long', 'ch2-short', 'ch2-medium', 'ch2-long', 'ch3-short', 'ch3-medium', 'ch3-long', 'ch4-short', 'ch4-medium', 'ch4-long']
# Aperture radii: [0.3] (arcsec)
# RA,δ: [345.81505833,8.87395278] (degrees)
# Point Source: False
# Aperture Correction: False (PSF Correction)
# Centering: True
# Centering lambda: 5.4μm
# Background Subtraction: False
# PSF sub-cubes Path: ../CRETA/PSFs/
# Data sub-cubes Path: ../CRETA/data/NGC7469/
# ########################################
# Loading Data
# Load file: ../CRETA/data/NGC7469/Level3_g140h-f100lp_s3d.fits
# Load file: ../CRETA/data/NGC7469/Level3_g235h-f170lp_s3d.fits
# Load file: ../CRETA/data/NGC7469/Level3_g395h-f290lp_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch1-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch1-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch1-long_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch2-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch2-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch2-long_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch3-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch3-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch3-long_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch4-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch4-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch4-long_s3d.fits
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# Centering around 5.399500119092409 um in cube ch1_SHORT
# Old coordinates were: 345.81505833 8.87395278
# New coordinates are: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505833, 8.87395278)>
# Per-band re-centering around 0.9704062933143935 um in cube G140H
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81526723, 8.87393467)>
# Per-band re-centering around 1.660691434380468 um in cube G235H
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81524248, 8.87393663)>
# Per-band re-centering around 2.871215809167602 um in cube G395H
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81524207, 8.87392658)>
# Per-band re-centering around 4.902500095486175 um in cube ch1_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505874, 8.87393501)>
# Per-band re-centering around 5.662499847530853 um in cube ch1_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506329, 8.87392821)>
# Per-band re-centering around 6.532500209927093 um in cube ch1_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506107, 8.87393765)>
# Per-band re-centering around 7.515000229119323 um in cube ch2_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505866, 8.87393817)>
# Per-band re-centering around 8.675000076531433 um in cube ch2_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505679, 8.87394853)>
# Per-band re-centering around 10.02500045800116 um in cube ch2_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506524, 8.87393436)>
# Per-band re-centering around 11.557500190800054 um in cube ch3_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506616, 8.87392467)>
# Per-band re-centering around 13.347500152653083 um in cube ch3_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506916, 8.87392202)>
# Per-band re-centering around 15.417499847477304 um in cube ch3_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506453, 8.87393263)>
# Per-band re-centering around 17.71500076306984 um in cube ch4_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506695, 8.87393001)>
# Per-band re-centering around 20.705000534188 um in cube ch4_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505906, 8.87393121)>
# Per-band re-centering around 24.205000534188 um in cube ch4_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81503673, 8.87389218)>
# G140H photometry exectued in: 3.5474460124969482 seconds
# G235H photometry exectued in: 3.4322991371154785 seconds
# G395H photometry exectued in: 3.2771310806274414 seconds
# ch1_SHORT photometry exectued in: 0.7929162979125977 seconds
# ch1_MEDIUM photometry exectued in: 0.8900978565216064 seconds
# ch1_LONG photometry exectued in: 1.086651086807251 seconds
# ch2_SHORT photometry exectued in: 0.6569280624389648 seconds
# ch2_MEDIUM photometry exectued in: 0.668586015701294 seconds
# ch2_LONG photometry exectued in: 0.7709660530090332 seconds
# ch3_SHORT photometry exectued in: 0.601046085357666 seconds
# ch3_MEDIUM photometry exectued in: 0.6762917041778564 seconds
# ch3_LONG photometry exectued in: 0.7851121425628662 seconds
# ch4_SHORT photometry exectued in: 0.5058801174163818 seconds
# ch4_MEDIUM photometry exectued in: 0.5785510540008545 seconds
# ch4_LONG photometry exectued in: 0.7080790996551514 seconds
# Photometry exectued in': 19.031135082244873 seconds
# Initiating stitching process
# Stitch ratios: [[1.065765635039456, 1.0791016402285105, 65.71915296692573, 0.9817629353401767, 1.0019469899119517, 0.8812660951473752, 1.028867902489856, 1.0203618002202592, 0.7787761231337297, 0.9923513257961114, 0.9697833420871936, 0.80271085038905, 0.9897231096353811, 0.9823055647797582, 1.0]]
# For radius 0.3                  arcsec:
# Stitching performed in: 2.247697114944458 seconds
# Output written in: 2.3088388442993164 seconds
# 1 file output(s) named: NGC7469_SingleExt_r0.3as
# {'extraction_RA': <Longitude 345.81505833 deg>, 'extraction_DEC': <Latitude 8.87395278 deg>, 'r_ap': '0.3                 ', 'exrtaction_type': 'extended source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'bkg_sub': False, 'bkg_r_in': None, 'bkg_an_w': None}
# Total execution time of single region extraction: 113.74926805496216 seconds

# %% [markdown]
# # CAFE FITTING

# %%
# Setup directories
#source_fd = '../../CRETA/extractions/'
#source_fn = 'NGC7469_SingleExt_r0.3as_cube.fits'
#source_fnb = source_fn.split('.fits')[0].replace('.','')

source_fd = '/Users/thomaslai/Documents/astro/CAFE/CAFE_bk_20230503_for_Lee_NGC3256_extraction_branch/CRETA/extractions/NGC7469_GridExt_7x7_s0.6as_cube_20230426/NIRSpec_and_MIRI/total_3_spec/'
source_fn = 'NGC7469_sum_sf_spec.dat'

cafe_dir = '../CAFE/'

# Get CAFE directory from sitepackages
# cafe_dir = site.getsitepackages()[0]+'/CAFE/'
#inppar_fn = cafe_dir+'inp_parfiles/inpars_jwst_nirspec-miri_AGN.ini'
inppar_fn = '/Users/thomaslai/Documents/astro/CAFE/CAFE_bk_20230503_for_Lee_NGC3256_extraction_branch/CAFE/inp_parfiles/inpars_jwst_nirspec-miri_NGC7469_based_on_SB.ini'
optpar_fn = cafe_dir+'opt_parfiles/default_opt.cafe'

z=0.01630

# %%
s = cafe.specmod(cafe_dir)

# %%
s.read_spec(source_fn, file_dir=source_fd, z=z)
# Out:
# Load data: /Users/thomaslai/Documents/astro/CAFE/CAFE_bk_20230503_for_Lee_NGC3256_extraction_branch/CRETA/extractions/NGC7469_GridExt_7x7_s0.6as_cube_20230426/NIRSpec_and_MIRI/total_3_spec/NGC7469_sum_sf_spec.dat

# %%
s.plot_spec_ini(inppar_fn, optpar_fn)
# Out:
# Generating continuum profiles for guess model from the .ini file
# Parameter object has 72 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# ISRF
# ISRF

# %%
s.fit_spec(inppar_fn, optpar_fn)
# Out:
# Generating parameter cube with initial/full parameter object
# Parameter object has 83 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Generating parameter object
# Parameter object has 72 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Generating continuum profiles
# ISRF
# ISRF
# 0.74 seconds to make continnum profiles
# Fitting 352 parameters
# Iteration 1/5(max): 2023-07-18 14:07:45.031493 -----------------
# True in 73 steps
# 83.96 seconds elapsed
# <Parameter 'g_H232O2_29620N_Peak', value=5.239994576534999e-18 +/- 0.00263, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=1.7373103815673456e-11 +/- 0.00268, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=7.199882262146059e-18 +/- 0.00288, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O5_34379N_Peak', value=3.647376726807654e-17 +/- 0.00328, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_44348N_Peak', value=2.2360320439337508e-17 +/- 0.00285, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=1.944249571143974e-18 +/- 0.00283, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S6_61088N_Peak', value=2.3111067428702343e-19 +/- 0.00697, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaIII_73177N_Peak', value=8.249534796132494e-16 +/- 0.00936, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=4.77284141110276e-14 +/- 0.0202, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=4.970162064879733e-12 +/- 0.0725, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd20_PAH30_30100_Peak', value=1.3376773207827105e-07 +/- 0.000799, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=3.980796638833839e-17 +/- 0.00527, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_H2Oice_30500_Wave', value=3.0550866767197467 +/- 0.042, bounds=[3.0449132279128213:3.055086676719747]> at upper bound, fixing to 3.055086676719747
# <Parameter 'o_H2Oice_30500_Gamma', value=0.14399999678134914 +/- 0.024, bounds=[0.09999999776482582:0.14399999678134917]> at upper bound, fixing to 0.14399999678134917
# <Parameter 'o_CO2ice_42722_Gamma', value=0.006599999964237212 +/- 0.000591, bounds=[0.004583333308498065:0.006599999964237213]> at upper bound, fixing to 0.006599999964237213
# <Parameter 'o_CO11ice_43810_Wave', value=4.388306579723446 +/- 0.164, bounds=[4.373693504199893:4.388306579723447]> at upper bound, fixing to 4.388306579723447
# <Parameter 'o_CO12ice_46000_Wave', value=4.592328123604163 +/- 0.00378, bounds=[4.592328123604162:4.607671685660975]> at lower bound, fixing to 4.592328123604162
# <Parameter 'o_CO12ice_46000_Gamma', value=0.02333333405355613 +/- 0.00233, bounds=[0.023333334053556126:0.03360000103712082]> at lower bound, fixing to 0.023333334053556126
# <Parameter 'o_CO13ice_46822_Gamma', value=0.001416666685448339 +/- 0.00297, bounds=[0.0014166666854483387:0.0020400000270456077]> at lower bound, fixing to 0.0014166666854483387
# <Parameter 'g_H232O2_29620N_Peak', value=5.239994576534999e-18 +/- 0.00263, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O2_29620N_Peak', value=5.239994576534999e-18 +/- 0.00263, bounds=[0.0:inf]> lower than uncertainty 9.549543419702448e-05 , fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=1.7373103815673456e-11 +/- 0.00268, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=1.7373103815673456e-11 +/- 0.00268, bounds=[0.0:inf]> lower than uncertainty 9.66225728149953e-05 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=7.199882262146059e-18 +/- 0.00288, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=7.199882262146059e-18 +/- 0.00288, bounds=[0.0:inf]> lower than uncertainty 0.00010956643930992495 , fixing to 0.0
# <Parameter 'g_H221O5_34379N_Peak', value=3.647376726807654e-17 +/- 0.00328, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379N_Peak', value=3.647376726807654e-17 +/- 0.00328, bounds=[0.0:inf]> lower than uncertainty 0.00013381529076060227 , fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=0.0008671409798884757 +/- 0.00313, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O5_36630N_Peak', value=0.0007343850605954504 +/- 0.00283, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O6_39721N_Peak', value=0.0012218420003571968 +/- 0.00293, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=2.2360320439337508e-17 +/- 0.00285, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=2.2360320439337508e-17 +/- 0.00285, bounds=[0.0:inf]> lower than uncertainty 0.00012760601245118114 , fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=1.944249571143974e-18 +/- 0.00283, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=1.944249571143974e-18 +/- 0.00283, bounds=[0.0:inf]> lower than uncertainty 0.00012183702571394629 , fixing to 0.0
# <Parameter 'g_NaVII_46847N_Peak', value=0.001776709762035395 +/- 0.00415, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S6_61088N_Peak', value=2.3111067428702343e-19 +/- 0.00697, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S6_61088N_Peak', value=2.3111067428702343e-19 +/- 0.00697, bounds=[0.0:inf]> lower than uncertainty 0.0003145999672340826 , fixing to 0.0
# <Parameter 'g_NaIII_73177N_Peak', value=8.249534796132494e-16 +/- 0.00936, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIII_73177N_Peak', value=8.249534796132494e-16 +/- 0.00936, bounds=[0.0:inf]> lower than uncertainty 0.0004702043632785599 , fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=4.77284141110276e-14 +/- 0.0202, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_79016N_Peak', value=4.77284141110276e-14 +/- 0.0202, bounds=[0.0:inf]> lower than uncertainty 0.0007792796218636231 , fixing to 0.0
# <Parameter 'g_FeVII_95267N_Peak', value=0.003433267702520923 +/- 0.0125, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_131022N_Peak', value=0.010326358730285505 +/- 0.0218, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArIII_218302N_Peak', value=0.014778630994728478 +/- 0.0643, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=4.970162064879733e-12 +/- 0.0725, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=4.970162064879733e-12 +/- 0.0725, bounds=[0.0:inf]> lower than uncertainty 0.004207102807979943 , fixing to 0.0
# <Parameter 'd20_PAH30_30100_Peak', value=1.3376773207827105e-07 +/- 0.000799, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd20_PAH30_30100_Peak', value=1.3376773207827105e-07 +/- 0.000799, bounds=[0.0:inf]> lower than uncertainty 9.41290260483436e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=3.980796638833839e-17 +/- 0.00527, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=3.980796638833839e-17 +/- 0.00527, bounds=[0.0:inf]> lower than uncertainty 0.0009794656821804563 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Gamma', value=0.001416666685448339 +/- 0.00297, bounds=[0.0014166666854483387:0.0020400000270456077]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=0.014986735394634309 +/- 0.0331, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Saving parameters in cube to disk: ../CAFE/output/NGC7469_sum_sf_spec/NGC7469_sum_sf_spec_parcube
# Saving parameters in asdf to disk: ../CAFE/output/NGC7469_sum_sf_spec/NGC7469_sum_sf_spec_cafefit
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)

# %%
# Line and PAH averaged velocity gradient wrt z, in [km/s]
print(s.parcube['VALUE'].data[-1,0,0])
print(s.parcube['VALUE'].data[-1,0,0]/2.998e5)
# Out:
# -14.990905923543115
# -5.0003021759650155e-05

# %%
s.plot_spec_fit(inppar_fn, optpar_fn)
# Out:
# ISRF
# ISRF

# %%
# Load the parameter cube from drive
parcube_fd = '../CAFE/output/'+source_fnb+'/'
parcube_fn = source_fnb+'_parcube.fits'

# %%
s.read_spec(source_fn, file_dir=source_fd, z=z)
# Out:
# Load data: ../CRETA/extractions/NGC7469_SingleExt_r0.3as_cube.fits
# Filename: ../CRETA/extractions/NGC7469_SingleExt_r0.3as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        36   (20624,)   float64
#   2  ERR           1 ImageHDU         7   (20624,)   float64
#   3  FLUX_ST       1 ImageHDU         7   (20624,)   float64
#   4  ERR_ST        1 ImageHDU         7   (20624,)   float64
#   5  DQ            1 ImageHDU         7   (20624,)   float64
#   6  WAVE          1 ImageHDU         7   (20624,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   20624R x 1C   [20A]

# %%
s.read_parcube_file(parcube_fn, file_dir=parcube_fd)
# Out:
# Filename: ../CAFE/output/NGC7469_SingleExt_r03as_cube/NGC7469_SingleExt_r03as_cube_parcube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  VALUE         1 ImageHDU        38   (1, 1, 511)   float64
#   2  STDERR        1 ImageHDU        38   (1, 1, 511)   float64
#   3  VARY          1 ImageHDU        38   (1, 1, 511)   float64
#   4  MIN           1 ImageHDU        38   (1, 1, 511)   float64
#   5  MAX           1 ImageHDU        38   (1, 1, 511)   float64
#   6  EXPR          1 BinTableHDU     13   511R x 2C   [I, 24A]
#   7  PARNAME       1 BinTableHDU     13   511R x 2C   [I, 32A]

# %%
from astropy.io import ascii
from astropy.table import Table
from astropy.table import QTable

# Read output PAH table
pah = cafeio.pah_table(s.parcube, 0, 0)
# Read output line table
line = cafeio.line_table(s.parcube, 0, 0)

pah62 = pah[pah.index == 'PAH62'].pah_strength.values[0]
pah62_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah77 = pah[pah.index == 'PAH77_C'].pah_strength.values[0]
pah77_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah113 = pah[pah.index == 'PAH113_C'].pah_strength.values[0]
pah113_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]

x = pah62 / pah77 
x_unc = pah62 / pah77 * np.sqrt((pah62_unc/pah62)**2 + (pah77_unc/pah77)**2)
y = pah113 / pah77
y_unc = pah113 / pah77 * np.sqrt((pah113_unc/pah113)**2 + (pah77_unc/pah77)**2)

print('6.2/7.7 = {} +/- {}'.format(x, x_unc))
print('11.3/7.7 = {} +/- {}'.format(y, y_unc))

print(pah)

# Make an astropy table 
t = QTable([pah.index.values, pah.pah_strength, pah.pah_strength_unc],
           names = ('pah_complex', 'pah_strength', 'pah_strength_unc'),
           meta={'wavelength': 'micron',
                 'flux': 'W/m^2',
                }
          )

# Write PAH table in an .ecsv file
#t.write('./NGC7469_pah_tbl.ecsv', overwrite=False)
# Out:
# 6.2/7.7 = 0.25351188734624475 +/- 0.0034044745674291937
# 11.3/7.7 = 0.356680430651966 +/- 0.003503717300159815
#              pah_strength  pah_strength_unc
# pah_complex
# PAH113_C     6.500340e-15      1.310185e-16
# PAH120       1.808623e-15      6.444581e-17
# PAH126_C     3.722689e-15      1.075620e-16
# PAH136       4.428247e-16      5.131223e-17
# PAH142       1.306008e-16      4.058921e-17
# PAH164       4.540795e-16      2.923910e-17
# PAH170_C     2.301282e-15      1.472775e-16
# PAH33        2.071846e-15      6.676345e-17
# PAH62        4.620140e-15      6.014248e-17
# PAH77_C      1.822455e-14      2.672891e-16
# PAH83        1.863945e-15      6.114917e-17
# PAH86        4.127514e-15      6.639078e-17
# ali34        2.282618e-16      1.899190e-17
# ali345       2.829862e-16      2.611798e-17
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /Users/thomaslai/opt/anaconda3/lib/python3.9/site-packages/astropy/units/quantity.py:666: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
