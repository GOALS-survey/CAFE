# %%
import os
os._exit(00)

# %%
import sys
sys.path.insert(0, '../CAFE')
sys.path.insert(0, '../CRETA')

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib widget
import matplotlib.ticker
from matplotlib.backends.backend_pdf import PdfPages

import creta
import cafe_io
from cafe_io import *
import cafe_helper
from cafe_helper import *
import cafe

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# User API Created
# <style>.container { width:100% !important; }</style>

# %%
# SPECTRAL EXTRACTION

# %%
# Read parameter file with extraction keywords
creta_dir = '../CRETA/'
pf = open(creta_dir+'/param_files/IIZw096_grid_params.txt','r')
print(pf.read())
pf.close()
# Out:
# cubes = g395h, ch1-short, ch1-medium, ch1-long, ch2-short, ch2-medium, ch2-long, ch3-short, ch3-medium, ch3-long, ch4-short, ch4-medium, ch4-long
# user_ra = 314.35153333
# user_dec = 17.12755833
# user_center = True
# centering = False
# lambda_cent = 5.4
# nx_steps = 3
# ny_steps = 3
# spax_size = 0.5
# step_size = -1
# convolve = False

# %%
# Load the extraction tool (CRETA)
c = creta.creta(creta_dir)
# Out:
# CAFE Region Extraction Tool Automaton (CRETA) initialized

# %%
# Perform the extraction
c.gridExtraction(parameter_file=True, parfile_name='IIZw096_grid_params.txt', data_path='../CRETA/data/IIZw096/', output_filebase_name='IIZw096')
# Out:
# Load file: ../CRETA/data/IIZw096/Level3_g395h-f290lp_s3d_WCScorr.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch1-short_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch1-medium_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch1-long_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch2-short_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch2-medium_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch2-long_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch3-short_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch3-medium_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch3-long_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch4-short_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch4-medium_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch4-long_s3d.fits
# Last cube is:  ch4_LONG
# Cubes: ['g395h', 'ch1-short', 'ch1-medium', 'ch1-long', 'ch2-short', 'ch2-medium', 'ch2-long', 'ch3-short', 'ch3-medium', 'ch3-long', 'ch4-short', 'ch4-medium', 'ch4-long']
# RA,δ: [314.35153333,17.12755833] (degrees)
# Grid Extraction Parameters:
# NX Steps: 3
# NY Steps: 3
# Spaxel Size:  0.5
# Step Size: 0.5
# Loading Data
# Load file: ../CRETA/data/IIZw096/Level3_g395h-f290lp_s3d_WCScorr.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch1-short_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch1-medium_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch1-long_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch2-short_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch2-medium_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch2-long_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch3-short_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch3-medium_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch3-long_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch4-short_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch4-medium_s3d.fits
# Load file: ../CRETA/data/IIZw096/Level3_bandcube_ch4-long_s3d.fits
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# G395H photometry exectued in: 14.340716123580933 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_SHORT photometry exectued in: 3.5274930000305176 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_MEDIUM photometry exectued in: 3.977382183074951 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_LONG photometry exectued in: 4.258607864379883 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_SHORT photometry exectued in: 3.1805338859558105 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_MEDIUM photometry exectued in: 3.7341578006744385 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_LONG photometry exectued in: 3.742316961288452 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_SHORT photometry exectued in: 2.038205862045288 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_MEDIUM photometry exectued in: 2.513421058654785 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_LONG photometry exectued in: 3.2227373123168945 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_SHORT photometry exectued in: 1.8242769241333008 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_MEDIUM photometry exectued in: 1.5807437896728516 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_LONG photometry exectued in: 1.6476211547851562 seconds
# Grid point 0 stitched in: 0.020140886306762695 seconds
# Output written in: 0.5028769969940186 seconds
# Grid point 1 stitched in: 0.022377967834472656 seconds
# Output written in: 0.7199511528015137 seconds
# Grid point 2 stitched in: 0.021457195281982422 seconds
# Output written in: 0.4412071704864502 seconds
# Grid point 3 stitched in: 0.0210721492767334 seconds
# Output written in: 0.4434962272644043 seconds
# Grid point 4 stitched in: 0.031408071517944336 seconds
# Output written in: 0.6948800086975098 seconds
# Grid point 5 stitched in: 0.021676063537597656 seconds
# Output written in: 0.471081018447876 seconds
# Grid point 6 stitched in: 0.021357059478759766 seconds
# Output written in: 0.43897175788879395 seconds
# Grid point 7 stitched in: 0.02713298797607422 seconds
# Output written in: 0.9170801639556885 seconds
# Grid point 8 stitched in: 0.0257110595703125 seconds
# Output written in: 0.4873638153076172 seconds
# {'extraction_RA': <Longitude 314.35167866 deg>, 'extraction_DEC': <Latitude 17.12741944 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.35167866 deg>, 'extraction_DEC': <Latitude 17.12755833 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.35167866 deg>, 'extraction_DEC': <Latitude 17.12769722 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.35153333 deg>, 'extraction_DEC': <Latitude 17.12741944 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.35153333 deg>, 'extraction_DEC': <Latitude 17.12755833 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.35153333 deg>, 'extraction_DEC': <Latitude 17.12769722 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.351388 deg>, 'extraction_DEC': <Latitude 17.12741944 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.351388 deg>, 'extraction_DEC': <Latitude 17.12755833 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.351388 deg>, 'extraction_DEC': <Latitude 17.12769722 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]

# %%
# CAFE FITTING

# %%
# Setup directories
source_fd = '../CRETA/extractions/'
#source_fn = 'last_result_GridExt_3x3_cube.fits'
source_fn = 'IIZw096_GridExt_3x3_s0.5as_cube.fits'
source_fnb = source_fn.split('.fits')[0].replace('.','')

cafe_dir = '../CAFE/'
inppar_fn = cafe_dir+'inp_parfiles/inpars_jwst_nirspec-miri_SB.ini'
optpar_fn = cafe_dir+'opt_parfiles/default_opt.cafe'

z=0.036245

# %%
s = cafe.cubemod(cafe_dir)

# %%
s.read_cube(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ../CRETA/extractions/IIZw096_GridExt_3x3_s0.5as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        38   (3, 3, 15142)   float64
#   2  ERR           1 ImageHDU         9   (3, 3, 15142)   float64
#   3  FLUX_ST       1 ImageHDU         9   (3, 3, 15142)   float64
#   4  ERR_ST        1 ImageHDU         9   (3, 3, 15142)   float64
#   5  DQ            1 ImageHDU         9   (3, 3, 15142)   float64
#   6  WAVE          1 ImageHDU         7   (15142,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   15142R x 1C   [20A]

# %%
s.plot_cube_ini(1, 1, inppar_fn, optpar_fn)
# Out:
# Generating continuum profiles for guess model
# Parameter object has 94 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s.fit_cube(inppar_fn, optpar_fn)
# Out:
# Generating fitting sequence
# Highest SNR spaxel is: 1 1
# Generating initial/full parameter object with all potential lines
# Parameter object has 120 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Generating parameter cube with initial/full parameter object
# Regenerating continuum profiles
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [1 1]
# Parameter object has 94 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-07 00:00:30.704978 -----------------
# True in 39 steps
# 224.96 seconds elapsed
# No errors retuned
# <Parameter 'STB_010', value=2.473492845845345e-16, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O2_27862B_Gamma', value=0.006671112302949256, bounds=[0.0002778181807355326:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_H221O3_29741B_Wave', value=2.974116005776083, bounds=[2.9691398599066043:2.9790601400933956]> at initial value 2.9741 . Fixing value.
# <Parameter 'g_Brackett54_40523N_Peak', value=6.80422041014652e-08, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O7_40540N_Peak', value=1.0500056916634598e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_40819N_Peak', value=2.4257005935880445e-15, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O8_41625N_Peak', value=2.835270602043005e-14, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O8_41625B_Peak', value=2.640704062702812e-14, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys106_51287N_Peak', value=1.1842659391985957e-07, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys96_59066B_Gamma', value=0.00027595440648787235, bounds=[0.0002759544063903498:0.0066711140760507]> at lower bound, fixing to 0.0002759544063903498
# <Parameter 'g_PIII_178850N_Peak', value=6.422172715206986e-21, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_179359N_Peak', value=1.2254996601605651e-16, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeIII_229250N_Peak', value=1.0581989287287687e-09, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=5.296049520523774e-06, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=4.84114812521426e-14, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=1.6860122088724058e-11, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=2.797809730898381e-14, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=2.0683548288154764e-16, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=4.4668902513143025e-15, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO2ice_42736_Wave', value=4.266472683022972, bounds=[4.266472683022863:4.280727519919031]> at lower bound, fixing to 4.266472683022863
# <Parameter 'o_CO2ice_42736_Gamma', value=0.007083333718288504, bounds=[0.007083333718279998:0.010200000554323196]> at lower bound, fixing to 0.007083333718279998
# <Parameter 'o_CO11ice_43810_Wave', value=4.373693504199894, bounds=[4.373693504199893:4.388306579723447]> at lower bound, fixing to 4.373693504199893
# <Parameter 'o_CO11ice_43810_Gamma', value=0.08333333457509705, bounds=[0.08333333457509677:0.12000000178813934]> at lower bound, fixing to 0.08333333457509677
# <Parameter 'o_CO12ice_45440_Wave', value=4.536423517225527, bounds=[4.536421762934679:4.551578534611708]> at lower bound, fixing to 4.536421762934679
# <Parameter 'o_CO12ice_45440_Gamma', value=0.04000009392232378, bounds=[0.040000000347693764:0.05760000050067901]> at lower bound, fixing to 0.040000000347693764
# <Parameter 'o_CO12ice_45440_Peak', value=5.191906262640477e-15, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Wave', value=4.674402336537351, bounds=[4.674391082479923:4.690008827493221]> at lower bound, fixing to 4.674391082479923
# <Parameter 'o_CO13ice_46822_Peak', value=1.2945575882188294e-10, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# Rerunning fit
# Iteration 2/5(max): 2023-01-07 00:04:16.050114 -----------------
# True in 7 steps
# 33.39 seconds elapsed
# <Parameter 'STB_TAU', value=5.491994981700661e-09 +/- 0.998, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_COV', value=0.9999966828235197 +/- 0.56, bounds=[0.0:1.0]> at upper bound, fixing to  1.0
# <Parameter 'STB_TAU', value=5.491994981700661e-09 +/- 0.998, bounds=[0.0:inf]> unconstrained at 18173030613.887993 % error. Fixing value.
# <Parameter 'g_H232O2_29620N_Peak', value=0.00021662984044927731 +/- 0.000578, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O3_29741N_Peak', value=0.00023749180477500583 +/- 0.00102, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=0.00019872436016018182 +/- 0.000669, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O3_31637N_Peak', value=0.00016825490848458965 +/- 0.00041, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899N_Peak', value=2.4162391594271312e-05 +/- 0.105, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Gamma', value=0.00042911614710576827 +/- 0.0102, bounds=[0.00041423524280688234:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Peak', value=0.00018959127459889443 +/- 0.102, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=0.00012892795597404678 +/- 0.000438, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379N_Peak', value=1.8346747947577452e-05 +/- 0.0876, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Gamma', value=0.00039650120942157346 +/- 0.00347, bounds=[0.00038142125163831273:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Peak', value=0.0004175189602049246 +/- 0.0849, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=0.00018579344038824016 +/- 0.0005, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O6_35007N_Peak', value=0.0004974299785768831 +/- 0.00153, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O6_35007B_Peak', value=0.0004883091261579199 +/- 0.00119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075N_Peak', value=0.00046770254222700404 +/- 0.00169, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S12_39947N_Peak', value=0.00031849629337542333 +/- 0.000658, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys146_40209N_Peak', value=0.000257719184237057 +/- 0.000571, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066N_Peak', value=0.0004040349717147012 +/- 0.00204, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys86_75005N_Peak', value=0.001087478907382553 +/- 0.00432, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArIII_218302N_Peak', value=0.008932192267453263 +/- 0.0185, bounds=[0.0:inf]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [2 1]
# Parameter object has 97 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [2 1] will be initialized with results from spaxel [1 1]
# Parameter object has 97 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-07 00:04:52.983472 -----------------
# True in 31 steps
# 191.1 seconds elapsed
# <Parameter 'STB_010', value=1.9517849736472407e-13 +/- 0.0261, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O2_27862B_Wave', value=2.7911337076636262 +/- 0.0236, bounds=[2.7818392242903207:2.791133708835227]> at upper bound, fixing to 2.791133708835227
# <Parameter 'g_H221O2_27862B_Gamma', value=0.006671114076050699 +/- 0.0219, bounds=[0.0002778181807355326:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_H221O4_31899B_Gamma', value=0.0004142364903677921 +/- 1.95e+07, bounds=[0.00041423524280688234:0.0066711140760507]> at lower bound, fixing to 0.00041423524280688234
# <Parameter 'g_H221O4_31899B_Peak', value=7.301149452903082e-17 +/- 0.000684, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O5_34379N_Peak', value=6.107790836847371e-17 +/- 0.000673, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O5_34379B_Gamma', value=0.0003814224313863218 +/- 2.79e+14, bounds=[0.00038142125163831273:0.0066711140760507]> at lower bound, fixing to 0.00038142125163831273
# <Parameter 'g_H221O5_34379B_Peak', value=2.750396364476226e-19 +/- 0.000706, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_40763N_Peak', value=2.0559873356708299e-19 +/- 0.000569, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O8_41625B_Wave', value=4.1698707982909164 +/- 0.00253, bounds=[4.155985130682815:4.169870814380385]> at upper bound, fixing to 4.169870814380385
# <Parameter 'g_FeII_44348N_Peak', value=8.792312550631953e-21 +/- 0.000675, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_48891N_Peak', value=1.4838062116705823e-14 +/- 0.000879, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_50624N_Peak', value=3.793628646220826e-14 +/- 0.00095, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys96_59066N_Peak', value=7.256827075119795e-17 +/- 0.00396, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=2.980945025711204e-11 +/- 0.00453, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=3.123281629717467e-13 +/- 0.0108, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=3.6468974950636443e-16 +/- 0.0213, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=1.2768526838956607e-15 +/- 0.000731, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=8.861659728080836e-19 +/- 0.000986, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=1.078564960089798e-21 +/- 0.000666, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=3.0245247122319317e-24 +/- 0.000822, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd17_PAH189_189200_Peak', value=3.4151351939544847e-20 +/- 0.00283, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO11ice_43810_Wave', value=4.366848088798508 +/- 0.114, bounds=[4.366848088797303:4.381438292902873]> at lower bound, fixing to 4.366848088797303
# <Parameter 'o_CO11ice_43810_Gamma', value=0.10000000149009972 +/- 0.0081, bounds=[0.06944444547924732:0.10000000149011612]> at upper bound, fixing to 0.10000000149011612
# <Parameter 'o_CO12ice_45440_Wave', value=4.529323209811905 +/- 0.0428, bounds=[4.529321656039027:4.544454705340861]> at lower bound, fixing to 4.529321656039027
# <Parameter 'o_CO12ice_45440_Gamma', value=0.033333333623078144 +/- 0.0229, bounds=[0.03333333362307814:0.04800000041723251]> at lower bound, fixing to 0.03333333362307814
# <Parameter 'o_CO13ice_46822_Gamma', value=0.0011805944500147992 +/- 0.00229, bounds=[0.001180594450014799:0.0017000560080213105]> at lower bound, fixing to 0.001180594450014799
# <Parameter 'STB_TAU', value=0.0009997318178827923 +/- 27.1, bounds=[0.0:inf]> unconstrained at 2706227.340469281 % error. Fixing value.
# <Parameter 'STB_COV', value=0.05365311993094382 +/- 29.3, bounds=[0.0:1.0]> unconstrained at 54641.68186586861 % error. Fixing value.
# <Parameter 'STB_010', value=1.9517849736472407e-13 +/- 0.0261, bounds=[0.0:1.0]> unconstrained at 13383741659893.268 % error. Fixing value.
# <Parameter 'g_H221O2_27862N_Peak', value=0.0001796790412049272 +/- 0.00106, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O2_27862B_Gamma', value=0.006671114076050699 +/- 0.0219, bounds=[0.0002778181807355326:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O2_27862B_Peak', value=0.00011389134273113015 +/- 0.000274, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O3_28025N_Peak', value=0.00028172032436020775 +/- 0.00423, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund115_28730N_Peak', value=0.0009006353601892374 +/- 0.00199, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O2_29620N_Peak', value=0.00041692672597180174 +/- 0.000834, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O3_29741N_Peak', value=0.00028388156692860523 +/- 0.00231, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O3_29741B_Peak', value=0.0006329416783169421 +/- 0.00165, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O4_30039N_Peak', value=0.00020075049560335528 +/- 0.0607, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O4_30039B_Gamma', value=0.0005037371899461797 +/- 0.00367, bounds=[0.00044280650492084354:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H210O4_30039B_Peak', value=0.0006481940036962818 +/- 0.0517, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O3_31637N_Peak', value=0.00026955928713612363 +/- 0.000622, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899N_Peak', value=0.00022955975874537672 +/- 0.000617, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Wave', value=3.1852194394583657 +/- 2.25e+07, bounds=[3.184907379787415:3.1955485671572355]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Gamma', value=0.0004142364903677921 +/- 1.95e+07, bounds=[0.00041423524280688234:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Peak', value=7.301149452903082e-17 +/- 0.000684, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Peak', value=7.301149452903082e-17 +/- 0.000684, bounds=[0.0:inf]> lower than uncertainty 1.4415384601939827e-06 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=3.710763916715387e-05 +/- 0.000537, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379N_Peak', value=6.107790836847371e-17 +/- 0.000673, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379N_Peak', value=6.107790836847371e-17 +/- 0.000673, bounds=[0.0:inf]> lower than uncertainty 1.7388135834159387e-06 , fixing to 0.0
# <Parameter 'g_H221O5_34379B_Wave', value=3.4326276674768343 +/- 9.56e+14, bounds=[3.4325192266124804:3.4439877171791777]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Gamma', value=0.0003814224313863218 +/- 2.79e+14, bounds=[0.00038142125163831273:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Peak', value=2.750396364476226e-19 +/- 0.000706, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Peak', value=2.750396364476226e-19 +/- 0.000706, bounds=[0.0:inf]> lower than uncertainty 1.6659636461704085e-06 , fixing to 0.0
# <Parameter 'g_H210O6_35007N_Peak', value=6.012282598475075e-05 +/- 0.00422, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O6_35007B_Gamma', value=0.0006075886813384694 +/- 0.00152, bounds=[0.0003739205937240101:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H210O6_35007B_Peak', value=0.0005297015217978909 +/- 0.00382, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O5_36630N_Peak', value=0.00018015790684585214 +/- 0.000557, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=2.9328905542875403e-05 +/- 0.000606, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075N_Peak', value=0.0003164082100420684 +/- 0.00251, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075B_Gamma', value=0.00043115700283366163 +/- 0.00471, bounds=[0.0003411464716267018:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075B_Peak', value=0.0001563397092243724 +/- 0.00108, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys146_40209N_Peak', value=0.0011883161420741483 +/- 0.0114, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Brackett54_40523N_Peak', value=0.002727279449026364 +/- 0.0206, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40763N_Peak', value=2.0559873356708299e-19 +/- 0.000569, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40763N_Peak', value=2.0559873356708299e-19 +/- 0.000569, bounds=[0.0:inf]> lower than uncertainty 1.8387128481023642e-06 , fixing to 0.0
# <Parameter 'g_H210O8_41625N_Peak', value=1.4005472933280971e-05 +/- 0.000614, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Gamma', value=0.00034215765409317475 +/- 0.00124, bounds=[0.0003097332479213639:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Peak', value=0.00034084507999269324 +/- 0.000741, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=8.792312550631953e-21 +/- 0.000675, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=8.792312550631953e-21 +/- 0.000675, bounds=[0.0:inf]> lower than uncertainty 2.9499111084094756e-06 , fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=4.904813025710479e-05 +/- 0.000713, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=1.4838062116705823e-14 +/- 0.000879, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=1.4838062116705823e-14 +/- 0.000879, bounds=[0.0:inf]> lower than uncertainty 3.7328882312436893e-06 , fixing to 0.0
# <Parameter 'g_FeII_50624N_Peak', value=3.793628646220826e-14 +/- 0.00095, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_50624N_Peak', value=3.793628646220826e-14 +/- 0.00095, bounds=[0.0:inf]> lower than uncertainty 4.247158861351065e-06 , fixing to 0.0
# <Parameter 'g_Humphreys106_51287N_Peak', value=0.0010977654716069311 +/- 0.00301, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_56739N_Peak', value=0.0004954520673142704 +/- 0.0014, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066N_Peak', value=7.256827075119795e-17 +/- 0.00396, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066N_Peak', value=7.256827075119795e-17 +/- 0.00396, bounds=[0.0:inf]> lower than uncertainty 6.788477554111706e-06 , fixing to 0.0
# <Parameter 'g_H200S6_61088N_Peak', value=3.5310199102798836e-05 +/- 0.00137, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=2.980945025711204e-11 +/- 0.00453, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=2.980945025711204e-11 +/- 0.00453, bounds=[0.0:inf]> lower than uncertainty 1.079233048421834e-05 , fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=3.123281629717467e-13 +/- 0.0108, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_PIII_178850N_Peak', value=3.123281629717467e-13 +/- 0.0108, bounds=[0.0:inf]> lower than uncertainty 3.241084479547568e-05 , fixing to 0.0
# <Parameter 'g_FeII_179359N_Peak', value=0.00019989468981742193 +/- 0.0107, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=3.6468974950636443e-16 +/- 0.0213, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=3.6468974950636443e-16 +/- 0.0213, bounds=[0.0:inf]> lower than uncertainty 0.0001668064158019008 , fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=1.2768526838956607e-15 +/- 0.000731, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd8_PAH107_106800_Peak', value=1.2768526838956607e-15 +/- 0.000731, bounds=[0.0:inf]> lower than uncertainty 8.819049854381943e-06 , fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=8.861659728080836e-19 +/- 0.000986, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd11_PAH127_126900_Peak', value=8.861659728080836e-19 +/- 0.000986, bounds=[0.0:inf]> lower than uncertainty 1.4474870093776668e-05 , fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=1.078564960089798e-21 +/- 0.000666, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd15_PAH159_159000_Peak', value=1.078564960089798e-21 +/- 0.000666, bounds=[0.0:inf]> lower than uncertainty 1.631376414004714e-05 , fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=3.0245247122319317e-24 +/- 0.000822, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH164_164500_Peak', value=3.0245247122319317e-24 +/- 0.000822, bounds=[0.0:inf]> lower than uncertainty 1.5123786869182431e-05 , fixing to 0.0
# <Parameter 'd17_PAH189_189200_Peak', value=3.4151351939544847e-20 +/- 0.00283, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd17_PAH189_189200_Peak', value=3.4151351939544847e-20 +/- 0.00283, bounds=[0.0:inf]> lower than uncertainty 4.010539398685975e-05 , fixing to 0.0
# <Parameter 'o_CO2ice_42736_Peak', value=0.06560711023991403 +/- 0.333, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO11ice_43810_Peak', value=0.2477972523845248 +/- 0.991, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO12ice_45440_Peak', value=0.04987110590737664 +/- 0.163, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=0.05332838610022187 +/- 0.175, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [2 2]
# Parameter object has 93 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [2 2] will be initialized with results from spaxel [1 1]
# Parameter object has 93 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-07 00:08:08.341273 -----------------
# True in 93 steps
# 544.01 seconds elapsed
# No errors retuned
# <Parameter 'STB_FLX', value=8.963824097985977e-07, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_010', value=1.9379264304983152e-08, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O3_28025N_Peak', value=1.8822568792410327e-08, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O3_29741N_Peak', value=2.1292460554415165e-13, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O4_30039N_Peak', value=1.3182076944249089e-08, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O4_31899N_Peak', value=4.8092933059022025e-12, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O4_31899B_Gamma', value=0.0004142353219806843, bounds=[0.00041423524280688234:0.0066711140760507]> at lower bound, fixing to 0.00041423524280688234
# <Parameter 'g_CaIV_32067N_Peak', value=5.767716478329635e-15, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O5_32350N_Peak', value=8.369891499389659e-11, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O5_34379N_Peak', value=5.818970967787383e-08, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O5_34379B_Gamma', value=0.0003814212584850316, bounds=[0.00038142125163831273:0.0066711140760507]> at lower bound, fixing to 0.00038142125163831273
# <Parameter 'g_H200S17_34850N_Peak', value=5.679822373592165e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O6_35007B_Wave', value=3.5068989165472453, bounds=[3.4952209362117315:3.5068989212976374]> at upper bound, fixing to 3.5068989212976374
# <Parameter 'g_H210O8_41625B_Wave', value=4.155985413833785, bounds=[4.155985130682815:4.169870814380385]> at lower bound, fixing to 4.155985130682815
# <Parameter 'g_H210O8_41625B_Gamma', value=0.006671108516240667, bounds=[0.0003097332479213639:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_Humphreys106_51287B_Wave', value=5.13772396615255, bounds=[5.120622976691033:5.137731640161434]> at upper bound, fixing to 5.137731640161434
# <Parameter 'g_Humphreys106_51287B_Gamma', value=0.006671112562845588, bounds=[0.0002476669451385073:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_FeII_56739N_Peak', value=1.2455660557841607e-11, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=8.445608073805697e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_179359N_Peak', value=1.2618186342589183e-09, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=2.2340410575436673e-11, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd20_PAH30_30100_Peak', value=1.6492380435366156e-23, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd1_PAH53_53300_Peak', value=1.3042941009195894e-09, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd2_PAH57_56700_Peak', value=1.2657431826231964e-12, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=1.9740694164144247e-28, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=1.2609955024563775e-12, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=2.6567506323938552e-12, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=1.8589200367563787e-11, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=6.666167079141818e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=1.3121842503381318e-09, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=3.4569970736842193e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=3.6645211738299434e-11, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO2ice_42736_Wave', value=4.274027608442049, bounds=[4.259795082548333:4.274027608717891]> at upper bound, fixing to 4.274027608717891
# <Parameter 'o_CO2ice_42736_Gamma', value=0.005902778100826678, bounds=[0.005902778098566665:0.008500000461935997]> at lower bound, fixing to 0.005902778098566665
# <Parameter 'o_CO2ice_42736_Peak', value=9.077937764340894e-11, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO11ice_43810_Wave', value=4.366848089104372, bounds=[4.366848088797303:4.381438292902873]> at lower bound, fixing to 4.366848088797303
# <Parameter 'o_CO11ice_43810_Gamma', value=0.06944444548310912, bounds=[0.06944444547924732:0.10000000149011612]> at lower bound, fixing to 0.06944444547924732
# <Parameter 'o_CO11ice_43810_Peak', value=1.3925470780211374e-09, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO12ice_45440_Wave', value=4.529321656332795, bounds=[4.529321656039027:4.544454705340861]> at lower bound, fixing to 4.529321656039027
# <Parameter 'o_CO12ice_45440_Gamma', value=0.0333333343619271, bounds=[0.03333333362307814:0.04800000041723251]> at lower bound, fixing to 0.03333333362307814
# <Parameter 'o_CO12ice_45440_Peak', value=2.1900933571904102e-09, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Wave', value=4.66707503514322, bounds=[4.667075035143042:4.682668336296209]> at lower bound, fixing to 4.667075035143042
# <Parameter 'o_CO13ice_46822_Gamma', value=0.0011806053015865272, bounds=[0.001180594450014799:0.0017000560080213105]> at lower bound, fixing to 0.001180594450014799
# Rerunning fit
# Iteration 2/5(max): 2023-01-07 00:17:12.730190 -----------------
# True in 6 steps
# 21.87 seconds elapsed
# <Parameter 'g_H210O7_38075B_Wave', value=3.8015407948770656 +/- 0.00681, bounds=[3.801540753171128:3.8142421923731695]> at lower bound, fixing to 3.801540753171128
# <Parameter 'g_H210O7_38075B_Gamma', value=0.00667111407363154 +/- 0.00415, bounds=[0.0003411464716267018:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_Brackett54_40523N_Peak', value=5.639429995800675e-08 +/- 0.0395, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund75_46538B_Gamma', value=0.006671113884715664 +/- 0.00133, bounds=[0.00027472498851076636:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_Pfund65_74578N_Peak', value=2.0381137013966897e-07 +/- 0.00277, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O2_27862N_Peak', value=0.0002769614982141677 +/- 0.016, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O2_27862B_Gamma', value=0.0002778214680498662 +/- 0.00722, bounds=[0.0002778181807355326:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O2_27862B_Peak', value=0.0009535124833405248 +/- 0.0221, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund115_28730N_Peak', value=0.0011075164531163736 +/- 0.0226, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund115_28730B_Gamma', value=0.0003637219580140095 +/- 0.00131, bounds=[0.000268995503249586:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund115_28730B_Peak', value=0.002563051445697326 +/- 0.00737, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O2_29620N_Peak', value=0.00014620980271171194 +/- 0.00399, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund105_30392N_Peak', value=0.00034907140520158805 +/- 0.088, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund105_30392B_Peak', value=0.004976057580600884 +/- 0.0802, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O3_31637N_Peak', value=0.0006349352912478388 +/- 0.00276, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Peak', value=0.000990854655715544 +/- 0.00265, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Peak', value=0.0010041425429777129 +/- 0.00296, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Brackett54_40523N_Peak', value=5.639429995800675e-08 +/- 0.0395, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Brackett54_40523N_Peak', value=5.639429995800675e-08 +/- 0.0395, bounds=[0.0:inf]> lower than uncertainty 2.8707392976727177e-05 , fixing to 0.0
# <Parameter 'g_H221O7_40540N_Peak', value=0.0027863576533475 +/- 0.00606, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625N_Peak', value=1.9981388414261387e-05 +/- 0.00316, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=0.0004157019445497448 +/- 0.00389, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys106_51287N_Peak', value=0.015168376967179173 +/- 0.0375, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066N_Peak', value=0.0007786514627152901 +/- 0.00229, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066B_Gamma', value=0.0009148544448182813 +/- 0.00381, bounds=[0.0002759544063903498:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066B_Peak', value=0.0003552412945242831 +/- 0.000906, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIII_73177N_Peak', value=0.00047212972777714124 +/- 0.00102, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=2.0381137013966897e-07 +/- 0.00277, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=2.0381137013966897e-07 +/- 0.00277, bounds=[0.0:inf]> lower than uncertainty 6.658032161334333e-06 , fixing to 0.0
# <Parameter 'g_Humphreys86_75005N_Peak', value=0.0004888491022185204 +/- 0.00189, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ClII_143678N_Peak', value=0.00048360031367033097 +/- 0.0016, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArIII_218302N_Peak', value=0.004615291717500337 +/- 0.0104, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeIII_229250N_Peak', value=0.003295041984317159 +/- 0.0119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [0 1]
# Parameter object has 96 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [0 1] will be initialized with results from spaxel [1 1]
# Parameter object has 96 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-07 00:17:38.911174 -----------------
# True in 17 steps
# 100.87 seconds elapsed
# <Parameter 'g_H221O3_29741N_Peak', value=7.5946211716876865e-06 +/- 0.00686, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=5.178227482689559e-06 +/- 0.000868, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O5_34379B_Peak', value=3.4635631871458444e-06 +/- 0.105, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O6_35007B_Wave', value=3.5068978905609107 +/- 0.00603, bounds=[3.4952209362117315:3.5068989212976374]> at upper bound, fixing to 3.5068989212976374
# <Parameter 'g_FeII_40819N_Peak', value=3.4974865183532944e-07 +/- 0.00107, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=3.713312609785515e-08 +/- 0.00102, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O8_41625B_Wave', value=4.16986779372048 +/- 0.0147, bounds=[4.155985130682815:4.169870814380385]> at upper bound, fixing to 4.169870814380385
# <Parameter 'g_FeII_48891N_Peak', value=4.749019706063129e-09 +/- 0.00166, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd1_PAH52_52400_Peak', value=5.34654277553659e-07 +/- 0.000615, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd2_PAH57_56700_Peak', value=7.859888641950812e-07 +/- 0.000282, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=1.485009349227358e-06 +/- 0.00133, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=6.255338773682091e-13 +/- 0.000936, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=1.5783139472304805e-13 +/- 0.00113, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd17_PAH189_189200_Peak', value=1.15221651582472e-06 +/- 0.00311, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO2ice_42736_Wave', value=4.259798763112922 +/- 0.0078, bounds=[4.259795082548333:4.274027608717891]> at lower bound, fixing to 4.259795082548333
# <Parameter 'o_CO11ice_43810_Wave', value=4.366850432572163 +/- 0.186, bounds=[4.366848088797303:4.381438292902873]> at lower bound, fixing to 4.366848088797303
# <Parameter 'o_CO12ice_45440_Wave', value=4.529321656103441 +/- 0.0934, bounds=[4.529321656039027:4.544454705340861]> at lower bound, fixing to 4.529321656039027
# <Parameter 'o_CO12ice_45440_Gamma', value=0.033333351372408955 +/- 0.061, bounds=[0.03333333362307814:0.04800000041723251]> at lower bound, fixing to 0.03333333362307814
# <Parameter 'o_CO13ice_46822_Wave', value=4.66707520280321 +/- 0.00739, bounds=[4.667075035143042:4.682668336296209]> at lower bound, fixing to 4.667075035143042
# <Parameter 'STB_TAU', value=0.00031597273015560566 +/- 6.14, bounds=[0.0:inf]> unconstrained at 1943284.229825968 % error. Fixing value.
# <Parameter 'STB_COV', value=0.5521419142001843 +/- 49, bounds=[0.0:1.0]> unconstrained at 8872.020500568873 % error. Fixing value.
# <Parameter 'STB_010', value=4.556079757314397e-05 +/- 0.0624, bounds=[0.0:1.0]> unconstrained at 136894.44006278177 % error. Fixing value.
# <Parameter 'g_Pfund115_28730N_Peak', value=0.0015709618873442975 +/- 0.00321, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O3_29741N_Peak', value=7.5946211716876865e-06 +/- 0.00686, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=0.00027984116888758184 +/- 0.00139, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O4_30039N_Peak', value=0.0017195913671143232 +/- 0.0107, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O4_30039B_Peak', value=0.00252426475103341 +/- 0.00975, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund105_30392B_Peak', value=0.0019380737994234988 +/- 0.00532, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899N_Peak', value=0.0012340492063949052 +/- 0.11, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Gamma', value=0.00042246801879714343 +/- 0.0165, bounds=[0.00041423524280688234:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Peak', value=0.00016750265726008957 +/- 0.107, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=5.178227482689559e-06 +/- 0.000868, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379N_Peak', value=0.0009713642917512793 +/- 0.106, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Gamma', value=0.00038160551282474055 +/- 0.68, bounds=[0.00038142125163831273:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Peak', value=3.4635631871458444e-06 +/- 0.105, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=3.549143038325591e-05 +/- 0.000984, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075N_Peak', value=0.0010989164005087801 +/- 0.0028, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075B_Peak', value=0.000656758497086499 +/- 0.00215, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Brackett54_40523N_Peak', value=0.008045762285273532 +/- 0.052, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=3.4974865183532944e-07 +/- 0.00107, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=3.4974865183532944e-07 +/- 0.00107, bounds=[0.0:inf]> lower than uncertainty 4.2290134861357545e-06 , fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=3.713312609785515e-08 +/- 0.00102, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_41150N_Peak', value=3.713312609785515e-08 +/- 0.00102, bounds=[0.0:inf]> lower than uncertainty 3.988225910919e-06 , fixing to 0.0
# <Parameter 'g_H210O8_41625N_Peak', value=0.0004228153874298364 +/- 0.00109, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Gamma', value=0.00045935870138462685 +/- 0.00898, bounds=[0.0003097332479213639:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Peak', value=9.286860685751414e-05 +/- 0.00117, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=0.0005622915594268853 +/- 0.00138, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=4.749019706063129e-09 +/- 0.00166, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=4.749019706063129e-09 +/- 0.00166, bounds=[0.0:inf]> lower than uncertainty 8.320760364082503e-06 , fixing to 0.0
# <Parameter 'g_Humphreys106_51287N_Peak', value=0.002313389396336042 +/- 0.14, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys106_51287B_Gamma', value=0.0002823626138621692 +/- 0.00659, bounds=[0.0002476669451385073:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys106_51287B_Peak', value=0.0011272151449343748 +/- 0.103, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066N_Peak', value=1.5291371811985066e-05 +/- 0.0042, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066B_Gamma', value=0.0003909884531691555 +/- 0.00099, bounds=[0.0002759544063903498:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H200S6_61088N_Peak', value=0.0009146946948353376 +/- 0.00305, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_PIII_178850N_Peak', value=0.004365910917485633 +/- 0.012, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_179359N_Peak', value=0.003861742374476929 +/- 0.0124, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeIII_229250N_Peak', value=0.004038142292568737 +/- 0.0186, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd1_PAH52_52400_Peak', value=5.34654277553659e-07 +/- 0.000615, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd1_PAH52_52400_Peak', value=5.34654277553659e-07 +/- 0.000615, bounds=[0.0:inf]> lower than uncertainty 1.901796345477014e-05 , fixing to 0.0
# <Parameter 'd2_PAH57_56700_Peak', value=7.859888641950812e-07 +/- 0.000282, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd2_PAH57_56700_Peak', value=7.859888641950812e-07 +/- 0.000282, bounds=[0.0:inf]> lower than uncertainty 1.662275312647551e-05 , fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=2.3804138003557093e-05 +/- 0.000842, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd8_PAH107_106800_Peak', value=0.00033303532731892085 +/- 0.000722, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd11_PAH127_126900_Peak', value=1.485009349227358e-06 +/- 0.00133, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd11_PAH127_126900_Peak', value=1.485009349227358e-06 +/- 0.00133, bounds=[0.0:inf]> lower than uncertainty 2.2795046347291146e-05 , fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=6.255338773682091e-13 +/- 0.000936, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd15_PAH159_159000_Peak', value=6.255338773682091e-13 +/- 0.000936, bounds=[0.0:inf]> lower than uncertainty 2.9021816144573024e-05 , fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=1.5783139472304805e-13 +/- 0.00113, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH164_164500_Peak', value=1.5783139472304805e-13 +/- 0.00113, bounds=[0.0:inf]> lower than uncertainty 2.6843972824836506e-05 , fixing to 0.0
# <Parameter 'd17_PAH189_189200_Peak', value=1.15221651582472e-06 +/- 0.00311, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd17_PAH189_189200_Peak', value=1.15221651582472e-06 +/- 0.00311, bounds=[0.0:inf]> lower than uncertainty 4.9826442261301996e-05 , fixing to 0.0
# <Parameter 'o_CO2ice_42736_Peak', value=0.18484015452710656 +/- 1.32, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO11ice_43810_Peak', value=0.32376697103455265 +/- 1.66, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO12ice_45440_Peak', value=0.040175428209486275 +/- 0.145, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Gamma', value=0.0013646581371451125 +/- 0.00406, bounds=[0.001180594450014799:0.0017000560080213105]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=0.09722009698412569 +/- 0.373, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [1 2]
# Parameter object has 96 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [1 2] will be initialized with results from spaxel [1 1]
# Parameter object has 96 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-07 00:19:23.717212 -----------------
# True in 27 steps
# 157.36 seconds elapsed
# <Parameter 'STB_TAU', value=3.95376577222105e-13 +/- 8.23, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_COV', value=0.9999999999969214 +/- 195, bounds=[0.0:1.0]> at upper bound, fixing to  1.0
# <Parameter 'STB_010', value=4.764809881610849e-10 +/- 0.147, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O2_27862N_Peak', value=3.6991913764454455e-07 +/- 0.00251, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O3_29741N_Peak', value=6.41737922323864e-06 +/- 0.00269, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O4_31899B_Wave', value=3.195544371094263 +/- 9.17e+04, bounds=[3.184907379787415:3.1955485671572355]> at upper bound, fixing to 3.1955485671572355
# <Parameter 'g_H221O4_31899B_Gamma', value=0.0004142352466290251 +/- 7.16e+04, bounds=[0.00041423524280688234:0.0066711140760507]> at lower bound, fixing to 0.00041423524280688234
# <Parameter 'g_H221O4_31899B_Peak', value=4.1875940868232e-12 +/- 0.000638, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=7.165524707655777e-13 +/- 0.00053, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O5_34379B_Wave', value=3.4439875095531924 +/- 3.78e+07, bounds=[3.4325192266124804:3.4439877171791777]> at upper bound, fixing to 3.4439877171791777
# <Parameter 'g_H221O5_34379B_Gamma', value=0.0003814212519588493 +/- 3.57e+07, bounds=[0.00038142125163831273:0.0066711140760507]> at lower bound, fixing to 0.00038142125163831273
# <Parameter 'g_H221O5_34379B_Peak', value=1.5871614525491307e-15 +/- 0.000632, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O6_35007B_Wave', value=3.5068989071815326 +/- 0.00899, bounds=[3.4952209362117315:3.5068989212976374]> at upper bound, fixing to 3.5068989212976374
# <Parameter 'g_H210O7_38075N_Peak', value=9.648123543164382e-10 +/- 0.00892, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Brackett54_40523N_Peak', value=2.766508322409015e-09 +/- 0.0285, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_40819N_Peak', value=1.0192032612239204e-14 +/- 0.000637, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O8_41625N_Peak', value=3.4399020062765454e-13 +/- 0.000685, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O8_41625B_Wave', value=4.1698707869645295 +/- 0.00695, bounds=[4.155985130682815:4.169870814380385]> at upper bound, fixing to 4.169870814380385
# <Parameter 'g_H210O8_41625B_Gamma', value=0.00030973324816558186 +/- 0.00372, bounds=[0.0003097332479213639:0.0066711140760507]> at lower bound, fixing to 0.0003097332479213639
# <Parameter 'g_FeII_48891N_Peak', value=4.1800618562677924e-17 +/- 0.000981, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys106_51287B_Gamma', value=0.006671114074100159 +/- 0.00162, bounds=[0.0002476669451385073:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_FeII_56739N_Peak', value=2.96151691986096e-14 +/- 0.00117, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys96_59066N_Peak', value=1.7305950672445975e-11 +/- 0.00447, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=3.0260357978406015e-10 +/- 0.00366, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# ...
# <Parameter 'd16_PAH164_164500_Peak', value=4.802794073815138e-06, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO2ice_42736_Wave', value=4.269142361172755, bounds=[4.259795082548333:4.274027608717891]> at initial value 4.2691416170591285 . Fixing value.
# <Parameter 'o_CO11ice_43810_Wave', value=4.367718504940306, bounds=[4.366848088797303:4.381438292902873]> at initial value 4.36772784142839 . Fixing value.
# <Parameter 'o_CO12ice_45440_Wave', value=4.529464563279848, bounds=[4.529321656039027:4.544454705340861]> at initial value 4.5294646228930855 . Fixing value.
# <Parameter 'o_CO13ice_46822_Wave', value=4.668159155729945, bounds=[4.667075035143042:4.682668336296209]> at initial value 4.668161683612285 . Fixing value.
# <Parameter 'o_CO13ice_46822_Gamma', value=0.0011806787851744325, bounds=[0.001180594450014799:0.0017000560080213105]> at initial value 0.0011806791085443072 . Fixing value.
# Rerunning fit
# Iteration 3/5(max): 2023-01-07 01:14:28.384571 -----------------
# True in 14 steps
# 65.52 seconds elapsed
# No errors retuned
# <Parameter 'STB_FLX', value=1.9999999949116223, bounds=[0.0:2.0]> at upper bound, fixing to  2.0
# <Parameter 'STB_TAU', value=4.5880721637703253e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_COV', value=0.9999999462287888, bounds=[0.0:1.0]> at upper bound, fixing to  1.0
# <Parameter 'g_H221O2_27862B_Gamma', value=0.006671113950776537, bounds=[0.0002778181807355326:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_H221O5_34379N_Peak', value=2.6782976413053905e-16, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O5_34379B_Gamma', value=0.00038142125163871194, bounds=[0.00038142125163831273:0.0066711140760507]> at lower bound, fixing to 0.00038142125163831273
# <Parameter 'g_FeII_40819N_Peak', value=2.5852506289276715e-14, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O8_41625N_Peak', value=5.941194694293258e-14, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys106_51287N_Peak', value=1.0510427611674776e-15, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys106_51287B_Peak', value=1.2688645653544296e-08, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys96_59066N_Peak', value=5.978289443130526e-18, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys96_59066B_Gamma', value=0.000275954406390354, bounds=[0.0002759544063903498:0.0066711140760507]> at lower bound, fixing to 0.0002759544063903498
# <Parameter 'g_Humphreys96_59066B_Peak', value=1.454235682788312e-20, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaIII_73177N_Peak', value=2.2796721024299276e-13, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys86_75005B_Wave', value=7.5137816319993185, bounds=[7.488760714158908:7.513781632014434]> at upper bound, fixing to 7.513781632014434
# <Parameter 'g_Humphreys86_75005B_Gamma', value=0.006671114072517408, bounds=[0.0003149159888484965:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_ArV_79016N_Peak', value=4.0218253841858923e-19, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_179359N_Peak', value=3.3886522004402724e-14, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd1_PAH52_52400_Peak', value=1.8642759376070723e-17, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd1_PAH53_53300_Peak', value=2.548435948599037e-16, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd7_PAH86_86100_Peak', value=1.15760067189758e-13, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd9_PAH113_113300_Peak', value=2.5706601556701815e-13, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH179_178700_Peak', value=5.802360944130141e-12, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd17_PAH189_189200_Peak', value=4.959116539498888e-15, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO11ice_43810_Gamma', value=0.1000000014901161, bounds=[0.06944444547924732:0.10000000149011612]> at upper bound, fixing to 0.10000000149011612
# <Parameter 'o_CO12ice_45440_Gamma', value=0.033333333623078144, bounds=[0.03333333362307814:0.04800000041723251]> at lower bound, fixing to 0.03333333362307814
# <Parameter 'o_CO12ice_45440_Peak', value=1.899490297418828e-13, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# Rerunning fit
# Iteration 4/5(max): 2023-01-07 01:15:34.161119 -----------------
# True in 4 steps
# 15.17 seconds elapsed
# <Parameter 'g_H210O3_28025N_Peak', value=0.0004414461000723017 +/- 0.00446, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund115_28730N_Peak', value=0.0007232981126969089 +/- 0.00223, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O2_29620N_Peak', value=0.0004886697037310141 +/- 0.00149, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O3_29741N_Peak', value=0.00018989678502121066 +/- 0.00344, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=3.644319287877657e-05 +/- 0.00143, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O4_30039N_Peak', value=0.0012393093017118682 +/- 0.00378, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund105_30392B_Peak', value=0.0007392537774221564 +/- 0.00182, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899N_Peak', value=0.0001723919142376573 +/- 0.00333, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Peak', value=0.0009809576681127138 +/- 0.00315, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=0.00010855569814178564 +/- 0.000942, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O5_32350N_Peak', value=0.0005341603672556149 +/- 0.00365, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys196_36459N_Peak', value=0.00035444453994016683 +/- 0.0009, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys186_36926N_Peak', value=0.0003013772316700838 +/- 0.000884, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund85_37406N_Peak', value=0.00011281650520778152 +/- 0.0043, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys176_37494N_Peak', value=0.0003078016529655636 +/- 0.000947, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075N_Peak', value=7.055294080093462e-05 +/- 0.00256, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O6_39721N_Peak', value=0.00015233084742181447 +/- 0.00125, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S12_39947N_Peak', value=0.00020708805928721798 +/- 0.00145, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Brackett54_40523N_Peak', value=0.0007635168604876294 +/- 0.00855, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O7_40540N_Peak', value=0.0009211193765961106 +/- 0.00343, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_41150N_Peak', value=1.7567107442148653e-05 +/- 0.00152, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Gamma', value=0.0006101808892585546 +/- 0.0037, bounds=[0.0003097332479213639:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Peak', value=0.0002087868169522106 +/- 0.00107, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KIII_46180N_Peak', value=0.003188736069749641 +/- 0.00668, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_PIII_178850N_Peak', value=0.0020436545556227286 +/- 0.00476, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeIII_229250N_Peak', value=0.0017059212712581169 +/- 0.00804, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=0.09601980114538866 +/- 0.341, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [0 2]
# Parameter object has 25 lines, 25 PAHs, 0 opacity features, and 42 continuum parameters
# Current spaxel [0 2] will be initialized with results from spaxel [1 1]
# Parameter object has 25 lines, 25 PAHs, 0 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-07 01:15:52.519051 -----------------
# True in 53 steps
# 53.28 seconds elapsed
# <Parameter 'g_H200S6_61088N_Peak', value=5.527133430615704e-08 +/- 0.0022, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=4.792850853741833e-07 +/- 0.00552, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys86_75005N_Peak', value=2.157956554945825e-07 +/- 0.00956, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=9.916968669223092e-08 +/- 0.00175, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd1_PAH52_52400_Peak', value=2.602404480426999e-13 +/- 0.261, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd1_PAH53_53300_Peak', value=2.1425699469593353e-13 +/- 0.176, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd2_PAH57_56700_Peak', value=5.450445649355809e-35 +/- 0.000503, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=7.440869649119205e-12 +/- 0.000286, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=2.6755027232498155e-30 +/- 0.000594, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=1.7509200345411384e-12 +/- 0.000316, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=4.20854873917861e-30 +/- 0.000615, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=1.0642935579561543e-24 +/- 0.000898, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=1.3501602210984462e-09 +/- 0.000541, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=9.859778300271598e-35 +/- 0.000647, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=7.956141799004813e-33 +/- 0.000882, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'COO_TAU', value=0.6469452753455691 +/- 1.39, bounds=[0.0:inf]> unconstrained at 214.44483715460905 % error. Fixing value.
# <Parameter 'HOT_FLX', value=1.4776443536736663 +/- 4.12, bounds=[0.0:2.0]> unconstrained at 279.1406784424596 % error. Fixing value.
# <Parameter 'STB_FLX', value=0.9656262353413656 +/- 719, bounds=[0.0:2.0]> unconstrained at 74475.52187901821 % error. Fixing value.
# <Parameter 'STB_TAU', value=0.9520313298133838 +/- 1.71e+03, bounds=[0.0:inf]> unconstrained at 179469.03152154566 % error. Fixing value.
# <Parameter 'STB_COV', value=0.5357709767695825 +/- 1.35e+03, bounds=[0.0:1.0]> unconstrained at 252637.87862994373 % error. Fixing value.
# <Parameter 'STB_010', value=0.7190924600133908 +/- 1.12e+04, bounds=[0.0:1.0]> unconstrained at 1551177.1771044554 % error. Fixing value.
# <Parameter 'g_H200S6_61088N_Peak', value=5.527133430615704e-08 +/- 0.0022, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S6_61088N_Peak', value=5.527133430615704e-08 +/- 0.0022, bounds=[0.0:inf]> lower than uncertainty 2.1201715788992263e-05 , fixing to 0.0
# <Parameter 'g_NaIII_73177N_Peak', value=0.0004123215905360309 +/- 0.00132, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=4.792850853741833e-07 +/- 0.00552, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=4.792850853741833e-07 +/- 0.00552, bounds=[0.0:inf]> lower than uncertainty 1.7741435472299183e-05 , fixing to 0.0
# <Parameter 'g_Humphreys86_75005N_Peak', value=2.157956554945825e-07 +/- 0.00956, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys86_75005N_Peak', value=2.157956554945825e-07 +/- 0.00956, bounds=[0.0:inf]> lower than uncertainty 1.579361618331085e-05 , fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=9.916968669223092e-08 +/- 0.00175, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_79016N_Peak', value=9.916968669223092e-08 +/- 0.00175, bounds=[0.0:inf]> lower than uncertainty 1.5544085478008744e-05 , fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=0.0016671860335482427 +/- 0.00733, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_179359N_Peak', value=0.0028388196185137283 +/- 0.00723, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=0.004255818154737756 +/- 0.0131, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd1_PAH52_52400_Peak', value=2.602404480426999e-13 +/- 0.261, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd1_PAH53_53300_Peak', value=2.1425699469593353e-13 +/- 0.176, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd2_PAH57_56700_Peak', value=5.450445649355809e-35 +/- 0.000503, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd2_PAH57_56700_Peak', value=5.450445649355809e-35 +/- 0.000503, bounds=[0.0:inf]> lower than uncertainty 1.7133827887739378e-05 , fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=7.440869649119205e-12 +/- 0.000286, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd4_PAH67_66900_Peak', value=7.440869649119205e-12 +/- 0.000286, bounds=[0.0:inf]> lower than uncertainty 1.3454821267250546e-05 , fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=2.6755027232498155e-30 +/- 0.000594, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd5_PAH74_74200_Peak', value=2.6755027232498155e-30 +/- 0.000594, bounds=[0.0:inf]> lower than uncertainty 1.3059218403732172e-05 , fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=1.7509200345411384e-12 +/- 0.000316, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd6_PAH83_83300_Peak', value=1.7509200345411384e-12 +/- 0.000316, bounds=[0.0:inf]> lower than uncertainty 1.1561785257807092e-05 , fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=4.20854873917861e-30 +/- 0.000615, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd8_PAH107_106800_Peak', value=4.20854873917861e-30 +/- 0.000615, bounds=[0.0:inf]> lower than uncertainty 1.2261610637152993e-05 , fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=1.0642935579561543e-24 +/- 0.000898, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd11_PAH127_126900_Peak', value=1.0642935579561543e-24 +/- 0.000898, bounds=[0.0:inf]> lower than uncertainty 2.0748300577354454e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=1.3501602210984462e-09 +/- 0.000541, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=1.3501602210984462e-09 +/- 0.000541, bounds=[0.0:inf]> lower than uncertainty 2.2422161107947905e-05 , fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=9.859778300271598e-35 +/- 0.000647, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd15_PAH159_159000_Peak', value=9.859778300271598e-35 +/- 0.000647, bounds=[0.0:inf]> lower than uncertainty 2.2556416284545286e-05 , fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=7.956141799004813e-33 +/- 0.000882, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH164_164500_Peak', value=7.956141799004813e-33 +/- 0.000882, bounds=[0.0:inf]> lower than uncertainty 2.3109442699317995e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------

# %%
# Line and PAH averaged velocity gradient wrt z, in [km/s]
print(s.parcube['VALUE'].data[-1])
print(s.parcube['VALUE'].data[-1]/2.998e5)
# Out:
# [[ 46.57380307  16.107925   -14.14207227]
#  [ 19.8121881   30.8243039  -18.6632874 ]
#  [  7.1698624    8.42628485   0.99653219]]
# [[ 1.55349577e-04  5.37289026e-05 -4.71716887e-05]
#  [ 6.60846835e-05  1.02816224e-04 -6.22524596e-05]
#  [ 2.39154850e-05  2.81063537e-05  3.32398995e-06]]

# %%
s.plot_cube_fit(1, 1, inppar_fn, optpar_fn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 s.plot_cube_fit(1, 1, inppar_fn, optpar_fn)
#
# File ~/Sync/pywork/CAFE/notebooks/../CAFE/cafe.py:347, in cubemod.plot_cube_fit(self, x, y, inparfile, optfile, savefig)
#     343 """
#     344 Plot the spectrum itself. If fitPars already exists, plot the fitted results as well.
#     345 """
#     346 if hasattr(self, 'parcube') is False:
# --> 347     raise ValueError('The spectrum is not fitted yet.')
#     348 else:
#     349     fitPars = parcube2parobj(self.parcube, x, y)
#
# ValueError: The spectrum is not fitted yet.

# %%
# Load the parameter cube from drive
parcube_fd = '../CAFE/output/'+source_fnb+'/'
parcube_fn = source_fnb+'_parcube.fits'

# %%
s.read_cube(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ../CRETA/extractions/IIZw096_GridExt_3x3_s0.5as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        38   (3, 3, 15142)   float64
#   2  ERR           1 ImageHDU         9   (3, 3, 15142)   float64
#   3  FLUX_ST       1 ImageHDU         9   (3, 3, 15142)   float64
#   4  ERR_ST        1 ImageHDU         9   (3, 3, 15142)   float64
#   5  DQ            1 ImageHDU         9   (3, 3, 15142)   float64
#   6  WAVE          1 ImageHDU         7   (15142,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   15142R x 1C   [20A]

# %%
s.read_parcube_file(parcube_fn, file_dir=parcube_fd)
# Out:
# Filename: ../CAFE/output/IIZw096_GridExt_3x3_s05as_cube/IIZw096_GridExt_3x3_s05as_cube_parcube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  VALUE         1 ImageHDU        38   (3, 3, 493)   float64
#   2  STDERR        1 ImageHDU        38   (3, 3, 493)   float64
#   3  VARY          1 ImageHDU        38   (3, 3, 493)   float64
#   4  MIN           1 ImageHDU        38   (3, 3, 493)   float64
#   5  MAX           1 ImageHDU        38   (3, 3, 493)   float64
#   6  EXPR          1 BinTableHDU     13   493R x 2C   [I, 24A]
#   7  PARNAME       1 BinTableHDU     13   493R x 2C   [I, 32A]

# %%
s.plot_cube_fit(1, 1, inppar_fn, optpar_fn)
# Out:
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Generate map of feature (TBD)

# %%
from astropy.io import ascii
from astropy.table import Table
from astropy.table import QTable

# Read output PAH table
pah = m.pah_table()
# Read output line table
line = m.line_table()

pah62 = pah[pah.index == 'PAH62'].pah_strength.values[0]
pah62_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah77 = pah[pah.index == 'PAH77_C'].pah_strength.values[0]
pah77_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah113 = pah[pah.index == 'PAH113_C'].pah_strength.values[0]
pah113_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]

x = pah62 / pah77 
x_unc = pah62 / pah77 * np.sqrt((pah62_unc/pah62)**2 + (pah77_unc/pah77)**2)
y = pah113 / pah77
y_unc = pah113 / pah77 * np.sqrt((pah113_unc/pah113)**2 + (pah77_unc/pah77)**2)

print('6.2/7.7 = {} +/- {}'.format(x, x_unc))
print('11.3/7.7 = {} +/- {}'.format(y, y_unc))

print(pah)

# Make an astropy table 
t = QTable([pah.index.values, pah.pah_strength, pah.pah_strength_unc],
           names = ('pah_complex', 'pah_strength', 'pah_strength_unc'),
           meta={'wavelength': 'micron',
                 'flux': 'W/m^2',
                }
          )

# Write PAH table in an .ecsv file
#t.write('./NGC7469_pah_tbl.ecsv', overwrite=False)
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 6.2/7.7 = 0.27497706375780917 +/- 0.01841045694281569
# 11.3/7.7 = 0.8185413910278543 +/- 0.022940147579330196
#              pah_strength  pah_strength_unc
# pah_complex
# PAH113_C     1.867022e-18      6.130991e-20
# PAH120       2.228631e-19      6.678562e-20
# PAH126_C     1.554609e-18      8.270987e-20
# PAH136       0.000000e+00      0.000000e+00
# PAH142       4.419746e-20      3.572571e-20
# PAH164       5.075110e-19      1.824103e-20
# PAH170_C     2.504853e-18      1.131216e-19
# PAH62        6.271987e-19      4.048978e-20
# PAH77_C      2.280913e-18      2.759058e-19
# PAH83        2.057891e-19      9.235792e-20
# PAH86        5.454928e-19      5.076714e-20
