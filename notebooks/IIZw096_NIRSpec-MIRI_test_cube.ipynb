# %%
import os
os._exit(00)

# %%
import sys
sys.path.insert(0, './CRETA')

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib widget
import matplotlib.ticker
from matplotlib.backends.backend_pdf import PdfPages

import creta
import cafe_io
from cafe_io import *
import cafe_helper
from cafe_helper import *
import cafe

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# User API Created
# <style>.container { width:100% !important; }</style>

# %%
# SPECTRAL EXTRACTION

# %%
# Read parameter file with extraction keywords
pf = open('./CRETA/param_files/IIZw096_grid_params.txt','r')
print(pf.read())
pf.close()
# Out:
# cubes = g395h, ch1-short, ch1-medium, ch1-long, ch2-short, ch2-medium, ch2-long, ch3-short, ch3-medium, ch3-long, ch4-short, ch4-medium, ch4-long
# user_ra = 314.35153333
# user_dec = 17.12755833
# user_center = True
# centering = False
# lambda_cent = 5.4
# nx_steps = 3
# ny_steps = 3
# spax_size = 0.5
# step_size = -1
# convolve = False

# %%
# Load the extraction tool (CRETA)
c = creta.creta()
# Out:
# CAFE Region Extraction Tool Automaton (CRETA) initialized

# %%
# Perform the extraction
c.gridExtraction(parameter_file=True, parfile_name='IIZw096_grid_params.txt', data_path='./CRETA/data/IIZw096/', output_filebase_name='IIZw096')
# Out:
# Load file: ./CRETA/data/IIZw096/Level3_g395h-f290lp_s3d_WCScorr.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch1-short_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch1-medium_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch1-long_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch2-short_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch2-medium_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch2-long_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch3-short_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch3-medium_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch3-long_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch4-short_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch4-medium_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch4-long_s3d.fits
# Last cube is:  ch4_LONG
# Cubes: ['g395h', 'ch1-short', 'ch1-medium', 'ch1-long', 'ch2-short', 'ch2-medium', 'ch2-long', 'ch3-short', 'ch3-medium', 'ch3-long', 'ch4-short', 'ch4-medium', 'ch4-long']
# RA,δ: [314.35153333,17.12755833] (degrees)
# Grid Extraction Parameters:
# NX Steps: 3
# NY Steps: 3
# Spaxel Size:  0.5
# Step Size: 0.5
# Loading Data
# Load file: ./CRETA/data/IIZw096/Level3_g395h-f290lp_s3d_WCScorr.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch1-short_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch1-medium_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch1-long_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch2-short_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch2-medium_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch2-long_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch3-short_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch3-medium_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch3-long_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch4-short_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch4-medium_s3d.fits
# Load file: ./CRETA/data/IIZw096/Level3_bandcube_ch4-long_s3d.fits
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# G395H photometry exectued in: 13.305682897567749 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_SHORT photometry exectued in: 3.3175430297851562 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_MEDIUM photometry exectued in: 3.645143985748291 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_LONG photometry exectued in: 4.4407618045806885 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_SHORT photometry exectued in: 2.7780630588531494 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_MEDIUM photometry exectued in: 2.943148136138916 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_LONG photometry exectued in: 3.754354953765869 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_SHORT photometry exectued in: 1.9558987617492676 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_MEDIUM photometry exectued in: 2.2590599060058594 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_LONG photometry exectued in: 2.645094871520996 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_SHORT photometry exectued in: 1.2974317073822021 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_MEDIUM photometry exectued in: 1.631795883178711 seconds
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_LONG photometry exectued in: 1.8734917640686035 seconds
# Grid point 0 stitched in: 0.018079042434692383 seconds
# Output written in: 0.4699270725250244 seconds
# Grid point 1 stitched in: 0.018947839736938477 seconds
# Output written in: 0.47134995460510254 seconds
# Grid point 2 stitched in: 0.021844863891601562 seconds
# Output written in: 0.41272425651550293 seconds
# Grid point 3 stitched in: 0.020226716995239258 seconds
# Output written in: 0.4730696678161621 seconds
# Grid point 4 stitched in: 0.021697044372558594 seconds
# Output written in: 0.5071570873260498 seconds
# Grid point 5 stitched in: 0.020743131637573242 seconds
# Output written in: 0.42051005363464355 seconds
# Grid point 6 stitched in: 0.020574092864990234 seconds
# Output written in: 0.4166421890258789 seconds
# Grid point 7 stitched in: 0.021305084228515625 seconds
# Output written in: 0.41460609436035156 seconds
# Grid point 8 stitched in: 0.024107933044433594 seconds
# Output written in: 0.47668004035949707 seconds
# {'extraction_RA': <Longitude 314.35167866 deg>, 'extraction_DEC': <Latitude 17.12741944 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.35167866 deg>, 'extraction_DEC': <Latitude 17.12755833 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.35167866 deg>, 'extraction_DEC': <Latitude 17.12769722 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.35153333 deg>, 'extraction_DEC': <Latitude 17.12741944 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.35153333 deg>, 'extraction_DEC': <Latitude 17.12755833 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.35153333 deg>, 'extraction_DEC': <Latitude 17.12769722 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.351388 deg>, 'extraction_DEC': <Latitude 17.12741944 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.351388 deg>, 'extraction_DEC': <Latitude 17.12755833 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 314.351388 deg>, 'extraction_DEC': <Latitude 17.12769722 deg>, 'grid_center_RA': 314.35153333, 'grid_center_DEC': 17.12755833, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': False, 'Centering_lambda': 5.4, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.870067691856675, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]

# %%
# CAFE FITTING

# %%
# Setup directories
source_fd = './CRETA/extractions/'
#source_fn = 'last_result_GridExt_3x3_cube.fits'
source_fn = 'IIZw096_GridExt_3x3_s0.5as_cube.fits'
source_fnb = source_fn.split('.fits')[0].replace('.','')
inppar_fn = './inp_parfiles/inpars_jwst_nirspec-miri_SB.ini'

optpar_fn = './opt_parfiles/default_opt.cafe'

z=0.036245

# %%
s = cafe.cubemod()

# %%
s.read_cube(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ./CRETA/extractions/IIZw096_GridExt_3x3_s0.5as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        38   (3, 3, 15142)   float64
#   2  ERR           1 ImageHDU         9   (3, 3, 15142)   float64
#   3  FLUX_ST       1 ImageHDU         9   (3, 3, 15142)   float64
#   4  ERR_ST        1 ImageHDU         9   (3, 3, 15142)   float64
#   5  DQ            1 ImageHDU         9   (3, 3, 15142)   float64
#   6  WAVE          1 ImageHDU         7   (15142,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   15142R x 1C   [20A]

# %%
s.plot_cube_ini(1, 1, inppar_fn, optpar_fn)
# Out:
# Generating continuum profiles for guess model
# Parameter object has 96 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s.fit_cube(inppar_fn, optpar_fn)
# Out:
# Generating fitting sequence
# Highest SNR spaxel is: 1 1
# Generating initial/full parameter object with all potential lines
# Parameter object has 120 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Generating parameter cube with initial/full parameter object
# Regenerating continuum profiles
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [1 1]
# Parameter object has 96 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2022-12-29 15:10:36.539538 -----------------
# True in 38 steps
# 219.97 seconds elapsed
# <Parameter 'STB_TAU', value=2.203520785694813e-11 +/- 2.62, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_COV', value=0.999996879059121 +/- 50.5, bounds=[0.0:1.0]> at upper bound, fixing to  1.0
# <Parameter 'STB_010', value=1.667754308099612e-10 +/- 0.0451, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O2_27862B_Gamma', value=0.00667111407523995 +/- 0.00935, bounds=[0.00027782045105655687:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_H221O4_31899B_Gamma', value=0.00041423875416420736 +/- 2.16e+07, bounds=[0.00041423875401121256:0.0066711140760507]> at lower bound, fixing to 0.00041423875401121256
# <Parameter 'g_H221O4_31899B_Peak', value=5.65225098859243e-17 +/- 0.00117, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Brackett54_40523N_Peak', value=9.694767952799186e-08 +/- 0.0123, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O7_40540N_Peak', value=3.2656331766696436e-09 +/- 0.00346, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_40819N_Peak', value=6.483327238493939e-17 +/- 0.000545, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O8_41625N_Peak', value=7.360273744990779e-14 +/- 0.000537, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O8_41625B_Wave', value=4.169442126422849 +/- 4.89e+06, bounds=[4.15555787191461:4.1694421280853895]> at upper bound, fixing to 4.1694421280853895
# <Parameter 'g_H210O8_41625B_Gamma', value=0.00030973581817244034 +/- 2.74e+06, bounds=[0.0003097358180451155:0.0066711140760507]> at lower bound, fixing to 0.0003097358180451155
# <Parameter 'g_H210O8_41625B_Peak', value=8.356701337638723e-14 +/- 0.000638, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_48891N_Peak', value=6.170169257410394e-13 +/- 0.000826, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys106_51287N_Peak', value=2.744374790365374e-13 +/- 0.00472, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys96_59066B_Gamma', value=0.00027595631926712446 +/- 0.000543, bounds=[0.00027595631732863234:0.0066711140760507]> at lower bound, fixing to 0.00027595631732863234
# <Parameter 'g_PIII_178850N_Peak', value=6.179690759099446e-19 +/- 0.0132, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_179359N_Peak', value=1.0776694544204026e-18 +/- 0.0138, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeIII_229250N_Peak', value=1.880674242807011e-12 +/- 0.0209, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=8.305095813145843e-10 +/- 0.0251, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=6.976158740014338e-13 +/- 0.000308, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=5.6537220798826765e-11 +/- 0.000613, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=2.9089044170289695e-13 +/- 0.00136, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=1.0108235794380393e-14 +/- 0.00084, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=8.42532603291231e-13 +/- 0.00098, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO2ice_42736_Wave', value=4.266472683022952 +/- 0.00397, bounds=[4.266472683022863:4.280727519919031]> at lower bound, fixing to 4.266472683022863
# <Parameter 'o_CO2ice_42736_Gamma', value=0.007083333718287151 +/- 0.0023, bounds=[0.007083333718279998:0.010200000554323196]> at lower bound, fixing to 0.007083333718279998
# <Parameter 'o_CO11ice_43810_Wave', value=4.3736935041999 +/- 0.0679, bounds=[4.373693504199893:4.388306579723447]> at lower bound, fixing to 4.373693504199893
# <Parameter 'o_CO11ice_43810_Gamma', value=0.08333333457509678 +/- 0.00557, bounds=[0.08333333457509677:0.12000000178813934]> at lower bound, fixing to 0.08333333457509677
# <Parameter 'o_CO12ice_45440_Wave', value=4.536421762934915 +/- 1.74e+07, bounds=[4.536421762934679:4.551578534611708]> at lower bound, fixing to 4.536421762934679
# <Parameter 'o_CO12ice_45440_Gamma', value=0.04000000034771861 +/- 9.04e+06, bounds=[0.040000000347693764:0.05760000050067901]> at lower bound, fixing to 0.040000000347693764
# <Parameter 'o_CO12ice_45440_Peak', value=1.7893647560757887e-12 +/- 0.0418, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Wave', value=4.674391082480782 +/- 3.25e+07, bounds=[4.674391082479923:4.690008827493221]> at lower bound, fixing to 4.674391082479923
# <Parameter 'o_CO13ice_46822_Gamma', value=0.0014166666854574137 +/- 8.55e+06, bounds=[0.0014166666854483387:0.0020400000270456077]> at lower bound, fixing to 0.0014166666854483387
# <Parameter 'o_CO13ice_46822_Peak', value=3.486855139673428e-12 +/- 0.0554, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_TAU', value=2.203520785694813e-11 +/- 2.62, bounds=[0.0:inf]> unconstrained at 11896092327796.963 % error. Fixing value.
# <Parameter 'STB_COV', value=0.999996879059121 +/- 50.5, bounds=[0.0:1.0]> unconstrained at 5048.4632001905975 % error. Fixing value.
# <Parameter 'STB_010', value=1.667754308099612e-10 +/- 0.0451, bounds=[0.0:1.0]> unconstrained at 27050143898.384468 % error. Fixing value.
# <Parameter 'g_H232O2_29620N_Peak', value=0.00021600323319264075 +/- 0.000578, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O3_29741N_Peak', value=0.00023713742765460146 +/- 0.0011, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=0.00019862267129476218 +/- 0.00067, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O3_31637N_Peak', value=0.00016868063079487024 +/- 0.000411, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899N_Peak', value=0.00021176483763067728 +/- 0.000433, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Wave', value=3.185198999758371 +/- 3.48e+07, bounds=[3.1845799533022014:3.195220046697799]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Gamma', value=0.00041423875416420736 +/- 2.16e+07, bounds=[0.00041423875401121256:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Peak', value=5.65225098859243e-17 +/- 0.00117, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Peak', value=5.65225098859243e-17 +/- 0.00117, bounds=[0.0:inf]> lower than uncertainty 1.2573700343942732e-06 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=0.00012952962599794077 +/- 0.000439, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379N_Peak', value=0.0003688886523243528 +/- 0.00505, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Gamma', value=0.0004570195227885709 +/- 0.0114, bounds=[0.00038142446332216075:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Peak', value=9.128515292787467e-05 +/- 0.00227, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=0.0001838445226524045 +/- 0.0005, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O6_35007N_Peak', value=0.0004962419337235529 +/- 0.00153, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O6_35007B_Peak', value=0.0004880136810395913 +/- 0.00119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075N_Peak', value=0.00046105061934173953 +/- 0.00166, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S12_39947N_Peak', value=0.00032237930637506163 +/- 0.000659, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys146_40209N_Peak', value=0.0002612868813156136 +/- 0.000572, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Brackett54_40523N_Peak', value=9.694767952799186e-08 +/- 0.0123, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Brackett54_40523N_Peak', value=9.694767952799186e-08 +/- 0.0123, bounds=[0.0:inf]> lower than uncertainty 5.672116399402945e-06 , fixing to 0.0
# <Parameter 'g_H221O7_40540N_Peak', value=3.2656331766696436e-09 +/- 0.00346, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O7_40540N_Peak', value=3.2656331766696436e-09 +/- 0.00346, bounds=[0.0:inf]> lower than uncertainty 4.4323209341401355e-06 , fixing to 0.0
# <Parameter 'g_FeII_40819N_Peak', value=6.483327238493939e-17 +/- 0.000545, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=6.483327238493939e-17 +/- 0.000545, bounds=[0.0:inf]> lower than uncertainty 2.260375477681527e-06 , fixing to 0.0
# <Parameter 'g_H210O8_41625N_Peak', value=7.360273744990779e-14 +/- 0.000537, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625N_Peak', value=7.360273744990779e-14 +/- 0.000537, bounds=[0.0:inf]> lower than uncertainty 2.2409168811048057e-06 , fixing to 0.0
# <Parameter 'g_H210O8_41625B_Wave', value=4.169442126422849 +/- 4.89e+06, bounds=[4.15555787191461:4.1694421280853895]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Gamma', value=0.00030973581817244034 +/- 2.74e+06, bounds=[0.0003097358180451155:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Peak', value=8.356701337638723e-14 +/- 0.000638, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Peak', value=8.356701337638723e-14 +/- 0.000638, bounds=[0.0:inf]> lower than uncertainty 2.3114761456992337e-06 , fixing to 0.0
# <Parameter 'g_FeII_48891N_Peak', value=6.170169257410394e-13 +/- 0.000826, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=6.170169257410394e-13 +/- 0.000826, bounds=[0.0:inf]> lower than uncertainty 4.5251103117262375e-06 , fixing to 0.0
# <Parameter 'g_Humphreys106_51287N_Peak', value=2.744374790365374e-13 +/- 0.00472, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys106_51287N_Peak', value=2.744374790365374e-13 +/- 0.00472, bounds=[0.0:inf]> lower than uncertainty 7.1625775472394975e-06 , fixing to 0.0
# <Parameter 'g_Humphreys96_59066N_Peak', value=0.00040964335799654117 +/- 0.00295, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys86_75005N_Peak', value=0.0011099595961984489 +/- 0.00431, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_PIII_178850N_Peak', value=6.179690759099446e-19 +/- 0.0132, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_PIII_178850N_Peak', value=6.179690759099446e-19 +/- 0.0132, bounds=[0.0:inf]> lower than uncertainty 5.215267431939162e-05 , fixing to 0.0
# <Parameter 'g_FeII_179359N_Peak', value=1.0776694544204026e-18 +/- 0.0138, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_179359N_Peak', value=1.0776694544204026e-18 +/- 0.0138, bounds=[0.0:inf]> lower than uncertainty 5.429963690517514e-05 , fixing to 0.0
# <Parameter 'g_ArIII_218302N_Peak', value=0.008909517823826919 +/- 0.0185, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeIII_229250N_Peak', value=1.880674242807011e-12 +/- 0.0209, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeIII_229250N_Peak', value=1.880674242807011e-12 +/- 0.0209, bounds=[0.0:inf]> lower than uncertainty 0.00015245891407921966 , fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=8.305095813145843e-10 +/- 0.0251, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=8.305095813145843e-10 +/- 0.0251, bounds=[0.0:inf]> lower than uncertainty 0.00023597055667003212 , fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=6.976158740014338e-13 +/- 0.000308, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd6_PAH83_83300_Peak', value=6.976158740014338e-13 +/- 0.000308, bounds=[0.0:inf]> lower than uncertainty 1.083899938467666e-05 , fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=5.6537220798826765e-11 +/- 0.000613, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd8_PAH107_106800_Peak', value=5.6537220798826765e-11 +/- 0.000613, bounds=[0.0:inf]> lower than uncertainty 1.0141834608156664e-05 , fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=2.9089044170289695e-13 +/- 0.00136, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd11_PAH127_126900_Peak', value=2.9089044170289695e-13 +/- 0.00136, bounds=[0.0:inf]> lower than uncertainty 2.3764664836035862e-05 , fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=1.0108235794380393e-14 +/- 0.00084, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd15_PAH159_159000_Peak', value=1.0108235794380393e-14 +/- 0.00084, bounds=[0.0:inf]> lower than uncertainty 2.7797501190911318e-05 , fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=8.42532603291231e-13 +/- 0.00098, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH164_164500_Peak', value=8.42532603291231e-13 +/- 0.00098, bounds=[0.0:inf]> lower than uncertainty 2.39044293018109e-05 , fixing to 0.0
# <Parameter 'o_CO2ice_42736_Peak', value=0.09280132885400517 +/- 0.328, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO11ice_43810_Peak', value=0.25641555244084635 +/- 0.706, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO12ice_45440_Wave', value=4.536421762934915 +/- 1.74e+07, bounds=[4.536421762934679:4.551578534611708]> unconstrained, fixing entire feature
# <Parameter 'o_CO12ice_45440_Gamma', value=0.04000000034771861 +/- 9.04e+06, bounds=[0.040000000347693764:0.05760000050067901]> unconstrained, fixing entire feature
# <Parameter 'o_CO12ice_45440_Peak', value=1.7893647560757887e-12 +/- 0.0418, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO12ice_45440_Peak', value=1.7893647560757887e-12 +/- 0.0418, bounds=[0.0:1.0]> lower than uncertainty 2.921698390961221e-06 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Wave', value=4.674391082480782 +/- 3.25e+07, bounds=[4.674391082479923:4.690008827493221]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Gamma', value=0.0014166666854574137 +/- 8.55e+06, bounds=[0.0014166666854483387:0.0020400000270456077]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=3.486855139673428e-12 +/- 0.0554, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=3.486855139673428e-12 +/- 0.0554, bounds=[0.0:1.0]> lower than uncertainty 4.5067345436536875e-06 , fixing to 0.0
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [2 1]
# Parameter object has 97 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [2 1] will be initialized with results from spaxel [1 1]
# Parameter object has 97 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2022-12-29 15:14:20.423638 -----------------
# True in 30 steps
# 163.32 seconds elapsed
# <Parameter 'STB_010', value=1.842123731450108e-20 +/- 0.0263, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O2_27862B_Wave', value=2.79113856552963 +/- 0.0219, bounds=[2.781860643563496:2.7911551996729633]> at upper bound, fixing to 2.7911551996729633
# <Parameter 'g_H221O2_27862B_Gamma', value=0.006671113307277214 +/- 0.0204, bounds=[0.00027782045105655687:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_H221O5_34379N_Peak', value=2.932473796419426e-15 +/- 0.000671, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O5_34379B_Peak', value=3.3329838727018826e-17 +/- 0.000667, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_40763N_Peak', value=2.6284156432170117e-18 +/- 0.000568, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_44348N_Peak', value=1.0334934663552935e-19 +/- 0.000674, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_48891N_Peak', value=4.5064676912609844e-12 +/- 0.000878, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_50624N_Peak', value=2.466683595774605e-11 +/- 0.000949, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys96_59066B_Wave', value=5.89740079117983 +/- 0.00959, bounds=[5.897400788626856:5.917104767205629]> at lower bound, fixing to 5.897400788626856
# <Parameter 'g_Humphreys96_59066B_Gamma', value=0.006671114076050698 +/- 0.00381, bounds=[0.00027595631732863234:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_Pfund65_74578N_Peak', value=4.299178255618438e-09 +/- 0.00452, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=9.782426859817389e-11 +/- 0.0107, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=3.5194902020772324e-11 +/- 0.0213, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=3.217412498624268e-14 +/- 0.00073, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=6.502219588140974e-19 +/- 0.000985, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=8.184471519659122e-29 +/- 0.000665, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=8.222056699058368e-20 +/- 0.000821, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd17_PAH189_189200_Peak', value=8.12825508606188e-17 +/- 0.00283, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO11ice_43810_Wave', value=4.366881712133169 +/- 0.115, bounds=[4.366881712132294:4.3814720285777735]> at lower bound, fixing to 4.366881712132294
# <Parameter 'o_CO11ice_43810_Gamma', value=0.10000000149005785 +/- 0.00814, bounds=[0.06944444547924732:0.10000000149011612]> at upper bound, fixing to 0.10000000149011612
# <Parameter 'o_CO12ice_45440_Wave', value=4.529356895965857 +/- 0.0435, bounds=[4.529356530368572:4.54448969619005]> at lower bound, fixing to 4.529356530368572
# <Parameter 'o_CO12ice_45440_Gamma', value=0.03333333362307834 +/- 0.0234, bounds=[0.03333333362307814:0.04800000041723251]> at lower bound, fixing to 0.03333333362307814
# <Parameter 'o_CO13ice_46822_Gamma', value=0.0011805555712080195 +/- 0.00234, bounds=[0.001180555571206949:0.0017000000225380065]> at lower bound, fixing to 0.001180555571206949
# <Parameter 'STB_TAU', value=0.00356420007539255 +/- 609, bounds=[0.0:inf]> unconstrained at 17090622.377598595 % error. Fixing value.
# <Parameter 'STB_COV', value=0.002457097692447143 +/- 29.4, bounds=[0.0:1.0]> unconstrained at 1194646.1667655434 % error. Fixing value.
# <Parameter 'STB_010', value=1.842123731450108e-20 +/- 0.0263, bounds=[0.0:1.0]> unconstrained at 1.4302017418051246e+20 % error. Fixing value.
# <Parameter 'g_H221O2_27862N_Peak', value=0.00017876530788903314 +/- 0.00106, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O2_27862B_Gamma', value=0.006671113307277214 +/- 0.0204, bounds=[0.00027782045105655687:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O2_27862B_Peak', value=0.00012251699302014008 +/- 0.000274, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O3_28025N_Peak', value=0.00029308311847257634 +/- 0.00413, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund115_28730N_Peak', value=0.0009110558334629265 +/- 0.00199, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O3_29741N_Peak', value=0.0002839447406365678 +/- 0.00231, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O3_29741B_Peak', value=0.0006319402254417422 +/- 0.00164, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O4_30039N_Peak', value=0.0002989172433631768 +/- 0.0421, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O4_30039B_Gamma', value=0.0004938366493033663 +/- 0.00753, bounds=[0.0004428102799143725:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H210O4_30039B_Peak', value=0.0005654409610758496 +/- 0.031, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O3_31637N_Peak', value=0.0002669410082175579 +/- 0.000621, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899N_Peak', value=2.0976983129202854e-05 +/- 0.547, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Gamma', value=0.0004142445270008321 +/- 0.056, bounds=[0.00041423875401121256:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Peak', value=0.00021289342580862466 +/- 0.547, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=3.454510117688127e-05 +/- 0.000537, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379N_Peak', value=2.932473796419426e-15 +/- 0.000671, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379N_Peak', value=2.932473796419426e-15 +/- 0.000671, bounds=[0.0:inf]> lower than uncertainty 1.7388294138581266e-06 , fixing to 0.0
# <Parameter 'g_H221O5_34379B_Wave', value=3.4413535674226985 +/- 2.61e+07, bounds=[3.432545655913769:3.444014234784179]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Gamma', value=0.00038144780907309393 +/- 1.06e+07, bounds=[0.00038142446332216075:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Peak', value=3.3329838727018826e-17 +/- 0.000667, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Peak', value=3.3329838727018826e-17 +/- 0.000667, bounds=[0.0:inf]> lower than uncertainty 1.681233831783348e-06 , fixing to 0.0
# <Parameter 'g_H210O6_35007N_Peak', value=6.326091931594244e-05 +/- 0.00421, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O6_35007B_Gamma', value=0.0006092439733833815 +/- 0.00154, bounds=[0.0003739237374596216:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H210O6_35007B_Peak', value=0.000526452772369996 +/- 0.00381, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O5_36630N_Peak', value=0.00017581199479252733 +/- 0.000556, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=2.5429503217832784e-05 +/- 0.000606, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075N_Peak', value=0.00021319239367413307 +/- 0.00576, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075B_Gamma', value=0.0005344102478129477 +/- 0.00523, bounds=[0.0003411493207170549:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075B_Peak', value=0.00018721741963870987 +/- 0.00244, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys146_40209N_Peak', value=0.001171091222664057 +/- 0.0113, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Brackett54_40523N_Peak', value=0.002061602167716051 +/- 0.021, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40763N_Peak', value=2.6284156432170117e-18 +/- 0.000568, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40763N_Peak', value=2.6284156432170117e-18 +/- 0.000568, bounds=[0.0:inf]> lower than uncertainty 1.8387340291133527e-06 , fixing to 0.0
# <Parameter 'g_H210O8_41625N_Peak', value=1.2361790956533772e-05 +/- 0.000613, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Gamma', value=0.00032016376957304596 +/- 0.00114, bounds=[0.0003097358180451155:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Peak', value=0.00034766978121457794 +/- 0.000769, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=1.0334934663552935e-19 +/- 0.000674, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=1.0334934663552935e-19 +/- 0.000674, bounds=[0.0:inf]> lower than uncertainty 2.949722293187392e-06 , fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=5.297452941782519e-05 +/- 0.000712, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=4.5064676912609844e-12 +/- 0.000878, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=4.5064676912609844e-12 +/- 0.000878, bounds=[0.0:inf]> lower than uncertainty 3.7329165921553873e-06 , fixing to 0.0
# <Parameter 'g_FeII_50624N_Peak', value=2.466683595774605e-11 +/- 0.000949, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_50624N_Peak', value=2.466683595774605e-11 +/- 0.000949, bounds=[0.0:inf]> lower than uncertainty 4.2472017977371815e-06 , fixing to 0.0
# <Parameter 'g_Humphreys106_51287N_Peak', value=0.0010702656197376413 +/- 0.00301, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_56739N_Peak', value=0.0005222145750744291 +/- 0.0014, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S6_61088N_Peak', value=5.082466596104805e-05 +/- 0.00137, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=4.299178255618438e-09 +/- 0.00452, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=4.299178255618438e-09 +/- 0.00452, bounds=[0.0:inf]> lower than uncertainty 1.0792307265652776e-05 , fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=9.782426859817389e-11 +/- 0.0107, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_PIII_178850N_Peak', value=9.782426859817389e-11 +/- 0.0107, bounds=[0.0:inf]> lower than uncertainty 3.2411160197557475e-05 , fixing to 0.0
# <Parameter 'g_FeII_179359N_Peak', value=0.00020399159013197887 +/- 0.0107, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=3.5194902020772324e-11 +/- 0.0213, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=3.5194902020772324e-11 +/- 0.0213, bounds=[0.0:inf]> lower than uncertainty 0.00016680808456082485 , fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=3.217412498624268e-14 +/- 0.00073, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd8_PAH107_106800_Peak', value=3.217412498624268e-14 +/- 0.00073, bounds=[0.0:inf]> lower than uncertainty 8.81921500991571e-06 , fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=6.502219588140974e-19 +/- 0.000985, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd11_PAH127_126900_Peak', value=6.502219588140974e-19 +/- 0.000985, bounds=[0.0:inf]> lower than uncertainty 1.4474946979938644e-05 , fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=8.184471519659122e-29 +/- 0.000665, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd15_PAH159_159000_Peak', value=8.184471519659122e-29 +/- 0.000665, bounds=[0.0:inf]> lower than uncertainty 1.6313896720378722e-05 , fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=8.222056699058368e-20 +/- 0.000821, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH164_164500_Peak', value=8.222056699058368e-20 +/- 0.000821, bounds=[0.0:inf]> lower than uncertainty 1.5123886108314954e-05 , fixing to 0.0
# <Parameter 'd17_PAH189_189200_Peak', value=8.12825508606188e-17 +/- 0.00283, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd17_PAH189_189200_Peak', value=8.12825508606188e-17 +/- 0.00283, bounds=[0.0:inf]> lower than uncertainty 4.0105808814076115e-05 , fixing to 0.0
# <Parameter 'o_CO2ice_42736_Peak', value=0.06591699161953497 +/- 0.334, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO11ice_43810_Peak', value=0.2485492986984531 +/- 0.994, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO12ice_45440_Peak', value=0.04917682314028076 +/- 0.16, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=0.051941320848632413 +/- 0.171, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [2 2]
# Parameter object has 93 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [2 2] will be initialized with results from spaxel [1 1]
# Parameter object has 93 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2022-12-29 15:17:07.547681 -----------------
# True in 124 steps
# 702.11 seconds elapsed
# No errors retuned
# <Parameter 'STB_FLX', value=1.5922979213805715e-07, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_010', value=7.442666510816535e-06, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O3_28025N_Peak', value=3.6561666204620614e-08, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O3_29741N_Peak', value=7.30114091307615e-12, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=1.433531656104947e-12, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O4_31899N_Peak', value=4.75538171132864e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O4_31899B_Gamma', value=0.00041423875401121267, bounds=[0.00041423875401121256:0.0066711140760507]> at lower bound, fixing to 0.00041423875401121256
# <Parameter 'g_CaIV_32067N_Peak', value=1.8392955379647934e-15, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O5_32350N_Peak', value=4.551200997758881e-09, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O5_34379B_Gamma', value=0.0003814244804003406, bounds=[0.00038142446332216075:0.0066711140760507]> at lower bound, fixing to 0.00038142446332216075
# <Parameter 'g_H221O5_34379B_Peak', value=5.838721343118007e-11, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=7.420640857640176e-11, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O6_35007B_Wave', value=3.5069259229077345, bounds=[3.4952478482961493:3.5069259232988093]> at upper bound, fixing to 3.5069259232988093
# <Parameter 'g_H210O6_35007B_Gamma', value=0.006671114064628675, bounds=[0.0003739237374596216:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_H210O7_38075B_Gamma', value=0.006671099274538675, bounds=[0.0003411493207170549:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_Brackett54_40523N_Peak', value=3.6237900602023493e-06, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O8_41625B_Wave', value=4.156018377496121, bounds=[4.156017130440403:4.169902921053301]> at lower bound, fixing to 4.156017130440403
# <Parameter 'g_H210O8_41625B_Gamma', value=0.0066711109094326594, bounds=[0.0003097358180451155:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_Humphreys106_51287B_Wave', value=5.137770697453948, bounds=[5.120662403851814:5.137771199053457]> at upper bound, fixing to 5.137771199053457
# <Parameter 'g_Humphreys106_51287B_Gamma', value=0.006671113966574338, bounds=[0.0002476689739893653:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_FeII_56739N_Peak', value=1.1204078504175092e-12, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=3.695555114410162e-07, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=1.0450151981922203e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_179359N_Peak', value=1.9677534473892739e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=4.267766697043923e-12, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd20_PAH30_30100_Peak', value=1.2355278688877472e-13, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd1_PAH53_53300_Peak', value=1.0580165335363221e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd2_PAH57_56700_Peak', value=2.645984256094534e-13, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=1.9510075511869328e-28, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=6.338116987910863e-14, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=2.149602529656342e-13, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=5.933138667619104e-13, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=9.221839669588051e-11, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=2.1211519367493347e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=4.285576677463848e-11, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=2.292388244683057e-14, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO2ice_42736_Wave', value=4.274060517067429, bounds=[4.2598278816093815:4.274060517364842]> at upper bound, fixing to 4.274060517364842
# <Parameter 'o_CO2ice_42736_Gamma', value=0.0059027781010256315, bounds=[0.005902778098566665:0.008500000461935997]> at lower bound, fixing to 0.005902778098566665
# <Parameter 'o_CO2ice_42736_Peak', value=7.700725531001066e-13, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO11ice_43810_Wave', value=4.366881712166647, bounds=[4.366881712132294:4.3814720285777735]> at lower bound, fixing to 4.366881712132294
# <Parameter 'o_CO11ice_43810_Gamma', value=0.0694444455870035, bounds=[0.06944444547924732:0.10000000149011612]> at lower bound, fixing to 0.06944444547924732
# <Parameter 'o_CO11ice_43810_Peak', value=1.4822891137056277e-09, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO12ice_45440_Wave', value=4.529356530368892, bounds=[4.529356530368572:4.54448969619005]> at lower bound, fixing to 4.529356530368572
# <Parameter 'o_CO12ice_45440_Gamma', value=0.03333333381874897, bounds=[0.03333333362307814:0.04800000041723251]> at lower bound, fixing to 0.03333333362307814
# <Parameter 'o_CO12ice_45440_Peak', value=7.47064710674857e-10, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Wave', value=4.667110970130224, bounds=[4.667110970129591:4.682704391346195]> at lower bound, fixing to 4.667110970129591
# Rerunning fit
# Iteration 2/5(max): 2022-12-29 15:28:49.972460 -----------------
# True in 4 steps
# 15.59 seconds elapsed
# <Parameter 'g_H210O7_38075B_Wave', value=3.801570025880952 +/- 0.00681, bounds=[3.8015700238202608:3.8142715608193263]> at lower bound, fixing to 3.8015700238202608
# <Parameter 'g_Pfund75_46538B_Gamma', value=0.006671114071171469 +/- 0.00131, bounds=[0.00027472725171369346:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_H221O2_27862N_Peak', value=0.00026448303789605645 +/- 0.0175, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O2_27862B_Gamma', value=0.00027789148406531127 +/- 0.0074, bounds=[0.00027782045105655687:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O2_27862B_Peak', value=0.0009546773134153593 +/- 0.0211, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund115_28730N_Peak', value=0.0011033440299099417 +/- 0.0191, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund115_28730B_Gamma', value=0.0003605876030466964 +/- 0.00116, bounds=[0.0002689976978606609:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund115_28730B_Peak', value=0.0025743934382843198 +/- 0.00688, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O2_29620N_Peak', value=0.0001439022630769194 +/- 0.00399, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O4_30039N_Peak', value=3.6193240661534494e-05 +/- 0.181, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O4_30039B_Peak', value=0.006311053134030678 +/- 0.167, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund105_30392N_Peak', value=0.0006832378148156246 +/- 0.07, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund105_30392B_Peak', value=0.004693116019573772 +/- 0.0589, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O3_31637N_Peak', value=0.0006338522850663819 +/- 0.00275, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Peak', value=0.0009903378486052525 +/- 0.00265, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379N_Peak', value=0.0009024396543362902 +/- 0.00287, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O7_40540N_Peak', value=0.002787365247615711 +/- 0.00559, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625N_Peak', value=1.9333345987436427e-05 +/- 0.00316, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=0.0004140135781355895 +/- 0.00388, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys106_51287N_Peak', value=0.015124530485769044 +/- 0.0375, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066N_Peak', value=0.0008172859999783018 +/- 0.00214, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066B_Gamma', value=0.0010633024946276202 +/- 0.00447, bounds=[0.00027595631732863234:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066B_Peak', value=0.00029764839655797707 +/- 0.000841, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIII_73177N_Peak', value=0.00047271079102332415 +/- 0.00102, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys86_75005N_Peak', value=0.0004230635879721351 +/- 0.00173, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ClII_143678N_Peak', value=0.0004825740659036214 +/- 0.0016, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArIII_218302N_Peak', value=0.004609956309655546 +/- 0.0104, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeIII_229250N_Peak', value=0.0032891131147446766 +/- 0.0119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [0 1]
# Parameter object has 96 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [0 1] will be initialized with results from spaxel [1 1]
# Parameter object has 96 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2022-12-29 15:29:08.988090 -----------------
# True in 17 steps
# 98.83 seconds elapsed
# <Parameter 'STB_010', value=2.93838347045256e-09 +/- 0.0571, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=4.381280693769178e-08 +/- 0.000873, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O5_34379B_Peak', value=1.0645398435982754e-11 +/- 0.0013, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=5.707010244307604e-06 +/- 0.000989, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O6_35007B_Wave', value=3.5069229992789173 +/- 0.0061, bounds=[3.4952478482961493:3.5069259232988093]> at upper bound, fixing to 3.5069259232988093
# <Parameter 'g_H221O7_40540N_Peak', value=4.892997216658897e-06 +/- 0.00724, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_40819N_Peak', value=1.3801887454215567e-07 +/- 0.00107, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=1.2558103072649328e-08 +/- 0.00102, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O8_41625B_Peak', value=1.907921953200826e-08 +/- 0.0014, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_48891N_Peak', value=1.3558543819663598e-09 +/- 0.00167, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys106_51287B_Gamma', value=0.00024766897503986736 +/- 0.00207, bounds=[0.0002476689739893653:0.0066711140760507]> at lower bound, fixing to 0.0002476689739893653
# <Parameter 'g_Humphreys96_59066N_Peak', value=3.253808412582949e-07 +/- 0.00445, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd1_PAH52_52400_Peak', value=1.95551048834324e-07 +/- 0.000618, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd2_PAH57_56700_Peak', value=1.785462146015634e-07 +/- 0.000283, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=7.145008823577948e-06 +/- 0.000843, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=6.769591902147925e-07 +/- 0.00134, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=1.384765596688e-09 +/- 0.000942, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=1.4911180117166233e-11 +/- 0.00114, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO2ice_42736_Wave', value=4.259829561748794 +/- 0.00765, bounds=[4.2598278816093815:4.274060517364842]> at lower bound, fixing to 4.2598278816093815
# <Parameter 'o_CO11ice_43810_Wave', value=4.366882729890006 +/- 0.195, bounds=[4.366881712132294:4.3814720285777735]> at lower bound, fixing to 4.366881712132294
# <Parameter 'o_CO12ice_45440_Wave', value=4.5293565389309745 +/- 0.0811, bounds=[4.529356530368572:4.54448969619005]> at lower bound, fixing to 4.529356530368572
# <Parameter 'o_CO12ice_45440_Gamma', value=0.03333333900731335 +/- 0.0506, bounds=[0.03333333362307814:0.04800000041723251]> at lower bound, fixing to 0.03333333362307814
# <Parameter 'o_CO13ice_46822_Wave', value=4.667111694142056 +/- 0.00674, bounds=[4.667110970129591:4.682704391346195]> at lower bound, fixing to 4.667110970129591
# <Parameter 'STB_TAU', value=5.489228739688143e-05 +/- 3.58, bounds=[0.0:inf]> unconstrained at 6530534.88637129 % error. Fixing value.
# <Parameter 'STB_COV', value=0.8820888438665415 +/- 53.4, bounds=[0.0:1.0]> unconstrained at 6052.812356568853 % error. Fixing value.
# <Parameter 'STB_010', value=2.93838347045256e-09 +/- 0.0571, bounds=[0.0:1.0]> unconstrained at 1944486846.2191634 % error. Fixing value.
# <Parameter 'g_H221O2_27862B_Gamma', value=0.0010829536101964012 +/- 0.00287, bounds=[0.00027782045105655687:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O2_27862B_Peak', value=0.0005298892682798922 +/- 0.00179, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund115_28730N_Peak', value=0.0013118742636806615 +/- 0.00363, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O3_29741N_Peak', value=0.00012559035004404371 +/- 0.00646, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=0.00031337738768731876 +/- 0.0014, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O4_30039N_Peak', value=0.0008562689756817574 +/- 0.0352, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O4_30039B_Peak', value=0.003966298373072851 +/- 0.0343, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund105_30392B_Peak', value=0.0016667028266667016 +/- 0.00358, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Gamma', value=0.00041608468456859685 +/- 0.013, bounds=[0.00041423875401121256:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Peak', value=3.9985627415573974e-05 +/- 0.00106, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=4.381280693769178e-08 +/- 0.000873, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=4.381280693769178e-08 +/- 0.000873, bounds=[0.0:inf]> lower than uncertainty 2.5188424858093114e-06 , fixing to 0.0
# <Parameter 'g_H221O5_34379B_Wave', value=3.435298255062454 +/- 7.78e+04, bounds=[3.432545655913769:3.444014234784179]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Gamma', value=0.00038143241835081917 +/- 5.32e+04, bounds=[0.00038142446332216075:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Peak', value=1.0645398435982754e-11 +/- 0.0013, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Peak', value=1.0645398435982754e-11 +/- 0.0013, bounds=[0.0:inf]> lower than uncertainty 3.2323926792395934e-06 , fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=5.707010244307604e-06 +/- 0.000989, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075N_Peak', value=0.0010898525090893758 +/- 0.00253, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075B_Peak', value=0.0007177740634464861 +/- 0.00186, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O7_40540N_Peak', value=4.892997216658897e-06 +/- 0.00724, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=1.3801887454215567e-07 +/- 0.00107, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=1.3801887454215567e-07 +/- 0.00107, bounds=[0.0:inf]> lower than uncertainty 4.229063474506705e-06 , fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=1.2558103072649328e-08 +/- 0.00102, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_41150N_Peak', value=1.2558103072649328e-08 +/- 0.00102, bounds=[0.0:inf]> lower than uncertainty 3.988253462687365e-06 , fixing to 0.0
# <Parameter 'g_H210O8_41625N_Peak', value=0.00042696287811137866 +/- 0.0011, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Wave', value=4.1594538150160565 +/- 45.3, bounds=[4.156017130440403:4.169902921053301]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Gamma', value=0.00031068040366946176 +/- 28.1, bounds=[0.0003097358180451155:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Peak', value=1.907921953200826e-08 +/- 0.0014, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Peak', value=1.907921953200826e-08 +/- 0.0014, bounds=[0.0:inf]> lower than uncertainty 4.254169953664702e-06 , fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=0.0005569659600175591 +/- 0.00138, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=1.3558543819663598e-09 +/- 0.00167, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=1.3558543819663598e-09 +/- 0.00167, bounds=[0.0:inf]> lower than uncertainty 8.320822599101979e-06 , fixing to 0.0
# ...
# <Parameter 'g_Pfund95_32970N_Peak', value=0.0013760297650609466 +/- 0.00307, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379N_Peak', value=0.0001863122563009254 +/- 0.00216, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Gamma', value=0.00038142446543033197 +/- 0.00103, bounds=[0.00038142446332216075:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Peak', value=0.000744341447445808 +/- 0.00199, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys196_36459N_Peak', value=0.0003387307514824521 +/- 0.000987, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys186_36926N_Peak', value=0.0002916856830192051 +/- 0.000973, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund85_37406N_Peak', value=0.0005243329948169074 +/- 0.00275, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys176_37494N_Peak', value=0.00029248872331297265 +/- 0.00101, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075N_Peak', value=1.3888268495577407e-05 +/- 0.00203, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O6_39721N_Peak', value=0.00014073320559698888 +/- 0.00137, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S12_39947N_Peak', value=0.00022249293297097445 +/- 0.00183, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys146_40209N_Peak', value=0.0005691175938663809 +/- 0.00125, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40763N_Peak', value=3.2303025776263675e-10 +/- 0.00125, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40763N_Peak', value=3.2303025776263675e-10 +/- 0.00125, bounds=[0.0:inf]> lower than uncertainty 5.900337242781404e-06 , fixing to 0.0
# <Parameter 'g_FeII_40819N_Peak', value=6.463903819128949e-08 +/- 0.00128, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=6.463903819128949e-08 +/- 0.00128, bounds=[0.0:inf]> lower than uncertainty 6.055910125688961e-06 , fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=4.961057742485751e-09 +/- 0.00165, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_41150N_Peak', value=4.961057742485751e-09 +/- 0.00165, bounds=[0.0:inf]> lower than uncertainty 6.927089658754188e-06 , fixing to 0.0
# <Parameter 'g_H210O8_41625N_Peak', value=1.1394952810767281e-05 +/- 0.00227, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Gamma', value=0.0006100997197154752 +/- 0.0045, bounds=[0.0003097358180451155:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625B_Peak', value=0.00019068336081822678 +/- 0.00186, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KIII_46180N_Peak', value=0.0038068452838823956 +/- 0.00813, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_50624N_Peak', value=2.130516875907112e-14 +/- 0.00231, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_50624N_Peak', value=2.130516875907112e-14 +/- 0.00231, bounds=[0.0:inf]> lower than uncertainty 1.469320636673091e-05 , fixing to 0.0
# <Parameter 'g_Humphreys106_51287N_Peak', value=2.803369808578458e-09 +/- 0.0151, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys106_51287N_Peak', value=2.803369808578458e-09 +/- 0.0151, bounds=[0.0:inf]> lower than uncertainty 3.714835114602996e-05 , fixing to 0.0
# <Parameter 'g_Humphreys106_51287B_Peak', value=0.006845101762657695 +/- 35.6, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066N_Peak', value=4.829180646472247e-12 +/- 0.00279, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066N_Peak', value=4.829180646472247e-12 +/- 0.00279, bounds=[0.0:inf]> lower than uncertainty 1.9468149231600117e-05 , fixing to 0.0
# <Parameter 'g_Humphreys96_59066B_Gamma', value=0.0002759563193875787 +/- 1.76e+07, bounds=[0.00027595631732863234:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066B_Peak', value=6.08908057205578e-14 +/- 0.00321, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066B_Peak', value=6.08908057205578e-14 +/- 0.00321, bounds=[0.0:inf]> lower than uncertainty 2.031121424302251e-05 , fixing to 0.0
# <Parameter 'g_H200S6_61088N_Peak', value=0.0013689150465124717 +/- 0.00342, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIII_73177N_Peak', value=1.7640083945122088e-06 +/- 0.0015, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIII_73177N_Peak', value=1.7640083945122088e-06 +/- 0.0015, bounds=[0.0:inf]> lower than uncertainty 1.6040326712036293e-05 , fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=9.774172911743649e-11 +/- 0.00188, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_79016N_Peak', value=9.774172911743649e-11 +/- 0.00188, bounds=[0.0:inf]> lower than uncertainty 1.4186734845912513e-05 , fixing to 0.0
# <Parameter 'g_FeVII_95267N_Peak', value=2.0346099707091678e-11 +/- 0.00323, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeVII_95267N_Peak', value=2.0346099707091678e-11 +/- 0.00323, bounds=[0.0:inf]> lower than uncertainty 8.651803894621466e-06 , fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=0.002353495750255553 +/- 0.00549, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_179359N_Peak', value=6.810200468478676e-08 +/- 0.00582, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_179359N_Peak', value=6.810200468478676e-08 +/- 0.00582, bounds=[0.0:inf]> lower than uncertainty 2.5383485475717326e-05 , fixing to 0.0
# <Parameter 'g_FeIII_229250N_Peak', value=0.0011382684920755463 +/- 0.00881, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd1_PAH52_52400_Peak', value=2.2956210866684542e-11 +/- 0.00205, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd1_PAH52_52400_Peak', value=2.2956210866684542e-11 +/- 0.00205, bounds=[0.0:inf]> lower than uncertainty 3.608563876565792e-05 , fixing to 0.0
# <Parameter 'd1_PAH53_53300_Peak', value=3.066871280445229e-10 +/- 0.0019, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd1_PAH53_53300_Peak', value=3.066871280445229e-10 +/- 0.0019, bounds=[0.0:inf]> lower than uncertainty 3.650539786188229e-05 , fixing to 0.0
# <Parameter 'd7_PAH86_86100_Peak', value=1.969962686652824e-06 +/- 0.000244, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd7_PAH86_86100_Peak', value=1.969962686652824e-06 +/- 0.000244, bounds=[0.0:inf]> lower than uncertainty 1.1269260090208019e-05 , fixing to 0.0
# <Parameter 'd9_PAH113_113300_Peak', value=1.9659202178384077e-06 +/- 0.000518, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd9_PAH113_113300_Peak', value=1.9659202178384077e-06 +/- 0.000518, bounds=[0.0:inf]> lower than uncertainty 6.980431055426161e-06 , fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=1.7951797773502908e-11 +/- 0.000453, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH164_164500_Peak', value=1.7951797773502908e-11 +/- 0.000453, bounds=[0.0:inf]> lower than uncertainty 1.3778863361614198e-05 , fixing to 0.0
# <Parameter 'd16_PAH179_178700_Peak', value=7.093334110385869e-06 +/- 0.00146, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH179_178700_Peak', value=7.093334110385869e-06 +/- 0.00146, bounds=[0.0:inf]> lower than uncertainty 2.2449642865539774e-05 , fixing to 0.0
# <Parameter 'd17_PAH189_189200_Peak', value=5.503149220310087e-09 +/- 0.00142, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd17_PAH189_189200_Peak', value=5.503149220310087e-09 +/- 0.00142, bounds=[0.0:inf]> lower than uncertainty 2.8227305464461935e-05 , fixing to 0.0
# <Parameter 'o_CO12ice_45440_Peak', value=1.7189326784542605e-06 +/- 0.142, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO12ice_45440_Peak', value=1.7189326784542605e-06 +/- 0.142, bounds=[0.0:1.0]> lower than uncertainty 8.33732624723456e-06 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=0.05155720030220601 +/- 0.379, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [0 2]
# Parameter object has 25 lines, 25 PAHs, 0 opacity features, and 42 continuum parameters
# Current spaxel [0 2] will be initialized with results from spaxel [1 1]
# Parameter object has 25 lines, 25 PAHs, 0 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2022-12-29 16:25:27.852555 -----------------
# True in 37 steps
# 44.64 seconds elapsed
# <Parameter 'g_H200S6_61088N_Peak', value=1.1471516829496521e-08 +/- 0.00236, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=5.550099291918244e-09 +/- 0.00543, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys86_75005N_Peak', value=2.477603786210229e-07 +/- 0.0102, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=2.73017768573743e-08 +/- 0.00188, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd1_PAH52_52400_Peak', value=9.7863615629526e-15 +/- 0.278, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd1_PAH53_53300_Peak', value=8.905749428929199e-14 +/- 0.189, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd2_PAH57_56700_Peak', value=2.0541288353138494e-22 +/- 0.000537, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=2.5322515858234996e-16 +/- 0.000611, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=2.0320600199876273e-07 +/- 0.00033, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=5.565919729326256e-23 +/- 0.000662, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=1.1580909325796482e-18 +/- 0.000954, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=2.4138372353165634e-10 +/- 0.000581, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=7.012693226953894e-31 +/- 0.000698, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=1.8546004080060942e-27 +/- 0.000932, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'HOT_FLX', value=1.4491510105943248 +/- 4.77, bounds=[0.0:2.0]> unconstrained at 329.2811901721813 % error. Fixing value.
# <Parameter 'STB_FLX', value=0.8651395653098836 +/- 921, bounds=[0.0:2.0]> unconstrained at 106501.18477621418 % error. Fixing value.
# <Parameter 'STB_TAU', value=0.9211635010699558 +/- 2.46e+03, bounds=[0.0:inf]> unconstrained at 266642.0193893057 % error. Fixing value.
# <Parameter 'STB_COV', value=0.4651076823333244 +/- 1.79e+03, bounds=[0.0:1.0]> unconstrained at 385864.45954481553 % error. Fixing value.
# <Parameter 'STB_010', value=0.7171627333371174 +/- 1.66e+04, bounds=[0.0:1.0]> unconstrained at 2318695.3579929816 % error. Fixing value.
# <Parameter 'g_H200S6_61088N_Peak', value=1.1471516829496521e-08 +/- 0.00236, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S6_61088N_Peak', value=1.1471516829496521e-08 +/- 0.00236, bounds=[0.0:inf]> lower than uncertainty 2.1201906512832585e-05 , fixing to 0.0
# <Parameter 'g_NaIII_73177N_Peak', value=0.0005050850274045065 +/- 0.00141, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=5.550099291918244e-09 +/- 0.00543, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=5.550099291918244e-09 +/- 0.00543, bounds=[0.0:inf]> lower than uncertainty 1.774122464466234e-05 , fixing to 0.0
# <Parameter 'g_Humphreys86_75005N_Peak', value=2.477603786210229e-07 +/- 0.0102, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys86_75005N_Peak', value=2.477603786210229e-07 +/- 0.0102, bounds=[0.0:inf]> lower than uncertainty 1.5793645808060227e-05 , fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=2.73017768573743e-08 +/- 0.00188, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_79016N_Peak', value=2.73017768573743e-08 +/- 0.00188, bounds=[0.0:inf]> lower than uncertainty 1.5544161417950996e-05 , fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=0.0015848466438004223 +/- 0.00792, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_179359N_Peak', value=0.002944304965593049 +/- 0.00781, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=0.0038631895863667984 +/- 0.014, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd1_PAH52_52400_Peak', value=9.7863615629526e-15 +/- 0.278, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd1_PAH53_53300_Peak', value=8.905749428929199e-14 +/- 0.189, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd2_PAH57_56700_Peak', value=2.0541288353138494e-22 +/- 0.000537, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd2_PAH57_56700_Peak', value=2.0541288353138494e-22 +/- 0.000537, bounds=[0.0:inf]> lower than uncertainty 1.7133983798350558e-05 , fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=5.40888665620702e-05 +/- 0.000296, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd5_PAH74_74200_Peak', value=2.5322515858234996e-16 +/- 0.000611, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd5_PAH74_74200_Peak', value=2.5322515858234996e-16 +/- 0.000611, bounds=[0.0:inf]> lower than uncertainty 1.3059374780429155e-05 , fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=2.0320600199876273e-07 +/- 0.00033, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd6_PAH83_83300_Peak', value=2.0320600199876273e-07 +/- 0.00033, bounds=[0.0:inf]> lower than uncertainty 1.1561921376373362e-05 , fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=5.565919729326256e-23 +/- 0.000662, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd8_PAH107_106800_Peak', value=5.565919729326256e-23 +/- 0.000662, bounds=[0.0:inf]> lower than uncertainty 1.2261603158504936e-05 , fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=1.1580909325796482e-18 +/- 0.000954, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd11_PAH127_126900_Peak', value=1.1580909325796482e-18 +/- 0.000954, bounds=[0.0:inf]> lower than uncertainty 2.0748443365295922e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=2.4138372353165634e-10 +/- 0.000581, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=2.4138372353165634e-10 +/- 0.000581, bounds=[0.0:inf]> lower than uncertainty 2.242239073756482e-05 , fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=7.012693226953894e-31 +/- 0.000698, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd15_PAH159_159000_Peak', value=7.012693226953894e-31 +/- 0.000698, bounds=[0.0:inf]> lower than uncertainty 2.2556572075153093e-05 , fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=1.8546004080060942e-27 +/- 0.000932, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH164_164500_Peak', value=1.8546004080060942e-27 +/- 0.000932, bounds=[0.0:inf]> lower than uncertainty 2.3109712034333857e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------

# %%
# Line and PAH averaged velocity gradient wrt z, in [km/s]
print(s.parcube['VALUE'].data[-1])
print(s.parcube['VALUE'].data[-1]/2.998e5)
# Out:
# [[ 33.76360779  16.05611155 -13.91929438]
#  [ 19.90797705  33.13290544 -18.63086373]
#  [  7.18040327   8.43029406   1.03625237]]
# [[ 1.12620440e-04  5.35560759e-05 -4.64286003e-05]
#  [ 6.64041930e-05  1.10516696e-04 -6.21443087e-05]
#  [ 2.39506447e-05  2.81197267e-05  3.45647889e-06]]

# %%
s.plot_cube_fit(1, 1, inppar_fn, optpar_fn)
# Out:
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Load the parameter cube from drive
parcube_fd = '/Users/tanio/Sync/pywork/CAFE_dev/output/'+source_fnb+'/'
parcube_fn = source_fnb+'_parcube.fits'

# %%
s.read_cube(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ./CRETA/extractions/IIZw096_GridExt_3x3_s0.5as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        38   (3, 3, 15142)   float64
#   2  ERR           1 ImageHDU         9   (3, 3, 15142)   float64
#   3  FLUX_ST       1 ImageHDU         9   (3, 3, 15142)   float64
#   4  ERR_ST        1 ImageHDU         9   (3, 3, 15142)   float64
#   5  DQ            1 ImageHDU         9   (3, 3, 15142)   float64
#   6  WAVE          1 ImageHDU         7   (15142,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   15142R x 1C   [20A]

# %%
s.read_parcube_file(parcube_fn, file_dir=parcube_fd)
# Out:
# Filename: /Users/tanio/Sync/pywork/CAFE_dev/output/IIZw096_GridExt_3x3_s05as_cube/IIZw096_GridExt_3x3_s05as_cube_parcube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  VALUE         1 ImageHDU        38   (3, 3, 373)   float64
#   2  STDERR        1 ImageHDU        38   (3, 3, 373)   float64
#   3  VARY          1 ImageHDU        38   (3, 3, 373)   float64
#   4  MIN           1 ImageHDU        38   (3, 3, 373)   float64
#   5  MAX           1 ImageHDU        38   (3, 3, 373)   float64
#   6  EXPR          1 BinTableHDU     13   373R x 2C   [I, 24A]
#   7  PARNAME       1 BinTableHDU     13   373R x 2C   [I, 32A]
# /Users/tanio/Sync/pywork/CAFE_dev/pycafe.py:110: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/tanio/Sync/pywork/CAFE_dev/output/IIZw096_GridExt_3x3_s05as_cube/IIZw096_GridExt_3x3_s05as_cube_parcube.fits'>
#   self.parcube = parcube

# %%
s.plot_cube_fit(1, 1, inppar_fn, optpar_fn)
# Out:
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Generate map of feature (TBD)

# %%
from astropy.io import ascii
from astropy.table import Table
from astropy.table import QTable

# Read output PAH table
pah = m.pah_table()
# Read output line table
line = m.line_table()

pah62 = pah[pah.index == 'PAH62'].pah_strength.values[0]
pah62_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah77 = pah[pah.index == 'PAH77_C'].pah_strength.values[0]
pah77_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah113 = pah[pah.index == 'PAH113_C'].pah_strength.values[0]
pah113_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]

x = pah62 / pah77 
x_unc = pah62 / pah77 * np.sqrt((pah62_unc/pah62)**2 + (pah77_unc/pah77)**2)
y = pah113 / pah77
y_unc = pah113 / pah77 * np.sqrt((pah113_unc/pah113)**2 + (pah77_unc/pah77)**2)

print('6.2/7.7 = {} +/- {}'.format(x, x_unc))
print('11.3/7.7 = {} +/- {}'.format(y, y_unc))

print(pah)

# Make an astropy table 
t = QTable([pah.index.values, pah.pah_strength, pah.pah_strength_unc],
           names = ('pah_complex', 'pah_strength', 'pah_strength_unc'),
           meta={'wavelength': 'micron',
                 'flux': 'W/m^2',
                }
          )

# Write PAH table in an .ecsv file
#t.write('./NGC7469_pah_tbl.ecsv', overwrite=False)
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 6.2/7.7 = 0.27497706375780917 +/- 0.01841045694281569
# 11.3/7.7 = 0.8185413910278543 +/- 0.022940147579330196
#              pah_strength  pah_strength_unc
# pah_complex
# PAH113_C     1.867022e-18      6.130991e-20
# PAH120       2.228631e-19      6.678562e-20
# PAH126_C     1.554609e-18      8.270987e-20
# PAH136       0.000000e+00      0.000000e+00
# PAH142       4.419746e-20      3.572571e-20
# PAH164       5.075110e-19      1.824103e-20
# PAH170_C     2.504853e-18      1.131216e-19
# PAH62        6.271987e-19      4.048978e-20
# PAH77_C      2.280913e-18      2.759058e-19
# PAH83        2.057891e-19      9.235792e-20
# PAH86        5.454928e-19      5.076714e-20
