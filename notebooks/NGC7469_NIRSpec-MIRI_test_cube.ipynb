# %%
import os

os._exit(00)

# %%
import sys
sys.path.insert(0, '../')
sys.path.insert(0, '../../CRETA/')

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib widget
import matplotlib.ticker
from matplotlib.backends.backend_pdf import PdfPages

import creta
import cafe_io
from cafe_io import *
import cafe_helper
from cafe_helper import *
import cafe

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# User API Created
# <style>.container { width:100% !important; }</style>

# %%
# SPECTRAL EXTRACTION

# %%
# Read parameter file with extraction keywords
creta_dir = '../../CRETA/'
pf = open(creta_dir+'param_files/NGC7469_grid_params.txt','r')
print(pf.read())
pf.close()
# Out:
# cubes = g395h, ch1-short, ch1-medium, ch1-long, ch2-short, ch2-medium, ch2-long, ch3-short, ch3-medium, ch3-long, ch4-short, ch4-medium, ch4-long
# user_ra = 23h03m15.614s
# user_dec = 08d52m26.23s
# user_center = True
# centering = True
# lambda_cent = 5.4
# nx_steps = 7
# ny_steps = 7
# spax_size = 0.45
# step_size = -1
# convolve = False

# %%
# Load the extraction tool (CRETA)
c = creta.creta(creta_dir)
# Out:
# CAFE Region Extraction Tool Automaton (CRETA) initialized

# %%
# Perform the extraction
c.gridExtraction(parameter_file=True, perband_cent=True, parfile_name='NGC7469_grid_params.txt', data_path='../../CRETA/data/NGC7469/', output_filebase_name='NGC7469')
# Out:
# Load file: ../../CRETA/data/NGC7469/Level3_g395h-f290lp_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch1-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch1-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch1-long_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch2-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch2-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch2-long_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch3-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch3-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch3-long_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch4-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch4-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch4-long_s3d.fits
# Last cube is:  ch4_LONG
# Cubes: ['g395h', 'ch1-short', 'ch1-medium', 'ch1-long', 'ch2-short', 'ch2-medium', 'ch2-long', 'ch3-short', 'ch3-medium', 'ch3-long', 'ch4-short', 'ch4-medium', 'ch4-long']
# RA,δ: [345.81505833,8.87395278] (degrees)
# Grid Extraction Parameters:
# NX Steps: 7
# NY Steps: 7
# Spaxel Size:  0.45
# Step Size: 0.45
# Loading Data
# Load file: ../../CRETA/data/NGC7469/Level3_g395h-f290lp_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch1-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch1-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch1-long_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch2-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch2-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch2-long_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch3-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch3-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch3-long_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch4-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch4-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch4-long_s3d.fits
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# Centering around 5.399500119092409 um in cube ch1_SHORT
# Old coordinates were: 345.81505833 8.87395278
# New coordinates are: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505833, 8.87395278)>
# Per-band re-centering around 2.871215809167602 um in cube G395H
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81524207, 8.87392658)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# G395H photometry exectued in: 51.850990772247314 seconds
# Per-band re-centering around 4.902500095486175 um in cube ch1_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505874, 8.87393501)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_SHORT photometry exectued in: 10.844436883926392 seconds
# Per-band re-centering around 5.662499847530853 um in cube ch1_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506329, 8.87392821)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_MEDIUM photometry exectued in: 12.467895984649658 seconds
# Per-band re-centering around 6.532500209927093 um in cube ch1_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506107, 8.87393765)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_LONG photometry exectued in: 14.941110610961914 seconds
# Per-band re-centering around 7.515000229119323 um in cube ch2_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505866, 8.87393817)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_SHORT photometry exectued in: 8.059479713439941 seconds
# Per-band re-centering around 8.675000076531433 um in cube ch2_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505679, 8.87394853)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_MEDIUM photometry exectued in: 8.7661452293396 seconds
# Per-band re-centering around 10.02500045800116 um in cube ch2_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506524, 8.87393436)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_LONG photometry exectued in: 9.803196907043457 seconds
# Per-band re-centering around 11.557500190800054 um in cube ch3_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506616, 8.87392467)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_SHORT photometry exectued in: 7.782386064529419 seconds
# Per-band re-centering around 13.347500152653083 um in cube ch3_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506916, 8.87392202)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_MEDIUM photometry exectued in: 8.509747982025146 seconds
# Per-band re-centering around 15.417499847477304 um in cube ch3_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506453, 8.87393263)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_LONG photometry exectued in: 9.826892137527466 seconds
# Per-band re-centering around 17.71500076306984 um in cube ch4_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506695, 8.87393001)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_SHORT photometry exectued in: 5.659008026123047 seconds
# Per-band re-centering around 20.705000534188 um in cube ch4_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505906, 8.87393121)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_MEDIUM photometry exectued in: 6.654928922653198 seconds
# Per-band re-centering around 24.205000534188 um in cube ch4_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81503673, 8.87389218)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_LONG photometry exectued in: 7.890805006027222 seconds
# /usr/local/anaconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1119: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# Grid point 0 stitched in: 0.02810192108154297 seconds
# Output written in: 0.47160983085632324 seconds
# /usr/local/anaconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1119: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# Grid point 1 stitched in: 0.03075408935546875 seconds
# Output written in: 0.39434194564819336 seconds
# Grid point 2 stitched in: 0.025060176849365234 seconds
# Output written in: 0.40161681175231934 seconds
# Grid point 3 stitched in: 0.024263858795166016 seconds
# Output written in: 0.3638577461242676 seconds
# Grid point 4 stitched in: 0.026105880737304688 seconds
# Output written in: 0.36190199851989746 seconds
# Grid point 5 stitched in: 0.0269927978515625 seconds
# Output written in: 0.5913980007171631 seconds
# Grid point 6 stitched in: 0.02960991859436035 seconds
# Output written in: 0.40513014793395996 seconds
# Grid point 7 stitched in: 0.02694082260131836 seconds
# Output written in: 0.4017360210418701 seconds
# Grid point 8 stitched in: 0.03568577766418457 seconds
# Output written in: 0.4242701530456543 seconds
# Grid point 9 stitched in: 0.02523207664489746 seconds
# Output written in: 0.3930079936981201 seconds
# Grid point 10 stitched in: 0.02731609344482422 seconds
# Output written in: 0.36372995376586914 seconds
# Grid point 11 stitched in: 0.024842023849487305 seconds
# Output written in: 0.3755149841308594 seconds
# Grid point 12 stitched in: 0.025074005126953125 seconds
# Output written in: 0.37427401542663574 seconds
# Grid point 13 stitched in: 0.025514841079711914 seconds
# Output written in: 0.3666517734527588 seconds
# Grid point 14 stitched in: 0.025666236877441406 seconds
# Output written in: 0.611598014831543 seconds
# Grid point 15 stitched in: 0.030152082443237305 seconds
# Output written in: 0.4150519371032715 seconds
# Grid point 16 stitched in: 0.03157496452331543 seconds
# Output written in: 0.38471293449401855 seconds
# Grid point 17 stitched in: 0.02684807777404785 seconds
# Output written in: 0.3864121437072754 seconds
# Grid point 18 stitched in: 0.02410602569580078 seconds
# Output written in: 0.3532898426055908 seconds
# Grid point 19 stitched in: 0.0290377140045166 seconds
# Output written in: 0.35876989364624023 seconds
# Grid point 20 stitched in: 0.024617910385131836 seconds
# Output written in: 0.35669517517089844 seconds
# Grid point 21 stitched in: 0.02455282211303711 seconds
# Output written in: 0.3779139518737793 seconds
# Grid point 22 stitched in: 0.025371313095092773 seconds
# Output written in: 0.3460960388183594 seconds
# Grid point 23 stitched in: 0.025226116180419922 seconds
# Output written in: 0.36537814140319824 seconds
# Grid point 24 stitched in: 0.025686025619506836 seconds
# Output written in: 0.36689186096191406 seconds
# Grid point 25 stitched in: 0.02597975730895996 seconds
# Output written in: 0.3508780002593994 seconds
# Grid point 26 stitched in: 0.02536177635192871 seconds
# Output written in: 0.3501250743865967 seconds
# Grid point 27 stitched in: 0.025674104690551758 seconds
# Output written in: 0.34238719940185547 seconds
# Grid point 28 stitched in: 0.02382493019104004 seconds
# Output written in: 0.35041379928588867 seconds
# Grid point 29 stitched in: 0.02470111846923828 seconds
# Output written in: 0.3502390384674072 seconds
# Grid point 30 stitched in: 0.026376008987426758 seconds
# Output written in: 0.3413660526275635 seconds
# Grid point 31 stitched in: 0.027001142501831055 seconds
# Output written in: 0.4046661853790283 seconds
# Grid point 32 stitched in: 0.02756190299987793 seconds
# Output written in: 0.5240399837493896 seconds
# Grid point 33 stitched in: 0.02580404281616211 seconds
# Output written in: 0.6422121524810791 seconds
# Grid point 34 stitched in: 0.027179718017578125 seconds
# Output written in: 0.36620211601257324 seconds
# Grid point 35 stitched in: 0.02574896812438965 seconds
# Output written in: 0.3773162364959717 seconds
# Grid point 36 stitched in: 0.026050090789794922 seconds
# Output written in: 0.6017060279846191 seconds
# Grid point 37 stitched in: 0.026105165481567383 seconds
# Output written in: 0.37444090843200684 seconds
# Grid point 38 stitched in: 0.025938034057617188 seconds
# Output written in: 0.37140607833862305 seconds
# Grid point 39 stitched in: 0.029082059860229492 seconds
# Output written in: 0.6200299263000488 seconds
# Grid point 40 stitched in: 0.026974916458129883 seconds
# Output written in: 0.3812539577484131 seconds
# /usr/local/anaconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1119: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# Grid point 41 stitched in: 0.02526116371154785 seconds
# Output written in: 0.37915587425231934 seconds
# Grid point 42 stitched in: 0.02795696258544922 seconds
# Output written in: 0.625377893447876 seconds
# Grid point 43 stitched in: 0.026700735092163086 seconds
# Output written in: 0.38082098960876465 seconds
# Grid point 44 stitched in: 0.02389812469482422 seconds
# Output written in: 0.35924220085144043 seconds
# Grid point 45 stitched in: 0.026275157928466797 seconds
# Output written in: 0.35510802268981934 seconds
# Grid point 46 stitched in: 0.026313066482543945 seconds
# Output written in: 0.37828898429870605 seconds
# Grid point 47 stitched in: 0.0263059139251709 seconds
# Output written in: 0.3905329704284668 seconds
# /usr/local/anaconda3/lib/python3.8/site-packages/numpy/lib/nanfunctions.py:1119: RuntimeWarning: All-NaN slice encountered
#   r, k = function_base._ureduce(a, func=_nanmedian, axis=axis, out=out,
# Grid point 48 stitched in: 0.02692890167236328 seconds
# Output written in: 0.37229180335998535 seconds
# {'extraction_RA': <Longitude 345.81541627 deg>, 'extraction_DEC': <Latitude 8.87351718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 0, 'step_indy': 0, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81541627 deg>, 'extraction_DEC': <Latitude 8.87364218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 0, 'step_indy': 1, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81541627 deg>, 'extraction_DEC': <Latitude 8.87376718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 0, 'step_indy': 2, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81541627 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 0, 'step_indy': 3, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81541627 deg>, 'extraction_DEC': <Latitude 8.87401718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 0, 'step_indy': 4, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81541627 deg>, 'extraction_DEC': <Latitude 8.87414218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 0, 'step_indy': 5, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81541627 deg>, 'extraction_DEC': <Latitude 8.87426718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 0, 'step_indy': 6, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81528976 deg>, 'extraction_DEC': <Latitude 8.87351718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 1, 'step_indy': 0, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81528976 deg>, 'extraction_DEC': <Latitude 8.87364218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 1, 'step_indy': 1, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81528976 deg>, 'extraction_DEC': <Latitude 8.87376718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 1, 'step_indy': 2, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81528976 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 1, 'step_indy': 3, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81528976 deg>, 'extraction_DEC': <Latitude 8.87401718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 1, 'step_indy': 4, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81528976 deg>, 'extraction_DEC': <Latitude 8.87414218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 1, 'step_indy': 5, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81528976 deg>, 'extraction_DEC': <Latitude 8.87426718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 1, 'step_indy': 6, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81516324 deg>, 'extraction_DEC': <Latitude 8.87351718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 2, 'step_indy': 0, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81516324 deg>, 'extraction_DEC': <Latitude 8.87364218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 2, 'step_indy': 1, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81516324 deg>, 'extraction_DEC': <Latitude 8.87376718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 2, 'step_indy': 2, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81516324 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 2, 'step_indy': 3, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81516324 deg>, 'extraction_DEC': <Latitude 8.87401718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 2, 'step_indy': 4, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81516324 deg>, 'extraction_DEC': <Latitude 8.87414218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 2, 'step_indy': 5, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81516324 deg>, 'extraction_DEC': <Latitude 8.87426718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 2, 'step_indy': 6, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87351718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 3, 'step_indy': 0, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87364218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 3, 'step_indy': 1, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87376718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 3, 'step_indy': 2, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 3, 'step_indy': 3, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87401718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 3, 'step_indy': 4, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87414218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 3, 'step_indy': 5, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87426718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 3, 'step_indy': 6, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81491021 deg>, 'extraction_DEC': <Latitude 8.87351718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 4, 'step_indy': 0, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81491021 deg>, 'extraction_DEC': <Latitude 8.87364218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 4, 'step_indy': 1, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81491021 deg>, 'extraction_DEC': <Latitude 8.87376718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 4, 'step_indy': 2, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81491021 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 4, 'step_indy': 3, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81491021 deg>, 'extraction_DEC': <Latitude 8.87401718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 4, 'step_indy': 4, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81491021 deg>, 'extraction_DEC': <Latitude 8.87414218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 4, 'step_indy': 5, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81491021 deg>, 'extraction_DEC': <Latitude 8.87426718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 4, 'step_indy': 6, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.8147837 deg>, 'extraction_DEC': <Latitude 8.87351718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 5, 'step_indy': 0, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.8147837 deg>, 'extraction_DEC': <Latitude 8.87364218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 5, 'step_indy': 1, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.8147837 deg>, 'extraction_DEC': <Latitude 8.87376718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 5, 'step_indy': 2, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.8147837 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 5, 'step_indy': 3, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.8147837 deg>, 'extraction_DEC': <Latitude 8.87401718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 5, 'step_indy': 4, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.8147837 deg>, 'extraction_DEC': <Latitude 8.87414218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 5, 'step_indy': 5, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.8147837 deg>, 'extraction_DEC': <Latitude 8.87426718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 5, 'step_indy': 6, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81465718 deg>, 'extraction_DEC': <Latitude 8.87351718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 6, 'step_indy': 0, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81465718 deg>, 'extraction_DEC': <Latitude 8.87364218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 6, 'step_indy': 1, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81465718 deg>, 'extraction_DEC': <Latitude 8.87376718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 6, 'step_indy': 2, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81465718 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 6, 'step_indy': 3, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81465718 deg>, 'extraction_DEC': <Latitude 8.87401718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 6, 'step_indy': 4, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81465718 deg>, 'extraction_DEC': <Latitude 8.87414218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 6, 'step_indy': 5, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81465718 deg>, 'extraction_DEC': <Latitude 8.87426718 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 7, 'NY': 7, 'spax_size': 0.45, 'step_size': 0.45, 'step_indx': 6, 'step_indy': 6, 'CDELT1': 0.45, 'CDELT2': 0.45, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]

# %%
# CAFE FITTING

# %%
# Setup directories
source_fd = '../../CRETA/extractions/'
#source_fn = 'NGC7469_GridExt_3x3_s0.5as_cube.fits'
source_fn = 'NGC7469_GridExt_7x7_s0.45as_cube.fits'
source_fnb = source_fn.split('.fits')[0].replace('.','')

cafe_dir = '../'
inppar_fn = cafe_dir+'inp_parfiles/inpars_jwst_nirspec-miri_AGN.ini'
optpar_fn = cafe_dir+'opt_parfiles/default_opt.cafe'

z=0.01623
s = cafe.cubemod(cafe_dir)

# %%
s.read_cube(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ../../CRETA/extractions/NGC7469_GridExt_7x7_s0.45as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        38   (7, 7, 12894)   float64
#   2  ERR           1 ImageHDU         9   (7, 7, 12894)   float64
#   3  FLUX_ST       1 ImageHDU         9   (7, 7, 12894)   float64
#   4  ERR_ST        1 ImageHDU         9   (7, 7, 12894)   float64
#   5  DQ            1 ImageHDU         9   (7, 7, 12894)   float64
#   6  WAVE          1 ImageHDU         7   (12894,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   12894R x 1C   [20A]

# %%
s.plot_spec(2, 2)
# Out:
# <AxesSubplot:xlabel='Wavelength (micron)', ylabel='Flux (Jy)'>
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s.plot_cube_ini(2, 2, inppar_fn, optpar_fn)
# Out:
# Generating continuum profiles for guess model
# Parameter object has 84 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s.fit_cube(inppar_fn, optpar_fn)
# Out:
# Generating fitting sequence
# Highest SNR spaxel is: 3 3
# Generating initial/full parameter object with all potential lines
# Generating parameter cube with initial/full parameter object
# Parameter object has 112 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Regenerating parameter object for current spaxel [3 3]
# Parameter object has 85 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Regenerating continuum profiles
# ISRF
# ISRF
# Iteration 1/5(max): 2023-01-13 21:23:16.492944 -----------------
# True in 45 steps
# 219.13 seconds elapsed
# <Parameter 'STB_TAU', value=8.087129275520843e-06 +/- 4.05e+04, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_010', value=0.9999993336981048 +/- 6.56e+04, bounds=[0.0:1.0]> at upper bound, fixing to  1.0
# <Parameter 'DSK_FLX', value=3.8515083209738545e-10 +/- 0.0521, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'DSK_TAU', value=4.95143948205236e-08 +/- 2.13e+05, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=3.770902451968631e-20 +/- 0.00109, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVIII_30280B_Wave', value=3.0329999499666442 +/- 0.000845, bounds=[3.0229000500333556:3.0329999499666447]> at upper bound, fixing to 3.0329999499666447
# <Parameter 'g_MgVIII_30280B_Gamma', value=0.006671114076050699 +/- 0.000655, bounds=[0.0002598254251089757:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_KVII_31905N_Peak', value=3.6826366880098093e-19 +/- 0.000793, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund85_37406N_Peak', value=4.351635981018103e-30 +/- 0.00108, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NiI_39524N_Peak', value=3.72938233432559e-26 +/- 0.00124, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S12_39947N_Peak', value=5.1572463255937296e-17 +/- 0.00149, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_44348N_Peak', value=1.4947126565315334e-22 +/- 0.00105, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=1.264225956735522e-18 +/- 0.00148, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=4.3048498834739025e-21 +/- 0.00108, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaVIII_51789B_Wave', value=5.1702627418278855 +/- 0.00162, bounds=[5.170262741827885:5.187537258172115]> at lower bound, fixing to 5.170262741827885
# <Parameter 'g_NaVIII_51789B_Gamma', value=0.006671114076050699 +/- 0.000724, bounds=[0.00025025071915728595:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_FeVIII_54466B_Gamma', value=0.006671114076050699 +/- 0.000902, bounds=[0.00023720031464962568:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_MgVII_55032B_Gamma', value=0.006671114076050699 +/- 0.000733, bounds=[0.00023461347416231423:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_SiVII_64922N_Peak', value=5.0768878847287e-17 +/- 0.00182, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVII_64922B_Wave', value=6.481372448298868 +/- 0.00552, bounds=[6.481372448298866:6.503027551701135]> at lower bound, fixing to 6.481372448298866
# <Parameter 'g_SiVII_64922B_Gamma', value=0.006671114076050699 +/- 0.00199, bounds=[0.00025792875365166537:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_ArII_69853N_Peak', value=2.2793056813526295e-17 +/- 0.00364, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=3.220541611353007e-17 +/- 0.00224, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=2.367446533641751e-22 +/- 0.0113, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd0_PAH33_32900_Peak', value=3.2762131641147723e-19 +/- 0.000213, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=1.20115261834331e-17 +/- 0.000227, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=2.310424093442862e-19 +/- 0.000573, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=1.2926496461273392e-19 +/- 0.000344, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd7_PAH86_86100_Peak', value=5.329360887308158e-19 +/- 0.000352, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=1.5679456625128022e-18 +/- 0.000446, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=8.618289534677548e-20 +/- 0.000748, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_H2Oice_30500_Peak', value=9.462343467265074e-41 +/- 0.00778, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO2ice_42722_Peak', value=6.752898205923482e-29 +/- 0.00819, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=5.3598300430215346e-18 +/- 0.0131, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_FLX', value=1.228681087442272e-05 +/- 0.382, bounds=[0.0:2.0]> unconstrained at 3112233.4971779943 % error. Fixing value.
# <Parameter 'STB_TAU', value=8.087129275520843e-06 +/- 4.05e+04, bounds=[0.0:inf]> unconstrained at 501082618558.0161 % error. Fixing value.
# <Parameter 'STB_010', value=0.9999993336981048 +/- 6.56e+04, bounds=[0.0:1.0]> unconstrained at 6560882.085264659 % error. Fixing value.
# <Parameter 'DSK_FLX', value=3.8515083209738545e-10 +/- 0.0521, bounds=[0.0:2.0]> unconstrained at 13532962000.013947 % error. Fixing value.
# <Parameter 'DSK_TAU', value=4.95143948205236e-08 +/- 2.13e+05, bounds=[0.0:2.0]> unconstrained at 431184437759922.9 % error. Fixing value.
# <Parameter 'g_AlV_29052N_Peak', value=0.0004214978732025386 +/- 0.000983, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=3.770902451968631e-20 +/- 0.00109, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=3.770902451968631e-20 +/- 0.00109, bounds=[0.0:inf]> lower than uncertainty 1.7697600958480167e-05 , fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=3.6826366880098093e-19 +/- 0.000793, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=3.6826366880098093e-19 +/- 0.000793, bounds=[0.0:inf]> lower than uncertainty 1.706201885327394e-05 , fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=0.000345238703359077 +/- 0.000975, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S16_35470N_Peak', value=0.00047717132471405613 +/- 0.00119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund85_37406N_Peak', value=4.351635981018103e-30 +/- 0.00108, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund85_37406N_Peak', value=4.351635981018103e-30 +/- 0.00108, bounds=[0.0:inf]> lower than uncertainty 2.3516820450660305e-05 , fixing to 0.0
# <Parameter 'g_H200S13_38464N_Peak', value=0.00018377662246381869 +/- 0.00101, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NiI_39524N_Peak', value=3.72938233432559e-26 +/- 0.00124, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NiI_39524N_Peak', value=3.72938233432559e-26 +/- 0.00124, bounds=[0.0:inf]> lower than uncertainty 2.7141634764446423e-05 , fixing to 0.0
# <Parameter 'g_H200S12_39947N_Peak', value=5.1572463255937296e-17 +/- 0.00149, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S12_39947N_Peak', value=5.1572463255937296e-17 +/- 0.00149, bounds=[0.0:inf]> lower than uncertainty 3.204997422466013e-05 , fixing to 0.0
# <Parameter 'g_H200S10_44096N_Peak', value=0.0004805467115041613 +/- 0.00103, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=1.4947126565315334e-22 +/- 0.00105, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=1.4947126565315334e-22 +/- 0.00105, bounds=[0.0:inf]> lower than uncertainty 2.167776054037743e-05 , fixing to 0.0
# <Parameter 'g_ArVI_45295N_Peak', value=0.000828865094878584 +/- 0.00186, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=1.264225956735522e-18 +/- 0.00148, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=1.264225956735522e-18 +/- 0.00148, bounds=[0.0:inf]> lower than uncertainty 3.185068897133146e-05 , fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=4.3048498834739025e-21 +/- 0.00108, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KIII_46180N_Peak', value=4.3048498834739025e-21 +/- 0.00108, bounds=[0.0:inf]> lower than uncertainty 2.2209904926451536e-05 , fixing to 0.0
# <Parameter 'g_NaVIII_51789N_Peak', value=0.0006193265099199948 +/- 0.00182, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922N_Peak', value=5.0768878847287e-17 +/- 0.00182, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922N_Peak', value=5.0768878847287e-17 +/- 0.00182, bounds=[0.0:inf]> lower than uncertainty 3.6276817635517265e-05 , fixing to 0.0
# <Parameter 'g_ArII_69853N_Peak', value=2.2793056813526295e-17 +/- 0.00364, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=2.2793056813526295e-17 +/- 0.00364, bounds=[0.0:inf]> lower than uncertainty 3.841059215816651e-05 , fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=3.220541611353007e-17 +/- 0.00224, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=3.220541611353007e-17 +/- 0.00224, bounds=[0.0:inf]> lower than uncertainty 3.882385784372552e-05 , fixing to 0.0
# <Parameter 'g_FeIII_229250N_Peak', value=0.003351915154619774 +/- 0.0105, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=2.367446533641751e-22 +/- 0.0113, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=2.367446533641751e-22 +/- 0.0113, bounds=[0.0:inf]> lower than uncertainty 0.0002959492471511394 , fixing to 0.0
# <Parameter 'd0_PAH33_32900_Peak', value=3.2762131641147723e-19 +/- 0.000213, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd0_PAH33_32900_Peak', value=3.2762131641147723e-19 +/- 0.000213, bounds=[0.0:inf]> lower than uncertainty 2.2940578006321795e-05 , fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=1.20115261834331e-17 +/- 0.000227, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd4_PAH67_66900_Peak', value=1.20115261834331e-17 +/- 0.000227, bounds=[0.0:inf]> lower than uncertainty 2.875405482882764e-05 , fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=2.310424093442862e-19 +/- 0.000573, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd5_PAH74_74200_Peak', value=2.310424093442862e-19 +/- 0.000573, bounds=[0.0:inf]> lower than uncertainty 3.710248696615133e-05 , fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=1.2926496461273392e-19 +/- 0.000344, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd6_PAH83_83300_Peak', value=1.2926496461273392e-19 +/- 0.000344, bounds=[0.0:inf]> lower than uncertainty 4.0040268614962273e-05 , fixing to 0.0
# <Parameter 'd7_PAH86_86100_Peak', value=5.329360887308158e-19 +/- 0.000352, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd7_PAH86_86100_Peak', value=5.329360887308158e-19 +/- 0.000352, bounds=[0.0:inf]> lower than uncertainty 4.2206548134794195e-05 , fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=0.0003687039500797436 +/- 0.000947, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=1.5679456625128022e-18 +/- 0.000446, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=1.5679456625128022e-18 +/- 0.000446, bounds=[0.0:inf]> lower than uncertainty 6.612891242152572e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=8.618289534677548e-20 +/- 0.000748, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=8.618289534677548e-20 +/- 0.000748, bounds=[0.0:inf]> lower than uncertainty 6.550775053702543e-05 , fixing to 0.0
# <Parameter 'd16_PAH174_173750_Peak', value=0.00017088025147522984 +/- 0.000808, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'o_H2Oice_30500_Peak', value=9.462343467265074e-41 +/- 0.00778, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_H2Oice_30500_Peak', value=9.462343467265074e-41 +/- 0.00778, bounds=[0.0:1.0]> lower than uncertainty 2.1240087841819183e-05 , fixing to 0.0
# <Parameter 'o_CO2ice_42722_Peak', value=6.752898205923482e-29 +/- 0.00819, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO2ice_42722_Peak', value=6.752898205923482e-29 +/- 0.00819, bounds=[0.0:1.0]> lower than uncertainty 2.283024925777832e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=5.3598300430215346e-18 +/- 0.0131, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=5.3598300430215346e-18 +/- 0.0131, bounds=[0.0:1.0]> lower than uncertainty 2.2920589856917133e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------
# Regenerating parameter object for current spaxel [3 2]
# Parameter object has 80 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Regenerating continuum profiles
# ISRF
# ISRF
# Current spaxel [3 2] will be initialized with results from spaxel [3 3] and set to a SB inppar file
# Parameter object has 80 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-13 21:26:59.871851 -----------------
# True in 26 steps
# 109.52 seconds elapsed
# <Parameter 'g_MgVIII_30280N_Peak', value=6.945028938780691e-06 +/- 0.00158, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=5.377532039331711e-14 +/- 0.000598, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=2.1440162402635785e-08 +/- 0.000604, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S14_37240N_Peak', value=1.038534873878366e-09 +/- 0.000659, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund85_37406N_Peak', value=1.2447321119949769e-08 +/- 0.000614, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVII_55032N_Peak', value=1.0395552546752444e-06 +/- 0.000913, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys86_75005N_Peak', value=3.8301339968982443e-08 +/- 0.000765, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVII_90090N_Peak', value=1.8336342775749307e-08 +/- 0.000864, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_AlVI_91160N_Peak', value=6.305335900123899e-07 +/- 0.000899, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ClII_143678N_Peak', value=3.686003704863339e-07 +/- 0.00112, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArIII_218302N_Peak', value=8.404027215875617e-07 +/- 0.00427, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Gamma', value=0.0066711074011489065 +/- 0.00096, bounds=[0.0005367733614401021:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'd8_PAH107_106800_Peak', value=3.568775047574161e-10 +/- 0.000208, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=3.967087099644652e-07 +/- 0.000178, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=7.84643895784864e-10 +/- 0.000292, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=8.173977811904708e-08 +/- 0.000275, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_H2Oice_30500_Peak', value=2.4659282638840855e-08 +/- 0.0292, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=1.0143872917738132e-07 +/- 0.0496, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'WRM_TAU', value=0.00031167528261584026 +/- 0.139, bounds=[0.0:inf]> unconstrained at 44477.802741242194 % error. Fixing value.
# <Parameter 'STB_TAU', value=0.00017348535612834358 +/- 1.3, bounds=[0.0:inf]> unconstrained at 748724.049713925 % error. Fixing value.
# <Parameter 'STB_010', value=0.4623355952191709 +/- 22.9, bounds=[0.0:1.0]> unconstrained at 4943.720525963843 % error. Fixing value.
# <Parameter 'DSK_FLX', value=2.1377240740273083e-05 +/- 0.106, bounds=[0.0:2.0]> unconstrained at 496113.09394589264 % error. Fixing value.
# <Parameter 'DSK_TAU', value=6.253695728604652e-05 +/- 5.51e+03, bounds=[0.0:2.0]> unconstrained at 8808602051.857471 % error. Fixing value.
# <Parameter 'g_AlV_29052N_Peak', value=0.00016072029848242052 +/- 0.000715, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVIII_30280N_Peak', value=6.945028938780691e-06 +/- 0.00158, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVIII_30280N_Peak', value=6.945028938780691e-06 +/- 0.00158, bounds=[0.0:inf]> lower than uncertainty 2.212013266131555e-05 , fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=5.377532039331711e-14 +/- 0.000598, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=5.377532039331711e-14 +/- 0.000598, bounds=[0.0:inf]> lower than uncertainty 2.2113326953054294e-05 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=0.0002623313698452098 +/- 0.000543, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=2.1440162402635785e-08 +/- 0.000604, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=2.1440162402635785e-08 +/- 0.000604, bounds=[0.0:inf]> lower than uncertainty 2.1401389525542586e-05 , fixing to 0.0
# <Parameter 'g_H200S15_36250N_Peak', value=0.00018818065369712465 +/- 0.000578, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=1.038534873878366e-09 +/- 0.000659, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=1.038534873878366e-09 +/- 0.000659, bounds=[0.0:inf]> lower than uncertainty 2.3666401323304433e-05 , fixing to 0.0
# <Parameter 'g_Pfund85_37406N_Peak', value=1.2447321119949769e-08 +/- 0.000614, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund85_37406N_Peak', value=1.2447321119949769e-08 +/- 0.000614, bounds=[0.0:inf]> lower than uncertainty 2.1831999801751136e-05 , fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=0.0003794606972989818 +/- 0.00101, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaV_41594N_Peak', value=0.00012523435391160033 +/- 0.0013, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S10_44096N_Peak', value=0.0003809852061380343 +/- 0.000986, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=0.00037138219944570785 +/- 0.00116, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867B_Gamma', value=0.0003518084362784981 +/- 0.000918, bounds=[0.00029175833137554986:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867B_Peak', value=0.0005227886606759893 +/- 0.0011, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=2.1272602939463265e-05 +/- 0.00199, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVIII_51789N_Peak', value=0.0006041679229212904 +/- 0.00196, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeVIII_54466N_Peak', value=0.0003053841097294697 +/- 0.00105, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_55032N_Peak', value=1.0395552546752444e-06 +/- 0.000913, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_55032N_Peak', value=1.0395552546752444e-06 +/- 0.000913, bounds=[0.0:inf]> lower than uncertainty 2.400308460973878e-05 , fixing to 0.0
# <Parameter 'g_MgV_56098N_Peak', value=0.00032601715004376437 +/- 0.00124, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=0.0005109568280410135 +/- 0.00241, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys86_75005N_Peak', value=3.8301339968982443e-08 +/- 0.000765, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys86_75005N_Peak', value=3.8301339968982443e-08 +/- 0.000765, bounds=[0.0:inf]> lower than uncertainty 2.7082626285407957e-05 , fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=0.00021554968928372213 +/- 0.00113, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_90090N_Peak', value=1.8336342775749307e-08 +/- 0.000864, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_90090N_Peak', value=1.8336342775749307e-08 +/- 0.000864, bounds=[0.0:inf]> lower than uncertainty 2.6631274005761243e-05 , fixing to 0.0
# <Parameter 'g_AlVI_91160N_Peak', value=6.305335900123899e-07 +/- 0.000899, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_AlVI_91160N_Peak', value=6.305335900123899e-07 +/- 0.000899, bounds=[0.0:inf]> lower than uncertainty 2.713927852072351e-05 , fixing to 0.0
# <Parameter 'g_ClII_143678N_Peak', value=3.686003704863339e-07 +/- 0.00112, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ClII_143678N_Peak', value=3.686003704863339e-07 +/- 0.00112, bounds=[0.0:inf]> lower than uncertainty 4.01513446668169e-05 , fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=3.131781245925101e-05 +/- 0.00387, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_PIII_178850N_Peak', value=3.131781245925101e-05 +/- 0.00387, bounds=[0.0:inf]> lower than uncertainty 9.625578180447736e-05 , fixing to 0.0
# <Parameter 'g_ArIII_218302N_Peak', value=8.404027215875617e-07 +/- 0.00427, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArIII_218302N_Peak', value=8.404027215875617e-07 +/- 0.00427, bounds=[0.0:inf]> lower than uncertainty 0.00015357444718474807 , fixing to 0.0
# <Parameter 'd0_PAH35_34700_Peak', value=6.107535278088803e-05 +/- 0.000129, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd8_PAH107_106800_Peak', value=3.568775047574161e-10 +/- 0.000208, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd8_PAH107_106800_Peak', value=3.568775047574161e-10 +/- 0.000208, bounds=[0.0:inf]> lower than uncertainty 3.0510847029048942e-05 , fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=3.967087099644652e-07 +/- 0.000178, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=3.967087099644652e-07 +/- 0.000178, bounds=[0.0:inf]> lower than uncertainty 3.887643261689765e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=7.84643895784864e-10 +/- 0.000292, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=7.84643895784864e-10 +/- 0.000292, bounds=[0.0:inf]> lower than uncertainty 4.051473914988649e-05 , fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=8.173977811904708e-08 +/- 0.000275, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd14_PAH142_141900_Peak', value=8.173977811904708e-08 +/- 0.000275, bounds=[0.0:inf]> lower than uncertainty 3.931225812203158e-05 , fixing to 0.0
# <Parameter 'o_H2Oice_30500_Peak', value=2.4659282638840855e-08 +/- 0.0292, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_H2Oice_30500_Peak', value=2.4659282638840855e-08 +/- 0.0292, bounds=[0.0:1.0]> lower than uncertainty 2.5499813925524612e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=1.0143872917738132e-07 +/- 0.0496, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=1.0143872917738132e-07 +/- 0.0496, bounds=[0.0:1.0]> lower than uncertainty 3.907374086918739e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------
# Regenerating parameter object for current spaxel [3 4]
# Parameter object has 86 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Regenerating continuum profiles
# ISRF
# ISRF
# Current spaxel [3 4] will be initialized with results from spaxel [3 3] and set to a SB inppar file
# Parameter object has 86 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-13 21:28:53.137430 -----------------
# /Users/tanio/Sync/pywork/CAFE/CAFE/notebooks/../cafe_lib.py:731: RuntimeWarning: overflow encountered in double_scalars
#   const = p['STB_FLX'] * cont_profs['flux0']['STB'] / jSTB0
# /Users/tanio/Sync/pywork/CAFE/CAFE/notebooks/../cafe_lib.py:732: RuntimeWarning: invalid value encountered in multiply
#   fSTB = const * jSTB
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 s.fit_cube(inppar_fn, optpar_fn)
#
# File ~/Sync/pywork/CAFE/CAFE/notebooks/../cafe.py:297, in cubemod.fit_cube(self, inparfile, optfile, fit_pattern, cont_profs)
#     294     # The params file is regenerated but with the VARY, LIMS and ARG reset based on the new VALUES injected
#     295     params = param_gen.make_parobj(parobj_update=cube_params, get_all=True)
# --> 297 # Fit the spectrum
#     298 result = cafe_grinder(self, params, wave, flux, flux_unc, weight)
#     300 # Inject the result into the parameter cube
#
# File ~/Sync/pywork/CAFE/CAFE/notebooks/../cafe.py:53, in cafe_grinder(self, params, wave, flux, flux_unc, weight)
#      51 fitter = lm.Minimizer(chisquare, params, fcn_args=(wave, flux, flux_unc, weight, self.cont_profs, show))
#      52 ### Note that which fitting method is faster here is pretty uncertain, changes by target
# ---> 53 result = fitter.minimize(method=method, ftol=ftol) #, method='leastsq')
#      54 #print(lm.fit_report(result))
#      56 if result.success:
#      57     ### Print to terminal and log file
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/lmfit/minimizer.py:2363, in Minimizer.minimize(self, method, params, **kws)
#    2360         if (key.lower().startswith(user_method) or
#    2361                 val.lower().startswith(user_method)):
#    2362             kwargs['method'] = val
# -> 2363 return function(**kwargs)
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/lmfit/minimizer.py:1577, in Minimizer.least_squares(self, params, max_nfev, **kws)
#    1575 result.call_kws = kws
#    1576 try:
# -> 1577     ret = least_squares(self.__residual, start_vals,
#    1578                         bounds=(lower_bounds, upper_bounds),
#    1579                         kwargs=dict(apply_bounds_transformation=False),
#    1580                         max_nfev=2*self.max_nfev, **kws)
#    1581     result.residual = ret.fun
#    1582 except AbortFitException:
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/scipy/optimize/_lsq/least_squares.py:928, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     924     result = call_minpack(fun_wrapped, x0, jac_wrapped, ftol, xtol, gtol,
#     925                           max_nfev, x_scale, diff_step)
#     927 elif method == 'trf':
# --> 928     result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     929                  gtol, max_nfev, x_scale, loss_function, tr_solver,
#     930                  tr_options.copy(), verbose)
#     932 elif method == 'dogbox':
#     933     if tr_solver == 'lsmr' and 'regularize' in tr_options:
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/scipy/optimize/_lsq/trf.py:123, in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     119     return trf_no_bounds(
#     120         fun, jac, x0, f0, J0, ftol, xtol, gtol, max_nfev, x_scale,
#     121         loss_function, tr_solver, tr_options, verbose)
#     122 else:
# --> 123     return trf_bounds(
#     124         fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
#     125         loss_function, tr_solver, tr_options, verbose)
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/scipy/optimize/_lsq/trf.py:338, in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     334 step, step_h, predicted_reduction = select_step(
#     335     x, J_h, diag_h, g_h, p, p_h, d, Delta, lb, ub, theta)
#     337 x_new = make_strictly_feasible(x + step, lb, ub, rstep=0)
# --> 338 f_new = fun(x_new)
#     339 nfev += 1
#     341 step_h_norm = norm(step_h)
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/scipy/optimize/_lsq/least_squares.py:815, in least_squares.<locals>.fun_wrapped(x)
#     814 def fun_wrapped(x):
# --> 815     return np.atleast_1d(fun(x, *args, **kwargs))
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/lmfit/minimizer.py:604, in Minimizer.__residual(self, fvars, apply_bounds_transformation)
#     602     raise AbortFitException("fit aborted by user.")
#     603 else:
# --> 604     return _nan_policy(np.asarray(out).ravel(),
#     605                        nan_policy=self.nan_policy)
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/lmfit/minimizer.py:2447, in _nan_policy(arr, nan_policy, handle_inf)
#    2442     if contains_nan:
#    2443         msg = ('NaN values detected in your input data or the output of '
#    2444                'your objective/model function - fitting algorithms cannot '
#    2445                'handle this! Please read https://lmfit.github.io/lmfit-py/faq.html#i-get-errors-from-nan-in-my-fit-what-can-i-do '
#    2446                'for more information.')
# -> 2447         raise ValueError(msg)
#    2448 return arr
#
# ValueError: NaN values detected in your input data or the output of your objective/model function - fitting algorithms cannot handle this! Please read https://lmfit.github.io/lmfit-py/faq.html#i-get-errors-from-nan-in-my-fit-what-can-i-do for more information.

# %%
# Line and PAH averaged velocity gradient wrt z, in [km/s]
print(s.parcube['VALUE'].data[-1])
print(s.parcube['VALUE'].data[-1]/2.998e5)
# Out:
# [[ -3.72753961 -11.00464844  -8.81747928  29.09967474  28.7703357 ]
#  [-12.34798767  -3.77021421  10.68879981  60.84549737  31.3020794 ]
#  [ -1.03545365  11.17075753  -3.57906995  99.99548871  39.78171789]
#  [ 42.18127061  79.57204474 100.         100.          60.20557441]
#  [ -1.24814288   3.18770314  40.52689262  42.52440104  60.91081963]]
# [[-1.24334210e-05 -3.67066326e-05 -2.94112051e-05  9.70636249e-05
#    9.59650957e-05]
#  [-4.11874172e-05 -1.25757645e-05  3.56531014e-05  2.02953627e-04
#    1.04409871e-04]
#  [-3.45381470e-06  3.72606989e-05 -1.19381919e-05  3.33540656e-04
#    1.32694189e-04]
#  [ 1.40698034e-04  2.65417094e-04  3.33555704e-04  3.33555704e-04
#    2.00819127e-04]
#  [-4.16325175e-06  1.06327656e-05  1.35179762e-04  1.41842565e-04
#    2.03171513e-04]]

# %%
spaxel = [2, 4]
s.plot_cube_fit(spaxel[0], spaxel[1], self.inpar_fns[spaxel[0], spaxel[1]], optpar_fn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 s.plot_cube_fit(2, 4, inppar_fn, optpar_fn)
#
# NameError: name 's' is not defined

# %%
# Load the parameter cube from drive
parcube_fd = '../output/'+source_fnb+'/'
parcube_fn = source_fnb+'_parcube.fits'

# %%
s.read_cube(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ../../CRETA/extractions/NGC7469_GridExt_3x3_s0.5as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        38   (3, 3, 12894)   float64
#   2  ERR           1 ImageHDU         9   (3, 3, 12894)   float64
#   3  FLUX_ST       1 ImageHDU         9   (3, 3, 12894)   float64
#   4  ERR_ST        1 ImageHDU         9   (3, 3, 12894)   float64
#   5  DQ            1 ImageHDU         9   (3, 3, 12894)   float64
#   6  WAVE          1 ImageHDU         7   (12894,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   12894R x 1C   [20A]

# %%
s.read_parcube_file(parcube_fn, file_dir=parcube_fd)
# Out:
# Filename: ../output/NGC7469_GridExt_3x3_s05as_cube/NGC7469_GridExt_3x3_s05as_cube_parcube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  VALUE         1 ImageHDU        38   (3, 3, 472)   float64
#   2  STDERR        1 ImageHDU        38   (3, 3, 472)   float64
#   3  VARY          1 ImageHDU        38   (3, 3, 472)   float64
#   4  MIN           1 ImageHDU        38   (3, 3, 472)   float64
#   5  MAX           1 ImageHDU        38   (3, 3, 472)   float64
#   6  EXPR          1 BinTableHDU     13   472R x 2C   [I, 24A]
#   7  PARNAME       1 BinTableHDU     13   472R x 2C   [I, 32A]

# %%
s.plot_cube_fit(0, 0, inppar_fn, optpar_fn)
# Out:
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Generate map of feature (TBD)
#s.make_map('HOT_FLX')

# %%
from astropy.io import ascii
from astropy.table import Table
from astropy.table import QTable

# Read output PAH table
pah = cafeio.pah_table(s.parcube, 0, 0)
# Read output line table
line = cafeio.line_table(s.parcube, 0, 0)

pah62 = pah[pah.index == 'PAH62'].pah_strength.values[0]
pah62_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah77 = pah[pah.index == 'PAH77_C'].pah_strength.values[0]
pah77_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah113 = pah[pah.index == 'PAH113_C'].pah_strength.values[0]
pah113_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]

x = pah62 / pah77 
x_unc = pah62 / pah77 * np.sqrt((pah62_unc/pah62)**2 + (pah77_unc/pah77)**2)
y = pah113 / pah77
y_unc = pah113 / pah77 * np.sqrt((pah113_unc/pah113)**2 + (pah77_unc/pah77)**2)

print('6.2/7.7 = {} +/- {}'.format(x, x_unc))
print('11.3/7.7 = {} +/- {}'.format(y, y_unc))

print(pah)

# Make an astropy table 
t = QTable([pah.index.values, pah.pah_strength, pah.pah_strength_unc],
           names = ('pah_complex', 'pah_strength', 'pah_strength_unc'),
           meta={'wavelength': 'micron',
                 'flux': 'W/m^2',
                }
          )

# Write PAH table in an .ecsv file
#t.write('./NGC7469_pah_tbl.ecsv', overwrite=False)
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 6.2/7.7 = 0.2694158115306601 +/- 0.006545463417734035
# 11.3/7.7 = 0.3846227736544648 +/- 0.006771473023612428
#              pah_strength  pah_strength_unc
# pah_complex
# PAH113_C     2.106990e-19      5.208565e-21
# PAH120       5.274476e-20      2.831340e-21
# PAH126_C     1.072756e-19      3.656524e-21
# PAH136       1.232616e-20      1.720379e-21
# PAH142       0.000000e+00      0.000000e+00
# PAH164       9.552297e-21      7.926729e-22
# PAH170_C     1.487757e-20      2.290471e-21
# PAH33        4.747356e-20      2.642360e-21
# PAH62        1.475878e-19      3.462199e-21
# PAH77_C      5.478069e-19      1.755303e-20
# PAH83        3.863632e-20      3.610172e-21
# PAH86        1.087322e-19      3.472195e-21
# ali34        6.032916e-21      2.734573e-21
# ali345       1.208811e-20      4.178507e-21
