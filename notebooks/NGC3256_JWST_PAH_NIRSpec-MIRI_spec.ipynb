# %%
import os
os._exit(00)

# %%
import sys
sys.path.insert(0, '../')
sys.path.insert(0, '../../CRETA/')

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib widget
import matplotlib.ticker
from matplotlib.backends.backend_pdf import PdfPages

import creta
import cafe_io
from cafe_io import *
import cafe_helper
from cafe_helper import *
import cafe

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# SPECTRAL EXTRACTION

# %%
# Read parameter file with extraction keywords
creta_dir = '../../CRETA/'
param_fn = 'NGC3256_JWST_PAH'
pf = open(creta_dir+'param_files/'+param_fn+'_single_params.txt','r')
print(pf.read())
pf.close()
# Out:
# cubes = g140h, g235h, g395h, ch1-short, ch1-medium, ch1-long, ch2-short, ch2-medium, ch2-long, ch3-short, ch3-medium, ch3-long, ch4-short, ch4-medium, ch4-long
# user_r_ap = 1.0                 # [arcsec] Aperture size
# user_ra = 10h27m51.233s         # RA of the extraction location
# user_dec = -43d54m13.58s         # Dec of the extraction location
# point_source = False            # [True/False] True = Cone extraction. False = Cylinder extraction
# lambda_ap = 5.6                 # [microns] The user-specified aperture size (user_r_ap) will be defined at this wavelength (ignored if point_source=False; cylinder extraction)
# aperture_correction = False     # [True/False]
# centering = True                # [True/False] At lambda_cent, this will update user_ra,user_dec to recenter the extraction location
# lambda_cent = 5.6               # [microns] The wavelength at which to perform the centering (ignored if centering=False)
# background_sub = False          # [True/False]
# r_ann_in = 0.0                  # [arcsec] When background_sub=True, this defines the inner annulus size. This size will NOT scale with aperture size even when point_source=True
# ann_width = 0.0                 # [arcsec] When background_sub=True, this defines the annulus width. This size will NOT scale with aperture size even when point_source=True

# %%
# Load the extraction tool (CRETA)
c = creta.creta(creta_dir)
# Out:
# CAFE Region Extraction Tool Automaton (CRETA) initialized

# %%
# Perform the extraction
c.singleExtraction(parameter_file=True, perband_cent=True, parfile_name=param_fn+'_single_params.txt', data_path='../../CRETA/data/NGC3256/', output_filebase_name=param_fn)
# Out:
# User API Created
# PSFs: ../../CRETA/PSFs/
# Data: ../../CRETA/data/NGC3256/
# ########################################
#      Load User Parameters
# ########################################
# Cubes: ['g140h', 'g235h', 'g395h', 'ch1-short', 'ch1-medium', 'ch1-long', 'ch2-short', 'ch2-medium', 'ch2-long', 'ch3-short', 'ch3-medium', 'ch3-long', 'ch4-short', 'ch4-medium', 'ch4-long']
# Aperture radii: [1.0] (arcsec)
# RA,δ: [156.96347083,-43.90377222] (degrees)
# Point Source: False
# Aperture Correction: False (PSF Correction)
# Centering: True
# Centering lambda: 5.6μm
# Background Subtraction: False
# PSF sub-cubes Path: ../../CRETA/PSFs/
# Data sub-cubes Path: ../../CRETA/data/NGC3256/
# ########################################
# Loading Data
# Load file: ../../CRETA/data/NGC3256/Nuc1_Level3_g140h-f100lp_s3d.fits
# Load file: ../../CRETA/data/NGC3256/Nuc1_Level3_g235h-f170lp_s3d.fits
# Load file: ../../CRETA/data/NGC3256/Nuc1_Level3_g395h-f290lp_s3d.fits
# Load file: ../../CRETA/data/NGC3256/bandcube_ch1-short_s3d.fits
# Load file: ../../CRETA/data/NGC3256/bandcube_ch1-medium_s3d.fits
# Load file: ../../CRETA/data/NGC3256/bandcube_ch1-long_s3d.fits
# Load file: ../../CRETA/data/NGC3256/bandcube_ch2-short_s3d.fits
# Load file: ../../CRETA/data/NGC3256/bandcube_ch2-medium_s3d.fits
# Load file: ../../CRETA/data/NGC3256/bandcube_ch2-long_s3d.fits
# Load file: ../../CRETA/data/NGC3256/bandcube_ch3-short_s3d.fits
# Load file: ../../CRETA/data/NGC3256/bandcube_ch3-medium_s3d.fits
# Load file: ../../CRETA/data/NGC3256/bandcube_ch3-long_s3d.fits
# Load file: ../../CRETA/data/NGC3256/bandcube_ch4-short_s3d.fits
# Load file: ../../CRETA/data/NGC3256/bandcube_ch4-medium_s3d.fits
# Load file: ../../CRETA/data/NGC3256/bandcube_ch4-long_s3d.fits
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# Centering around 5.599600077694049 um in cube ch1_SHORT
# Old coordinates were: 156.96347083 -43.90377222
# New coordinates are: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96347083, -43.90377222)>
# Per-band re-centering around 0.970470936967188 um in cube G140H
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96362735, -43.90396704)>
# Per-band re-centering around 1.660880822023671 um in cube G235H
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.9636233, -43.9039715)>
# Per-band re-centering around 2.871080147861103 um in cube G395H
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96362347, -43.90397215)>
# Per-band re-centering around 4.902000095316907 um in cube ch1_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96343985, -43.90377601)>
# Per-band re-centering around 5.661999847361586 um in cube ch1_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.9634227, -43.90378854)>
# Per-band re-centering around 6.532000209757825 um in cube ch1_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96344883, -43.90377001)>
# Per-band re-centering around 7.513250228890683 um in cube ch2_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96345172, -43.90376817)>
# Per-band re-centering around 8.673250076302793 um in cube ch2_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96345968, -43.90375799)>
# Per-band re-centering around 10.023250457772518 um in cube ch2_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96345216, -43.90375797)>
# Per-band re-centering around 11.556250190595161 um in cube ch3_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96344461, -43.90376452)>
# Per-band re-centering around 13.34625015244819 um in cube ch3_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96344197, -43.90377066)>
# Per-band re-centering around 15.416249847272411 um in cube ch3_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96344439, -43.9037679)>
# Per-band re-centering around 17.71500076306984 um in cube ch4_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96344409, -43.90375402)>
# Per-band re-centering around 20.705000534188 um in cube ch4_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96346714, -43.90374619)>
# Per-band re-centering around 24.205000534188 um in cube ch4_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (156.96339208, -43.90374781)>
# G140H photometry exectued in: 3.5454821586608887 seconds
# G235H photometry exectued in: 3.622296094894409 seconds
# G395H photometry exectued in: 3.188232898712158 seconds
# ch1_SHORT photometry exectued in: 0.9191930294036865 seconds
# ch1_MEDIUM photometry exectued in: 1.0874080657958984 seconds
# ch1_LONG photometry exectued in: 1.2531442642211914 seconds
# ch2_SHORT photometry exectued in: 0.862443208694458 seconds
# ch2_MEDIUM photometry exectued in: 1.0077688694000244 seconds
# ch2_LONG photometry exectued in: 1.1963319778442383 seconds
# ch3_SHORT photometry exectued in: 0.6965079307556152 seconds
# ch3_MEDIUM photometry exectued in: 0.7879190444946289 seconds
# ch3_LONG photometry exectued in: 0.9042751789093018 seconds
# ch4_SHORT photometry exectued in: 0.47826695442199707 seconds
# ch4_MEDIUM photometry exectued in: 0.5597388744354248 seconds
# ch4_LONG photometry exectued in: 0.5570411682128906 seconds
# Photometry exectued in': 20.723783254623413 seconds
# Initiating stitching process
# Stitch ratios: [[0.9708793494172746, 1.0089324820228245, 0.01138360330352382, 0.9600112336451643, 0.9336169196369615, 1.00970883261912, 0.9862095001710748, 0.9786444149345098, 1.002095429613114, 1.007924821464091, 0.9977997452777027, 0.9672345887801213, 0.9800328394959954, 1.0067856400772854, 1.0]]
# For radius 1.0                  arcsec:
# WARNING: r_ap in G395H contains NaNs or/and extends beyond the cube FOV at some wavelength
# Stitching performed in: 2.67041277885437 seconds
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Output written in: 2.193488836288452 seconds
# 1 file output(s) named: NGC3256_JWST_PAH_SingleExt_r1.0as
# {'extraction_RA': <Longitude 156.96347083 deg>, 'extraction_DEC': <Latitude -43.90377222 deg>, 'r_ap': '1.0                 ', 'exrtaction_type': 'extended source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.599600077694049, 'bkg_sub': False, 'bkg_r_in': None, 'bkg_an_w': None}
# /Users/tanio/Sync/pywork/CAFE/CAFE/notebooks/../../CRETA/creta.py:574: ResourceWarning: unclosed file <_io.BufferedReader name='../../CRETA/extractions/NGC3256_JWST_PAH_SingleExt_r1.0as.fits'>
#   user.write_single_fitscube(output_file_name)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Total execution time of single region extraction: 193.26409196853638 seconds

# %%
# CAFE FITTING

# %%
# Setup directories
source_fd = '../../CRETA/extractions/'
source_fn = param_fn+'_SingleExt_r1.0as_cube.fits'
source_fnb = source_fn.split('.fits')[0].replace('.','')

cafe_dir = '../'
inppar_fn = cafe_dir+'inp_parfiles/inpars_jwst_nirspec-miri_NGC3256.ini'
optpar_fn = cafe_dir+'opt_parfiles/default_opt.cafe'

z=0.00937

# %%
s = cafe.specmod(cafe_dir)

# %%
s.read_spec(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ../../CRETA/extractions/NGC3256_JWST_PAH_SingleExt_r1.0as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        36   (22871,)   float64
#   2  ERR           1 ImageHDU         7   (22871,)   float64
#   3  FLUX_ST       1 ImageHDU         7   (22871,)   float64
#   4  ERR_ST        1 ImageHDU         7   (22871,)   float64
#   5  DQ            1 ImageHDU         7   (22871,)   float64
#   6  WAVE          1 ImageHDU         7   (22871,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   22871R x 1C   [20A]

# %%
s.plot_spec_ini(inppar_fn, optpar_fn)
# Out:
# Generating continuum profiles for guess model
# Parameter object has 164 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s.fit_spec(inppar_fn, optpar_fn)
# Out:
# Generating parameter cube with initial/full parameter object
# Parameter object has 226 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Generating parameter object
# Parameter object has 164 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Generating continuum profiles
# ISRF
# ISRF
# 2.54 seconds to make continnum profiles
# Fitting 628 parameters
# Iteration 1/5(max): 2023-01-17 15:09:41.025929 -----------------
# True in 38 steps
# 485.11 seconds elapsed
# <Parameter 'HOT_TAU', value=6.660207557554863e-10 +/- 0.153, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_COV', value=0.9999999999999605 +/- 0.113, bounds=[0.0:1.0]> at upper bound, fixing to  1.0
# <Parameter 'STB_010', value=0.999999999864207 +/- 3.53, bounds=[0.0:1.0]> at upper bound, fixing to  1.0
# <Parameter 'g_OI_11290B_Gamma', value=0.0004202189874066238 +/- 25.8, bounds=[0.00042021898629552397:0.0066711140760507]> at lower bound, fixing to 0.00042021898629552397
# <Parameter 'g_OI_11290B_Peak', value=2.3395219658560345e-07 +/- 0.0205, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_HeII75_11630N_Peak', value=9.446845673379158e-13 +/- 0.00528, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_HeII116_11676N_Peak', value=2.6631750945745946e-13 +/- 0.00521, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_HeII96_14764N_Peak', value=3.739054852063354e-14 +/- 0.00791, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Brackett204_15196N_Peak', value=4.72422366784686e-16 +/- 0.0086, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Brackett194_15265N_Peak', value=9.652087071423162e-15 +/- 0.00874, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Brackett164_15561N_Peak', value=2.66710056568593e-14 +/- 0.00936, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Brackett124_16412B_Wave', value=1.6439071080719292 +/- 0.000221, bounds=[1.638432891927952:1.643907108072048]> at upper bound, fixing to 1.643907108072048
# <Parameter 'g_Brackett114_16811N_Peak', value=3.8174471653279626e-11 +/- 0.0441, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Brackett64_26259N_Peak', value=5.999973091331869e-11 +/- 0.0452, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O2_26269N_Peak', value=3.1478299122109314e-08 +/- 0.0279, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O3_28025N_Peak', value=1.5477177344070336e-10 +/- 0.0379, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O3_29741B_Gamma', value=0.00026665878315802066 +/- 0.00459, bounds=[0.0002666572973103568:0.0066711140760507]> at lower bound, fixing to 0.0002666572973103568
# <Parameter 'g_H221O4_31899N_Peak', value=2.4645817336007084e-10 +/- 0.0717, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O4_31899B_Gamma', value=0.0004264746041696888 +/- 0.00939, bounds=[0.0004264746041692351:0.0066711140760507]> at lower bound, fixing to 0.0004264746041692351
# <Parameter 'g_CaIV_32067N_Peak', value=7.69561754152392e-18 +/- 0.00406, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_
bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO12ice_46000_Wave', value=4.5923281236041635 +/- 0.0263, bounds=[4.592328123604162:4.607671685660975]> at lower bound, fixing to 4.592328123604162
# <Parameter 'o_CO12ice_46000_Gamma', value=0.023333334053560504 +/- 0.014, bounds=[0.023333334053556126:0.03360000103712082]> at lower bound, fixing to 0.023333334053556126
# <Parameter 'o_CO13ice_46822_Gamma', value=0.0014166694378912293 +/- 1.17e+03, bounds=[0.0014166666854483387:0.0020400000270456077]> at lower bound, fixing to 0.0014166666854483387
# <Parameter 'o_CO13ice_46822_Peak', value=2.0056326050294144e-07 +/- 0.139, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'HOT_TAU', value=6.660207557554863e-10 +/- 0.153, bounds=[0.0:inf]> unconstrained at 22923061694.275974 % error. Fixing value.
# <Parameter 'STB_010', value=0.999999999864207 +/- 3.53, bounds=[0.0:1.0]> unconstrained at 352.6493544699481 % error. Fixing value.
# <Parameter 'g_HeII54_10126N_Peak', value=7.48776223660637e-05 +/- 0.0274, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_HeII54_10126B_Gamma', value=0.00048423593705617133 +/- 0.0366, bounds=[0.0004705913878740317:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_HeII54_10126B_Peak', value=0.0002191410353939822 +/- 0.0178, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Paschen63_10941N_Peak', value=0.0018646385397890436 +/- 0.0476, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_OI_11290N_Peak', value=0.00034411425761373326 +/- 0.0308, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_OI_11290B_Wave', value=1.1292356218829607 +/- 21, bounds=[1.1271170780520348:1.1308829219479652]> unconstrained, fixing entire feature
# <Parameter 'g_OI_11290B_Gamma', value=0.0004202189874066238 +/- 25.8, bounds=[0.00042021898629552397:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_OI_11290B_Peak', value=2.3395219658560345e-07 +/- 0.0205, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_OI_11290B_Peak', value=2.3395219658560345e-07 +/- 0.0205, bounds=[0.0:inf]> lower than uncertainty 1.868054543638764e-05 , fixing to 0.0
# <Parameter 'g_HeII75_11630N_Peak', value=9.446845673379158e-13 +/- 0.00528, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_HeII75_11630N_Peak', value=9.446845673379158e-13 +/- 0.00528, bounds=[0.0:inf]> lower than uncertainty 1.8441013254352973e-05 , fixing to 0.0
# <Parameter 'g_HeII116_11676N_Peak', value=2.6631750945745946e-13 +/- 0.00521, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_HeII116_11676N_Peak', value=2.6631750945745946e-13 +/- 0.00521, bounds=[0.0:inf]> lower than uncertainty 1.815342271742707e-05 , fixing to 0.0
# <Parameter 'g_HeII96_14764N_Peak', value=3.739054852063354e-14 +/- 0.00791, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_HeII96_14764N_Peak', value=3.739054852063354e-14 +/- 0.00791, bounds=[0.0:inf]> lower than uncertainty 3.215905571183839e-05 , fixing to 0.0
# <Parameter 'g_Brackett204_15196N_Peak', value=4.72422366784686e-16 +/- 0.0086, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_
bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys206_36070N_Peak', value=6.976329483031361e-13 +/- 0.00387, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys206_36070N_Peak', value=6.976329483031361e-13 +/- 0.00387, bounds=[0.0:inf]> lower than uncertainty 2.3814457108644074e-05 , fixing to 0.0
# <Parameter 'g_H200S15_36250N_Peak', value=1.9293873867425585e-13 +/- 0.00387, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S15_36250N_Peak', value=1.9293873867425585e-13 +/- 0.00387, bounds=[0.0:inf]> lower than uncertainty 2.3957093472474645e-05 , fixing to 0.0
# <Parameter 'g_Humphreys196_36459N_Peak', value=1.5447082291273033e-12 +/- 0.00382, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys196_36459N_Peak', value=1.5447082291273033e-12 +/- 0.00382, bounds=[0.0:inf]> lower than uncertainty 2.3675534582335755e-05 , fixing to 0.0
# <Parameter 'g_H232O5_36630N_Peak', value=2.1682339269903757e-13 +/- 0.00381, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O5_36630N_Peak', value=2.1682339269903757e-13 +/- 0.00381, bounds=[0.0:inf]> lower than uncertainty 2.366551836277393e-05 , fixing to 0.0
# <Parameter 'g_Humphreys186_36926N_Peak', value=0.0006595688257849011 +/- 0.00388, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund85_37406N_Peak', value=0.0031859414601236964 +/- 0.019, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O6_39721N_Peak', value=0.01405048969048503 +/- 0.0423, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaV_41594N_Peak', value=0.000279621210822378 +/- 0.00526, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O8_41625N_Peak', value=0.0005220270542031444 +/- 0.00532, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=5.03156507584863e-15 +/- 0.0069, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=5.03156507584863e-15 +/- 0.0069, bounds=[0.0:inf]> lower than uncertainty 4.2536776916506024e-05 , fixing to 0.0
# <Parameter 'g_NaVII_46847N_Peak', value=0.00020886828471572487 +/- 0.00653, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=0.0031185207059936477 +/- 0.00783, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys106_51287N_Peak', value=5.759836597619577e-09 +/- 0.0394, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys106_51287N_Peak', value=5.759836597619577e-09 +/- 0.0394, bounds=[0.0:inf]> lower than uncertainty 6.304666142844925e-05 , fixing to 0.0
# <Parameter 'g_Humphreys106_51287B_Peak', value=0.01376141699364738 +/- 0.0331, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066N_Peak', value=0.0030507489719146224 +/- 0.0218, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S6_61088N_Peak', value=1.7017266023848e-12 +/- 0.0114, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S6_61088N_Peak', value=1.7017266023848e-12 +/- 0.0114, bounds=[0.0:inf]> lower than uncertainty 8.126634412976721e-05 , fixing to 0.0
# <Parameter 'g_NaIII_73177N_Peak', value=5.020839137038468e-12 +/- 0.0138, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIII_73177N_Peak', value=5.020839137038468e-12 +/- 0.0138, bounds=[0.0:inf]> lower than uncertainty 0.00010991540850434399 , fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=4.331247020145789e-09 +/- 0.0485, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=4.331247020145789e-09 +/- 0.0485, bounds=[0.0:inf]> lower than uncertainty 0.00014438223324470385 , fixing to 0.0
# <Parameter 'g_Humphreys86_75005N_Peak', value=0.006901191634077897 +/- 0.05, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_79016N_Peak', value=0.008782580453065148 +/- 0.0212, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys76_123680N_Peak', value=2.4675698301047554e-14 +/- 0.0502, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys76_123680N_Peak', value=2.4675698301047554e-14 +/- 0.0502, bounds=[0.0:inf]> lower than uncertainty 0.00013058397996195298 , fixing to 0.0
# <Parameter 'g_ArV_131022N_Peak', value=9.329350903767955e-14 +/- 0.0221, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_131022N_Peak', value=9.329350903767955e-14 +/- 0.0221, bounds=[0.0:inf]> lower than uncertainty 0.0001413776824403508 , fixing to 0.0
# <Parameter 'g_OIV_258903N_Peak', value=1.4854018611573596e-15 +/- 0.138, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_OIV_258903N_Peak', value=1.4854018611573596e-15 +/- 0.138, bounds=[0.0:inf]> lower than uncertainty 0.0011406133950956697 , fixing to 0.0
# <Parameter 'd20_PAH30_30100_Peak', value=0.0005890720849249128 +/- 0.00154, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=9.465274730101526e-14 +/- 0.00495, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=9.465274730101526e-14 +/- 0.00495, bounds=[0.0:inf]> lower than uncertainty 0.00014500524970697566 , fixing to 0.0
# <Parameter 'o_CO11ice_43810_Wave', value=4.3736935041998946 +/- 1.13e+16, bounds=[4.373693504199893:4.388306579723447]> unconstrained, fixing entire feature
# <Parameter 'o_CO11ice_43810_Gamma', value=0.08333333457509678 +/- 2.58e+15, bounds=[0.08333333457509677:0.12000000178813934]> unconstrained, fixing entire feature
# <Parameter 'o_CO11ice_43810_Peak', value=2.1585658472487841e-13 +/- 0.019, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO11ice_43810_Peak', value=2.1585658472487841e-13 +/- 0.019, bounds=[0.0:1.0]> lower than uncertainty 3.581409224489345e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Wave', value=4.67462140975095 +/- 2.22e+03, bounds=[4.674391082479923:4.690008827493221]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Gamma', value=0.0014166694378912293 +/- 1.17e+03, bounds=[0.0014166666854483387:0.0020400000270456077]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=2.0056326050294144e-07 +/- 0.139, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=2.0056326050294144e-07 +/- 0.139, bounds=[0.0:1.0]> lower than uncertainty 4.344166716236989e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------

# %%
# Line and PAH averaged velocity gradient wrt z, in [km/s]
print(s.parcube['VALUE'].data[-1,0,0])
print(s.parcube['VALUE'].data[-1,0,0]/2.998e5)
# Out:
# 1.1974197887791702
# 3.99406200393319e-06

# %%
s.plot_spec_fit(inppar_fn, optpar_fn)
# Out:
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Load the parameter cube from drive
parcube_fd = '../CAFE/output/'+source_fnb+'/'
parcube_fn = source_fnb+'_parcube.fits'

# %%
s.read_spec(source_fn, file_dir=source_fd, z=z)
# Out:
# Load data: ../CRETA/extractions/IIZw096_SingleExt_r0.3as_cube.fits
# Filename: ../CRETA/extractions/IIZw096_SingleExt_r0.3as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        36   (22873,)   float64
#   2  ERR           1 ImageHDU         7   (22873,)   float64
#   3  FLUX_ST       1 ImageHDU         7   (22873,)   float64
#   4  ERR_ST        1 ImageHDU         7   (22873,)   float64
#   5  DQ            1 ImageHDU         7   (22873,)   float64
#   6  WAVE          1 ImageHDU         7   (22873,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   22873R x 1C   [20A]

# %%
s.read_parcube_file(parcube_fn, file_dir=parcube_fd)
# Out:
# Filename: ../CAFE/output/IIZw096_SingleExt_r03as_cube/IIZw096_SingleExt_r03as_cube_parcube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  VALUE         1 ImageHDU        38   (1, 1, 661)   float64
#   2  STDERR        1 ImageHDU        38   (1, 1, 661)   float64
#   3  VARY          1 ImageHDU        38   (1, 1, 661)   float64
#   4  MIN           1 ImageHDU        38   (1, 1, 661)   float64
#   5  MAX           1 ImageHDU        38   (1, 1, 661)   float64
#   6  EXPR          1 BinTableHDU     13   661R x 2C   [I, 24A]
#   7  PARNAME       1 BinTableHDU     13   661R x 2C   [I, 32A]

# %%
from astropy.io import ascii
from astropy.table import Table
from astropy.table import QTable

# Read output PAH table
pah = cafeio.pah_table(s.parcube, 0, 0)
# Read output line table
line = cafeio.line_table(s.parcube, 0, 0)

pah62 = pah[pah.index == 'PAH62'].pah_strength.values[0]
pah62_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah77 = pah[pah.index == 'PAH77_C'].pah_strength.values[0]
pah77_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah113 = pah[pah.index == 'PAH113_C'].pah_strength.values[0]
pah113_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]

x = pah62 / pah77 
x_unc = pah62 / pah77 * np.sqrt((pah62_unc/pah62)**2 + (pah77_unc/pah77)**2)
y = pah113 / pah77
y_unc = pah113 / pah77 * np.sqrt((pah113_unc/pah113)**2 + (pah77_unc/pah77)**2)

print('6.2/7.7 = {} +/- {}'.format(x, x_unc))
print('11.3/7.7 = {} +/- {}'.format(y, y_unc))

print(pah)

# Make an astropy table 
t = QTable([pah.index.values, pah.pah_strength, pah.pah_strength_unc],
           names = ('pah_complex', 'pah_strength', 'pah_strength_unc'),
           meta={'wavelength': 'micron',
                 'flux': 'W/m^2',
                }
          )

# Write PAH table in an .ecsv file
#t.write('./NGC7469_pah_tbl.ecsv', overwrite=False)
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 6.2/7.7 = 0.15948781487926658 +/- 0.0031868275085701115
# 11.3/7.7 = 0.1088119424851446 +/- 0.003165629837104753
#              pah_strength  pah_strength_unc
# pah_complex
# PAH113_C     1.662026e-19      1.188710e-20
# PAH120       3.909301e-19      9.583194e-21
# PAH126_C     1.227071e-18      1.686315e-20
# PAH136       4.660945e-19      7.598355e-21
# PAH142       1.058069e-19      6.443677e-21
# PAH164       0.000000e+00      0.000000e+00
# PAH170_C     8.027622e-19      2.300560e-20
# PAH33        9.455213e-20      2.401250e-21
# PAH62        2.436064e-19      4.806904e-21
# PAH77_C      1.527430e-18      4.073222e-20
# PAH83        0.000000e+00      0.000000e+00
# PAH86        1.908567e-20      5.671144e-21
# ali34        9.270681e-21      2.196371e-21
# ali345       2.194231e-20      3.405685e-21
