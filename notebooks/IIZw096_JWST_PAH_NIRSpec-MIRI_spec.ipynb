# %%
import os
os._exit(00)

# %%
import sys
sys.path.insert(0, '../')
sys.path.insert(0, '../../CRETA/')

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib widget
import matplotlib.ticker
from matplotlib.backends.backend_pdf import PdfPages

import creta
import cafe_io
from cafe_io import *
import cafe_helper
from cafe_helper import *
import cafe

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# User API Created
# <style>.container { width:100% !important; }</style>

# %%
# SPECTRAL EXTRACTION

# %%
# Read parameter file with extraction keywords
creta_dir = '../../CRETA/'
param_fn = 'IIZw096_JWST_PAH'
pf = open(creta_dir+'param_files/'+param_fn+'_single_params.txt','r')
print(pf.read())
pf.close()
# Out:
# cubes = g395h, ch1-short, ch1-medium, ch1-long, ch2-short, ch2-medium, ch2-long, ch3-short, ch3-medium, ch3-long
# user_r_ap = 0.3                 # [arcsec] Aperture size
# user_ra = 20h57m24.368s         # RA of the extraction location
# user_dec = 17d07m39.21s         # Dec of the extraction location
# point_source = False            # [True/False] True = Cone extraction. False = Cylinder extraction
# lambda_ap = 5.4                 # [microns] The user-specified aperture size (user_r_ap) will be defined at this wavelength (ignored if point_source=False; cylinder extraction)
# aperture_correction = False     # [True/False]
# centering = True                # [True/False] At lambda_cent, this will update user_ra,user_dec to recenter the extraction location
# lambda_cent = 5.4               # [microns] The wavelength at which to perform the centering (ignored if centering=False)
# background_sub = False          # [True/False]
# r_ann_in = 0.0                  # [arcsec] When background_sub=True, this defines the inner annulus size. This size will NOT scale with aperture size even when point_source=True
# ann_width = 0.0                 # [arcsec] When background_sub=True, this defines the annulus width. This size will NOT scale with aperture size even when point_source=True

# %%
# Load the extraction tool (CRETA)
c = creta.creta(creta_dir)
# Out:
# CAFE Region Extraction Tool Automaton (CRETA) initialized

# %%
# Perform the extraction
c.singleExtraction(parameter_file=True, parfile_name=param_fn+'_single_params.txt', data_path='../../CRETA/data/IIZw096/', output_filebase_name=param_fn)
# Out:
# User API Created
# PSFs: ../../CRETA/PSFs/
# Data: ../../CRETA/data/IIZw096/
# ########################################
#      Load User Parameters
# ########################################
# Cubes: ['g395h', 'ch1-short', 'ch1-medium', 'ch1-long', 'ch2-short', 'ch2-medium', 'ch2-long', 'ch3-short', 'ch3-medium', 'ch3-long']
# Aperture radii: [0.3] (arcsec)
# RA,δ: [314.35153333,17.12755833] (degrees)
# Point Source: False
# Aperture Correction: False (PSF Correction)
# Centering: True
# Centering lambda: 5.4μm
# Background Subtraction: False
# PSF sub-cubes Path: ../../CRETA/PSFs/
# Data sub-cubes Path: ../../CRETA/data/IIZw096/
# ########################################
# Loading Data
# Load file: ../../CRETA/data/IIZw096/Level3_g395h-f290lp_s3d_WCScorr.fits
# Load file: ../../CRETA/data/IIZw096/Level3_bandcube_ch1-short_s3d.fits
# Load file: ../../CRETA/data/IIZw096/Level3_bandcube_ch1-medium_s3d.fits
# Load file: ../../CRETA/data/IIZw096/Level3_bandcube_ch1-long_s3d.fits
# Load file: ../../CRETA/data/IIZw096/Level3_bandcube_ch2-short_s3d.fits
# Load file: ../../CRETA/data/IIZw096/Level3_bandcube_ch2-medium_s3d.fits
# Load file: ../../CRETA/data/IIZw096/Level3_bandcube_ch2-long_s3d.fits
# Load file: ../../CRETA/data/IIZw096/Level3_bandcube_ch3-short_s3d.fits
# Load file: ../../CRETA/data/IIZw096/Level3_bandcube_ch3-medium_s3d.fits
# Load file: ../../CRETA/data/IIZw096/Level3_bandcube_ch3-long_s3d.fits
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# Centering around 5.399600082746474 um in cube ch1_SHORT
# Old coordinates were: 314.35153333 17.12755833
# New coordinates are: <SkyCoord (ICRS): (ra, dec) in deg
#     (314.35153333, 17.12755833)>
# G395H photometry exectued in: 3.617079973220825 seconds
# ch1_SHORT photometry exectued in: 1.0445477962493896 seconds
# ch1_MEDIUM photometry exectued in: 1.2439749240875244 seconds
# ch1_LONG photometry exectued in: 1.4116499423980713 seconds
# ch2_SHORT photometry exectued in: 0.9287900924682617 seconds
# ch2_MEDIUM photometry exectued in: 1.0663440227508545 seconds
# ch2_LONG photometry exectued in: 1.2117071151733398 seconds
# ch3_SHORT photometry exectued in: 0.7465488910675049 seconds
# ch3_MEDIUM photometry exectued in: 0.8113000392913818 seconds
# ch3_LONG photometry exectued in: 0.9475572109222412 seconds
# Photometry exectued in': 13.071043968200684 seconds
# Initiating stitching process
# Stitch ratios: [[0.008990612850224596, 0.9763015026589322, 1.0119086030642697, 0.9244633762193476, 0.9679603051700624, 1.0504209066788517, 0.8932539238556843, 0.9989926575893733, 0.9714468703321787, 1.0]]
# For radius 0.3                  arcsec:
# Stitching performed in: 1.3845901489257812 seconds
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Output written in: 2.2869699001312256 seconds
# 1 file output(s) named: IIZw096_JWST_PAH_SingleExt_r0.3as
# {'extraction_RA': <Longitude 314.35153333 deg>, 'extraction_DEC': <Latitude 17.12755833 deg>, 'r_ap': '0.3                 ', 'exrtaction_type': 'extended source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399600082746474, 'bkg_sub': False, 'bkg_r_in': None, 'bkg_an_w': None}
# /Users/tanio/Sync/pywork/CAFE/CAFE/notebooks/../../CRETA/creta.py:574: ResourceWarning: unclosed file <_io.BufferedReader name='../../CRETA/extractions/IIZw096_JWST_PAH_SingleExt_r0.3as.fits'>
#   user.write_single_fitscube(output_file_name)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Total execution time of single region extraction: 29705.245645046234 seconds

# %%
# CAFE FITTING

# %%
# Setup directories
source_fd = '../../CRETA/extractions/'
source_fn = param_fn+'_SingleExt_r0.3as_cube.fits'
source_fnb = source_fn.split('.fits')[0].replace('.','')

cafe_dir = '../'
inppar_fn = cafe_dir+'inp_parfiles/inpars_jwst_nirspec-miri_SB.ini'
optpar_fn = cafe_dir+'opt_parfiles/default_opt.cafe'

z=0.03637

# %%
s = cafe.specmod(cafe_dir)

# %%
s.read_spec(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ../../CRETA/extractions/IIZw096_JWST_PAH_SingleExt_r0.3as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        36   (13349,)   float64
#   2  ERR           1 ImageHDU         7   (13349,)   float64
#   3  FLUX_ST       1 ImageHDU         7   (13349,)   float64
#   4  ERR_ST        1 ImageHDU         7   (13349,)   float64
#   5  DQ            1 ImageHDU         7   (13349,)   float64
#   6  WAVE          1 ImageHDU         7   (13349,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   13349R x 1C   [20A]

# %%
s.plot_spec_ini(inppar_fn, optpar_fn)
# Out:
# Generating continuum profiles for guess model
# Parameter object has 92 lines, 25 PAHs, 5 opacity features, and 42 continuum parameters
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s.fit_spec(inppar_fn, optpar_fn)
# Out:
# Generating parameter cube with initial/full parameter object
# Parameter object has 113 lines, 25 PAHs, 5 opacity features, and 42 continuum parameters
# Generating parameter object
# Parameter object has 92 lines, 25 PAHs, 5 opacity features, and 42 continuum parameters
# Generating continuum profiles
# ISRF
# ISRF
# 2.37 seconds to make continnum profiles
# Fitting 400 parameters
# Iteration 1/5(max): 2023-01-16 23:10:40.997418 -----------------
# True in 34 steps
# 173.19 seconds elapsed
# No errors retuned
# <Parameter 'COO_TAU', value=2.2872186702894236e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_TAU', value=6.7321764924774875e-09, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_COV', value=0.999999972822858, bounds=[0.0:1.0]> at upper bound, fixing to  1.0
# <Parameter 'STB_010', value=1.433343548257771e-13, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'g_H221O2_27862B_Gamma', value=0.006671113966453239, bounds=[0.00027778290297371844:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_H221O4_31899B_Gamma', value=0.00041417995939458687, bounds=[0.0004141799566755615:0.0066711140760507]> at lower bound, fixing to 0.0004141799566755615
# <Parameter 'g_H221O7_40540N_Peak', value=9.812001678581268e-25, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_40819N_Peak', value=2.932669912627371e-16, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=6.2649275166332325e-18, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaV_41594N_Peak', value=2.6571695649399223e-16, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O8_41625N_Peak', value=3.3026440213435867e-15, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H210O8_41625B_Wave', value=4.169442128063462, bounds=[4.15555787191461:4.1694421280853895]> at upper bound, fixing to 4.1694421280853895
# <Parameter 'g_H210O8_41625B_Gamma', value=0.00030969291345186436, bounds=[0.0003096929134518515:0.0066711140760507]> at lower bound, fixing to 0.0003096929134518515
# <Parameter 'g_Humphreys106_51287N_Peak', value=1.6068435273462896e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys106_51287B_Wave', value=5.128639800799013, bounds=[5.120096547698466:5.137203452301534]> at initial value 5.12865 . Fixing value.
# <Parameter 'g_Humphreys96_59066B_Gamma', value=0.0002759245521443454, bounds=[0.00027592455141674965:0.0066711140760507]> at lower bound, fixing to 0.00027592455141674965
# <Parameter 'g_ArV_79016N_Peak', value=3.0030234807659025e-20, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys76_123680B_Wave', value=12.347372915288304, bounds=[12.347372915276852:12.388627084723149]> at lower bound, fixing to 12.347372915276852
# <Parameter 'g_Humphreys76_123680B_Gamma', value=0.0066711140759360835, bounds=[0.0003461561117959755:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'd6_PAH83_83300_Peak', value=1.8025042133487035e-15, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=1.020506272255323e-12, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=4.470366985326366e-15, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=2.2048693299758788e-17, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH164_164500_Peak', value=1.9952966915387305e-15, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_H2Oice_30500_Wave', value=3.055086676456868, bounds=[3.0449132279128213:3.055086676719747]> at upper bound, fixing to 3.055086676719747
# <Parameter 'o_H2Oice_30500_Gamma', value=0.09999999806426664, bounds=[0.09999999776482582:0.14399999678134917]> at lower bound, fixing to 0.09999999776482582
# <Parameter 'o_CO2ice_42722_Wave', value=4.265075024006145, bounds=[4.265075024006126:4.279325191142799]> at lower bound, fixing to 4.265075024006126
# <Parameter 'o_CO11ice_43810_Wave', value=4.373693504199894, bounds=[4.373693504199893:4.388306579723447]> at lower bound, fixing to 4.373693504199893
# <Parameter 'o_CO11ice_43810_Gamma', value=0.08333333457509678, bounds=[0.08333333457509677:0.12000000178813934]> at lower bound, fixing to 0.08333333457509677
# <Parameter 'o_CO12ice_46000_Wave', value=4.592328123604168, bounds=[4.592328123604162:4.607671685660975]> at lower bound, fixing to 4.592328123604162
# <Parameter 'o_CO12ice_46000_Gamma', value=0.02333333405355615, bounds=[0.023333334053556126:0.03360000103712082]> at lower bound, fixing to 0.023333334053556126
# <Parameter 'o_CO12ice_46000_Peak', value=8.552271590985381e-14, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Wave', value=4.67439303363844, bounds=[4.674391082479923:4.690008827493221]> at lower bound, fixing to 4.674391082479923
# <Parameter 'o_CO13ice_46822_Gamma', value=0.0014166666854483992, bounds=[0.0014166666854483387:0.0020400000270456077]> at lower bound, fixing to 0.0014166666854483387
# <Parameter 'o_CO13ice_46822_Peak', value=3.707961918567693e-14, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# Rerunning fit
# Iteration 2/5(max): 2023-01-16 23:13:34.453036 -----------------
# True in 6 steps
# 22.78 seconds elapsed
# <Parameter 'g_Pfund65_74578B_Gamma', value=0.006671114040155595 +/- 0.00114, bounds=[0.00026406733481945227:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_H221O2_27862B_Peak', value=0.00011502126432548965 +/- 0.000282, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund115_28730N_Peak', value=0.0011541486394801436 +/- 0.00361, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O2_29620N_Peak', value=0.00032786615431303756 +/- 0.000995, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O3_29741N_Peak', value=0.0003305691397097014 +/- 0.00199, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=0.0002679267556874487 +/- 0.00114, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_HeII76_30917N_Peak', value=0.00029986851140659763 +/- 0.000762, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899N_Peak', value=0.00038697587799948135 +/- 0.00115, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O4_31899B_Peak', value=0.00011517487496836804 +/- 0.000935, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=0.0002967558003203519 +/- 0.000736, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund95_32970N_Peak', value=0.002134386829979581 +/- 0.00453, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H232O4_33958N_Peak', value=0.000316573141968039 +/- 0.000859, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379N_Peak', value=0.000283593084769914 +/- 0.00257, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H221O5_34379B_Peak', value=0.0006727934438934942 +/- 0.00199, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=9.110253669601968e-05 +/- 0.000842, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O6_35007N_Peak', value=0.0006383375628073272 +/- 0.00422, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O6_35007B_Peak', value=0.0008226911133453434 +/- 0.00337, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210O7_38075N_Peak', value=0.0006853420184510213 +/- 0.00236, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys96_59066N_Peak', value=0.000929900348456404 +/- 0.00323, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys86_75005N_Peak', value=0.0022546782282425125 +/- 0.00655, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys76_123680N_Peak', value=0.0022275913230660254 +/- 0.00723, bounds=[0.0:inf]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# ISRF
# ISRF
# ---------------------------------------------------------------------------
# RepresenterError                          Traceback (most recent call last)
# Input In [57], in <cell line: 1>()
# ----> 1 s.fit_spec(inppar_fn, optpar_fn)
#
# File ~/Sync/pywork/CAFE/CAFE/notebooks/../cafe.py:575, in specmod.fit_spec(self, inparfile, optfile, ini_parcube, cont_profs)
#     573 parcube.writeto(outPath+source_fn+'_parcube.fits', overwrite=True)
#     574 # Save .asdf to disk
# --> 575 self.save_asdf(inparfile, optfile, file_name=source_fn)
#     577 return self
#
# File ~/Sync/pywork/CAFE/CAFE/notebooks/../cafe.py:726, in specmod.save_asdf(self, inparfile, optfile, asdf, pah_tbl, line_tbl, file_name)
#     724 # Save output result to .asdf file
#     725 target = AsdfFile(cafefit)
# --> 726 target.write_to(file_name+'.asdf')
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/asdf/asdf.py:1296, in AsdfFile.write_to(self, fd, all_array_storage, all_array_compression, pad_blocks, include_block_index, version, compression_kwargs, **kwargs)
#    1292 self._pre_write(fd, all_array_storage, all_array_compression,
#    1293                 compression_kwargs=compression_kwargs)
#    1295 try:
# -> 1296     self._serial_write(fd, pad_blocks, include_block_index)
#    1297     fd.flush()
#    1298 finally:
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/asdf/asdf.py:1053, in AsdfFile._serial_write(self, fd, pad_blocks, include_block_index)
#    1052 def _serial_write(self, fd, pad_blocks, include_block_index):
# -> 1053     self._write_tree(self._tree, fd, pad_blocks)
#    1054     self.blocks.write_internal_blocks_serial(fd, pad_blocks)
#    1055     self.blocks.write_external_blocks(fd.uri, pad_blocks)
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/asdf/asdf.py:1022, in AsdfFile._write_tree(self, tree, fd, pad_blocks)
#    1019         else:
#    1020             tagged_tree.pop('history', None)
# -> 1022     yamlutil.dump_tree(
#    1023         tree, fd, self, tree_finalizer=_tree_finalizer,
#    1024         _serialization_context=serialization_context
#    1025     )
#    1027 if pad_blocks:
#    1028     padding = util.calculate_padding(
#    1029         fd.tell(), pad_blocks, fd.block_size)
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/asdf/yamlutil.py:408, in dump_tree(tree, fd, ctx, tree_finalizer, _serialization_context)
#     405             if key not in tags:
#     406                 tags[key] = val
# --> 408 yaml.dump_all(
#     409     [tree], stream=fd, Dumper=AsdfDumper,
#     410     explicit_start=True, explicit_end=True,
#     411     version=yaml_version,
#     412     allow_unicode=True, encoding='utf-8',
#     413     tags=tags)
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/yaml/__init__.py:241, in dump_all(documents, stream, Dumper, default_style, default_flow_style, canonical, indent, width, allow_unicode, line_break, encoding, explicit_start, explicit_end, version, tags, sort_keys)
#     239     dumper.open()
#     240     for data in documents:
# --> 241         dumper.represent(data)
#     242     dumper.close()
#     243 finally:
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/yaml/representer.py:27, in BaseRepresenter.represent(self, data)
#      26 def represent(self, data):
# ---> 27     node = self.represent_data(data)
#      28     self.serialize(node)
#      29     self.represented_objects = {}
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/asdf/yamlutil.py:48, in AsdfDumper.represent_data(self, data)
#      47 def represent_data(self, data):
# ---> 48     node = super(AsdfDumper, self).represent_data(data)
#      50     tag_name = getattr(data, '_tag', None)
#      51     if tag_name is not None:
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/yaml/representer.py:58, in BaseRepresenter.represent_data(self, data)
#      56     node = self.yaml_multi_representers[None](self, data)
#      57 elif None in self.yaml_representers:
# ---> 58     node = self.yaml_representers[None](self, data)
#      59 else:
#      60     node = ScalarNode(None, str(data))
#
# File /usr/local/anaconda3/lib/python3.8/site-packages/yaml/representer.py:231, in SafeRepresenter.represent_undefined(self, data)
#     230 def represent_undefined(self, data):
# --> 231     raise RepresenterError("cannot represent an object", data)
#
# RepresenterError: ('cannot represent an object', {'cafefit': {'obsspec': {'wave': array([ 2.76934656,  2.76998822,  2.77062988, ..., 17.34298541,
#        17.34539768, 17.34780994]), 'flux': array([0.00049464, 0.00052485, 0.00050316, ..., 0.09768507, 0.09793548,
#        0.0992432 ]), 'flux_unc': array([3.11446694e-06, 1.95642381e-06, 1.82735371e-06, ...,
#        4.14179837e-05, 4.08604123e-05, 4.08502790e-05])}, 'fitPars': {'CIR_FLX': <Parameter 'CIR_FLX', value=0.0 (fixed), bounds=[0.0:2.0]>, 'CIR_TMP': <Parameter 'CIR_TMP', value=3.74 (fixed), bounds=[0.0:inf]>, 'CLD_FLX': <Parameter 'CLD_FLX', value=0.0 (fixed), bounds=[0.0:2.0]>, 'CLD_TMP': <Parameter 'CLD_TMP', value=6.89 (fixed), bounds=[0.0:inf]>, 'COO_FLX': <Parameter 'COO_FLX', value=0.7618523893525315 +/- 0.00502, bounds=[0.0:2.0]>, 'COO_TMP': <Parameter 'COO_TMP', value=40.96214939037471 +/- 0.389, bounds=[0.0:inf]>, 'COO_TAU': <Parameter 'COO_TAU', value=0.0 (fixed), bounds=[0.0:inf]>, 'COO_MIX': <Parameter 'COO_MIX', value=0.0 (fixed), bounds=[0.0:1.0]>, 'COO_COV': <Parameter 'COO_COV', value=1.0 (fixed), bounds=[0.0:1.0]>, 'WRM_FLX': <Parameter 'WRM_FLX', value=0.5340419591812796 +/- 0.00344, bounds=[0.0:2.0]>, 'WRM_TMP': <Parameter 'WRM_TMP', value=70.46801232418031 +/- 0.676, bounds=[0.0:inf]>, 'WRM_TAU': <Parameter 'WRM_TAU', value=10.980398089204055 +/- 0.118, bounds=[0.0:inf]>, 'WRM_MIX': <Parameter 'WRM_MIX', value=0.0 (fixed), bounds=[0.0:1.0]>, 'WRM_COV': <Parameter 'WRM_COV', value=1.0 (fixed), bounds=[0.0:1.0]>, 'HOT_FLX': <Parameter 'HOT_FLX', value=0.5802875461342809 +/- 0.00774, bounds=[0.0:2.0]>, 'HOT_TMP': <Parameter 'HOT_TMP', value=188.10678873811844 +/- 1.88, bounds=[100.0:1027.2]>, 'HOT_TAU': <Parameter 'HOT_TAU', value=2.068269984069815 +/- 0.0486, bounds=[0.0:inf]>, 'HOT_MIX': <Parameter 'HOT_MIX', value=0.0 (fixed), bounds=[0.0:1.0]>, 'HOT_COV': <Parameter 'HOT_COV', value=1.0 (fixed), bounds=[0.0:1.0]>, 'STR_FLX': <Parameter 'STR_FLX', value=0.0 (fixed), bounds=[0.0:2.0]>, 'STR_TAU': <Parameter 'STR_TAU', value=0.0 (fixed), bounds=[0.0:inf]>, 'STR_MIX': <Parameter 'STR_MIX', value=1.0 (fixed), bounds=[0.0:1.0]>, 'STR_COV': <Parameter 'STR_COV', value=1.0 (fixed), bounds=[0.0:1.0]>, 'STB_FLX': <Parameter 'STB_FLX', value=1.1415074831947234 +/- 0.0486, bounds=[0.0:2.0]>, 'STB_TAU': <Parameter 'STB_TAU', value=0.0 (fixed), bounds=[0.0:inf]>, 'STB_MIX': <Parameter 'STB_MIX', value=0.0 (fixed), bounds=[0.0:1.0]>, 'STB_COV': <Parameter 'STB_COV', value=1.0 (fixed), bounds=[0.0:1.0]>, 'STB_100': <Parameter 'STB_100', value=0.0 (fixed), bounds=[0.0:1.0]>, 'STB_010': <Parameter 'STB_010', value=0.0 (fixed), bounds=[0.0:1.0]>, 'DSK_FLX': <Parameter 'DSK_FLX', value=0.0 (fixed), bounds=[0.0:2.0]>, 'DSK_TAU': <Parameter 'DSK_TAU', value=0.0 (fixed), bounds=[0.0:2.0]>, 'DSK_COV': <Parameter 'DSK_COV', value=1.0 (fixed), bounds=[0.0:1.0]>, 'PAH_FLX': <Parameter 'PAH_FLX', value=1.0 (fixed), bounds=[0.0:2.0]>, 'PAH_TAU': <Parameter 'PAH_TAU', value=10.980398089204055 +/- 0.118, bounds=[0.0:inf], expr='WRM_TAU'>, 'PAH_MIX': <Parameter 'PAH_MIX', value=1.0 (fixed), bounds=[0.0:1.0]>, 'PAH_COV': <Parameter 'PAH_COV', value=1.0 (fixed), bounds=[0.0:1.0]>, 'ICE3_TAU': <Parameter 'ICE3_TAU', value=0.0 (fixed), bounds=[0.0:2.0]>, 'ICE6_TAU': <Parameter 'ICE6_TAU', value=0.0 (fixed), bounds=[0.0:2.0]>, 'CO2_TAU': <Parameter 'CO2_TAU', value=0.0 (fixed), bounds=[0.0:2.0]>, 'HAC_TAU': <Parameter 'HAC_TAU', value=0.0 (fixed), bounds=[0.0:2.0]>, 'CORV_TAU': <Parameter 'CORV_TAU', value=0.0 (fixed), bounds=[0.0:2.0]>, 'CRYSI_233_TAU': <Parameter 'CRYSI_233_TAU', value=0.0 
#        11.22997875, 11.32997857, 11.98997732, 12.61997612, 12.68997599,
#        13.4799745 , 14.03997344, 14.18997315, 15.89996992, 16.44996888]), 'width': array([0.04 , 0.013, 0.005, 0.029, 0.011, 0.008, 0.035, 0.03 , 0.07 ,
#        0.126, 0.044, 0.053, 0.05 , 0.039, 0.02 , 0.012, 0.032, 0.045,
#        0.042, 0.013, 0.04 , 0.016, 0.025, 0.02 , 0.014]), 'peak': array([0.00082785, 0.00770606, 0.00150659, 0.00143291, 0.00161862,
#        0.00204318, 0.00214451, 0.01545594, 0.00436181, 0.00244482,
#        0.03744795, 0.03475946, 0.        , 0.00560818, 0.        ,
#        0.0169816 , 0.01606733, 0.04070971, 0.1197996 , 0.        ,
#        0.05273121, 0.01269785, 0.01765449, 0.        , 0.        ]), 'name': ['20_PAH30_30100', '0_PAH33_32900', '0_PAH34_34000', '0_PAH35_34700', '1_PAH52_52400', '1_PAH53_53300', '2_PAH57_57000', '3_PAH62_62200', '4_PAH67_66900', '5_PAH74_74200', '5_PAH76_76000', '5_PAH78_78500', '6_PAH83_83300', '7_PAH86_86100', '8_PAH107_106800', '9_PAH112_112300', '9_PAH113_113300', '10_PAH120_119900', '11_PAH126_126200', '11_PAH127_126900', '12_PAH135_134800', '13_PAH140_140400', '14_PAH142_141900', '15_PAH159_159000', '16_PAH164_164500'], 'strength': array([5.14873056e-14, 1.43133380e-13, 1.04266416e-14, 5.61938672e-14,
#        1.59847530e-14, 1.44309448e-14, 6.18202708e-14, 3.50166990e-13,
#        2.13690891e-13, 1.93496467e-13, 1.01727749e-12, 1.10029329e-12,
#        0.00000000e+00, 1.19213867e-13, 0.00000000e+00, 8.53000945e-14,
#        2.12651213e-13, 7.13429720e-13, 1.85916101e-12, 0.00000000e+00,
#        7.27236118e-13, 6.76854336e-14, 1.44819447e-13, 0.00000000e+00,
#        0.00000000e+00])}}, 'asdf_library': {'name': 'asdf', 'version': '2.8.1', 'homepage': 'http://github.com/asdf-format/asdf', 'author': 'The ASDF Developers'}, 'history': {'extensions': []}})

# %%
# Line and PAH averaged velocity gradient wrt z, in [km/s]
print(s.parcube['VALUE'].data[-1,0,0])
print(s.parcube['VALUE'].data[-1,0,0]/2.998e5)
# Out:
# -0.5794554949388337
# -1.9328068543656896e-06

# %%
s.plot_spec_fit(inppar_fn, optpar_fn)
# Out:
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Load the parameter cube from drive
parcube_fd = '../CAFE/output/'+source_fnb+'/'
parcube_fn = source_fnb+'_parcube.fits'

# %%
s.read_spec(source_fn, file_dir=source_fd, z=z)
# Out:
# Load data: ../CRETA/extractions/IIZw096_SingleExt_r0.3as_cube.fits
# Filename: ../CRETA/extractions/IIZw096_SingleExt_r0.3as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        36   (22873,)   float64
#   2  ERR           1 ImageHDU         7   (22873,)   float64
#   3  FLUX_ST       1 ImageHDU         7   (22873,)   float64
#   4  ERR_ST        1 ImageHDU         7   (22873,)   float64
#   5  DQ            1 ImageHDU         7   (22873,)   float64
#   6  WAVE          1 ImageHDU         7   (22873,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   22873R x 1C   [20A]

# %%
s.read_parcube_file(parcube_fn, file_dir=parcube_fd)
# Out:
# Filename: ../CAFE/output/IIZw096_SingleExt_r03as_cube/IIZw096_SingleExt_r03as_cube_parcube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  VALUE         1 ImageHDU        38   (1, 1, 661)   float64
#   2  STDERR        1 ImageHDU        38   (1, 1, 661)   float64
#   3  VARY          1 ImageHDU        38   (1, 1, 661)   float64
#   4  MIN           1 ImageHDU        38   (1, 1, 661)   float64
#   5  MAX           1 ImageHDU        38   (1, 1, 661)   float64
#   6  EXPR          1 BinTableHDU     13   661R x 2C   [I, 24A]
#   7  PARNAME       1 BinTableHDU     13   661R x 2C   [I, 32A]

# %%
from astropy.io import ascii
from astropy.table import Table
from astropy.table import QTable

# Read output PAH table
pah = cafeio.pah_table(s.parcube, 0, 0)
# Read output line table
line = cafeio.line_table(s.parcube, 0, 0)

pah62 = pah[pah.index == 'PAH62'].pah_strength.values[0]
pah62_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah77 = pah[pah.index == 'PAH77_C'].pah_strength.values[0]
pah77_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah113 = pah[pah.index == 'PAH113_C'].pah_strength.values[0]
pah113_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]

x = pah62 / pah77 
x_unc = pah62 / pah77 * np.sqrt((pah62_unc/pah62)**2 + (pah77_unc/pah77)**2)
y = pah113 / pah77
y_unc = pah113 / pah77 * np.sqrt((pah113_unc/pah113)**2 + (pah77_unc/pah77)**2)

print('6.2/7.7 = {} +/- {}'.format(x, x_unc))
print('11.3/7.7 = {} +/- {}'.format(y, y_unc))

print(pah)

# Make an astropy table 
t = QTable([pah.index.values, pah.pah_strength, pah.pah_strength_unc],
           names = ('pah_complex', 'pah_strength', 'pah_strength_unc'),
           meta={'wavelength': 'micron',
                 'flux': 'W/m^2',
                }
          )

# Write PAH table in an .ecsv file
#t.write('./NGC7469_pah_tbl.ecsv', overwrite=False)
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 6.2/7.7 = 0.15948781487926658 +/- 0.0031868275085701115
# 11.3/7.7 = 0.1088119424851446 +/- 0.003165629837104753
#              pah_strength  pah_strength_unc
# pah_complex
# PAH113_C     1.662026e-19      1.188710e-20
# PAH120       3.909301e-19      9.583194e-21
# PAH126_C     1.227071e-18      1.686315e-20
# PAH136       4.660945e-19      7.598355e-21
# PAH142       1.058069e-19      6.443677e-21
# PAH164       0.000000e+00      0.000000e+00
# PAH170_C     8.027622e-19      2.300560e-20
# PAH33        9.455213e-20      2.401250e-21
# PAH62        2.436064e-19      4.806904e-21
# PAH77_C      1.527430e-18      4.073222e-20
# PAH83        0.000000e+00      0.000000e+00
# PAH86        1.908567e-20      5.671144e-21
# ali34        9.270681e-21      2.196371e-21
# ali345       2.194231e-20      3.405685e-21
