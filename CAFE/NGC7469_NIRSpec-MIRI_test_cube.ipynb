# %%
import os
os._exit(00)

# %%
import sys
sys.path.insert(0, './CRETA')

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib widget
import matplotlib.ticker
from matplotlib.backends.backend_pdf import PdfPages

import creta
import cafe_io
from cafe_io import *
import cafe_helper
from cafe_helper import *
import cafe

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# User API Created
# <style>.container { width:100% !important; }</style>

# %%
# SPECTRAL EXTRACTION

# %%
# Read parameter file with extraction keywords
pf = open('./CRETA/param_files/NGC7469_grid_params.txt','r')
print(pf.read())
pf.close()
# Out:
# cubes = g395h, ch1-short, ch1-medium, ch1-long, ch2-short, ch2-medium, ch2-long, ch3-short, ch3-medium, ch3-long, ch4-short, ch4-medium, ch4-long
# user_ra = 23h03m15.614s
# user_dec = 08d52m26.23s
# user_center = True
# centering = True
# lambda_cent = 5.4
# nx_steps = 3
# ny_steps = 3
# spax_size = 0.5
# step_size = -1
# convolve = False

# %%
# Load the extraction tool (CRETA)
c = creta.creta()
# Out:
# CAFE Region Extraction Tool Automaton (CRETA) initialized

# %%
# Perform the extraction
c.gridExtraction(parameter_file=True, perband_cent=True, parfile_name='NGC7469_grid_params.txt', data_path='./CRETA/data/NGC7469/', output_filebase_name='NGC7469')
# Out:
# Load file: ./CRETA/data/NGC7469/Level3_g395h-f290lp_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch1-short_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch1-medium_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch1-long_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch2-short_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch2-medium_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch2-long_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch3-short_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch3-medium_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch3-long_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch4-short_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch4-medium_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch4-long_s3d.fits
# Last cube is:  ch4_LONG
# Cubes: ['g395h', 'ch1-short', 'ch1-medium', 'ch1-long', 'ch2-short', 'ch2-medium', 'ch2-long', 'ch3-short', 'ch3-medium', 'ch3-long', 'ch4-short', 'ch4-medium', 'ch4-long']
# RA,δ: [345.81505833,8.87395278] (degrees)
# Grid Extraction Parameters:
# NX Steps: 3
# NY Steps: 3
# Spaxel Size:  0.5
# Step Size: 0.5
# Loading Data
# Load file: ./CRETA/data/NGC7469/Level3_g395h-f290lp_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch1-short_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch1-medium_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch1-long_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch2-short_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch2-medium_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch2-long_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch3-short_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch3-medium_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch3-long_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch4-short_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch4-medium_s3d.fits
# Load file: ./CRETA/data/NGC7469/bandcube_ch4-long_s3d.fits
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# Centering around 5.399500119092409 um in cube ch1_SHORT
# Old coordinates were: 345.81505833 8.87395278
# New coordinates are: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505833, 8.87395278)>
# Per-band re-centering around 2.871215809167602 um in cube G395H
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81524207, 8.87392658)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# G395H photometry exectued in: 12.878298997879028 seconds
# Per-band re-centering around 4.902500095486175 um in cube ch1_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505874, 8.87393501)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_SHORT photometry exectued in: 3.006808042526245 seconds
# Per-band re-centering around 5.662499847530853 um in cube ch1_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506329, 8.87392821)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_MEDIUM photometry exectued in: 3.081894874572754 seconds
# Per-band re-centering around 6.532500209927093 um in cube ch1_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506107, 8.87393765)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_LONG photometry exectued in: 3.5923619270324707 seconds
# Per-band re-centering around 7.515000229119323 um in cube ch2_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505866, 8.87393817)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_SHORT photometry exectued in: 2.0551137924194336 seconds
# Per-band re-centering around 8.675000076531433 um in cube ch2_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505679, 8.87394853)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_MEDIUM photometry exectued in: 2.1908631324768066 seconds
# Per-band re-centering around 10.02500045800116 um in cube ch2_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506524, 8.87393436)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_LONG photometry exectued in: 2.497345209121704 seconds
# Per-band re-centering around 11.557500190800054 um in cube ch3_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506616, 8.87392467)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_SHORT photometry exectued in: 1.860008955001831 seconds
# Per-band re-centering around 13.347500152653083 um in cube ch3_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506916, 8.87392202)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_MEDIUM photometry exectued in: 2.378187894821167 seconds
# Per-band re-centering around 15.417499847477304 um in cube ch3_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506453, 8.87393263)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_LONG photometry exectued in: 2.3692197799682617 seconds
# Per-band re-centering around 17.71500076306984 um in cube ch4_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506695, 8.87393001)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_SHORT photometry exectued in: 1.4340848922729492 seconds
# Per-band re-centering around 20.705000534188 um in cube ch4_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505906, 8.87393121)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_MEDIUM photometry exectued in: 1.6626999378204346 seconds
# Per-band re-centering around 24.205000534188 um in cube ch4_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81503673, 8.87389218)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_LONG photometry exectued in: 1.9191579818725586 seconds
# Grid point 0 stitched in: 0.07259702682495117 seconds
# Output written in: 0.3978097438812256 seconds
# Grid point 1 stitched in: 0.017661094665527344 seconds
# Output written in: 0.35788393020629883 seconds
# Grid point 2 stitched in: 0.016618967056274414 seconds
# Output written in: 0.36624717712402344 seconds
# Grid point 3 stitched in: 0.01834416389465332 seconds
# Output written in: 0.4404909610748291 seconds
# Grid point 4 stitched in: 0.01819014549255371 seconds
# Output written in: 0.36583399772644043 seconds
# Grid point 5 stitched in: 0.018628835678100586 seconds
# Output written in: 0.3897397518157959 seconds
# Grid point 6 stitched in: 0.018344879150390625 seconds
# Output written in: 0.3772151470184326 seconds
# Grid point 7 stitched in: 0.017757892608642578 seconds
# Output written in: 0.37523889541625977 seconds
# Grid point 8 stitched in: 0.017064809799194336 seconds
# Output written in: 0.4523897171020508 seconds
# {'extraction_RA': <Longitude 345.8151773 deg>, 'extraction_DEC': <Latitude 8.87375329 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.8151773 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.8151773 deg>, 'extraction_DEC': <Latitude 8.87403107 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87375329 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87403107 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81489616 deg>, 'extraction_DEC': <Latitude 8.87375329 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81489616 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81489616 deg>, 'extraction_DEC': <Latitude 8.87403107 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]

# %%
# CAFE FITTING

# %%
# Setup directories
source_fd = './CRETA/extractions/'
source_fn = 'NGC7469_GridExt_3x3_s0.5as_cube.fits'
source_fnb = source_fn.split('.fits')[0].replace('.','')
inppar_fn = './inp_parfiles/inpars_jwst_nirspec-miri_AGN.ini'

optpar_fn = './opt_parfiles/default_opt.cafe'

z=0.01630

# %%
s = cafe.cubemod()

# %%
s.read_cube(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ./CRETA/extractions/NGC7469_GridExt_3x3_s0.5as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        38   (3, 3, 12894)   float64
#   2  ERR           1 ImageHDU         9   (3, 3, 12894)   float64
#   3  FLUX_ST       1 ImageHDU         9   (3, 3, 12894)   float64
#   4  ERR_ST        1 ImageHDU         9   (3, 3, 12894)   float64
#   5  DQ            1 ImageHDU         9   (3, 3, 12894)   float64
#   6  WAVE          1 ImageHDU         7   (12894,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   12894R x 1C   [20A]

# %%
s.plot_cube_ini(1, 1, inppar_fn, optpar_fn)
# Out:
# Generating continuum profiles for guess model
# Parameter object has 80 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# AGN
# AGN
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s.fit_cube(inppar_fn, optpar_fn)
# Out:
# Generating fitting sequence
# Highest SNR spaxel is: 1 1
# Generating initial/full parameter object with all potential lines
# Parameter object has 109 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Generating parameter cube with initial/full parameter object
# Regenerating continuum profiles
# AGN
# AGN
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [1 1]
# Parameter object has 80 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2022-12-29 12:59:25.295599 -----------------
# True in 47 steps
# 168.91 seconds elapsed
# <Parameter 'HOT_TMP', value=1027.1980506619918 +/- 282, bounds=[100.0:1027.2]> at upper bound, fixing to  1027.2
# <Parameter 'STB_FLX', value=4.488973447885847e-07 +/- 0.191, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_TAU', value=4.2941846992247007e-07 +/- 6.13e+04, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'DSK_FLX', value=5.01250882944069e-13 +/- 0.028, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'DSK_TAU', value=6.666472311850057e-09 +/- 4.92e+06, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=2.105592400048807e-22 +/- 0.00128, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVIII_30280B_Wave', value=3.0329999499666442 +/- 0.000903, bounds=[3.0229000500333556:3.0329999499666447]> at upper bound, fixing to 3.0329999499666447
# <Parameter 'g_MgVIII_30280B_Gamma', value=0.006671114076050699 +/- 0.000705, bounds=[0.0002598066564908304:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_KVII_31905N_Peak', value=7.437764091512886e-20 +/- 0.000883, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S14_37240N_Peak', value=7.658773569409836e-24 +/- 0.00113, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S13_38464N_Peak', value=6.340003515895012e-14 +/- 0.00113, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NiI_39524N_Peak', value=1.469406820195422e-19 +/- 0.00137, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S12_39947N_Peak', value=1.145426829782563e-12 +/- 0.00166, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=8.04470691390076e-24 +/- 0.0015, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=1.1985749770504515e-30 +/- 0.0012, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeVIII_54466B_Gamma', value=0.006671114076050615 +/- 0.00101, bounds=[0.00023718297586477506:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_Pfund65_74578N_Peak', value=6.313897640538855e-15 +/- 0.00256, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=5.318401087508054e-18 +/- 0.0131, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_259883N_Peak', value=3.849426542128521e-22 +/- 0.0171, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd0_PAH33_32900_Peak', value=6.147515382954452e-20 +/- 0.000234, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=1.4854517383540806e-19 +/- 0.000261, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=5.908077973450825e-23 +/- 0.000517, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=1.341166860017417e-22 +/- 0.000376, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd7_PAH86_86100_Peak', value=9.664496362686289e-22 +/- 0.000381, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=3.1381569164025814e-22 +/- 0.000453, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=6.837011636448246e-21 +/- 0.00083, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=5.082117383699465e-26 +/- 0.0138, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_FLX', value=4.488973447885847e-07 +/- 0.191, bounds=[0.0:2.0]> unconstrained at 42601089.120615326 % error. Fixing value.
# <Parameter 'STB_TAU', value=4.2941846992247007e-07 +/- 6.13e+04, bounds=[0.0:inf]> unconstrained at 14278043249191.969 % error. Fixing value.
# <Parameter 'STB_010', value=0.01185945100192592 +/- 1.7e+04, bounds=[0.0:1.0]> unconstrained at 143249604.29336163 % error. Fixing value.
# <Parameter 'DSK_FLX', value=5.01250882944069e-13 +/- 0.028, bounds=[0.0:2.0]> unconstrained at 5583304467524.157 % error. Fixing value.
# <Parameter 'DSK_TAU', value=6.666472311850057e-09 +/- 4.92e+06, bounds=[0.0:2.0]> unconstrained at 7.37491353787075e+16 % error. Fixing value.
# <Parameter 'g_CoII_29846N_Peak', value=2.105592400048807e-22 +/- 0.00128, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=2.105592400048807e-22 +/- 0.00128, bounds=[0.0:inf]> lower than uncertainty 1.8751118718536155e-05 , fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=7.437764091512886e-20 +/- 0.000883, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=7.437764091512886e-20 +/- 0.000883, bounds=[0.0:inf]> lower than uncertainty 1.763001500477078e-05 , fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=0.00036440310223327904 +/- 0.0011, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=7.658773569409836e-24 +/- 0.00113, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=7.658773569409836e-24 +/- 0.00113, bounds=[0.0:inf]> lower than uncertainty 2.2786795223655035e-05 , fixing to 0.0
# <Parameter 'g_H200S13_38464N_Peak', value=6.340003515895012e-14 +/- 0.00113, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S13_38464N_Peak', value=6.340003515895012e-14 +/- 0.00113, bounds=[0.0:inf]> lower than uncertainty 2.2907553076581616e-05 , fixing to 0.0
# <Parameter 'g_NiI_39524N_Peak', value=1.469406820195422e-19 +/- 0.00137, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NiI_39524N_Peak', value=1.469406820195422e-19 +/- 0.00137, bounds=[0.0:inf]> lower than uncertainty 2.7792045887521157e-05 , fixing to 0.0
# <Parameter 'g_H200S12_39947N_Peak', value=1.145426829782563e-12 +/- 0.00166, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S12_39947N_Peak', value=1.145426829782563e-12 +/- 0.00166, bounds=[0.0:inf]> lower than uncertainty 3.325160770973567e-05 , fixing to 0.0
# <Parameter 'g_CaV_41594N_Peak', value=0.000501724233490374 +/- 0.00143, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=8.949146510739898e-05 +/- 0.0012, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=8.04470691390076e-24 +/- 0.0015, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=8.04470691390076e-24 +/- 0.0015, bounds=[0.0:inf]> lower than uncertainty 3.3426483028619654e-05 , fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=1.1985749770504515e-30 +/- 0.0012, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KIII_46180N_Peak', value=1.1985749770504515e-30 +/- 0.0012, bounds=[0.0:inf]> lower than uncertainty 2.3001256597393773e-05 , fixing to 0.0
# <Parameter 'g_NaVII_46847N_Peak', value=0.000470770676319754 +/- 0.00139, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=6.313897640538855e-15 +/- 0.00256, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=6.313897640538855e-15 +/- 0.00256, bounds=[0.0:inf]> lower than uncertainty 3.991095907135378e-05 , fixing to 0.0
# <Parameter 'g_ArV_131022N_Peak', value=0.0005458046291318535 +/- 0.00349, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=5.318401087508054e-18 +/- 0.0131, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=5.318401087508054e-18 +/- 0.0131, bounds=[0.0:inf]> lower than uncertainty 0.00031359210181570264 , fixing to 0.0
# <Parameter 'g_FeII_259883N_Peak', value=3.849426542128521e-22 +/- 0.0171, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_259883N_Peak', value=3.849426542128521e-22 +/- 0.0171, bounds=[0.0:inf]> lower than uncertainty 0.00040755275820787213 , fixing to 0.0
# <Parameter 'd0_PAH33_32900_Peak', value=6.147515382954452e-20 +/- 0.000234, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd0_PAH33_32900_Peak', value=6.147515382954452e-20 +/- 0.000234, bounds=[0.0:inf]> lower than uncertainty 2.4735762519542536e-05 , fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=1.4854517383540806e-19 +/- 0.000261, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd4_PAH67_66900_Peak', value=1.4854517383540806e-19 +/- 0.000261, bounds=[0.0:inf]> lower than uncertainty 3.1459283408281596e-05 , fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=5.908077973450825e-23 +/- 0.000517, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd5_PAH74_74200_Peak', value=5.908077973450825e-23 +/- 0.000517, bounds=[0.0:inf]> lower than uncertainty 3.9312502485764056e-05 , fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=1.341166860017417e-22 +/- 0.000376, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd6_PAH83_83300_Peak', value=1.341166860017417e-22 +/- 0.000376, bounds=[0.0:inf]> lower than uncertainty 4.1235379722782285e-05 , fixing to 0.0
# <Parameter 'd7_PAH86_86100_Peak', value=9.664496362686289e-22 +/- 0.000381, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd7_PAH86_86100_Peak', value=9.664496362686289e-22 +/- 0.000381, bounds=[0.0:inf]> lower than uncertainty 4.309766320957993e-05 , fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=3.1381569164025814e-22 +/- 0.000453, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=3.1381569164025814e-22 +/- 0.000453, bounds=[0.0:inf]> lower than uncertainty 6.784013404453833e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=6.837011636448246e-21 +/- 0.00083, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=6.837011636448246e-21 +/- 0.00083, bounds=[0.0:inf]> lower than uncertainty 6.711148034830704e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=5.082117383699465e-26 +/- 0.0138, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=5.082117383699465e-26 +/- 0.0138, bounds=[0.0:1.0]> lower than uncertainty 2.4144772339486736e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# AGN
# AGN
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [1 0]
# Parameter object has 83 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [1 0] will be initialized with results from spaxel [1 1]
# Parameter object has 83 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2022-12-29 13:02:19.298063 -----------------
# True in 53 steps
# 189.82 seconds elapsed
# <Parameter 'STB_010', value=1.10755650969346e-06 +/- 0.00867, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=1.8822653270707506e-18 +/- 0.00071, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=2.124396391580684e-17 +/- 0.000705, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S14_37240N_Peak', value=1.6629678600015602e-22 +/- 0.00076, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=2.8097773065531357e-22 +/- 0.00123, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=7.048032634548857e-23 +/- 0.00125, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaVIII_51789B_Gamma', value=0.006671114076050699 +/- 0.00185, bounds=[0.00025023236764237696:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_MgVII_55032N_Peak', value=3.55623019358598e-20 +/- 0.00105, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVII_90090N_Peak', value=3.604485970102569e-20 +/- 0.000962, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_AlVI_91160N_Peak', value=1.0796497221835019e-19 +/- 0.000989, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ClII_143678N_Peak', value=2.7236536454148597e-17 +/- 0.00119, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Wave', value=24.277197856358065 +/- 0.0108, bounds=[24.27719785635425:24.35831111347538]> at lower bound, fixing to 24.27719785635425
# <Parameter 'g_NeV_243175B_Gamma', value=0.006671114076050699 +/- 0.00102, bounds=[0.000536762505574601:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'd8_PAH107_106800_Peak', value=1.2812819488050574e-33 +/- 0.000228, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=1.008327844531981e-15 +/- 0.00018, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=5.964780372996118e-26 +/- 0.00031, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=5.632032845182108e-24 +/- 0.000291, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'WRM_TAU', value=0.011727886606992727 +/- 0.104, bounds=[0.0:inf]> unconstrained at 885.6333793706037 % error. Fixing value.
# <Parameter 'STB_TAU', value=0.34680248729322 +/- 1.04, bounds=[0.0:inf]> unconstrained at 300.7107743789601 % error. Fixing value.
# <Parameter 'STB_010', value=1.10755650969346e-06 +/- 0.00867, bounds=[0.0:1.0]> unconstrained at 782492.5387956242 % error. Fixing value.
# <Parameter 'DSK_FLX', value=0.004056063593917574 +/- 0.0528, bounds=[0.0:2.0]> unconstrained at 1302.5666528406784 % error. Fixing value.
# <Parameter 'DSK_TAU', value=0.007433911018575569 +/- 19.9, bounds=[0.0:2.0]> unconstrained at 267047.54182115744 % error. Fixing value.
# <Parameter 'g_AlV_29052N_Peak', value=0.0001000235755848659 +/- 0.000866, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVIII_30280N_Peak', value=1.4729049712941157e-05 +/- 0.00151, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=1.8822653270707506e-18 +/- 0.00071, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=1.8822653270707506e-18 +/- 0.00071, bounds=[0.0:inf]> lower than uncertainty 2.483792651629028e-05 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=0.00018213655022249987 +/- 0.00063, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=2.124396391580684e-17 +/- 0.000705, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=2.124396391580684e-17 +/- 0.000705, bounds=[0.0:inf]> lower than uncertainty 2.3841267509189412e-05 , fixing to 0.0
# <Parameter 'g_H200S15_36250N_Peak', value=0.0002673576533137221 +/- 0.000679, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=1.6629678600015602e-22 +/- 0.00076, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=1.6629678600015602e-22 +/- 0.00076, bounds=[0.0:inf]> lower than uncertainty 2.5890997158660078e-05 , fixing to 0.0
# <Parameter 'g_Pfund85_37406N_Peak', value=1.7692621263397402e-05 +/- 0.000726, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_41150N_Peak', value=0.00033574792615170883 +/- 0.00119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaV_41594N_Peak', value=0.00019232875436280152 +/- 0.00154, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S10_44096N_Peak', value=0.0005176769367704079 +/- 0.00116, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=0.0005315095292065658 +/- 0.00128, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=0.000435810460443613 +/- 0.00144, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=0.0001587890674342448 +/- 0.00188, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=2.8097773065531357e-22 +/- 0.00123, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=2.8097773065531357e-22 +/- 0.00123, bounds=[0.0:inf]> lower than uncertainty 3.901628624683164e-05 , fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=7.048032634548857e-23 +/- 0.00125, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KIII_46180N_Peak', value=7.048032634548857e-23 +/- 0.00125, bounds=[0.0:inf]> lower than uncertainty 3.951545170893992e-05 , fixing to 0.0
# <Parameter 'g_FeII_46719N_Peak', value=0.0006074143416528109 +/- 0.00127, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVIII_51789N_Peak', value=0.00035043315371019375 +/- 0.00226, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_55032N_Peak', value=3.55623019358598e-20 +/- 0.00105, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_55032N_Peak', value=3.55623019358598e-20 +/- 0.00105, bounds=[0.0:inf]> lower than uncertainty 2.778373785051582e-05 , fixing to 0.0
# <Parameter 'g_MgV_56098N_Peak', value=0.000159968499749603 +/- 0.00144, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_56739N_Peak', value=0.0003395679948598876 +/- 0.00101, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIII_73177N_Peak', value=0.00014525975060210905 +/- 0.000976, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=0.0006853758827557893 +/- 0.00253, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_79016N_Peak', value=0.00029192288943639353 +/- 0.00131, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_90090N_Peak', value=3.604485970102569e-20 +/- 0.000962, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_90090N_Peak', value=3.604485970102569e-20 +/- 0.000962, bounds=[0.0:inf]> lower than uncertainty 2.8335889180744875e-05 , fixing to 0.0
# <Parameter 'g_AlVI_91160N_Peak', value=1.0796497221835019e-19 +/- 0.000989, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_AlVI_91160N_Peak', value=1.0796497221835019e-19 +/- 0.000989, bounds=[0.0:inf]> lower than uncertainty 2.9221372369076376e-05 , fixing to 0.0
# <Parameter 'g_ClII_143678N_Peak', value=2.7236536454148597e-17 +/- 0.00119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ClII_143678N_Peak', value=2.7236536454148597e-17 +/- 0.00119, bounds=[0.0:inf]> lower than uncertainty 4.064648117207549e-05 , fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=0.000819852876321747 +/- 0.00397, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_259883N_Peak', value=0.003528000565472477 +/- 0.00803, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd8_PAH107_106800_Peak', value=1.2812819488050574e-33 +/- 0.000228, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd8_PAH107_106800_Peak', value=1.2812819488050574e-33 +/- 0.000228, bounds=[0.0:inf]> lower than uncertainty 3.272819601021732e-05 , fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=1.008327844531981e-15 +/- 0.00018, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=1.008327844531981e-15 +/- 0.00018, bounds=[0.0:inf]> lower than uncertainty 4.0718273935812584e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=5.964780372996118e-26 +/- 0.00031, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=5.964780372996118e-26 +/- 0.00031, bounds=[0.0:inf]> lower than uncertainty 4.228306611624902e-05 , fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=5.632032845182108e-24 +/- 0.000291, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd14_PAH142_141900_Peak', value=5.632032845182108e-24 +/- 0.000291, bounds=[0.0:inf]> lower than uncertainty 3.914645943020748e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=0.014012808814746387 +/- 0.0549, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# AGN
# AGN
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [1 2]
# Parameter object has 79 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [1 2] will be initialized with results from spaxel [1 1]
# Parameter object has 79 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2022-12-29 13:05:34.296246 -----------------
# True in 34 steps
# 137.09 seconds elapsed
# No errors retuned
# <Parameter 'HOT_TMP', value=1027.1999999939435, bounds=[100.0:1027.2]> at upper bound, fixing to  1027.2
# <Parameter 'HOT_TMP', value=1027.1999999939435, bounds=[100.0:1027.2]> at initial value 1027.2 . Fixing value.
# <Parameter 'STB_TAU', value=1.4439087671012782e-14, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_010', value=6.969335042888938e-16, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'DSK_FLX', value=3.0689221995672466e-16, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'DSK_TAU', value=1.999982079622325, bounds=[0.0:2.0]> at upper bound, fixing to  2.0
# <Parameter 'g_KVII_31905N_Peak', value=2.7154926365209625e-19, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_AlVI_36597N_Peak', value=1.909184395490271e-18, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S13_38464N_Peak', value=4.559306117904916e-19, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_40763N_Peak', value=8.55892907314552e-21, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=1.4868158055521124e-21, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgIV_44867N_Peak', value=4.652709468586297e-17, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=3.4446154417659485e-18, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SIX_46585N_Peak', value=1.990356642054066e-06, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVIII_50019N_Peak', value=8.378773166608582e-20, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SVII_52334N_Peak', value=5.669939961759773e-20, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVIII_52910N_Peak', value=6.856938104592787e-17, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeVIII_54466B_Wave', value=5.437599930092829, bounds=[5.437573181635409:5.455740816722731]> at lower bound, fixing to 5.437573181635409
# <Parameter 'g_FeVIII_54466B_Gamma', value=0.006671114076050699, bounds=[0.00023718297586477506:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_MgVII_55032N_Peak', value=1.505901183951797e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeVI_76524N_Peak', value=5.874849917575691e-17, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SIV_105105N_Peak', value=5.914387029065392e-11, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_143217N_Peak', value=4.7325858551956466e-07, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=4.934350313502658e-19, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_179359N_Peak', value=1.992032915805449e-21, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_OIV_258903N_Peak', value=1.6358301930046228e-15, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=7.840016565795701e-19, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd10_PAH120_119900_Peak', value=5.030552325631454e-21, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=1.2888936283437269e-22, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=2.3216729669834482e-21, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO2ice_42736_Peak', value=1.1222967419038524e-16, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# Rerunning fit
# Iteration 2/5(max): 2022-12-29 13:07:51.724265 -----------------
# True in 4 steps
# 12.69 seconds elapsed
# <Parameter 'g_ArIII_89914N_Peak', value=1.0715645089855792e-06 +/- 0.00149, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVIII_30280N_Peak', value=0.00011264070011063294 +/- 0.00123, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=1.0175956185829029e-05 +/- 0.00046, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S15_36250N_Peak', value=0.0001044392217057839 +/- 0.000543, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=4.935145129272279e-05 +/- 0.0015, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund75_46538N_Peak', value=0.00031467013910646384 +/- 0.00092, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVIII_51789N_Peak', value=0.00044177559044925404 +/- 0.0015, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgV_56098N_Peak', value=0.00022918794499742146 +/- 0.00145, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArIII_89914N_Peak', value=1.0715645089855792e-06 +/- 0.00149, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArIII_89914N_Peak', value=1.0715645089855792e-06 +/- 0.00149, bounds=[0.0:inf]> lower than uncertainty 3.081497513685258e-05 , fixing to 0.0
# <Parameter 'g_ArV_131022N_Peak', value=0.0005392645373366525 +/- 0.00133, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeIII_229250N_Peak', value=0.0008936977544986345 +/- 0.00555, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd0_PAH34_34260_Peak', value=3.0306558763250876e-05 +/- 0.000102, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=0.012465179176451333 +/- 0.0359, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# AGN
# AGN
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [2 1]
# Parameter object has 78 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [2 1] will be initialized with results from spaxel [1 1]
# Parameter object has 78 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2022-12-29 13:08:09.566089 -----------------
# True in 59 steps
# 221.04 seconds elapsed
# <Parameter 'STB_TAU', value=1.631240750229265e-07 +/- 0.962, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_010', value=1.0147271275667573e-15 +/- 0.0108, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'DSK_FLX', value=6.41461541687779e-08 +/- 0.049, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'DSK_TAU', value=4.682534292525296e-06 +/- 6.22e+04, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVIII_30280B_Wave', value=3.0330316905951578 +/- 0.00273, bounds=[3.0229316849654717:3.033031690595159]> at upper bound, fixing to 3.033031690595159
# <Parameter 'g_MgVIII_30280B_Gamma', value=0.006671114076050687 +/- 0.00227, bounds=[0.0002598066564908304:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_KVII_31905N_Peak', value=3.380977953561638e-25 +/- 0.000344, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=1.5125435054444676e-23 +/- 0.000381, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=2.3492809799936673e-19 +/- 0.000406, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_40819N_Peak', value=2.099728821049755e-19 +/- 0.000983, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaVII_40858N_Peak', value=4.724206625061031e-25 +/- 0.000718, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=2.0405969459610317e-22 +/- 0.000538, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CII_42988N_Peak', value=6.060006855159294e-19 +/- 0.000556, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgIV_44867N_Peak', value=7.804223897325963e-20 +/- 0.000789, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArVI_45295N_Peak', value=1.0509223497608213e-17 +/- 0.000794, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=2.6528844680852538e-24 +/- 0.00066, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=5.1222837613522e-26 +/- 0.000687, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SIX_46413N_Peak', value=3.476052475715919e-27 +/- 0.000725, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SVII_50027N_Peak', value=9.641576266916554e-35 +/- 0.00102, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SVII_50027B_Wave', value=5.011095836635478 +/- 0.00287, bounds=[4.994408870812518:5.011095836635479]> at upper bound, fixing to 5.011095836635479
# <Parameter 'g_SVII_50027B_Gamma', value=0.006671114076050699 +/- 0.00135, bounds=[0.0002596345073937826:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_SVII_52334N_Peak', value=2.5917440972534297e-24 +/- 0.00104, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVIII_52910N_Peak', value=2.5207453482033434e-21 +/- 0.00123, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeVIII_54466B_Gamma', value=0.006671114076050699 +/- 0.00209, bounds=[0.00023718297586477506:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_MgVII_55032B_Wave', value=5.512435806299072 +/- 0.000414, bounds=[5.494079376707668:5.512435806299073]> at upper bound, fixing to 5.512435806299073
# <Parameter 'g_MgV_56098N_Peak', value=7.851779016654332e-18 +/- 0.00142, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeVI_76524N_Peak', value=1.1562478553229787e-24 +/- 0.00207, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=6.960964918166177e-28 +/- 0.00119, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaIV_90410N_Peak', value=3.0738307188834406e-24 +/- 0.001, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SIV_105105N_Peak', value=1.432358861245939e-14 +/- 0.00174, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArV_131022N_Peak', value=2.291187810239453e-16 +/- 0.00142, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_143217N_Peak', value=9.803630880475936e-17 +/- 0.00237, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Gamma', value=0.006671114076050699 +/- 0.000545, bounds=[0.000536762505574601:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_SI_252490N_Peak', value=2.1351549843663696e-23 +/- 0.00529, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_OIV_258903N_Peak', value=1.873189010430343e-11 +/- 0.0324, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_259883N_Peak', value=3.5122429359324473e-23 +/- 0.00715, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=2.5967487420176242e-30 +/- 0.000196, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=5.902549749356898e-31 +/- 0.000314, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=3.02163747784192e-23 +/- 0.0403, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_TAU', value=1.631240750229265e-07 +/- 0.962, bounds=[0.0:inf]> unconstrained at 589869579.9649283 % error. Fixing value.
# <Parameter 'STB_010', value=1.0147271275667573e-15 +/- 0.0108, bounds=[0.0:1.0]> unconstrained at 1061437430934074.0 % error. Fixing value.
# <Parameter 'DSK_FLX', value=6.41461541687779e-08 +/- 0.049, bounds=[0.0:2.0]> unconstrained at 76457221.0763848 % error. Fixing value.
# <Parameter 'DSK_TAU', value=4.682534292525296e-06 +/- 6.22e+04, bounds=[0.0:2.0]> unconstrained at 1327965757493.3188 % error. Fixing value.
# <Parameter 'g_MgVIII_30280N_Peak', value=1.902904283699438e-05 +/- 0.000609, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=3.380977953561638e-25 +/- 0.000344, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=3.380977953561638e-25 +/- 0.000344, bounds=[0.0:inf]> lower than uncertainty 1.3702030631551175e-05 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=1.5125435054444676e-23 +/- 0.000381, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=1.5125435054444676e-23 +/- 0.000381, bounds=[0.0:inf]> lower than uncertainty 1.566508282928493e-05 , fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=2.3492809799936673e-19 +/- 0.000406, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=2.3492809799936673e-19 +/- 0.000406, bounds=[0.0:inf]> lower than uncertainty 1.567894208605227e-05 , fixing to 0.0
# <Parameter 'g_AlVI_36597N_Peak', value=0.00010085763578657878 +/- 0.00045, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=2.099728821049755e-19 +/- 0.000983, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=2.099728821049755e-19 +/- 0.000983, bounds=[0.0:inf]> lower than uncertainty 2.9661270613382918e-05 , fixing to 0.0
# <Parameter 'g_CaVII_40858N_Peak', value=4.724206625061031e-25 +/- 0.000718, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaVII_40858N_Peak', value=4.724206625061031e-25 +/- 0.000718, bounds=[0.0:inf]> lower than uncertainty 2.9518260257290444e-05 , fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=2.0405969459610317e-22 +/- 0.000538, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_41150N_Peak', value=2.0405969459610317e-22 +/- 0.000538, bounds=[0.0:inf]> lower than uncertainty 2.2208394736302084e-05 , fixing to 0.0
# <Parameter 'g_CII_42988N_Peak', value=6.060006855159294e-19 +/- 0.000556, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CII_42988N_Peak', value=6.060006855159294e-19 +/- 0.000556, bounds=[0.0:inf]> lower than uncertainty 2.2086381275863663e-05 , fixing to 0.0
# <Parameter 'g_MgIV_44867N_Peak', value=7.804223897325963e-20 +/- 0.000789, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=7.804223897325963e-20 +/- 0.000789, bounds=[0.0:inf]> lower than uncertainty 2.4858183592462747e-05 , fixing to 0.0
# <Parameter 'g_ArVI_45295N_Peak', value=1.0509223497608213e-17 +/- 0.000794, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=1.0509223497608213e-17 +/- 0.000794, bounds=[0.0:inf]> lower than uncertainty 2.8992053200597813e-05 , fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=2.6528844680852538e-24 +/- 0.00066, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=2.6528844680852538e-24 +/- 0.00066, bounds=[0.0:inf]> lower than uncertainty 2.5942340283682464e-05 , fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=5.1222837613522e-26 +/- 0.000687, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KIII_46180N_Peak', value=5.1222837613522e-26 +/- 0.000687, bounds=[0.0:inf]> lower than uncertainty 2.7616923088856378e-05 , fixing to 0.0
# <Parameter 'g_SIX_46413N_Peak', value=3.476052475715919e-27 +/- 0.000725, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIX_46413N_Peak', value=3.476052475715919e-27 +/- 0.000725, bounds=[0.0:inf]> lower than uncertainty 2.8596550487248323e-05 , fixing to 0.0
# <Parameter 'g_SVII_50027N_Peak', value=9.641576266916554e-35 +/- 0.00102, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_50027N_Peak', value=9.641576266916554e-35 +/- 0.00102, bounds=[0.0:inf]> lower than uncertainty 3.9564241533200656e-05 , fixing to 0.0
# <Parameter 'g_SVII_52334N_Peak', value=2.5917440972534297e-24 +/- 0.00104, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_52334N_Peak', value=2.5917440972534297e-24 +/- 0.00104, bounds=[0.0:inf]> lower than uncertainty 3.488154144249066e-05 , fixing to 0.0
# <Parameter 'g_SiVIII_52910N_Peak', value=2.5207453482033434e-21 +/- 0.00123, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_52910N_Peak', value=2.5207453482033434e-21 +/- 0.00123, bounds=[0.0:inf]> lower than uncertainty 3.6740394710611605e-05 , fixing to 0.0
# <Parameter 'g_SiVIII_52910B_Gamma', value=0.0030565506239253136 +/- 0.0065, bounds=[0.00024459709043674874:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_FeVIII_54466N_Peak', value=0.0003039673592608402 +/- 0.00113, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgV_56098N_Peak', value=7.851779016654332e-18 +/- 0.00142, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgV_56098N_Peak', value=7.851779016654332e-18 +/- 0.00142, bounds=[0.0:inf]> lower than uncertainty 3.7863671072809884e-05 , fixing to 0.0
# <Parameter 'g_NeVI_76524N_Peak', value=1.1562478553229787e-24 +/- 0.00207, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeVI_76524N_Peak', value=1.1562478553229787e-24 +/- 0.00207, bounds=[0.0:inf]> lower than uncertainty 4.6641561276834414e-05 , fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=6.960964918166177e-28 +/- 0.00119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_79016N_Peak', value=6.960964918166177e-28 +/- 0.00119, bounds=[0.0:inf]> lower than uncertainty 4.0866770982829965e-05 , fixing to 0.0
# <Parameter 'g_ArIII_89914N_Peak', value=0.00024523894070952135 +/- 0.00138, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIV_90410N_Peak', value=3.0738307188834406e-24 +/- 0.001, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIV_90410N_Peak', value=3.0738307188834406e-24 +/- 0.001, bounds=[0.0:inf]> lower than uncertainty 3.559941051111206e-05 , fixing to 0.0
# <Parameter 'g_SIV_105105N_Peak', value=1.432358861245939e-14 +/- 0.00174, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIV_105105N_Peak', value=1.432358861245939e-14 +/- 0.00174, bounds=[0.0:inf]> lower than uncertainty 4.4037508525780986e-05 , fixing to 0.0
# <Parameter 'g_ArV_131022N_Peak', value=2.291187810239453e-16 +/- 0.00142, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_131022N_Peak', value=2.291187810239453e-16 +/- 0.00142, bounds=[0.0:inf]> lower than uncertainty 5.053269674176599e-05 , fixing to 0.0
# <Parameter 'g_NeV_143217N_Peak', value=9.803630880475936e-17 +/- 0.00237, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeV_143217N_Peak', value=9.803630880475936e-17 +/- 0.00237, bounds=[0.0:inf]> lower than uncertainty 6.434712864896633e-05 , fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=0.00114906703111302 +/- 0.003, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_179359N_Peak', value=0.0008405800550885677 +/- 0.00393, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=2.1351549843663696e-23 +/- 0.00529, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=2.1351549843663696e-23 +/- 0.00529, bounds=[0.0:inf]> lower than uncertainty 0.0002555836082696449 , fixing to 0.0
# <Parameter 'g_OIV_258903N_Peak', value=1.873189010430343e-11 +/- 0.0324, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_OIV_258903N_Peak', value=1.873189010430343e-11 +/- 0.0324, bounds=[0.0:inf]> lower than uncertainty 0.00039493382029309054 , fixing to 0.0
# <Parameter 'g_FeII_259883N_Peak', value=3.5122429359324473e-23 +/- 0.00715, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_259883N_Peak', value=3.5122429359324473e-23 +/- 0.00715, bounds=[0.0:inf]> lower than uncertainty 0.00033494567269504 , fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=2.5967487420176242e-30 +/- 0.000196, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=2.5967487420176242e-30 +/- 0.000196, bounds=[0.0:inf]> lower than uncertainty 4.626940337069057e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=5.902549749356898e-31 +/- 0.000314, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=5.902549749356898e-31 +/- 0.000314, bounds=[0.0:inf]> lower than uncertainty 4.525467850581641e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=3.02163747784192e-23 +/- 0.0403, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=3.02163747784192e-23 +/- 0.0403, bounds=[0.0:1.0]> lower than uncertainty 3.19968283111946e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# AGN
# AGN
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [2 0]
# Parameter object has 81 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [2 0] will be initialized with results from spaxel [1 1]
# Parameter object has 81 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2022-12-29 13:11:56.243432 -----------------
# True in 64 steps
# 232.42 seconds elapsed
# <Parameter 'HOT_TMP', value=1027.1996249914177 +/- 1.77e+03, bounds=[100.0:1027.2]> at upper bound, fixing to  1027.2
# <Parameter 'DSK_FLX', value=1.626427394577435e-07 +/- 0.0314, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=4.792018989717219e-07 +/- 0.000593, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVIII_30280B_Wave', value=3.0330316388574476 +/- 0.00477, bounds=[3.0229316849654717:3.033031690595159]> at upper bound, fixing to 3.033031690595159
# <Parameter 'g_MgVIII_30280B_Gamma', value=0.006671114072451134 +/- 0.00397, bounds=[0.0002598066564908304:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_KVII_31905N_Peak', value=1.7956272102392997e-24 +/- 0.000408, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=2.0532655590736776e-19 +/- 0.000428, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVIII_50019N_Peak', value=2.131776763106528e-14 +/- 0.00115, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVIII_50019B_Wave', value=5.010294493804106 +/- 0.00507, bounds=[4.9936101966772215:5.010294494026627]> at upper bound, fixing to 5.010294494026627
# <Parameter 'g_SiVIII_50019B_Gamma', value=0.006671114076050699 +/- 0.00241, bounds=[0.00025967880740211376:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_NaVIII_51789B_Gamma', value=0.006671114047548587 +/- 0.00305, bounds=[0.00025023236764237696:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_MgVII_55032B_Gamma', value=0.00023459679475980807 +/- 0.00514, bounds=[0.00023459633539198787:0.0066711140760507]> at lower bound, fixing to 0.00023459633539198787
# <Parameter 'g_MgVII_90090N_Peak', value=7.962269299754865e-26 +/- 0.000772, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Gamma', value=0.006671114076050699 +/- 0.000803, bounds=[0.000536762505574601:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'd8_PAH107_106800_Peak', value=7.825349690889615e-15 +/- 0.000173, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=2.0314398783331643e-37 +/- 0.000253, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=5.612142435111984e-25 +/- 0.000238, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_010', value=4.3508198313728074e-05 +/- 0.00473, bounds=[0.0:1.0]> unconstrained at 10862.975292681018 % error. Fixing value.
# <Parameter 'DSK_FLX', value=1.626427394577435e-07 +/- 0.0314, bounds=[0.0:2.0]> unconstrained at 19311166.22007598 % error. Fixing value.
# <Parameter 'DSK_TAU', value=0.10741862789190945 +/- 9.13e+04, bounds=[0.0:2.0]> unconstrained at 84961402.83207726 % error. Fixing value.
# <Parameter 'g_CoII_29846N_Peak', value=4.792018989717219e-07 +/- 0.000593, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=4.792018989717219e-07 +/- 0.000593, bounds=[0.0:inf]> lower than uncertainty 2.0674468892626856e-05 , fixing to 0.0
# <Parameter 'g_MgVIII_30280N_Peak', value=2.0255531249454677e-05 +/- 0.000673, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=1.7956272102392997e-24 +/- 0.000408, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=1.7956272102392997e-24 +/- 0.000408, bounds=[0.0:inf]> lower than uncertainty 1.8534767018253073e-05 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=2.0532655590736776e-19 +/- 0.000428, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=2.0532655590736776e-19 +/- 0.000428, bounds=[0.0:inf]> lower than uncertainty 1.9583482536876117e-05 , fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=2.6467909173786735e-05 +/- 0.000472, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=0.00012069653014178075 +/- 0.00047, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NiI_39524N_Peak', value=7.794219247677335e-05 +/- 0.000563, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_41150N_Peak', value=0.00015685929021594378 +/- 0.000638, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=0.00020072817101952624 +/- 0.000909, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=3.710842396112977e-05 +/- 0.000866, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46719N_Peak', value=0.00013336101886641234 +/- 0.000848, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=7.062850047196961e-05 +/- 0.00103, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_50019N_Peak', value=2.131776763106528e-14 +/- 0.00115, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_50019N_Peak', value=2.131776763106528e-14 +/- 0.00115, bounds=[0.0:inf]> lower than uncertainty 5.121234843152777e-05 , fixing to 0.0
# <Parameter 'g_NaVIII_51789N_Peak', value=5.695983686918948e-05 +/- 0.00138, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_52334N_Peak', value=1.193365164548003e-05 +/- 0.000756, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_52334N_Peak', value=1.193365164548003e-05 +/- 0.000756, bounds=[0.0:inf]> lower than uncertainty 2.8172868288286093e-05 , fixing to 0.0
# <Parameter 'g_SiVIII_52910N_Peak', value=9.611839093577067e-05 +/- 0.000874, bounds=[0.0:inf]> unconstrained, fixing entire feature
# ...
# <Parameter 'g_NeVI_76524N_Peak', value=3.0713124106650515e-28 +/- 0.0015, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeVI_76524N_Peak', value=3.0713124106650515e-28 +/- 0.0015, bounds=[0.0:inf]> lower than uncertainty 3.2950032480399366e-05 , fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=0.0002839538675509854 +/- 0.000837, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArIII_89914N_Peak', value=2.7163131523204244e-05 +/- 0.00115, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_AlVI_91160N_Peak', value=0.00016122622259431014 +/- 0.000607, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIV_105105N_Peak', value=6.398797810554638e-38 +/- 0.00158, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIV_105105N_Peak', value=6.398797810554638e-38 +/- 0.00158, bounds=[0.0:inf]> lower than uncertainty 3.133725454767942e-05 , fixing to 0.0
# <Parameter 'g_ArV_131022N_Peak', value=0.00017499756851300366 +/- 0.000901, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeV_143217N_Peak', value=1.6977994430029333e-20 +/- 0.00211, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeV_143217N_Peak', value=1.6977994430029333e-20 +/- 0.00211, bounds=[0.0:inf]> lower than uncertainty 4.952054514129502e-05 , fixing to 0.0
# <Parameter 'g_ArIII_218302N_Peak', value=0.0009104992858645198 +/- 0.0029, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeV_243175N_Peak', value=1.0888747129399005e-17 +/- 0.0107, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeV_243175N_Peak', value=1.0888747129399005e-17 +/- 0.0107, bounds=[0.0:inf]> lower than uncertainty 0.00017390331929845626 , fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=4.440721479533062e-12 +/- 0.00433, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=4.440721479533062e-12 +/- 0.00433, bounds=[0.0:inf]> lower than uncertainty 0.00021706467759066765 , fixing to 0.0
# <Parameter 'g_OIV_258903N_Peak', value=2.0356265924114447e-14 +/- 0.0258, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_OIV_258903N_Peak', value=2.0356265924114447e-14 +/- 0.0258, bounds=[0.0:inf]> lower than uncertainty 0.00034351016521092675 , fixing to 0.0
# <Parameter 'd8_PAH107_106800_Peak', value=3.160867885523333e-05 +/- 0.000151, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=3.300905996555402e-38 +/- 0.00013, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=3.300905996555402e-38 +/- 0.00013, bounds=[0.0:inf]> lower than uncertainty 3.311704189025246e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=1.2275610336155616e-36 +/- 0.000213, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=1.2275610336155616e-36 +/- 0.000213, bounds=[0.0:inf]> lower than uncertainty 3.363535066788599e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=0.004120754176591968 +/- 0.102, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# AGN
# AGN
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [2 2]
# Parameter object has 71 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [2 2] will be initialized with results from spaxel [1 1]
# Parameter object has 71 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2022-12-29 13:29:56.325504 -----------------
# True in 45 steps
# 177.15 seconds elapsed
# <Parameter 'g_SXIII_28926N_Peak', value=1.4218289315601018e-09 +/- 0.000356, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVIII_30280N_Peak', value=2.2858384070088812e-10 +/- 0.000425, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=3.1448164707261666e-11 +/- 0.000238, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=3.191294450744578e-10 +/- 0.000234, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=7.090112907962607e-11 +/- 0.000302, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_40819N_Peak', value=4.142301752431273e-25 +/- 0.000448, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaVII_40858N_Peak', value=9.158711573090528e-18 +/- 0.000451, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaVII_46847N_Peak', value=8.080514544609995e-28 +/- 0.000575, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_48891N_Peak', value=2.915051280819208e-15 +/- 0.000656, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaVIII_51789N_Peak', value=1.7279656967980353e-13 +/- 0.000779, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaVIII_51789B_Gamma', value=0.006671074630439135 +/- 0.0028, bounds=[0.00025023236764237696:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_SiVIII_52910N_Peak', value=5.8796603787262547e-08 +/- 0.000575, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeVIII_54466B_Wave', value=5.4375755041212015 +/- 0.00979, bounds=[5.437573181635409:5.455740816722731]> at lower bound, fixing to 5.437573181635409
# <Parameter 'g_MgVII_55032N_Peak', value=2.192462586956026e-07 +/- 0.000667, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVII_55032B_Wave', value=5.512429808798452 +/- 0.00149, bounds=[5.494079376707668:5.512435806299073]> at upper bound, fixing to 5.512435806299073
# <Parameter 'g_MgV_56098N_Peak', value=1.0185663001429387e-12 +/- 0.000792, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeVI_76524N_Peak', value=3.72764668506475e-10 +/- 0.00118, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVII_90090N_Peak', value=1.9018192097290067e-16 +/- 0.00057, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_AlVI_91160N_Peak', value=4.332552796935428e-12 +/- 0.000595, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SIV_105105N_Peak', value=6.001678800385122e-08 +/- 0.000968, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_143217N_Peak', value=6.295781114419626e-08 +/- 0.00167, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Gamma', value=0.006671114076050699 +/- 0.000965, bounds=[0.000536762505574601:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_SI_252490N_Peak', value=3.995680031335446e-09 +/- 0.00441, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_OIV_258903N_Peak', value=6.690830536678169e-09 +/- 0.0243, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=4.174538838673418e-11 +/- 0.00021, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=7.690263348997889e-09 +/- 0.000192, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH174_173750_Peak', value=3.11392885877544e-07 +/- 0.000254, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=4.909037199545489e-12 +/- 0.0852, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_010', value=0.00036449972114066786 +/- 0.0131, bounds=[0.0:1.0]> unconstrained at 3595.4488448040493 % error. Fixing value.
# <Parameter 'DSK_TAU', value=0.000709574506005565 +/- 0.366, bounds=[0.0:2.0]> unconstrained at 51577.27880564079 % error. Fixing value.
# <Parameter 'g_SXIII_28926N_Peak', value=1.4218289315601018e-09 +/- 0.000356, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SXIII_28926N_Peak', value=1.4218289315601018e-09 +/- 0.000356, bounds=[0.0:inf]> lower than uncertainty 9.917362387237768e-06 , fixing to 0.0
# <Parameter 'g_MgVIII_30280N_Peak', value=2.2858384070088812e-10 +/- 0.000425, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVIII_30280N_Peak', value=2.2858384070088812e-10 +/- 0.000425, bounds=[0.0:inf]> lower than uncertainty 9.514237814053292e-06 , fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=3.1448164707261666e-11 +/- 0.000238, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=3.1448164707261666e-11 +/- 0.000238, bounds=[0.0:inf]> lower than uncertainty 9.413610684691807e-06 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=3.191294450744578e-10 +/- 0.000234, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=3.191294450744578e-10 +/- 0.000234, bounds=[0.0:inf]> lower than uncertainty 9.85307675788314e-06 , fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=7.090112907962607e-11 +/- 0.000302, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=7.090112907962607e-11 +/- 0.000302, bounds=[0.0:inf]> lower than uncertainty 1.009106480212296e-05 , fixing to 0.0
# <Parameter 'g_H200S14_37240N_Peak', value=5.332223772173514e-05 +/- 0.000275, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=4.142301752431273e-25 +/- 0.000448, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=4.142301752431273e-25 +/- 0.000448, bounds=[0.0:inf]> lower than uncertainty 1.6571861448791584e-05 , fixing to 0.0
# <Parameter 'g_CaVII_40858N_Peak', value=9.158711573090528e-18 +/- 0.000451, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaVII_40858N_Peak', value=9.158711573090528e-18 +/- 0.000451, bounds=[0.0:inf]> lower than uncertainty 1.9479346933090398e-05 , fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=5.109520508131397e-05 +/- 0.000352, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=2.4563035867120833e-05 +/- 0.00048, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=4.699332208258978e-05 +/- 0.000524, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVII_46847N_Peak', value=8.080514544609995e-28 +/- 0.000575, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVII_46847N_Peak', value=8.080514544609995e-28 +/- 0.000575, bounds=[0.0:inf]> lower than uncertainty 1.9178645401449022e-05 , fixing to 0.0
# <Parameter 'g_FeII_48891N_Peak', value=2.915051280819208e-15 +/- 0.000656, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=2.915051280819208e-15 +/- 0.000656, bounds=[0.0:inf]> lower than uncertainty 2.303561808792752e-05 , fixing to 0.0
# <Parameter 'g_NaVIII_51789N_Peak', value=1.7279656967980353e-13 +/- 0.000779, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVIII_51789N_Peak', value=1.7279656967980353e-13 +/- 0.000779, bounds=[0.0:inf]> lower than uncertainty 2.9885658762914582e-05 , fixing to 0.0
# <Parameter 'g_SiVIII_52910N_Peak', value=5.8796603787262547e-08 +/- 0.000575, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_52910N_Peak', value=5.8796603787262547e-08 +/- 0.000575, bounds=[0.0:inf]> lower than uncertainty 1.771594377110177e-05 , fixing to 0.0
# <Parameter 'g_FeVIII_54466N_Peak', value=2.35941959438521e-05 +/- 0.000526, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_55032N_Peak', value=2.192462586956026e-07 +/- 0.000667, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_55032N_Peak', value=2.192462586956026e-07 +/- 0.000667, bounds=[0.0:inf]> lower than uncertainty 1.722643994348456e-05 , fixing to 0.0
# <Parameter 'g_MgV_56098N_Peak', value=1.0185663001429387e-12 +/- 0.000792, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgV_56098N_Peak', value=1.0185663001429387e-12 +/- 0.000792, bounds=[0.0:inf]> lower than uncertainty 1.6926759366955178e-05 , fixing to 0.0
# <Parameter 'g_FeII_56739N_Peak', value=0.0001133265518153242 +/- 0.000567, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeVI_76524N_Peak', value=3.72764668506475e-10 +/- 0.00118, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeVI_76524N_Peak', value=3.72764668506475e-10 +/- 0.00118, bounds=[0.0:inf]> lower than uncertainty 2.4789475202482883e-05 , fixing to 0.0
# <Parameter 'g_MgVII_90090N_Peak', value=1.9018192097290067e-16 +/- 0.00057, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_90090N_Peak', value=1.9018192097290067e-16 +/- 0.00057, bounds=[0.0:inf]> lower than uncertainty 1.937232162940815e-05 , fixing to 0.0
# <Parameter 'g_AlVI_91160N_Peak', value=4.332552796935428e-12 +/- 0.000595, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_AlVI_91160N_Peak', value=4.332552796935428e-12 +/- 0.000595, bounds=[0.0:inf]> lower than uncertainty 1.9571845346669658e-05 , fixing to 0.0
# <Parameter 'g_FeVII_95267N_Peak', value=0.0002961578996269039 +/- 0.00062, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIV_105105N_Peak', value=6.001678800385122e-08 +/- 0.000968, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIV_105105N_Peak', value=6.001678800385122e-08 +/- 0.000968, bounds=[0.0:inf]> lower than uncertainty 2.5568309992236904e-05 , fixing to 0.0
# <Parameter 'g_NeV_143217N_Peak', value=6.295781114419626e-08 +/- 0.00167, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeV_143217N_Peak', value=6.295781114419626e-08 +/- 0.00167, bounds=[0.0:inf]> lower than uncertainty 3.65242952388516e-05 , fixing to 0.0
# <Parameter 'g_NeV_243175N_Peak', value=0.0008465214501288712 +/- 0.00454, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=3.995680031335446e-09 +/- 0.00441, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=3.995680031335446e-09 +/- 0.00441, bounds=[0.0:inf]> lower than uncertainty 0.00019642578925516466 , fixing to 0.0
# <Parameter 'g_OIV_258903N_Peak', value=6.690830536678169e-09 +/- 0.0243, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_OIV_258903N_Peak', value=6.690830536678169e-09 +/- 0.0243, bounds=[0.0:inf]> lower than uncertainty 0.00032539708556602074 , fixing to 0.0
# <Parameter 'g_FeII_259883N_Peak', value=0.0018906118575497868 +/- 0.00661, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=4.174538838673418e-11 +/- 0.00021, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=4.174538838673418e-11 +/- 0.00021, bounds=[0.0:inf]> lower than uncertainty 3.0200586290431997e-05 , fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=7.690263348997889e-09 +/- 0.000192, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd15_PAH159_159000_Peak', value=7.690263348997889e-09 +/- 0.000192, bounds=[0.0:inf]> lower than uncertainty 3.5118172665137665e-05 , fixing to 0.0
# <Parameter 'd16_PAH170_170400_Peak', value=2.823090454396893e-05 +/- 0.000225, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH174_173750_Peak', value=3.11392885877544e-07 +/- 0.000254, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH174_173750_Peak', value=3.11392885877544e-07 +/- 0.000254, bounds=[0.0:inf]> lower than uncertainty 4.0479873680825416e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=4.909037199545489e-12 +/- 0.0852, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=4.909037199545489e-12 +/- 0.0852, bounds=[0.0:1.0]> lower than uncertainty 1.9345916534743125e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------

# %%
# Line and PAH averaged velocity gradient wrt z, in [km/s]
print(s.parcube['VALUE'].data[-1])
print(s.parcube['VALUE'].data[-1]/2.998e5)
# Out:
# [[-33.12774695 -17.94881988  29.79515779]
#  [-21.5783697    3.13743508  94.89977061]
#  [ 53.44529311  80.37588246  99.99333297]]
# [[-1.10499489e-04 -5.98693125e-05  9.93834483e-05]
#  [-7.19758829e-05  1.04650936e-05  3.16543598e-04]
#  [ 1.78269824e-04  2.68098340e-04  3.33533466e-04]]

# %%
s.plot_cube_fit(1, 1, inppar_fn, optpar_fn)
# Out:
# AGN
# AGN
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Load the parameter cube from drive
parcube_fd = '/Users/tanio/Sync/pywork/CAFE_dev/output/'+source_fnb+'/'
parcube_fn = source_fnb+'_parcube.fits'

# %%
s.read_cube(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ./CRETA/extractions/NGC7469_GridExt_3x3_s0.5as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        38   (3, 3, 12894)   float64
#   2  ERR           1 ImageHDU         9   (3, 3, 12894)   float64
#   3  FLUX_ST       1 ImageHDU         9   (3, 3, 12894)   float64
#   4  ERR_ST        1 ImageHDU         9   (3, 3, 12894)   float64
#   5  DQ            1 ImageHDU         9   (3, 3, 12894)   float64
#   6  WAVE          1 ImageHDU         7   (12894,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   12894R x 1C   [20A]

# %%
s.read_parcube_file(parcube_fn, file_dir=parcube_fd)
# Out:
# Filename: /Users/tanio/Sync/pywork/CAFE_dev/output/NGC7469_GridExt_3x3_s05as_cube/NGC7469_GridExt_3x3_s05as_cube_parcube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  VALUE         1 ImageHDU        38   (3, 3, 460)   float64
#   2  STDERR        1 ImageHDU        38   (3, 3, 460)   float64
#   3  VARY          1 ImageHDU        38   (3, 3, 460)   float64
#   4  MIN           1 ImageHDU        38   (3, 3, 460)   float64
#   5  MAX           1 ImageHDU        38   (3, 3, 460)   float64
#   6  EXPR          1 BinTableHDU     13   460R x 2C   [I, 24A]
#   7  PARNAME       1 BinTableHDU     13   460R x 2C   [I, 32A]

# %%
s.plot_cube_fit(1, 1, inppar_fn, optpar_fn)
# Out:
# AGN
# AGN
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Generate map of feature (TBD)
#s.make_map('HOT_FLX')

# %%
from astropy.io import ascii
from astropy.table import Table
from astropy.table import QTable

# Read output PAH table
pah = cafeio.pah_table(s.parcube, 0, 0)
# Read output line table
line = cafeio.line_table(s.parcube, 0, 0)

pah62 = pah[pah.index == 'PAH62'].pah_strength.values[0]
pah62_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah77 = pah[pah.index == 'PAH77_C'].pah_strength.values[0]
pah77_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah113 = pah[pah.index == 'PAH113_C'].pah_strength.values[0]
pah113_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]

x = pah62 / pah77 
x_unc = pah62 / pah77 * np.sqrt((pah62_unc/pah62)**2 + (pah77_unc/pah77)**2)
y = pah113 / pah77
y_unc = pah113 / pah77 * np.sqrt((pah113_unc/pah113)**2 + (pah77_unc/pah77)**2)

print('6.2/7.7 = {} +/- {}'.format(x, x_unc))
print('11.3/7.7 = {} +/- {}'.format(y, y_unc))

print(pah)

# Make an astropy table 
t = QTable([pah.index.values, pah.pah_strength, pah.pah_strength_unc],
           names = ('pah_complex', 'pah_strength', 'pah_strength_unc'),
           meta={'wavelength': 'micron',
                 'flux': 'W/m^2',
                }
          )

# Write PAH table in an .ecsv file
#t.write('./NGC7469_pah_tbl.ecsv', overwrite=False)
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 6.2/7.7 = 0.2694158115306601 +/- 0.006545463417734035
# 11.3/7.7 = 0.3846227736544648 +/- 0.006771473023612428
#              pah_strength  pah_strength_unc
# pah_complex
# PAH113_C     2.106990e-19      5.208565e-21
# PAH120       5.274476e-20      2.831340e-21
# PAH126_C     1.072756e-19      3.656524e-21
# PAH136       1.232616e-20      1.720379e-21
# PAH142       0.000000e+00      0.000000e+00
# PAH164       9.552297e-21      7.926729e-22
# PAH170_C     1.487757e-20      2.290471e-21
# PAH33        4.747356e-20      2.642360e-21
# PAH62        1.475878e-19      3.462199e-21
# PAH77_C      5.478069e-19      1.755303e-20
# PAH83        3.863632e-20      3.610172e-21
# PAH86        1.087322e-19      3.472195e-21
# ali34        6.032916e-21      2.734573e-21
# ali345       1.208811e-20      4.178507e-21
