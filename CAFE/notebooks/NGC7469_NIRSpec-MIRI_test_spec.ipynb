# %%
import os
os._exit(00)

# %%
import sys
sys.path.insert(0, '../../CAFE')
sys.path.insert(0, '../../CRETA')

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib widget
import matplotlib.ticker
from matplotlib.backends.backend_pdf import PdfPages

import creta
import cafe_io
from cafe_io import *
import cafe_helper
from cafe_helper import *
import cafe

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# User API Created
# <style>.container { width:100% !important; }</style>

# %%
# SPECTRAL EXTRACTION

# %%
# Read parameter file with extraction keywords
creta_dir = '../../CRETA/'
pf = open(creta_dir+'param_files/NGC7469_single_params.txt','r')
print(pf.read())
pf.close()
# Out:
# cubes = g140h, g235h, g395h, ch1-short, ch1-medium, ch1-long, ch2-short, ch2-medium, ch2-long, ch3-short, ch3-medium, ch3-long, ch4-short, ch4-medium, ch4-long
# user_r_ap = 0.3                 # [arcsec] Aperture size
# user_ra = 23h03m15.614s         # RA of the extraction location
# user_dec = 08d52m26.23s         # Dec of the extraction location
# point_source = False            # [True/False] True = Cone extraction. False = Cylinder extraction
# lambda_ap = 5.4                 # [microns] The user-specified aperture size (user_r_ap) will be defined at this wavelength (ignored if point_source=False; cylinder extraction)
# aperture_correction = False     # [True/False]
# centering = True                # [True/False] At lambda_cent, this will update user_ra,user_dec to recenter the extraction location
# lambda_cent = 5.4               # [microns] The wavelength at which to perform the centering (ignored if centering=False)
# background_sub = False          # [True/False]
# r_ann_in = 0.0                  # [arcsec] When background_sub=True, this defines the inner annulus size. This size will NOT scale with aperture size even when point_source=True
# ann_width = 0.0                 # [arcsec] When background_sub=True, this defines the annulus width. This size will NOT scale with aperture size even when point_source=True

# %%
# Load the extraction tool (CRETA)
c = creta.creta(creta_dir)
# Out:
# CAFE Region Extraction Tool Automaton (CRETA) initialized

# %%
# Perform the extraction
c.singleExtraction(parameter_file=True, perband_cent=True, parfile_name='NGC7469_single_params.txt', data_path='../CRETA/data/NGC7469/', output_filebase_name='NGC7469')
# Out:
# User API Created
# PSFs: ../CRETA/PSFs/
# Data: ../CRETA/data/NGC7469/
# ########################################
#      Load User Parameters
# ########################################
# Cubes: ['g140h', 'g235h', 'g395h', 'ch1-short', 'ch1-medium', 'ch1-long', 'ch2-short', 'ch2-medium', 'ch2-long', 'ch3-short', 'ch3-medium', 'ch3-long', 'ch4-short', 'ch4-medium', 'ch4-long']
# Aperture radii: [0.3] (arcsec)
# RA,δ: [345.81505833,8.87395278] (degrees)
# Point Source: False
# Aperture Correction: False (PSF Correction)
# Centering: True
# Centering lambda: 5.4μm
# Background Subtraction: False
# PSF sub-cubes Path: ../CRETA/PSFs/
# Data sub-cubes Path: ../CRETA/data/NGC7469/
# ########################################
# Loading Data
# Load file: ../CRETA/data/NGC7469/Level3_g140h-f100lp_s3d.fits
# Load file: ../CRETA/data/NGC7469/Level3_g235h-f170lp_s3d.fits
# Load file: ../CRETA/data/NGC7469/Level3_g395h-f290lp_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch1-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch1-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch1-long_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch2-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch2-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch2-long_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch3-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch3-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch3-long_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch4-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch4-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch4-long_s3d.fits
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# Centering around 5.399500119092409 um in cube ch1_SHORT
# Old coordinates were: 345.81505833 8.87395278
# New coordinates are: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505833, 8.87395278)>
# Per-band re-centering around 0.9704062933143935 um in cube G140H
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81526723, 8.87393467)>
# Per-band re-centering around 1.660691434380468 um in cube G235H
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81524248, 8.87393663)>
# Per-band re-centering around 2.871215809167602 um in cube G395H
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81524207, 8.87392658)>
# Per-band re-centering around 4.902500095486175 um in cube ch1_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505874, 8.87393501)>
# Per-band re-centering around 5.662499847530853 um in cube ch1_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506329, 8.87392821)>
# Per-band re-centering around 6.532500209927093 um in cube ch1_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506107, 8.87393765)>
# Per-band re-centering around 7.515000229119323 um in cube ch2_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505866, 8.87393817)>
# Per-band re-centering around 8.675000076531433 um in cube ch2_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505679, 8.87394853)>
# Per-band re-centering around 10.02500045800116 um in cube ch2_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506524, 8.87393436)>
# Per-band re-centering around 11.557500190800054 um in cube ch3_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506616, 8.87392467)>
# Per-band re-centering around 13.347500152653083 um in cube ch3_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506916, 8.87392202)>
# Per-band re-centering around 15.417499847477304 um in cube ch3_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506453, 8.87393263)>
# Per-band re-centering around 17.71500076306984 um in cube ch4_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506695, 8.87393001)>
# Per-band re-centering around 20.705000534188 um in cube ch4_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505906, 8.87393121)>
# Per-band re-centering around 24.205000534188 um in cube ch4_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81503673, 8.87389218)>
# G140H photometry exectued in: 3.5474460124969482 seconds
# G235H photometry exectued in: 3.4322991371154785 seconds
# G395H photometry exectued in: 3.2771310806274414 seconds
# ch1_SHORT photometry exectued in: 0.7929162979125977 seconds
# ch1_MEDIUM photometry exectued in: 0.8900978565216064 seconds
# ch1_LONG photometry exectued in: 1.086651086807251 seconds
# ch2_SHORT photometry exectued in: 0.6569280624389648 seconds
# ch2_MEDIUM photometry exectued in: 0.668586015701294 seconds
# ch2_LONG photometry exectued in: 0.7709660530090332 seconds
# ch3_SHORT photometry exectued in: 0.601046085357666 seconds
# ch3_MEDIUM photometry exectued in: 0.6762917041778564 seconds
# ch3_LONG photometry exectued in: 0.7851121425628662 seconds
# ch4_SHORT photometry exectued in: 0.5058801174163818 seconds
# ch4_MEDIUM photometry exectued in: 0.5785510540008545 seconds
# ch4_LONG photometry exectued in: 0.7080790996551514 seconds
# Photometry exectued in': 19.031135082244873 seconds
# Initiating stitching process
# Stitch ratios: [[1.065765635039456, 1.0791016402285105, 65.71915296692573, 0.9817629353401767, 1.0019469899119517, 0.8812660951473752, 1.028867902489856, 1.0203618002202592, 0.7787761231337297, 0.9923513257961114, 0.9697833420871936, 0.80271085038905, 0.9897231096353811, 0.9823055647797582, 1.0]]
# For radius 0.3                  arcsec:
# Stitching performed in: 2.247697114944458 seconds
# Output written in: 2.3088388442993164 seconds
# 1 file output(s) named: NGC7469_SingleExt_r0.3as
# {'extraction_RA': <Longitude 345.81505833 deg>, 'extraction_DEC': <Latitude 8.87395278 deg>, 'r_ap': '0.3                 ', 'exrtaction_type': 'extended source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'bkg_sub': False, 'bkg_r_in': None, 'bkg_an_w': None}
# Total execution time of single region extraction: 113.74926805496216 seconds

# %% [markdown]
# # CAFE FITTING

# %%
# Setup directories
source_fd = '../../CRETA/extractions/'
source_fn = 'NGC7469_SingleExt_r0.3as_cube.fits'
source_fnb = source_fn.split('.fits')[0].replace('.','')

cafe_dir = '../../CAFE/'
inppar_fn = cafe_dir+'inp_parfiles/inpars_jwst_nirspec-miri_AGN.ini'
optpar_fn = cafe_dir+'opt_parfiles/default_opt.cafe'

z=0.01630

# %%
s = cafe.specmod(cafe_dir)

# %%
s.read_spec(source_fn, file_dir=source_fd, z=z)
# Out:
# Load data: ../../CRETA/extractions/NGC7469_SingleExt_r0.3as_cube.fits
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Documents/astro/CAFE/CAFE/CAFE/notebooks/../../CAFE/cafe.py:407, in specmod.read_spec(self, file_name, file_dir, extract, trim, keep_next, z)
#     406 try:
# --> 407     cube = cafeio.read_cretacube(file_dir+file_name, extract)
#     408 except:
#
# File ~/Documents/astro/CAFE/CAFE/CAFE/notebooks/../../CAFE/cafe_io.py:56, in cafe_io.read_cretacube(self, file_name, extract)
#      54 def read_cretacube(self, file_name, extract):
# ---> 56     cube = fits.open(file_name)
#      57     cube.info()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:176, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     174     raise ValueError(f'Empty filename: {name!r}')
# --> 176 return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#     177                         lazy_load_hdus, ignore_missing_simple, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:411, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     403 """
#     404 Creates an `HDUList` instance from a file-like object.
#     405
#    (...)
#     408 documentation for details of the parameters accepted by this method).
#     409 """
# --> 411 return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     412                      save_backup=save_backup, cache=cache,
#     413                      ignore_missing_simple=ignore_missing_simple,
#     414                      lazy_load_hdus=lazy_load_hdus, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:1071, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#    1069 if not isinstance(fileobj, _File):
#    1070     # instantiate a FITS file object (ffo)
# -> 1071     fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1072 # The Astropy mode is determined by the _File initializer if the
#    1073 # supplied mode was None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/utils/decorators.py:546, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     544         warnings.warn(msg, warning_type, stacklevel=2)
# --> 546 return function(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/fits/file.py:175, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache)
#     174 elif isinstance(fileobj, (str, bytes)):
# --> 175     self._open_filename(fileobj, mode, overwrite)
#     176 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/fits/file.py:564, in _File._open_filename(self, filename, mode, overwrite)
#     563 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 564     self._file = fileobj_open(self.name, IO_FITS_MODES[mode])
#     565     self.close_on_error = True
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/fits/util.py:388, in fileobj_open(filename, mode)
#     379 """
#     380 A wrapper around the `open()` builtin.
#     381
#    (...)
#     385 a raw random-access file reader.
#     386 """
# --> 388 return open(filename, mode, buffering=0)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../CRETA/extractions/NGC7469_SingleExt_r0.3as_cube.fits'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Documents/astro/CAFE/CAFE/CAFE/notebooks/../../CAFE/cafe.py:417, in specmod.read_spec(self, file_name, file_dir, extract, trim, keep_next, z)
#     416 try:
# --> 417     spec = cafeio.customFITSReader(file_dir+file_name, extract) # Returns a spectrum1D
#     418 except:
#
# File ~/Documents/astro/CAFE/CAFE/CAFE/notebooks/../../CAFE/cafe_io.py:91, in cafe_io.customFITSReader(file_name, extract)
#      83 @staticmethod
#      84 def customFITSReader(file_name, extract):
#      85
#    (...)
#      88     # 'ap_PSC': Aperture flux point-source corrected
#      89     # 'ap_st': Aperture flux stitched (if PSC has been applied, that is the stitched spectrum)
# ---> 91     hdu_list = fits.open(file_name)
#      92     res_spec1d = []
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:176, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     174     raise ValueError(f'Empty filename: {name!r}')
# --> 176 return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#     177                         lazy_load_hdus, ignore_missing_simple, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:411, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     403 """
#     404 Creates an `HDUList` instance from a file-like object.
#     405
#    (...)
#     408 documentation for details of the parameters accepted by this method).
#     409 """
# --> 411 return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     412                      save_backup=save_backup, cache=cache,
#     413                      ignore_missing_simple=ignore_missing_simple,
#     414                      lazy_load_hdus=lazy_load_hdus, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:1071, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#    1069 if not isinstance(fileobj, _File):
#    1070     # instantiate a FITS file object (ffo)
# -> 1071     fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1072 # The Astropy mode is determined by the _File initializer if the
#    1073 # supplied mode was None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/utils/decorators.py:546, in deprecated_renamed_argument.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     544         warnings.warn(msg, warning_type, stacklevel=2)
# --> 546 return function(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/fits/file.py:175, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache)
#     174 elif isinstance(fileobj, (str, bytes)):
# --> 175     self._open_filename(fileobj, mode, overwrite)
#     176 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/fits/file.py:564, in _File._open_filename(self, filename, mode, overwrite)
#     563 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 564     self._file = fileobj_open(self.name, IO_FITS_MODES[mode])
#     565     self.close_on_error = True
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/fits/util.py:388, in fileobj_open(filename, mode)
#     379 """
#     380 A wrapper around the `open()` builtin.
#     381
#    (...)
#     385 a raw random-access file reader.
#     386 """
# --> 388 return open(filename, mode, buffering=0)
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../CRETA/extractions/NGC7469_SingleExt_r0.3as_cube.fits'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/Documents/astro/CAFE/CAFE/CAFE/notebooks/../../CAFE/cafe.py:421, in specmod.read_spec(self, file_name, file_dir, extract, trim, keep_next, z)
#     420     from astropy.table import Table
# --> 421     tab = Table.read(file_dir+file_name, format='ascii.basic', names=['wave', 'flux', 'flux_unc'])
#     422 except:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/table/connect.py:62, in TableRead.__call__(self, *args, **kwargs)
#      60 descriptions = kwargs.pop('descriptions', None)
# ---> 62 out = self.registry.read(cls, *args, **kwargs)
#      64 # For some readers (e.g., ascii.ecsv), the returned `out` class is not
#      65 # guaranteed to be the same as the desired output `cls`.  If so,
#      66 # try coercing to desired class without copying (io.registry.read
#      67 # would normally do a copy).  The normal case here is swapping
#      68 # Table <=> QTable.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/registry/core.py:199, in UnifiedInputRegistry.read(self, cls, format, cache, *args, **kwargs)
#     198 reader = self.get_reader(format, cls)
# --> 199 data = reader(*args, **kwargs)
#     201 if not isinstance(data, cls):
#     202     # User has read with a subclass where only the parent class is
#     203     # registered.  This returns the parent class, so try coercing
#     204     # to desired subclass.
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/ascii/connect.py:18, in io_read(format, filename, **kwargs)
#      17     kwargs['format'] = format
# ---> 18 return read(filename, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/ascii/ui.py:341, in read(table, guess, **kwargs)
#     337 # Get the table from guess in ``dat``.  If ``dat`` comes back as None
#     338 # then there was just one set of kwargs in the guess list so fall
#     339 # through below to the non-guess way so that any problems result in a
#     340 # more useful traceback.
# --> 341 dat = _guess(table, new_kwargs, format, fast_reader)
#     342 if dat is None:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/ascii/ui.py:506, in _guess(table, read_kwargs, format, fast_reader)
#     505 reader.guessing = True
# --> 506 dat = reader.read(table)
#     507 _read_trace.append({'kwargs': copy.deepcopy(guess_kwargs),
#     508                     'Reader': reader.__class__,
#     509                     'status': 'Success (guessing)',
#     510                     'dt': f'{(time.time() - t0) * 1000:.3f} ms'})
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/astropy/io/ascii/fastbasic.py:109, in FastBasic.read(self, table)
#     107 self.kwargs['fast_reader'] = fast_reader
# --> 109 self.engine = cparser.CParser(table, self.strip_whitespace_lines,
#     110                               self.strip_whitespace_fields,
#     111                               delimiter=self.delimiter,
#     112                               header_start=self.header_start,
#     113                               comment=self.comment,
#     114                               quotechar=self.quotechar,
#     115                               data_start=self.data_start,
#     116                               fill_extra_cols=self.fill_extra_cols,
#     117                               **self.kwargs)
#     118 conversion_info = self._read_header()
#
# File astropy/io/ascii/cparser.pyx:248, in astropy.io.ascii.cparser.CParser.__cinit__()
#
# File astropy/io/ascii/cparser.pyx:296, in astropy.io.ascii.cparser.CParser.setup_tokenizer()
#
# File astropy/io/ascii/cparser.pyx:124, in astropy.io.ascii.cparser.FileString.__cinit__()
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../CRETA/extractions/NGC7469_SingleExt_r0.3as_cube.fits'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 s.read_spec(source_fn, file_dir=source_fd, z=z)
#
# File ~/Documents/astro/CAFE/CAFE/CAFE/notebooks/../../CAFE/cafe.py:423, in specmod.read_spec(self, file_name, file_dir, extract, trim, keep_next, z)
#     421     tab = Table.read(file_dir+file_name, format='ascii.basic', names=['wave', 'flux', 'flux_unc'])
#     422 except:
# --> 423     raise IOError('The file is not a valid .txt (column-based) or .fits (CRETA output) file. Or maybe the data are not there.')
#     424 else:
#     425     spec = Spectrum1D(spectral_axis=tab['wave']*u.micron, flux=tab['flux']*u.Jy, uncertainty=StdDevUncertainty(tab['flux_unc']), redshift=z)
#
# OSError: The file is not a valid .txt (column-based) or .fits (CRETA output) file. Or maybe the data are not there.

# %%
s.plot_spec_ini(inppar_fn, optpar_fn)
# Out:
# Generating continuum profiles for guess model
# Parameter object has 126 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s.fit_spec(inppar_fn, optpar_fn)
# Out:
# Generating parameter object
# Parameter object has 126 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Generating continuum profiles
# ISRF
# ISRF
# 2.35 seconds to make continnum profiles
# Generating parameter cube
# Fitting 511 parameters
# Iteration 1/5(max): 2023-01-07 14:48:05.589950 -----------------
# True in 61 steps
# 492.84 seconds elapsed
# <Parameter 'DSK_FLX', value=7.792142063076325e-11 +/- 0.0282, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'g_Paschen63_10941B_Gamma', value=0.006671114076050699 +/- 0.000485, bounds=[0.000431075686423192:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_Paschen53_12822B_Gamma', value=0.006671114076050699 +/- 0.000316, bounds=[0.0003657292645975759:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_Paschen43_18756B_Gamma', value=0.006671114076050699 +/- 0.000212, bounds=[0.0004325502202656655:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_Brackett64_26259B_Gamma', value=0.006671114076050699 +/- 0.000669, bounds=[0.00030187149090572254:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_AlV_29052N_Peak', value=1.1334491788748368e-19 +/- 0.00137, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=9.734417457605644e-19 +/- 0.00151, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=1.819132672883334e-23 +/- 0.00106, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S14_37240N_Peak', value=1.5633859935864337e-18 +/- 0.00133, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=9.1108041463323e-28 +/- 0.00191, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=1.8378832132713123e-32 +/- 0.00141, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeVIII_54466B_Gamma', value=0.0066711140760506785 +/- 0.000965, bounds=[0.0002371829799907665:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_ArII_69853N_Peak', value=4.645233482177137e-13 +/- 0.00499, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=4.253638833269493e-12 +/- 0.00293, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=3.9699144246209064e-15 +/- 0.0152, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_259883N_Peak', value=4.26212196295813e-22 +/- 0.0196, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd20_PAH30_30100_Peak', value=4.3873151565748253e-36 +/- 0.000179, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd0_PAH33_32900_Peak', value=1.8713978116864334e-32 +/- 0.000247, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd0_PAH34_34260_Peak', value=1.2391144419848428e-17 +/- 0.000296, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=9.059322448685392e-39 +/- 0.000258, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=1.1403186044276092e-35 +/- 0.000529, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=1.7570126972148638e-34 +/- 0.000427, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd7_PAH86_86100_Peak', value=2.38995908834737e-35 +/- 0.000413, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=7.550647265810694e-07 +/- 0.00119, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=3.1849969747771167e-23 +/- 0.000528, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=1.3737051803905358e-25 +/- 0.000956, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=1.354748572490118e-12 +/- 0.0145, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'DSK_FLX', value=7.792142063076325e-11 +/- 0.0282, bounds=[0.0:2.0]> unconstrained at 36196730469.544945 % error. Fixing value.
# <Parameter 'DSK_TAU', value=0.014762287474451536 +/- 3.26e+05, bounds=[0.0:2.0]> unconstrained at 2209406989.378827 % error. Fixing value.
# <Parameter 'g_Paschen73_10052N_Peak', value=0.0002092540582577068 +/- 0.000956, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_OI_11290N_Peak', value=0.000112398717301833 +/- 0.000903, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_17419N_Peak', value=0.0005350985308191842 +/- 0.00155, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H210S6_17880N_Peak', value=0.0005819700564960838 +/- 0.0017, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_AlIX_20400N_Peak', value=0.0001448992801906467 +/- 0.000963, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_HeI_20587N_Peak', value=1.9308810959778316e-05 +/- 0.00119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_20894N_Peak', value=0.00034174056258589025 +/- 0.000891, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgII_21438N_Peak', value=0.0004093341039775974 +/- 0.00101, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_HeII_21891N_Peak', value=0.00021557946088667667 +/- 0.00112, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaI_22062N_Peak', value=0.00023532237480039894 +/- 0.000901, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_AlV_29052N_Peak', value=1.1334491788748368e-19 +/- 0.00137, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_AlV_29052N_Peak', value=1.1334491788748368e-19 +/- 0.00137, bounds=[0.0:inf]> lower than uncertainty 2.430933287738649e-05 , fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=9.734417457605644e-19 +/- 0.00151, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=9.734417457605644e-19 +/- 0.00151, bounds=[0.0:inf]> lower than uncertainty 2.62760488147526e-05 , fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=1.819132672883334e-23 +/- 0.00106, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=1.819132672883334e-23 +/- 0.00106, bounds=[0.0:inf]> lower than uncertainty 1.908000621934854e-05 , fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=2.8797742658367256e-05 +/- 0.00131, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=1.5633859935864337e-18 +/- 0.00133, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=1.5633859935864337e-18 +/- 0.00133, bounds=[0.0:inf]> lower than uncertainty 2.468874197206482e-05 , fixing to 0.0
# <Parameter 'g_NiI_39524N_Peak', value=0.0006920054136337922 +/- 0.00164, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=0.0001482914380253473 +/- 0.00139, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=9.1108041463323e-28 +/- 0.00191, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=9.1108041463323e-28 +/- 0.00191, bounds=[0.0:inf]> lower than uncertainty 3.6968334703587724e-05 , fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=1.8378832132713123e-32 +/- 0.00141, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KIII_46180N_Peak', value=1.8378832132713123e-32 +/- 0.00141, bounds=[0.0:inf]> lower than uncertainty 2.5151302762294365e-05 , fixing to 0.0
# <Parameter 'g_ArII_69853N_Peak', value=4.645233482177137e-13 +/- 0.00499, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=4.645233482177137e-13 +/- 0.00499, bounds=[0.0:inf]> lower than uncertainty 4.60969951273894e-05 , fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=4.253638833269493e-12 +/- 0.00293, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=4.253638833269493e-12 +/- 0.00293, bounds=[0.0:inf]> lower than uncertainty 4.369230800717561e-05 , fixing to 0.0
# <Parameter 'g_AlVI_91160N_Peak', value=0.0003577594863853906 +/- 0.00276, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_131022N_Peak', value=0.0012699354368085256 +/- 0.00402, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_PIII_178850N_Peak', value=0.0024815185537483304 +/- 0.0112, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeIII_229250N_Peak', value=0.001068434866861193 +/- 0.0143, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=3.9699144246209064e-15 +/- 0.0152, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=3.9699144246209064e-15 +/- 0.0152, bounds=[0.0:inf]> lower than uncertainty 0.00033716486371180844 , fixing to 0.0
# <Parameter 'g_FeII_259883N_Peak', value=4.26212196295813e-22 +/- 0.0196, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_259883N_Peak', value=4.26212196295813e-22 +/- 0.0196, bounds=[0.0:inf]> lower than uncertainty 0.0004381297402869354 , fixing to 0.0
# <Parameter 'd20_PAH30_30100_Peak', value=4.3873151565748253e-36 +/- 0.000179, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd20_PAH30_30100_Peak', value=4.3873151565748253e-36 +/- 0.000179, bounds=[0.0:inf]> lower than uncertainty 2.655850149634998e-05 , fixing to 0.0
# <Parameter 'd0_PAH33_32900_Peak', value=1.8713978116864334e-32 +/- 0.000247, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd0_PAH33_32900_Peak', value=1.8713978116864334e-32 +/- 0.000247, bounds=[0.0:inf]> lower than uncertainty 2.6733230000169954e-05 , fixing to 0.0
# <Parameter 'd0_PAH34_34260_Peak', value=1.2391144419848428e-17 +/- 0.000296, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd0_PAH34_34260_Peak', value=1.2391144419848428e-17 +/- 0.000296, bounds=[0.0:inf]> lower than uncertainty 2.2579504488060395e-05 , fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=9.059322448685392e-39 +/- 0.000258, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd4_PAH67_66900_Peak', value=9.059322448685392e-39 +/- 0.000258, bounds=[0.0:inf]> lower than uncertainty 3.434536272945833e-05 , fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=1.1403186044276092e-35 +/- 0.000529, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd5_PAH74_74200_Peak', value=1.1403186044276092e-35 +/- 0.000529, bounds=[0.0:inf]> lower than uncertainty 4.2943019830626255e-05 , fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=1.7570126972148638e-34 +/- 0.000427, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd6_PAH83_83300_Peak', value=1.7570126972148638e-34 +/- 0.000427, bounds=[0.0:inf]> lower than uncertainty 4.476745747269268e-05 , fixing to 0.0
# <Parameter 'd7_PAH86_86100_Peak', value=2.38995908834737e-35 +/- 0.000413, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd7_PAH86_86100_Peak', value=2.38995908834737e-35 +/- 0.000413, bounds=[0.0:inf]> lower than uncertainty 4.6848388179523806e-05 , fixing to 0.0
# <Parameter 'd11_PAH127_126900_Peak', value=7.550647265810694e-07 +/- 0.00119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd11_PAH127_126900_Peak', value=7.550647265810694e-07 +/- 0.00119, bounds=[0.0:inf]> lower than uncertainty 6.363633295931303e-05 , fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=3.1849969747771167e-23 +/- 0.000528, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=3.1849969747771167e-23 +/- 0.000528, bounds=[0.0:inf]> lower than uncertainty 7.215467688624665e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=1.3737051803905358e-25 +/- 0.000956, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=1.3737051803905358e-25 +/- 0.000956, bounds=[0.0:inf]> lower than uncertainty 7.184205336970622e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=1.354748572490118e-12 +/- 0.0145, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=1.354748572490118e-12 +/- 0.0145, bounds=[0.0:1.0]> lower than uncertainty 2.6430603303052192e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------

# %%
# Line and PAH averaged velocity gradient wrt z, in [km/s]
print(s.parcube['VALUE'].data[-1,0,0])
print(s.parcube['VALUE'].data[-1,0,0]/2.998e5)
# Out:
# -14.990905923543115
# -5.0003021759650155e-05

# %%
s.plot_spec_fit(inppar_fn, optpar_fn)
# Out:
# AGN
# AGN
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Load the parameter cube from drive
parcube_fd = '../CAFE/output/'+source_fnb+'/'
parcube_fn = source_fnb+'_parcube.fits'

# %%
s.read_spec(source_fn, file_dir=source_fd, z=z)
# Out:
# Load data: ../CRETA/extractions/NGC7469_SingleExt_r0.3as_cube.fits
# Filename: ../CRETA/extractions/NGC7469_SingleExt_r0.3as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        36   (20624,)   float64
#   2  ERR           1 ImageHDU         7   (20624,)   float64
#   3  FLUX_ST       1 ImageHDU         7   (20624,)   float64
#   4  ERR_ST        1 ImageHDU         7   (20624,)   float64
#   5  DQ            1 ImageHDU         7   (20624,)   float64
#   6  WAVE          1 ImageHDU         7   (20624,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   20624R x 1C   [20A]

# %%
s.read_parcube_file(parcube_fn, file_dir=parcube_fd)
# Out:
# Filename: ../CAFE/output/NGC7469_SingleExt_r03as_cube/NGC7469_SingleExt_r03as_cube_parcube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  VALUE         1 ImageHDU        38   (1, 1, 511)   float64
#   2  STDERR        1 ImageHDU        38   (1, 1, 511)   float64
#   3  VARY          1 ImageHDU        38   (1, 1, 511)   float64
#   4  MIN           1 ImageHDU        38   (1, 1, 511)   float64
#   5  MAX           1 ImageHDU        38   (1, 1, 511)   float64
#   6  EXPR          1 BinTableHDU     13   511R x 2C   [I, 24A]
#   7  PARNAME       1 BinTableHDU     13   511R x 2C   [I, 32A]

# %%
from astropy.io import ascii
from astropy.table import Table
from astropy.table import QTable

# Read output PAH table
pah = cafeio.pah_table(s.parcube, 0, 0)
# Read output line table
line = cafeio.line_table(s.parcube, 0, 0)

pah62 = pah[pah.index == 'PAH62'].pah_strength.values[0]
pah62_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah77 = pah[pah.index == 'PAH77_C'].pah_strength.values[0]
pah77_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah113 = pah[pah.index == 'PAH113_C'].pah_strength.values[0]
pah113_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]

x = pah62 / pah77 
x_unc = pah62 / pah77 * np.sqrt((pah62_unc/pah62)**2 + (pah77_unc/pah77)**2)
y = pah113 / pah77
y_unc = pah113 / pah77 * np.sqrt((pah113_unc/pah113)**2 + (pah77_unc/pah77)**2)

print('6.2/7.7 = {} +/- {}'.format(x, x_unc))
print('11.3/7.7 = {} +/- {}'.format(y, y_unc))

print(pah)

# Make an astropy table 
t = QTable([pah.index.values, pah.pah_strength, pah.pah_strength_unc],
           names = ('pah_complex', 'pah_strength', 'pah_strength_unc'),
           meta={'wavelength': 'micron',
                 'flux': 'W/m^2',
                }
          )

# Write PAH table in an .ecsv file
#t.write('./NGC7469_pah_tbl.ecsv', overwrite=False)
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 6.2/7.7 = 1.3880363104697235 +/- 0.10324166181217186
# 11.3/7.7 = 1.0013177027146338 +/- 0.08540260374841684
#              pah_strength  pah_strength_unc
# pah_complex
# PAH113_C     1.065369e-19      1.036621e-20
# PAH120       5.338336e-20      9.416703e-21
# PAH126_C     1.430245e-19      1.260815e-20
# PAH136       0.000000e+00      0.000000e+00
# PAH142       1.177408e-19      7.437818e-21
# PAH164       8.618155e-20      3.416383e-21
# PAH170_C     5.843914e-19      1.835059e-20
# PAH33        0.000000e+00      0.000000e+00
# PAH62        1.476824e-19      6.420931e-21
# PAH77_C      1.063967e-19      1.780275e-20
# PAH83        0.000000e+00      0.000000e+00
# PAH86        0.000000e+00      0.000000e+00
# ali34        0.000000e+00      0.000000e+00
# ali345       5.178915e-20      9.143394e-21
