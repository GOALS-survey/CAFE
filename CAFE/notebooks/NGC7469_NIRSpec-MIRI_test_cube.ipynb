# %%
import os
os._exit(00)

# %%
import sys
sys.path.insert(0, '../')
sys.path.insert(0, '../../CRETA/')

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib widget
import matplotlib.ticker
from matplotlib.backends.backend_pdf import PdfPages

import creta
import cafe_io
from cafe_io import *
import cafe_helper
from cafe_helper import *
import cafe

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# User API Created
# <style>.container { width:100% !important; }</style>

# %%
# SPECTRAL EXTRACTION

# %%
# Read parameter file with extraction keywords
creta_dir = '../../CRETA/'
pf = open(creta_dir+'param_files/NGC7469_grid_params.txt','r')
print(pf.read())
pf.close()
# Out:
# cubes = g395h, ch1-short, ch1-medium, ch1-long, ch2-short, ch2-medium, ch2-long, ch3-short, ch3-medium, ch3-long, ch4-short, ch4-medium, ch4-long
# user_ra = 23h03m15.614s
# user_dec = 08d52m26.23s
# user_center = True
# centering = True
# lambda_cent = 5.4
# nx_steps = 3
# ny_steps = 3
# spax_size = 0.5
# step_size = -1
# convolve = False

# %%
# Load the extraction tool (CRETA)
c = creta.creta(creta_dir)
# Out:
# CAFE Region Extraction Tool Automaton (CRETA) initialized

# %%
# Perform the extraction
c.gridExtraction(parameter_file=True, perband_cent=True, parfile_name='NGC7469_grid_params.txt', data_path='../../CRETA/data/NGC7469/', output_filebase_name='NGC7469')
# Out:
# Load file: ../../CRETA/data/NGC7469/Level3_g395h-f290lp_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch1-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch1-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch1-long_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch2-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch2-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch2-long_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch3-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch3-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch3-long_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch4-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch4-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch4-long_s3d.fits
# Last cube is:  ch4_LONG
# Cubes: ['g395h', 'ch1-short', 'ch1-medium', 'ch1-long', 'ch2-short', 'ch2-medium', 'ch2-long', 'ch3-short', 'ch3-medium', 'ch3-long', 'ch4-short', 'ch4-medium', 'ch4-long']
# RA,δ: [345.81505833,8.87395278] (degrees)
# Grid Extraction Parameters:
# NX Steps: 3
# NY Steps: 3
# Spaxel Size:  0.5
# Step Size: 0.5
# Loading Data
# Load file: ../../CRETA/data/NGC7469/Level3_g395h-f290lp_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch1-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch1-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch1-long_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch2-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch2-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch2-long_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch3-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch3-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch3-long_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch4-short_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch4-medium_s3d.fits
# Load file: ../../CRETA/data/NGC7469/bandcube_ch4-long_s3d.fits
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# Centering around 5.399500119092409 um in cube ch1_SHORT
# Old coordinates were: 345.81505833 8.87395278
# New coordinates are: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505833, 8.87395278)>
# Per-band re-centering around 2.871215809167602 um in cube G395H
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81524207, 8.87392658)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# G395H photometry exectued in: 13.612406969070435 seconds
# Per-band re-centering around 4.902500095486175 um in cube ch1_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505874, 8.87393501)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_SHORT photometry exectued in: 3.2760820388793945 seconds
# Per-band re-centering around 5.662499847530853 um in cube ch1_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506329, 8.87392821)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_MEDIUM photometry exectued in: 4.389977216720581 seconds
# Per-band re-centering around 6.532500209927093 um in cube ch1_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506107, 8.87393765)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_LONG photometry exectued in: 3.7673380374908447 seconds
# Per-band re-centering around 7.515000229119323 um in cube ch2_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505866, 8.87393817)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_SHORT photometry exectued in: 2.0240581035614014 seconds
# Per-band re-centering around 8.675000076531433 um in cube ch2_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505679, 8.87394853)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_MEDIUM photometry exectued in: 2.4286117553710938 seconds
# Per-band re-centering around 10.02500045800116 um in cube ch2_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506524, 8.87393436)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_LONG photometry exectued in: 2.5603811740875244 seconds
# Per-band re-centering around 11.557500190800054 um in cube ch3_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506616, 8.87392467)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_SHORT photometry exectued in: 1.972452163696289 seconds
# Per-band re-centering around 13.347500152653083 um in cube ch3_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506916, 8.87392202)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_MEDIUM photometry exectued in: 2.1744089126586914 seconds
# Per-band re-centering around 15.417499847477304 um in cube ch3_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506453, 8.87393263)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_LONG photometry exectued in: 2.439608097076416 seconds
# Per-band re-centering around 17.71500076306984 um in cube ch4_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506695, 8.87393001)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_SHORT photometry exectued in: 1.7563509941101074 seconds
# Per-band re-centering around 20.705000534188 um in cube ch4_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505906, 8.87393121)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_MEDIUM photometry exectued in: 1.788679838180542 seconds
# Per-band re-centering around 24.205000534188 um in cube ch4_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81503673, 8.87389218)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_LONG photometry exectued in: 1.8792262077331543 seconds
# Grid point 0 stitched in: 0.03921914100646973 seconds
# Output written in: 0.40205812454223633 seconds
# Grid point 1 stitched in: 0.016465187072753906 seconds
# Output written in: 0.3618450164794922 seconds
# Grid point 2 stitched in: 0.01767706871032715 seconds
# Output written in: 0.3655061721801758 seconds
# Grid point 3 stitched in: 0.01766204833984375 seconds
# Output written in: 0.3732888698577881 seconds
# Grid point 4 stitched in: 0.017398834228515625 seconds
# Output written in: 0.36832475662231445 seconds
# Grid point 5 stitched in: 0.01766514778137207 seconds
# Output written in: 0.44379496574401855 seconds
# Grid point 6 stitched in: 0.01781296730041504 seconds
# Output written in: 0.3756852149963379 seconds
# Grid point 7 stitched in: 0.016620635986328125 seconds
# Output written in: 0.36303210258483887 seconds
# Grid point 8 stitched in: 0.01742100715637207 seconds
# Output written in: 0.3613591194152832 seconds
# {'extraction_RA': <Longitude 345.8151773 deg>, 'extraction_DEC': <Latitude 8.87375329 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.8151773 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.8151773 deg>, 'extraction_DEC': <Latitude 8.87403107 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87375329 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87403107 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81489616 deg>, 'extraction_DEC': <Latitude 8.87375329 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81489616 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81489616 deg>, 'extraction_DEC': <Latitude 8.87403107 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]

# %%
# CAFE FITTING

# %%
# Setup directories
source_fd = '../../CRETA/extractions/'
source_fn = 'NGC7469_GridExt_3x3_s0.5as_cube.fits'
source_fnb = source_fn.split('.fits')[0].replace('.','')

cafe_dir = '../'
inppar_fn = cafe_dir+'inp_parfiles/inpars_jwst_nirspec-miri_AGN.ini'
optpar_fn = cafe_dir+'opt_parfiles/default_opt.cafe'

z=0.01623
s = cafe.cubemod(cafe_dir)

# %%
s.read_cube(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ../../CRETA/extractions/NGC7469_GridExt_3x3_s0.5as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        38   (3, 3, 12894)   float64
#   2  ERR           1 ImageHDU         9   (3, 3, 12894)   float64
#   3  FLUX_ST       1 ImageHDU         9   (3, 3, 12894)   float64
#   4  ERR_ST        1 ImageHDU         9   (3, 3, 12894)   float64
#   5  DQ            1 ImageHDU         9   (3, 3, 12894)   float64
#   6  WAVE          1 ImageHDU         7   (12894,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   12894R x 1C   [20A]

# %%
s.plot_cube_ini(1, 1, inppar_fn, optpar_fn)
# Out:
# Generating continuum profiles for guess model
# Parameter object has 85 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s.fit_cube(inppar_fn, optpar_fn)
# Out:
# Generating fitting sequence
# Highest SNR spaxel is: 1 1
# Generating initial/full parameter object with all potential lines
# Generating parameter cube with initial/full parameter object
# Parameter object has 112 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Regenerating parameter object for current spaxel [1 1]
# Parameter object has 85 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Regenerating continuum profiles
# ISRF
# ISRF
# Iteration 1/5(max): 2023-01-11 22:10:10.298164 -----------------
# True in 62 steps
# 255.41 seconds elapsed
# <Parameter 'HOT_TMP', value=1027.199965486256 +/- 929, bounds=[100.0:1027.2]> at upper bound, fixing to  1027.2
# <Parameter 'STB_010', value=0.9999999999999999 +/- 3.77e+04, bounds=[0.0:1.0]> at upper bound, fixing to  1.0
# <Parameter 'DSK_FLX', value=9.418099430554948e-11 +/- 0.0616, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'DSK_TAU', value=3.2733575997639734e-10 +/- 3.73e+05, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=2.0133765864412447e-16 +/- 0.00119, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVIII_30280B_Wave', value=3.0329999499664093 +/- 0.000891, bounds=[3.0229000500333556:3.0329999499666447]> at upper bound, fixing to 3.0329999499666447
# <Parameter 'g_MgVIII_30280B_Gamma', value=0.006671114076044824 +/- 0.000693, bounds=[0.0002598254251089757:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_KVII_31905N_Peak', value=9.114819031605654e-18 +/- 0.000864, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund85_37406N_Peak', value=1.6373650686783553e-17 +/- 0.00118, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NiI_39524N_Peak', value=1.2680321233684954e-24 +/- 0.00135, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S12_39947N_Peak', value=6.246342201016142e-14 +/- 0.00163, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_44348N_Peak', value=5.192536332934608e-20 +/- 0.00116, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=1.214351986680531e-23 +/- 0.00163, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=4.0605066617285033e-19 +/- 0.00119, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaVIII_51789B_Wave', value=5.1702627418286005 +/- 0.00167, bounds=[5.170262741827885:5.187537258172115]> at lower bound, fixing to 5.170262741827885
# <Parameter 'g_NaVIII_51789B_Gamma', value=0.006671114076046596 +/- 0.000744, bounds=[0.00025025071915728595:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_FeVIII_54466B_Gamma', value=0.0066711140760485526 +/- 0.000888, bounds=[0.00023720031464962568:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_MgVII_55032B_Gamma', value=0.006671114076050699 +/- 0.000707, bounds=[0.00023461347416231423:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_SiVII_64922N_Peak', value=2.113702576326634e-14 +/- 0.00201, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVII_64922B_Wave', value=6.481372448931258 +/- 0.00589, bounds=[6.481372448298866:6.503027551701135]> at lower bound, fixing to 6.481372448298866
# <Parameter 'g_SiVII_64922B_Gamma', value=0.006671114076050699 +/- 0.00213, bounds=[0.00025792875365166537:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_ArII_69853N_Peak', value=9.732026469431204e-14 +/- 0.00401, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=7.284735867790761e-15 +/- 0.00243, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=2.221913871031934e-14 +/- 0.0128, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd0_PAH33_32900_Peak', value=2.103162390308201e-15 +/- 0.00024, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=2.006112922799768e-14 +/- 0.000252, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=2.1730531449410452e-16 +/- 0.000683, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=7.327657281384641e-16 +/- 0.000384, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd7_PAH86_86100_Peak', value=3.662729100368828e-15 +/- 0.000393, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=2.196788094396202e-15 +/- 0.000514, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=9.530318794902729e-16 +/- 0.000815, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_H2Oice_30500_Peak', value=4.79173487513391e-31 +/- 0.00904, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO2ice_42722_Peak', value=7.181113907698114e-21 +/- 0.00845, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=3.222000426389297e-15 +/- 0.0135, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_FLX', value=0.00037037670858663653 +/- 0.468, bounds=[0.0:2.0]> unconstrained at 126341.78168665855 % error. Fixing value.
# <Parameter 'STB_TAU', value=2.35036210090178e-05 +/- 1.74e+03, bounds=[0.0:inf]> unconstrained at 7390584492.629322 % error. Fixing value.
# <Parameter 'STB_010', value=0.9999999999999999 +/- 3.77e+04, bounds=[0.0:1.0]> unconstrained at 3768215.077031564 % error. Fixing value.
# <Parameter 'DSK_FLX', value=9.418099430554948e-11 +/- 0.0616, bounds=[0.0:2.0]> unconstrained at 65361787957.05389 % error. Fixing value.
# <Parameter 'DSK_TAU', value=3.2733575997639734e-10 +/- 3.73e+05, bounds=[0.0:2.0]> unconstrained at 1.1385309244661365e+17 % error. Fixing value.
# <Parameter 'g_AlV_29052N_Peak', value=0.0004901238468574189 +/- 0.00107, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=2.0133765864412447e-16 +/- 0.00119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=2.0133765864412447e-16 +/- 0.00119, bounds=[0.0:inf]> lower than uncertainty 1.8326085256330093e-05 , fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=9.114819031605654e-18 +/- 0.000864, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=9.114819031605654e-18 +/- 0.000864, bounds=[0.0:inf]> lower than uncertainty 1.7646693126917935e-05 , fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=0.0003729867432071262 +/- 0.00106, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S16_35470N_Peak', value=0.0005929138728900336 +/- 0.00129, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund85_37406N_Peak', value=1.6373650686783553e-17 +/- 0.00118, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund85_37406N_Peak', value=1.6373650686783553e-17 +/- 0.00118, bounds=[0.0:inf]> lower than uncertainty 2.433914684653284e-05 , fixing to 0.0
# <Parameter 'g_H200S13_38464N_Peak', value=0.00017389442709192325 +/- 0.00111, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NiI_39524N_Peak', value=1.2680321233684954e-24 +/- 0.00135, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NiI_39524N_Peak', value=1.2680321233684954e-24 +/- 0.00135, bounds=[0.0:inf]> lower than uncertainty 2.7985830673320508e-05 , fixing to 0.0
# <Parameter 'g_H200S12_39947N_Peak', value=6.246342201016142e-14 +/- 0.00163, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S12_39947N_Peak', value=6.246342201016142e-14 +/- 0.00163, bounds=[0.0:inf]> lower than uncertainty 3.321641981949815e-05 , fixing to 0.0
# <Parameter 'g_FeII_44348N_Peak', value=5.192536332934608e-20 +/- 0.00116, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=5.192536332934608e-20 +/- 0.00116, bounds=[0.0:inf]> lower than uncertainty 2.2659282293672427e-05 , fixing to 0.0
# <Parameter 'g_ArVI_45295N_Peak', value=0.0008583282589182586 +/- 0.00214, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=1.214351986680531e-23 +/- 0.00163, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=1.214351986680531e-23 +/- 0.00163, bounds=[0.0:inf]> lower than uncertainty 3.357146521919346e-05 , fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=4.0605066617285033e-19 +/- 0.00119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KIII_46180N_Peak', value=4.0605066617285033e-19 +/- 0.00119, bounds=[0.0:inf]> lower than uncertainty 2.3246025550654566e-05 , fixing to 0.0
# <Parameter 'g_NaVII_46847N_Peak', value=0.0006774091250164282 +/- 0.00137, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVIII_51789N_Peak', value=0.0008890612694440281 +/- 0.00202, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922N_Peak', value=2.113702576326634e-14 +/- 0.00201, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922N_Peak', value=2.113702576326634e-14 +/- 0.00201, bounds=[0.0:inf]> lower than uncertainty 3.787539005713742e-05 , fixing to 0.0
# <Parameter 'g_ArII_69853N_Peak', value=9.732026469431204e-14 +/- 0.00401, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=9.732026469431204e-14 +/- 0.00401, bounds=[0.0:inf]> lower than uncertainty 4.02622792818243e-05 , fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=7.284735867790761e-15 +/- 0.00243, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=7.284735867790761e-15 +/- 0.00243, bounds=[0.0:inf]> lower than uncertainty 4.03944364091564e-05 , fixing to 0.0
# <Parameter 'g_FeIII_229250N_Peak', value=0.004802896280876193 +/- 0.0119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=2.221913871031934e-14 +/- 0.0128, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=2.221913871031934e-14 +/- 0.0128, bounds=[0.0:inf]> lower than uncertainty 0.00031914773191027624 , fixing to 0.0
# <Parameter 'd0_PAH33_32900_Peak', value=2.103162390308201e-15 +/- 0.00024, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd0_PAH33_32900_Peak', value=2.103162390308201e-15 +/- 0.00024, bounds=[0.0:inf]> lower than uncertainty 2.3676753895497382e-05 , fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=2.006112922799768e-14 +/- 0.000252, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd4_PAH67_66900_Peak', value=2.006112922799768e-14 +/- 0.000252, bounds=[0.0:inf]> lower than uncertainty 2.9953482776878807e-05 , fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=2.1730531449410452e-16 +/- 0.000683, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd5_PAH74_74200_Peak', value=2.1730531449410452e-16 +/- 0.000683, bounds=[0.0:inf]> lower than uncertainty 3.853340581213484e-05 , fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=7.327657281384641e-16 +/- 0.000384, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd6_PAH83_83300_Peak', value=7.327657281384641e-16 +/- 0.000384, bounds=[0.0:inf]> lower than uncertainty 4.098092021807845e-05 , fixing to 0.0
# <Parameter 'd7_PAH86_86100_Peak', value=3.662729100368828e-15 +/- 0.000393, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd7_PAH86_86100_Peak', value=3.662729100368828e-15 +/- 0.000393, bounds=[0.0:inf]> lower than uncertainty 4.3151587711931104e-05 , fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=2.196788094396202e-15 +/- 0.000514, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=2.196788094396202e-15 +/- 0.000514, bounds=[0.0:inf]> lower than uncertainty 6.761061232575263e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=9.530318794902729e-16 +/- 0.000815, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=9.530318794902729e-16 +/- 0.000815, bounds=[0.0:inf]> lower than uncertainty 6.745654303324554e-05 , fixing to 0.0
# <Parameter 'o_H2Oice_30500_Peak', value=4.79173487513391e-31 +/- 0.00904, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_H2Oice_30500_Peak', value=4.79173487513391e-31 +/- 0.00904, bounds=[0.0:1.0]> lower than uncertainty 2.194279155068256e-05 , fixing to 0.0
# <Parameter 'o_CO2ice_42722_Peak', value=7.181113907698114e-21 +/- 0.00845, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO2ice_42722_Peak', value=7.181113907698114e-21 +/- 0.00845, bounds=[0.0:1.0]> lower than uncertainty 2.3729887636260696e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=3.222000426389297e-15 +/- 0.0135, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=3.222000426389297e-15 +/- 0.0135, bounds=[0.0:1.0]> lower than uncertainty 2.4161946111194967e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------
# Regenerating parameter object for current spaxel [1 0]
# Parameter object has 83 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Regenerating continuum profiles
# ISRF
# ISRF
# Current spaxel [1 0] will be initialized with results from spaxel [1 1]
# Parameter object has 83 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-11 22:14:29.399901 -----------------
# /usr/local/anaconda3/lib/python3.8/site-packages/lmfit/minimizer.py:857: RuntimeWarning: invalid value encountered in sqrt
#   (par.stderr * np.sqrt(self.result.covar[jvar, jvar])))
# /usr/local/anaconda3/lib/python3.8/site-packages/lmfit/minimizer.py:850: RuntimeWarning: invalid value encountered in sqrt
#   par.stderr = np.sqrt(self.result.covar[ivar, ivar])
# /usr/local/anaconda3/lib/python3.8/site-packages/uncertainties/core.py:171: RuntimeWarning: invalid value encountered in sqrt
#   std_devs = numpy.sqrt(numpy.diag(covariance_mat))
# True in 48 steps
# 172.19 seconds elapsed
# <Parameter 'DSK_FLX', value=2.4454535761242016e-06 +/- 0.0638, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=3.996772212345897e-22 +/- 0.000693, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=1.3616458276469288e-15 +/- 0.000687, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S14_37240N_Peak', value=1.9525017800183016e-17 +/- 0.000742, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund85_37406N_Peak', value=3.1527485278136415e-06 +/- 0.000709, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaVII_46847N_Peak', value=1.8275538597882326e-12 +/- 0.00143, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaVIII_51789B_Gamma', value=0.006671114076017395 +/- 0.00184, bounds=[0.00025025071915728595:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_MgVII_55032N_Peak', value=8.926204960190861e-15 +/- 0.00103, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVII_64922N_Peak', value=4.678992149276545e-22 +/- 0.000918, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVII_64922B_Peak', value=7.8556504337194e-22 +/- 0.00109, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Humphreys86_75005N_Peak', value=1.091737002718048e-15 +/- 0.000897, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVII_90090N_Peak', value=7.740264317252194e-16 +/- 0.00094, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ClII_143678N_Peak', value=2.925961297972068e-15 +/- 0.00116, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArIII_218302N_Peak', value=4.370486797157984e-09 +/- 0.0045, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Wave', value=24.27660447512649 +/- 0.0102, bounds=[24.276604001169602:24.35771527414377]> at lower bound, fixing to 24.276604001169602
# <Parameter 'g_NeV_243175B_Gamma', value=0.006671114076050699 +/- 0.00095, bounds=[0.0005367733614401021:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'd8_PAH107_106800_Peak', value=3.383578421446125e-32 +/- 0.000222, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=6.409253724997674e-06 +/- 0.000179, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=1.2503261500896444e-32 +/- 0.000303, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=1.1197948635318522e-30 +/- 0.000284, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_H2Oice_30500_Peak', value=2.4222588510383636e-07 +/- 0.027, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# Successful fit ----------------------------------------------------
# Regenerating parameter object for current spaxel [1 2]
# Parameter object has 90 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Regenerating continuum profiles
# ISRF
# ISRF
# Current spaxel [1 2] will be initialized with results from spaxel [1 1]
# Parameter object has 90 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-11 22:17:24.684102 -----------------
# True in 36 steps
# 160.43 seconds elapsed
# <Parameter 'STB_010', value=7.430004187899711e-08 +/- 0.00923, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=3.810326040526582e-17 +/- 0.000405, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=1.6655545954248271e-10 +/- 0.000443, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_AlVI_36597N_Peak', value=2.6561751532085276e-10 +/- 0.000495, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S13_38464N_Peak', value=4.987097019369926e-12 +/- 0.000502, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgIV_44867N_Peak', value=1.4314711201706166e-06 +/- 0.00154, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaVII_46847N_Peak', value=5.168729981263078e-14 +/- 0.000882, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SVII_47307N_Peak', value=8.356761164943183e-12 +/- 0.000848, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVIII_50019N_Peak', value=1.1095714739486564e-10 +/- 0.00114, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SVII_52334N_Peak', value=1.8332655943113275e-11 +/- 0.00121, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVIII_52910N_Peak', value=1.4334768684607104e-06 +/- 0.00117, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeVIII_54466B_Gamma', value=0.0066711121546390905 +/- 0.0013, bounds=[0.00023720031464962568:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_NeVI_76524N_Peak', value=4.3367207480789547e-07 +/- 0.00214, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=1.3509908532557138e-12 +/- 0.00434, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_179359N_Peak', value=1.933812673112756e-15 +/- 0.00402, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=2.1073945436047833e-09 +/- 0.000134, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd10_PAH120_119900_Peak', value=1.1964818393800385e-08 +/- 0.000226, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=1.3235048700524907e-13 +/- 0.000183, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=5.2087565527416806e-12 +/- 0.000298, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_H2Oice_30500_Peak', value=4.6061261110741513e-14 +/- 0.0231, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO2ice_42722_Peak', value=4.2428457142597315e-13 +/- 0.0191, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_TAU', value=0.01614514369970093 +/- 1.9, bounds=[0.0:inf]> unconstrained at 11796.431044723753 % error. Fixing value.
# <Parameter 'STB_010', value=7.430004187899711e-08 +/- 0.00923, bounds=[0.0:1.0]> unconstrained at 12421629.21532955 % error. Fixing value.
# <Parameter 'DSK_FLX', value=2.3248718740825877e-05 +/- 0.102, bounds=[0.0:2.0]> unconstrained at 439660.34966010955 % error. Fixing value.
# <Parameter 'DSK_TAU', value=0.0006126630289029869 +/- 5.03e+03, bounds=[0.0:2.0]> unconstrained at 821034603.218586 % error. Fixing value.
# <Parameter 'g_MgVIII_30280N_Peak', value=0.00014167995653967984 +/- 0.00115, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=3.810326040526582e-17 +/- 0.000405, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=3.810326040526582e-17 +/- 0.000405, bounds=[0.0:inf]> lower than uncertainty 1.3310568436597253e-05 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=1.6655545954248271e-10 +/- 0.000443, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=1.6655545954248271e-10 +/- 0.000443, bounds=[0.0:inf]> lower than uncertainty 1.5345341523332434e-05 , fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=3.351783881987321e-05 +/- 0.000453, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S15_36250N_Peak', value=9.120708361865075e-05 +/- 0.000537, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_AlVI_36597N_Peak', value=2.6561751532085276e-10 +/- 0.000495, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_AlVI_36597N_Peak', value=2.6561751532085276e-10 +/- 0.000495, bounds=[0.0:inf]> lower than uncertainty 1.6559541565953017e-05 , fixing to 0.0
# <Parameter 'g_H200S13_38464N_Peak', value=4.987097019369926e-12 +/- 0.000502, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S13_38464N_Peak', value=4.987097019369926e-12 +/- 0.000502, bounds=[0.0:inf]> lower than uncertainty 1.7449086811723736e-05 , fixing to 0.0
# <Parameter 'g_CaV_41594N_Peak', value=0.0002496573996116063 +/- 0.000551, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=1.4314711201706166e-06 +/- 0.00154, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=1.4314711201706166e-06 +/- 0.00154, bounds=[0.0:inf]> lower than uncertainty 2.6655009673232492e-05 , fixing to 0.0
# <Parameter 'g_ArVI_45295N_Peak', value=0.00017838903410194608 +/- 0.00168, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KIII_46180N_Peak', value=0.00029831471578560764 +/- 0.000743, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIX_46585N_Peak', value=0.00028240457962820734 +/- 0.000912, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVII_46847N_Peak', value=5.168729981263078e-14 +/- 0.000882, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVII_46847N_Peak', value=5.168729981263078e-14 +/- 0.000882, bounds=[0.0:inf]> lower than uncertainty 2.9154359792390084e-05 , fixing to 0.0
# <Parameter 'g_SVII_47307N_Peak', value=8.356761164943183e-12 +/- 0.000848, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_47307N_Peak', value=8.356761164943183e-12 +/- 0.000848, bounds=[0.0:inf]> lower than uncertainty 2.9011239495383154e-05 , fixing to 0.0
# <Parameter 'g_FeII_48891N_Peak', value=0.00019624038653761198 +/- 0.000896, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_50019N_Peak', value=1.1095714739486564e-10 +/- 0.00114, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_50019N_Peak', value=1.1095714739486564e-10 +/- 0.00114, bounds=[0.0:inf]> lower than uncertainty 3.747740778237346e-05 , fixing to 0.0
# <Parameter 'g_NaVIII_51789N_Peak', value=0.0005829247620184398 +/- 0.00148, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_52334N_Peak', value=1.8332655943113275e-11 +/- 0.00121, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_52334N_Peak', value=1.8332655943113275e-11 +/- 0.00121, bounds=[0.0:inf]> lower than uncertainty 3.2790860354753426e-05 , fixing to 0.0
# <Parameter 'g_SiVIII_52910N_Peak', value=1.4334768684607104e-06 +/- 0.00117, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_52910N_Peak', value=1.4334768684607104e-06 +/- 0.00117, bounds=[0.0:inf]> lower than uncertainty 3.330981611797898e-05 , fixing to 0.0
# <Parameter 'g_MgVII_55032N_Peak', value=0.0002314477184541629 +/- 0.00132, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgV_56098N_Peak', value=0.0005885120939738783 +/- 0.00131, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922N_Peak', value=0.0003679352266755983 +/- 0.00122, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=6.463759451574864e-05 +/- 0.00134, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeVI_76524N_Peak', value=4.3367207480789547e-07 +/- 0.00214, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeVI_76524N_Peak', value=4.3367207480789547e-07 +/- 0.00214, bounds=[0.0:inf]> lower than uncertainty 4.5278322719378546e-05 , fixing to 0.0
# <Parameter 'g_ArIII_89914N_Peak', value=0.0004690563945346431 +/- 0.0015, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_PIII_178850N_Peak', value=1.3509908532557138e-12 +/- 0.00434, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_PIII_178850N_Peak', value=1.3509908532557138e-12 +/- 0.00434, bounds=[0.0:inf]> lower than uncertainty 9.419641649362955e-05 , fixing to 0.0
# <Parameter 'g_FeII_179359N_Peak', value=1.933812673112756e-15 +/- 0.00402, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_179359N_Peak', value=1.933812673112756e-15 +/- 0.00402, bounds=[0.0:inf]> lower than uncertainty 0.00010172474590957542 , fixing to 0.0
# <Parameter 'g_FeIII_229250N_Peak', value=0.001253708216626846 +/- 0.00547, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd0_PAH34_34260_Peak', value=3.6232624539902793e-05 +/- 0.000103, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd2_PAH57_57000_Peak', value=3.605190490403653e-05 +/- 0.000147, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd4_PAH67_66900_Peak', value=2.1073945436047833e-09 +/- 0.000134, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd4_PAH67_66900_Peak', value=2.1073945436047833e-09 +/- 0.000134, bounds=[0.0:inf]> lower than uncertainty 2.78603371996944e-05 , fixing to 0.0
# <Parameter 'd10_PAH120_119900_Peak', value=1.1964818393800385e-08 +/- 0.000226, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd10_PAH120_119900_Peak', value=1.1964818393800385e-08 +/- 0.000226, bounds=[0.0:inf]> lower than uncertainty 3.156756069432631e-05 , fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=1.3235048700524907e-13 +/- 0.000183, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=1.3235048700524907e-13 +/- 0.000183, bounds=[0.0:inf]> lower than uncertainty 4.071089585037725e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=5.2087565527416806e-12 +/- 0.000298, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=5.2087565527416806e-12 +/- 0.000298, bounds=[0.0:inf]> lower than uncertainty 4.143862746082576e-05 , fixing to 0.0
# <Parameter 'o_H2Oice_30500_Peak', value=4.6061261110741513e-14 +/- 0.0231, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_H2Oice_30500_Peak', value=4.6061261110741513e-14 +/- 0.0231, bounds=[0.0:1.0]> lower than uncertainty 1.440905298723568e-05 , fixing to 0.0
# <Parameter 'o_CO2ice_42722_Peak', value=4.2428457142597315e-13 +/- 0.0191, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO2ice_42722_Peak', value=4.2428457142597315e-13 +/- 0.0191, bounds=[0.0:1.0]> lower than uncertainty 2.018764249792287e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=0.004448566481201164 +/- 0.0371, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating parameter object for current spaxel [2 1]
# Parameter object has 76 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Regenerating continuum profiles
# ISRF
# ISRF
# Current spaxel [2 1] will be initialized with results from spaxel [1 1]
# Parameter object has 76 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-11 22:20:08.538160 -----------------
# True in 32 steps
# 78.82 seconds elapsed
# <Parameter 'g_CoII_29846N_Peak', value=9.361525585021788e-11 +/- 0.000537, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=3.1690148109416197e-13 +/- 0.000372, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=1.0743068327817722e-10 +/- 0.000419, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=2.3566225140274224e-15 +/- 0.000596, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SVII_52334N_Peak', value=1.2724397790972619e-09 +/- 0.00109, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeVIII_54466B_Gamma', value=0.006671112324704364 +/- 0.00263, bounds=[0.00023720031464962568:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_MgVII_55032N_Peak', value=5.100395524158345e-08 +/- 0.00125, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVII_64922B_Wave', value=6.481312820253687 +/- 0.0139, bounds=[6.4812817311151765:6.5029365314196035]> at lower bound, fixing to 6.4812817311151765
# <Parameter 'g_SiVII_64922B_Gamma', value=0.006671110872887255 +/- 0.00499, bounds=[0.00025792875365166537:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_ArII_69853N_Peak', value=9.338604753906e-15 +/- 0.00261, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaIII_73177N_Peak', value=1.3740448148191281e-06 +/- 0.00102, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeVI_76524N_Peak', value=1.2312353025297523e-06 +/- 0.00233, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Gamma', value=0.006671114039539445 +/- 0.000549, bounds=[0.0005367733614401021:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'd12_PAH135_134800_Peak', value=2.2674052499391203e-14 +/- 0.000197, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=5.611492439436422e-13 +/- 0.000327, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=4.487298032266955e-08 +/- 0.0407, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'HOT_TMP', value=1019.2386327753987 +/- 2.15e+03, bounds=[100.0:1027.2]> unconstrained at 210.88041794495962 % error. Fixing value.
# <Parameter 'STB_FLX', value=0.3150563974926274 +/- 1.33, bounds=[0.0:2.0]> unconstrained at 421.31815824486057 % error. Fixing value.
# <Parameter 'STB_TAU', value=0.8107848565042582 +/- 4.15, bounds=[0.0:inf]> unconstrained at 511.94147625958755 % error. Fixing value.
# <Parameter 'STB_010', value=0.7248143857542734 +/- 61.9, bounds=[0.0:1.0]> unconstrained at 8534.92795524591 % error. Fixing value.
# <Parameter 'DSK_FLX', value=2.8983404610658502e-05 +/- 0.0598, bounds=[0.0:2.0]> unconstrained at 206165.50795321833 % error. Fixing value.
# <Parameter 'DSK_TAU', value=0.07375269579253955 +/- 3.41e+03, bounds=[0.0:2.0]> unconstrained at 4629242.732577402 % error. Fixing value.
# <Parameter 'g_CoII_29846N_Peak', value=9.361525585021788e-11 +/- 0.000537, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=9.361525585021788e-11 +/- 0.000537, bounds=[0.0:inf]> lower than uncertainty 1.5319072414775873e-05 , fixing to 0.0
# <Parameter 'g_MgVIII_30280N_Peak', value=0.0001419237556641416 +/- 0.000664, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=3.1690148109416197e-13 +/- 0.000372, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=3.1690148109416197e-13 +/- 0.000372, bounds=[0.0:inf]> lower than uncertainty 1.3722865898414138e-05 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=1.0743068327817722e-10 +/- 0.000419, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=1.0743068327817722e-10 +/- 0.000419, bounds=[0.0:inf]> lower than uncertainty 1.58056690295772e-05 , fixing to 0.0
# <Parameter 'g_AlVI_36597N_Peak', value=0.00016138376951288353 +/- 0.000466, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=0.00021140969020737272 +/- 0.000457, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NiI_39524N_Peak', value=0.00012003877353266864 +/- 0.000581, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=6.259175937183998e-05 +/- 0.000795, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_41150N_Peak', value=2.3566225140274224e-15 +/- 0.000596, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_41150N_Peak', value=2.3566225140274224e-15 +/- 0.000596, bounds=[0.0:inf]> lower than uncertainty 2.159172771710855e-05 , fixing to 0.0
# <Parameter 'g_FeII_44348N_Peak', value=8.427343197072892e-05 +/- 0.000677, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=9.632011346882856e-05 +/- 0.00125, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=2.4952159265547545e-05 +/- 0.000997, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIX_46585N_Peak', value=0.00018119200433652563 +/- 0.000802, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_52334N_Peak', value=1.2724397790972619e-09 +/- 0.00109, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_52334N_Peak', value=1.2724397790972619e-09 +/- 0.00109, bounds=[0.0:inf]> lower than uncertainty 3.512543680888837e-05 , fixing to 0.0
# <Parameter 'g_SiVIII_52910N_Peak', value=0.00011060161116752584 +/- 0.0013, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_52910B_Gamma', value=0.0028615127324862545 +/- 0.0154, bounds=[0.00024461500386004656:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_52910B_Peak', value=9.145057947174796e-05 +/- 0.000451, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeVIII_54466N_Peak', value=0.00038541185349618237 +/- 0.00123, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_55032N_Peak', value=5.100395524158345e-08 +/- 0.00125, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_55032N_Peak', value=5.100395524158345e-08 +/- 0.00125, bounds=[0.0:inf]> lower than uncertainty 3.6258470528549694e-05 , fixing to 0.0
# <Parameter 'g_MgV_56098N_Peak', value=0.00033177526313576315 +/- 0.00143, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_56739N_Peak', value=0.0005651260780712179 +/- 0.00129, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922N_Peak', value=0.00048093398436013145 +/- 0.00124, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=9.338604753906e-15 +/- 0.00261, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=9.338604753906e-15 +/- 0.00261, bounds=[0.0:inf]> lower than uncertainty 5.66755457281178e-05 , fixing to 0.0
# <Parameter 'g_NaIII_73177N_Peak', value=1.3740448148191281e-06 +/- 0.00102, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIII_73177N_Peak', value=1.3740448148191281e-06 +/- 0.00102, bounds=[0.0:inf]> lower than uncertainty 4.202951659501419e-05 , fixing to 0.0
# <Parameter 'g_NeVI_76524N_Peak', value=1.2312353025297523e-06 +/- 0.00233, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeVI_76524N_Peak', value=1.2312353025297523e-06 +/- 0.00233, bounds=[0.0:inf]> lower than uncertainty 4.736437701174615e-05 , fixing to 0.0
# <Parameter 'g_ArV_131022N_Peak', value=0.0007087186404324264 +/- 0.00149, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_179359N_Peak', value=0.00014846943382792837 +/- 0.00346, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=0.000521858736885007 +/- 0.00548, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_259883N_Peak', value=0.00016639946859591025 +/- 0.00717, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_259883N_Peak', value=0.00016639946859591025 +/- 0.00717, bounds=[0.0:inf]> lower than uncertainty 0.0003356484256230442 , fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=2.2674052499391203e-14 +/- 0.000197, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=2.2674052499391203e-14 +/- 0.000197, bounds=[0.0:inf]> lower than uncertainty 4.675908173587949e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=5.611492439436422e-13 +/- 0.000327, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=5.611492439436422e-13 +/- 0.000327, bounds=[0.0:inf]> lower than uncertainty 4.568771600182315e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=4.487298032266955e-08 +/- 0.0407, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=4.487298032266955e-08 +/- 0.0407, bounds=[0.0:1.0]> lower than uncertainty 3.235546586933925e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------
# Regenerating parameter object for current spaxel [2 0]
# Parameter object has 85 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Regenerating continuum profiles
# ISRF
# ISRF
# Current spaxel [2 0] will be initialized with results from spaxel [1 1]
# Parameter object has 85 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-11 22:21:30.778327 -----------------
# True in 53 steps
# 214.44 seconds elapsed
# <Parameter 'DSK_FLX', value=2.59720938240342e-07 +/- 0.0308, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'g_AlV_29052N_Peak', value=2.1939616003695926e-08 +/- 0.000679, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=2.8930709179641062e-11 +/- 0.000583, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVIII_30280B_Wave', value=3.0329574894596223 +/- 0.00495, bounds=[3.0228577397076792:3.0329574982766996]> at upper bound, fixing to 3.0329574982766996
# <Parameter 'g_MgVIII_30280B_Gamma', value=0.006671114076012934 +/- 0.00406, bounds=[0.0002598254251089757:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_KVII_31905N_Peak', value=1.5856764549070208e-19 +/- 0.000408, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=3.0223253169667793e-15 +/- 0.000428, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaVII_40858N_Peak', value=1.0215406408857578e-14 +/- 0.00078, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArVI_45295N_Peak', value=9.043593671308487e-08 +/- 0.00284, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SVII_50027N_Peak', value=2.3453681825308725e-15 +/- 0.00113, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SVII_50027B_Wave', value=5.010973257293281 +/- 0.00611, bounds=[4.994286700386601:5.010973258022373]> at upper bound, fixing to 5.010973258022373
# <Parameter 'g_SVII_50027B_Gamma', value=0.0066711140760485265 +/- 0.00288, bounds=[0.0002596535923847277:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_SVII_52334N_Peak', value=4.427829798120066e-09 +/- 0.000753, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVII_55032B_Wave', value=5.512300964189081 +/- 0.000274, bounds=[5.493944983622352:5.512300964189082]> at upper bound, fixing to 5.512300964189082
# <Parameter 'g_MgV_56098B_Wave', value=5.619085025450788 +/- 0.00571, bounds=[5.600415624795365:5.61912733754109]> at upper bound, fixing to 5.61912733754109
# <Parameter 'g_ArII_69853N_Peak', value=2.267912700763498e-12 +/- 0.00265, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaIII_73177N_Peak', value=5.095208050772175e-12 +/- 0.000684, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVII_90090N_Peak', value=1.854737709965501e-23 +/- 0.000768, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Gamma', value=0.006671114076050699 +/- 0.000771, bounds=[0.0005367733614401021:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'd8_PAH107_106800_Peak', value=1.2599236354941834e-07 +/- 0.000175, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=4.433753194251448e-25 +/- 0.000247, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=4.86120799114815e-16 +/- 0.000233, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_010', value=0.9713437522726225 +/- 37.1, bounds=[0.0:1.0]> unconstrained at 3818.9891436392663 % error. Fixing value.
# <Parameter 'DSK_FLX', value=2.59720938240342e-07 +/- 0.0308, bounds=[0.0:2.0]> unconstrained at 11873914.238464477 % error. Fixing value.
# <Parameter 'DSK_TAU', value=0.06512075188892384 +/- 7.85e+04, bounds=[0.0:2.0]> unconstrained at 120528848.27113123 % error. Fixing value.
# <Parameter 'g_AlV_29052N_Peak', value=2.1939616003695926e-08 +/- 0.000679, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_AlV_29052N_Peak', value=2.1939616003695926e-08 +/- 0.000679, bounds=[0.0:inf]> lower than uncertainty 2.1997741618306503e-05 , fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=2.8930709179641062e-11 +/- 0.000583, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=2.8930709179641062e-11 +/- 0.000583, bounds=[0.0:inf]> lower than uncertainty 2.0483524300652536e-05 , fixing to 0.0
# <Parameter 'g_MgVIII_30280N_Peak', value=3.1657550004036176e-05 +/- 0.000663, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=1.5856764549070208e-19 +/- 0.000408, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=1.5856764549070208e-19 +/- 0.000408, bounds=[0.0:inf]> lower than uncertainty 1.864783039333668e-05 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=3.0223253169667793e-15 +/- 0.000428, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=3.0223253169667793e-15 +/- 0.000428, bounds=[0.0:inf]> lower than uncertainty 1.9517160871904973e-05 , fixing to 0.0
# <Parameter 'g_H200S14_37240N_Peak', value=0.00014472820576643758 +/- 0.000466, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NiI_39524N_Peak', value=2.063218315783995e-05 +/- 0.000558, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=1.0047160713478055e-05 +/- 0.000741, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=1.0047160713478055e-05 +/- 0.000741, bounds=[0.0:inf]> lower than uncertainty 3.450501901941621e-05 , fixing to 0.0
# <Parameter 'g_CaVII_40858N_Peak', value=1.0215406408857578e-14 +/- 0.00078, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaVII_40858N_Peak', value=1.0215406408857578e-14 +/- 0.00078, bounds=[0.0:inf]> lower than uncertainty 3.6011406344039544e-05 , fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=8.171795189127052e-05 +/- 0.000635, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaV_41594N_Peak', value=0.0002779875873004949 +/- 0.000615, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=0.0001881205440819635 +/- 0.00099, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=9.043593671308487e-08 +/- 0.00284, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=9.043593671308487e-08 +/- 0.00284, bounds=[0.0:inf]> lower than uncertainty 3.103769264847259e-05 , fixing to 0.0
# <Parameter 'g_ArVI_45295B_Gamma', value=0.0005738842177935754 +/- 0.00305, bounds=[0.000288793870608077:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295B_Peak', value=0.0002605460389475869 +/- 0.000875, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46719N_Peak', value=0.00016282957453463379 +/- 0.000833, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_50027N_Peak', value=2.3453681825308725e-15 +/- 0.00113, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_50027N_Peak', value=2.3453681825308725e-15 +/- 0.00113, bounds=[0.0:inf]> lower than uncertainty 5.0696982685047136e-05 , fixing to 0.0
# <Parameter 'g_SVII_52334N_Peak', value=4.427829798120066e-09 +/- 0.000753, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_52334N_Peak', value=4.427829798120066e-09 +/- 0.000753, bounds=[0.0:inf]> lower than uncertainty 2.8085749289095e-05 , fixing to 0.0
# <Parameter 'g_SiVIII_52910N_Peak', value=7.591985822391875e-05 +/- 0.000855, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeVIII_54466N_Peak', value=0.0001690132105603679 +/- 0.000791, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgV_56098N_Peak', value=0.0003624874663619018 +/- 0.000803, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922N_Peak', value=0.00010494229232276677 +/- 0.00117, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922B_Gamma', value=0.000938883914658797 +/- 0.00213, bounds=[0.00025792875365166537:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922B_Peak', value=0.0002518055955289367 +/- 0.000532, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=2.267912700763498e-12 +/- 0.00265, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=2.267912700763498e-12 +/- 0.00265, bounds=[0.0:inf]> lower than uncertainty 5.547247460225645e-05 , fixing to 0.0
# <Parameter 'g_NaIII_73177N_Peak', value=5.095208050772175e-12 +/- 0.000684, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIII_73177N_Peak', value=5.095208050772175e-12 +/- 0.000684, bounds=[0.0:inf]> lower than uncertainty 3.381952558274915e-05 , fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=0.0001828035443478452 +/- 0.00161, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeVI_76524N_Peak', value=0.00022650337645397514 +/- 0.00173, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_90090N_Peak', value=1.854737709965501e-23 +/- 0.000768, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_90090N_Peak', value=1.854737709965501e-23 +/- 0.000768, bounds=[0.0:inf]> lower than uncertainty 3.222754194056225e-05 , fixing to 0.0
# <Parameter 'g_ArIII_218302N_Peak', value=0.0005587249970444946 +/- 0.00282, bounds=[0.0:inf]> unconstrained, fixing entire feature
# ...
# <Parameter 'g_SVII_52334N_Peak', value=8.240670094203384e-05 +/- 0.000611, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_52910N_Peak', value=0.00012477148919652474 +/- 0.000646, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeVIII_54466N_Peak', value=0.00020384634133544343 +/- 0.000677, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgV_56098N_Peak', value=2.552420658113e-11 +/- 0.00081, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgV_56098N_Peak', value=2.552420658113e-11 +/- 0.00081, bounds=[0.0:inf]> lower than uncertainty 2.2576629135458575e-05 , fixing to 0.0
# <Parameter 'g_H200S6_61088N_Peak', value=1.1143713734102539e-05 +/- 0.000615, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S6_61088N_Peak', value=1.1143713734102539e-05 +/- 0.000615, bounds=[0.0:inf]> lower than uncertainty 2.572332857288442e-05 , fixing to 0.0
# <Parameter 'g_SiVII_64922N_Peak', value=2.81594816107398e-24 +/- 0.00192, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922N_Peak', value=2.81594816107398e-24 +/- 0.00192, bounds=[0.0:inf]> lower than uncertainty 2.5293398365904036e-05 , fixing to 0.0
# <Parameter 'g_SiVII_64922B_Wave', value=6.491047417191925 +/- 1.19e+08, bounds=[6.4812817311151765:6.5029365314196035]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922B_Gamma', value=0.00026221600251103376 +/- 6.77e+06, bounds=[0.00025792875365166537:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922B_Peak', value=2.6676228827243246e-26 +/- 0.00113, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922B_Peak', value=2.6676228827243246e-26 +/- 0.00113, bounds=[0.0:inf]> lower than uncertainty 2.3700376965268744e-05 , fixing to 0.0
# <Parameter 'g_ArII_69853N_Peak', value=9.709685758363036e-27 +/- 0.00318, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=9.709685758363036e-27 +/- 0.00318, bounds=[0.0:inf]> lower than uncertainty 4.858945031651282e-05 , fixing to 0.0
# <Parameter 'g_NaIII_73177N_Peak', value=0.00015645199350017866 +/- 0.000628, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=0.001076988247735854 +/- 0.00945, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578B_Peak', value=0.0017945474991065862 +/- 0.00465, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys86_75005N_Peak', value=0.0002178030447491304 +/- 0.000637, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_79016N_Peak', value=0.00037497275440564 +/- 0.0008, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArIII_89914N_Peak', value=0.0001905107573900297 +/- 0.00125, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=1.1649010552065958e-08 +/- 0.00377, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=1.1649010552065958e-08 +/- 0.00377, bounds=[0.0:inf]> lower than uncertainty 0.00019692028174110604 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=2.5817002760332234e-34 +/- 0.000188, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=2.5817002760332234e-34 +/- 0.000188, bounds=[0.0:inf]> lower than uncertainty 3.2895580846290854e-05 , fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=1.8427168552331916e-31 +/- 0.000179, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd14_PAH142_141900_Peak', value=1.8427168552331916e-31 +/- 0.000179, bounds=[0.0:inf]> lower than uncertainty 3.369551351592364e-05 , fixing to 0.0
# <Parameter 'd16_PAH170_170400_Peak', value=7.234481021175146e-15 +/- 0.000218, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH170_170400_Peak', value=7.234481021175146e-15 +/- 0.000218, bounds=[0.0:inf]> lower than uncertainty 4.661321556551034e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=0.00019275630036665742 +/- 0.0981, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating parameter object for current spaxel [0 1]
# Parameter object has 89 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Regenerating continuum profiles
# ISRF
# ISRF
# Current spaxel [0 1] will be initialized with results from spaxel [1 1]
# Parameter object has 89 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-11 22:29:33.743168 -----------------
# True in 29 steps
# 119.41 seconds elapsed
# <Parameter 'DSK_FLX', value=4.312901377983236e-07 +/- 0.078, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'g_AlV_29052N_Peak', value=7.797994388751464e-08 +/- 0.000515, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=3.8173024091573706e-17 +/- 0.000566, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=5.840571636826021e-13 +/- 0.000394, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NiI_39524N_Peak', value=2.8082144759487786e-16 +/- 0.000422, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S12_39947N_Peak', value=8.355699793882308e-10 +/- 0.000452, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=4.003306512795796e-13 +/- 0.000687, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SIX_46413N_Peak', value=4.3489185231494325e-16 +/- 0.000736, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SVII_47307N_Peak', value=1.2316634305756412e-17 +/- 0.000767, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVIII_50019B_Wave', value=5.010171925093994 +/- 0.00775, bounds=[4.993488045788022:5.010171935015513]> at upper bound, fixing to 5.010171935015513
# <Parameter 'g_SiVIII_50019B_Gamma', value=0.006671114075963115 +/- 0.00372, bounds=[0.00025969789585650674:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_SVII_52334N_Peak', value=5.2662150098372754e-12 +/- 0.000719, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVII_64922N_Peak', value=6.030103012182223e-06 +/- 0.00284, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=1.41365022876524e-10 +/- 0.00438, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Wave', value=24.2766057034516 +/- 0.0104, bounds=[24.276604001169602:24.35771527414377]> at lower bound, fixing to 24.276604001169602
# <Parameter 'g_NeV_243175B_Gamma', value=0.006671114076029185 +/- 0.000981, bounds=[0.0005367733614401021:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'd10_PAH120_119900_Peak', value=1.3183581258447277e-13 +/- 0.000204, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd11_PAH126_126200_Peak', value=7.909766069309571e-13 +/- 0.00027, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=1.958467496476949e-16 +/- 0.000195, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=1.4443578677176813e-15 +/- 0.000334, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_H2Oice_30500_Peak', value=2.476972165173112e-13 +/- 0.0332, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=2.6102726866644177e-11 +/- 0.0783, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_TAU', value=0.18181114976675683 +/- 1.49, bounds=[0.0:inf]> unconstrained at 818.7618902236997 % error. Fixing value.
# <Parameter 'STB_010', value=0.2259766173073485 +/- 4.14, bounds=[0.0:1.0]> unconstrained at 1832.6006698594736 % error. Fixing value.
# <Parameter 'DSK_FLX', value=4.312901377983236e-07 +/- 0.078, bounds=[0.0:2.0]> unconstrained at 18079760.262400433 % error. Fixing value.
# <Parameter 'DSK_TAU', value=0.002724865415657316 +/- 8.12e+04, bounds=[0.0:2.0]> unconstrained at 2979385097.5880675 % error. Fixing value.
# <Parameter 'g_AlV_29052N_Peak', value=7.797994388751464e-08 +/- 0.000515, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_AlV_29052N_Peak', value=7.797994388751464e-08 +/- 0.000515, bounds=[0.0:inf]> lower than uncertainty 1.2973019231644718e-05 , fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=3.8173024091573706e-17 +/- 0.000566, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=3.8173024091573706e-17 +/- 0.000566, bounds=[0.0:inf]> lower than uncertainty 1.2851592307401052e-05 , fixing to 0.0
# <Parameter 'g_MgVIII_30280N_Peak', value=0.0002696396709440046 +/- 0.000635, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=4.152246981994465e-05 +/- 0.000388, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund95_32970N_Peak', value=0.00019377688142643157 +/- 0.000422, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=5.840571636826021e-13 +/- 0.000394, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=5.840571636826021e-13 +/- 0.000394, bounds=[0.0:inf]> lower than uncertainty 1.187509582738185e-05 , fixing to 0.0
# <Parameter 'g_H200S16_35470N_Peak', value=0.00020932402365483245 +/- 0.000432, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=0.00020809577777924335 +/- 0.000453, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NiI_39524N_Peak', value=2.8082144759487786e-16 +/- 0.000422, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NiI_39524N_Peak', value=2.8082144759487786e-16 +/- 0.000422, bounds=[0.0:inf]> lower than uncertainty 1.3089132928016113e-05 , fixing to 0.0
# <Parameter 'g_H200S12_39947N_Peak', value=8.355699793882308e-10 +/- 0.000452, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S12_39947N_Peak', value=8.355699793882308e-10 +/- 0.000452, bounds=[0.0:inf]> lower than uncertainty 1.4037568721657123e-05 , fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=4.003306512795796e-13 +/- 0.000687, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_41150N_Peak', value=4.003306512795796e-13 +/- 0.000687, bounds=[0.0:inf]> lower than uncertainty 2.1043282149294747e-05 , fixing to 0.0
# <Parameter 'g_CaV_41594N_Peak', value=2.1938045013214997e-05 +/- 0.000533, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=0.00013069201033713896 +/- 0.00101, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=9.571649810506795e-05 +/- 0.00126, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KIII_46180N_Peak', value=6.62433819099641e-05 +/- 0.000738, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIX_46413N_Peak', value=4.3489185231494325e-16 +/- 0.000736, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIX_46413N_Peak', value=4.3489185231494325e-16 +/- 0.000736, bounds=[0.0:inf]> lower than uncertainty 2.154401802139709e-05 , fixing to 0.0
# <Parameter 'g_SVII_47307N_Peak', value=1.2316634305756412e-17 +/- 0.000767, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_47307N_Peak', value=1.2316634305756412e-17 +/- 0.000767, bounds=[0.0:inf]> lower than uncertainty 2.3840790338480088e-05 , fixing to 0.0
# <Parameter 'g_SiVIII_50019N_Peak', value=9.146809159463307e-05 +/- 0.00105, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_52334N_Peak', value=5.2662150098372754e-12 +/- 0.000719, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_52334N_Peak', value=5.2662150098372754e-12 +/- 0.000719, bounds=[0.0:inf]> lower than uncertainty 1.8272973639701707e-05 , fixing to 0.0
# <Parameter 'g_MgVII_55032N_Peak', value=0.000369976001015446 +/- 0.000816, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_56739N_Peak', value=0.00013125993599233407 +/- 0.00085, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922N_Peak', value=6.030103012182223e-06 +/- 0.00284, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922N_Peak', value=6.030103012182223e-06 +/- 0.00284, bounds=[0.0:inf]> lower than uncertainty 2.2276452010734026e-05 , fixing to 0.0
# <Parameter 'g_SiVII_64922B_Gamma', value=0.0005646681274892835 +/- 0.0133, bounds=[0.00025792875365166537:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_SiVII_64922B_Peak', value=5.4131867113572575e-05 +/- 0.00235, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=0.0005903891540608843 +/- 0.00258, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=0.000276678011875745 +/- 0.00151, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Humphreys86_75005N_Peak', value=0.0003628956882622577 +/- 0.000767, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_131022N_Peak', value=0.00040186397209260885 +/- 0.00139, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_PIII_178850N_Peak', value=1.41365022876524e-10 +/- 0.00438, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_PIII_178850N_Peak', value=1.41365022876524e-10 +/- 0.00438, bounds=[0.0:inf]> lower than uncertainty 9.681466474543303e-05 , fixing to 0.0
# <Parameter 'd10_PAH120_119900_Peak', value=1.3183581258447277e-13 +/- 0.000204, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd10_PAH120_119900_Peak', value=1.3183581258447277e-13 +/- 0.000204, bounds=[0.0:inf]> lower than uncertainty 2.973600849486182e-05 , fixing to 0.0
# <Parameter 'd11_PAH126_126200_Peak', value=7.909766069309571e-13 +/- 0.00027, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd11_PAH126_126200_Peak', value=7.909766069309571e-13 +/- 0.00027, bounds=[0.0:inf]> lower than uncertainty 3.371270816467269e-05 , fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=1.958467496476949e-16 +/- 0.000195, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=1.958467496476949e-16 +/- 0.000195, bounds=[0.0:inf]> lower than uncertainty 3.8187099543063874e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=1.4443578677176813e-15 +/- 0.000334, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=1.4443578677176813e-15 +/- 0.000334, bounds=[0.0:inf]> lower than uncertainty 4.261722246747316e-05 , fixing to 0.0
# <Parameter 'o_H2Oice_30500_Peak', value=2.476972165173112e-13 +/- 0.0332, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_H2Oice_30500_Peak', value=2.476972165173112e-13 +/- 0.0332, bounds=[0.0:1.0]> lower than uncertainty 1.3929694620013731e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=2.6102726866644177e-11 +/- 0.0783, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=2.6102726866644177e-11 +/- 0.0783, bounds=[0.0:1.0]> lower than uncertainty 2.5098992087561044e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------
# Regenerating parameter object for current spaxel [0 2]
# Parameter object has 89 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Regenerating continuum profiles
# ISRF
# ISRF
# Current spaxel [0 2] will be initialized with results from spaxel [1 1]
# Parameter object has 89 lines, 29 PAHs, 5 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-11 22:31:36.742695 -----------------

# %%
# Line and PAH averaged velocity gradient wrt z, in [km/s]
print(s.parcube['VALUE'].data[-1])
print(s.parcube['VALUE'].data[-1]/2.998e5)
# Out:
# [[ -2.15633778  10.36721807  52.9846466 ]
#  [  6.58994215 -24.24547139 100.        ]
#  [ 90.49923771 100.          99.97808252]]
# [[-7.19258765e-06  3.45804472e-05  1.76733311e-04]
#  [ 2.19811279e-05 -8.08721528e-05  3.33555704e-04]
#  [ 3.01865369e-04  3.33555704e-04  3.33482597e-04]]

# %%
s.plot_cube_fit(1, 1, inppar_fn, optpar_fn)
# Out:
# AGN
# AGN
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Load the parameter cube from drive
parcube_fd = '../output/'+source_fnb+'/'
parcube_fn = source_fnb+'_parcube.fits'

# %%
s.read_cube(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ./CRETA/extractions/NGC7469_GridExt_3x3_s0.5as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        38   (3, 3, 12894)   float64
#   2  ERR           1 ImageHDU         9   (3, 3, 12894)   float64
#   3  FLUX_ST       1 ImageHDU         9   (3, 3, 12894)   float64
#   4  ERR_ST        1 ImageHDU         9   (3, 3, 12894)   float64
#   5  DQ            1 ImageHDU         9   (3, 3, 12894)   float64
#   6  WAVE          1 ImageHDU         7   (12894,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   12894R x 1C   [20A]

# %%
s.read_parcube_file(parcube_fn, file_dir=parcube_fd)
# Out:
# Filename: /Users/tanio/Sync/pywork/CAFE_dev/output/NGC7469_GridExt_3x3_s05as_cube/NGC7469_GridExt_3x3_s05as_cube_parcube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  VALUE         1 ImageHDU        38   (3, 3, 460)   float64
#   2  STDERR        1 ImageHDU        38   (3, 3, 460)   float64
#   3  VARY          1 ImageHDU        38   (3, 3, 460)   float64
#   4  MIN           1 ImageHDU        38   (3, 3, 460)   float64
#   5  MAX           1 ImageHDU        38   (3, 3, 460)   float64
#   6  EXPR          1 BinTableHDU     13   460R x 2C   [I, 24A]
#   7  PARNAME       1 BinTableHDU     13   460R x 2C   [I, 32A]

# %%
s.plot_cube_fit(1, 1, inppar_fn, optpar_fn)
# Out:
# AGN
# AGN
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Generate map of feature (TBD)
#s.make_map('HOT_FLX')

# %%
from astropy.io import ascii
from astropy.table import Table
from astropy.table import QTable

# Read output PAH table
pah = cafeio.pah_table(s.parcube, 0, 0)
# Read output line table
line = cafeio.line_table(s.parcube, 0, 0)

pah62 = pah[pah.index == 'PAH62'].pah_strength.values[0]
pah62_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah77 = pah[pah.index == 'PAH77_C'].pah_strength.values[0]
pah77_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah113 = pah[pah.index == 'PAH113_C'].pah_strength.values[0]
pah113_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]

x = pah62 / pah77 
x_unc = pah62 / pah77 * np.sqrt((pah62_unc/pah62)**2 + (pah77_unc/pah77)**2)
y = pah113 / pah77
y_unc = pah113 / pah77 * np.sqrt((pah113_unc/pah113)**2 + (pah77_unc/pah77)**2)

print('6.2/7.7 = {} +/- {}'.format(x, x_unc))
print('11.3/7.7 = {} +/- {}'.format(y, y_unc))

print(pah)

# Make an astropy table 
t = QTable([pah.index.values, pah.pah_strength, pah.pah_strength_unc],
           names = ('pah_complex', 'pah_strength', 'pah_strength_unc'),
           meta={'wavelength': 'micron',
                 'flux': 'W/m^2',
                }
          )

# Write PAH table in an .ecsv file
#t.write('./NGC7469_pah_tbl.ecsv', overwrite=False)
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 6.2/7.7 = 0.2694158115306601 +/- 0.006545463417734035
# 11.3/7.7 = 0.3846227736544648 +/- 0.006771473023612428
#              pah_strength  pah_strength_unc
# pah_complex
# PAH113_C     2.106990e-19      5.208565e-21
# PAH120       5.274476e-20      2.831340e-21
# PAH126_C     1.072756e-19      3.656524e-21
# PAH136       1.232616e-20      1.720379e-21
# PAH142       0.000000e+00      0.000000e+00
# PAH164       9.552297e-21      7.926729e-22
# PAH170_C     1.487757e-20      2.290471e-21
# PAH33        4.747356e-20      2.642360e-21
# PAH62        1.475878e-19      3.462199e-21
# PAH77_C      5.478069e-19      1.755303e-20
# PAH83        3.863632e-20      3.610172e-21
# PAH86        1.087322e-19      3.472195e-21
# ali34        6.032916e-21      2.734573e-21
# ali345       1.208811e-20      4.178507e-21
