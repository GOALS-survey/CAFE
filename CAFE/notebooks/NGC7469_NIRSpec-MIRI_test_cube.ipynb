# %%
import os
os._exit(00)

# %%
import sys
sys.path.insert(0, '../CAFE')
sys.path.insert(0, '../CRETA')

import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib widget
import matplotlib.ticker
from matplotlib.backends.backend_pdf import PdfPages

import creta
import cafe_io
from cafe_io import *
import cafe_helper
from cafe_helper import *
import cafe

from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# User API Created
# <style>.container { width:100% !important; }</style>

# %%
# SPECTRAL EXTRACTION

# %%
# Read parameter file with extraction keywords
creta_dir = '../CRETA/'
pf = open(creta_dir+'param_files/NGC7469_grid_params.txt','r')
print(pf.read())
pf.close()
# Out:
# cubes = g395h, ch1-short, ch1-medium, ch1-long, ch2-short, ch2-medium, ch2-long, ch3-short, ch3-medium, ch3-long, ch4-short, ch4-medium, ch4-long
# user_ra = 23h03m15.614s
# user_dec = 08d52m26.23s
# user_center = True
# centering = True
# lambda_cent = 5.4
# nx_steps = 3
# ny_steps = 3
# spax_size = 0.5
# step_size = -1
# convolve = False

# %%
# Load the extraction tool (CRETA)
c = creta.creta(creta_dir)
# Out:
# CAFE Region Extraction Tool Automaton (CRETA) initialized

# %%
# Perform the extraction
c.gridExtraction(parameter_file=True, perband_cent=True, parfile_name='NGC7469_grid_params.txt', data_path='../CRETA/data/NGC7469/', output_filebase_name='NGC7469')
# Out:
# Load file: ../CRETA/data/NGC7469/Level3_g395h-f290lp_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch1-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch1-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch1-long_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch2-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch2-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch2-long_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch3-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch3-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch3-long_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch4-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch4-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch4-long_s3d.fits
# Last cube is:  ch4_LONG
# Cubes: ['g395h', 'ch1-short', 'ch1-medium', 'ch1-long', 'ch2-short', 'ch2-medium', 'ch2-long', 'ch3-short', 'ch3-medium', 'ch3-long', 'ch4-short', 'ch4-medium', 'ch4-long']
# RA,δ: [345.81505833,8.87395278] (degrees)
# Grid Extraction Parameters:
# NX Steps: 3
# NY Steps: 3
# Spaxel Size:  0.5
# Step Size: 0.5
# Loading Data
# Load file: ../CRETA/data/NGC7469/Level3_g395h-f290lp_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch1-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch1-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch1-long_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch2-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch2-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch2-long_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch3-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch3-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch3-long_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch4-short_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch4-medium_s3d.fits
# Load file: ../CRETA/data/NGC7469/bandcube_ch4-long_s3d.fits
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# Centering around 5.399500119092409 um in cube ch1_SHORT
# Old coordinates were: 345.81505833 8.87395278
# New coordinates are: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505833, 8.87395278)>
# Per-band re-centering around 2.871215809167602 um in cube G395H
# WARNING: The fit may be unsuccessful; check fit_info['message'] for more information. [astropy.modeling.fitting]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81524207, 8.87392658)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# G395H photometry exectued in: 12.7444429397583 seconds
# Per-band re-centering around 4.902500095486175 um in cube ch1_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505874, 8.87393501)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_SHORT photometry exectued in: 3.00164794921875 seconds
# Per-band re-centering around 5.662499847530853 um in cube ch1_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506329, 8.87392821)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_MEDIUM photometry exectued in: 3.102828025817871 seconds
# Per-band re-centering around 6.532500209927093 um in cube ch1_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506107, 8.87393765)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch1_LONG photometry exectued in: 3.7607901096343994 seconds
# Per-band re-centering around 7.515000229119323 um in cube ch2_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505866, 8.87393817)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_SHORT photometry exectued in: 2.134935140609741 seconds
# Per-band re-centering around 8.675000076531433 um in cube ch2_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505679, 8.87394853)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_MEDIUM photometry exectued in: 2.251627206802368 seconds
# Per-band re-centering around 10.02500045800116 um in cube ch2_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506524, 8.87393436)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch2_LONG photometry exectued in: 2.5232670307159424 seconds
# Per-band re-centering around 11.557500190800054 um in cube ch3_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506616, 8.87392467)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_SHORT photometry exectued in: 1.9069170951843262 seconds
# Per-band re-centering around 13.347500152653083 um in cube ch3_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506916, 8.87392202)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_MEDIUM photometry exectued in: 2.58209490776062 seconds
# Per-band re-centering around 15.417499847477304 um in cube ch3_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506453, 8.87393263)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch3_LONG photometry exectued in: 2.4823501110076904 seconds
# Per-band re-centering around 17.71500076306984 um in cube ch4_SHORT
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81506695, 8.87393001)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_SHORT photometry exectued in: 1.4843769073486328 seconds
# Per-band re-centering around 20.705000534188 um in cube ch4_MEDIUM
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81505906, 8.87393121)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_MEDIUM photometry exectued in: 1.7032771110534668 seconds
# Per-band re-centering around 24.205000534188 um in cube ch4_LONG
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# New re-centered coordinates: <SkyCoord (ICRS): (ra, dec) in deg
#     (345.81503673, 8.87389218)>
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# ch4_LONG photometry exectued in: 2.114119052886963 seconds
# Grid point 0 stitched in: 0.0358891487121582 seconds
# Output written in: 0.42360591888427734 seconds
# Grid point 1 stitched in: 0.018656015396118164 seconds
# Output written in: 0.48516416549682617 seconds
# Grid point 2 stitched in: 0.018037796020507812 seconds
# Output written in: 0.38906002044677734 seconds
# Grid point 3 stitched in: 0.018533945083618164 seconds
# Output written in: 0.38782167434692383 seconds
# Grid point 4 stitched in: 0.017902851104736328 seconds
# Output written in: 0.3867771625518799 seconds
# Grid point 5 stitched in: 0.01895594596862793 seconds
# Output written in: 0.3995239734649658 seconds
# Grid point 6 stitched in: 0.016841411590576172 seconds
# Output written in: 0.6179780960083008 seconds
# Grid point 7 stitched in: 0.018534183502197266 seconds
# Output written in: 0.3867809772491455 seconds
# Grid point 8 stitched in: 0.018377065658569336 seconds
# Output written in: 0.3987901210784912 seconds
# {'extraction_RA': <Longitude 345.8151773 deg>, 'extraction_DEC': <Latitude 8.87375329 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.8151773 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.8151773 deg>, 'extraction_DEC': <Latitude 8.87403107 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 0, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87375329 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81503673 deg>, 'extraction_DEC': <Latitude 8.87403107 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 1, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81489616 deg>, 'extraction_DEC': <Latitude 8.87375329 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 0, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81489616 deg>, 'extraction_DEC': <Latitude 8.87389218 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 1, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# {'extraction_RA': <Longitude 345.81489616 deg>, 'extraction_DEC': <Latitude 8.87403107 deg>, 'grid_center_RA': <Longitude 345.81505833 deg>, 'grid_center_DEC': <Latitude 8.87395278 deg>, 'exrtaction_type': 'extended_source', 'ap_corr': False, 'Centering': True, 'Centering_lambda': 5.399500119092409, 'NX': 3, 'NY': 3, 'spax_size': 0.5, 'step_size': 0.5, 'step_indx': 2, 'step_indy': 2, 'CDELT1': 0.5, 'CDELT2': 0.5, 'CRVAL3': 2.869885809168459, 'CRPIX3': 1, 'CRDELT3': nan, 'bkg_sub': False, 'bkg_r_in': 0.0, 'bkg_an_w': 0.0}
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]
# WARNING: No observer defined on WCS, SpectralCoord will be converted without any velocity frame change [astropy.wcs.wcsapi.fitswcs]

# %%
# CAFE FITTING

# %%
# Setup directories
source_fd = '../CRETA/extractions/'
source_fn = 'NGC7469_GridExt_3x3_s0.5as_cube.fits'
source_fnb = source_fn.split('.fits')[0].replace('.','')

cafe_dir = '../CAFE/'
inppar_fn = cafe_dir+'inp_parfiles/inpars_jwst_nirspec-miri_AGN.ini'
optpar_fn = cafe_dir+'opt_parfiles/default_opt.cafe'

z=0.01630

# %%
s = cafe.cubemod(cafe_dir)

# %%
s.read_cube(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ../CRETA/extractions/NGC7469_GridExt_3x3_s0.5as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        38   (3, 3, 12894)   float64
#   2  ERR           1 ImageHDU         9   (3, 3, 12894)   float64
#   3  FLUX_ST       1 ImageHDU         9   (3, 3, 12894)   float64
#   4  ERR_ST        1 ImageHDU         9   (3, 3, 12894)   float64
#   5  DQ            1 ImageHDU         9   (3, 3, 12894)   float64
#   6  WAVE          1 ImageHDU         7   (12894,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   12894R x 1C   [20A]

# %%
s.plot_cube_ini(1, 1, inppar_fn, optpar_fn)
# Out:
# Generating continuum profiles for guess model
# Parameter object has 81 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# AGN
# AGN
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
s.fit_cube(inppar_fn, optpar_fn)
# Out:
# Generating fitting sequence
# Highest SNR spaxel is: 1 1
# Generating initial/full parameter object with all potential lines
# Parameter object has 110 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Generating parameter cube with initial/full parameter object
# Regenerating continuum profiles
# AGN
# AGN
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [1 1]
# Parameter object has 81 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-06 23:30:33.224418 -----------------
# True in 46 steps
# 191.24 seconds elapsed
# No errors retuned
# <Parameter 'STB_FLX', value=1.3137875235018703e-10, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'DSK_FLX', value=1.7836794211223686e-13, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=1.2504983149535185e-32, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVIII_30280B_Wave', value=3.0329999499666442, bounds=[3.0229000500333556:3.0329999499666447]> at upper bound, fixing to 3.0329999499666447
# <Parameter 'g_MgVIII_30280B_Gamma', value=0.006671114076050699, bounds=[0.0002598066452992078:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_KVII_31905N_Peak', value=4.9365570848286054e-26, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S14_37240N_Peak', value=1.3231399771306057e-32, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NiI_39524N_Peak', value=1.5437057494314848e-25, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S12_39947N_Peak', value=2.185590272735413e-19, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=8.659970989230833e-30, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=8.121831186088866e-32, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeVIII_54466B_Gamma', value=0.006671114076050699, bounds=[0.0002371829799907665:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_ArII_69853N_Peak', value=6.709063705882737e-23, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=2.470229229707865e-19, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=5.159049853894336e-22, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_259883N_Peak', value=3.5341812462337887e-29, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd0_PAH33_32900_Peak', value=5.242873826892909e-26, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=6.260341002908174e-23, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd5_PAH74_74200_Peak', value=2.74931784706663e-26, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd6_PAH83_83300_Peak', value=1.0717250818626681e-26, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd7_PAH86_86100_Peak', value=7.607424001166966e-26, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=2.2830912096676505e-30, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=8.037059371197502e-27, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=3.9691873511674515e-26, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# Rerunning fit
# Iteration 2/5(max): 2023-01-06 23:33:44.690621 -----------------
# True in 52 steps
# 174.79 seconds elapsed
# No errors retuned
# <Parameter 'HOT_TMP', value=1027.1999967335955, bounds=[100.0:1027.2]> at upper bound, fixing to  1027.2
# <Parameter 'HOT_TMP', value=1027.1999967335955, bounds=[100.0:1027.2]> at initial value 1027.2 . Fixing value.
# <Parameter 'STB_010', value=0.47298157509597605, bounds=[0.0:1.0]> at initial value 0.47298157509597605 . Fixing value.
# <Parameter 'g_MgIV_44867B_Wave', value=4.483496023060661, bounds=[4.479197211474316:4.494162788525683]> at initial value 4.4835004198326125 . Fixing value.
# <Parameter 'g_ArVI_45295B_Wave', value=4.527279771651852, bounds=[4.521965763842561:4.537074236157438]> at initial value 4.527264114260206 . Fixing value.
# <Parameter 'g_FeVIII_54466B_Wave', value=5.444601026403895, bounds=[5.437516277518346:5.455683722481655]> at initial value 5.44459770570975 . Fixing value.
# <Parameter 'g_MgVII_55032B_Wave', value=5.503980203158184, bounds=[5.494021881254169:5.51237811874583]> at initial value 5.503975757568368 . Fixing value.
# <Parameter 'g_MgV_56098B_Wave', value=5.60739571713088, bounds=[5.600494012675116:5.619205987324883]> at initial value 5.60739652898819 . Fixing value.
# <Parameter 'g_ArII_69853B_Wave', value=6.986124668570966, bounds=[6.9736241100733825:6.996923889926618]> at initial value 6.986121596401389 . Fixing value.
# <Parameter 'g_Pfund65_74578B_Wave', value=7.460360041614782, bounds=[7.445362041360907:7.470237958639093]> at initial value 7.4603655921316445 . Fixing value.
# <Parameter 'g_NeVI_76524B_Wave', value=7.647664113779679, bounds=[7.639637491661108:7.665162508338892]> at initial value 7.64768518471382 . Fixing value.
# <Parameter 'g_ArIII_89914B_Wave', value=8.98580000038238, bounds=[8.97638436957972:9.00637563042028]> at initial value 8.985802491131727 . Fixing value.
# <Parameter 'g_SIV_105105B_Wave', value=10.503713005565675, bounds=[10.492970813875917:10.528029186124083]> at initial value 10.503763447021234 . Fixing value.
# <Parameter 'g_NeV_143217B_Wave', value=14.314166241621194, bounds=[14.297814576384257:14.345585423615743]> at initial value 14.314159734217098 . Fixing value.
# <Parameter 'g_NeIII_155551B_Wave', value=15.544196186968287, bounds=[15.529157538358906:15.581042461641093]> at initial value 15.544177084603763 . Fixing value.
# <Parameter 'g_SIII_187130N_Peak', value=0.10223201483191904, bounds=[0.0:inf]> at initial value 0.10223128088771881 . Fixing value.
# <Parameter 'g_NeV_243175B_Wave', value=24.30599019997287, bounds=[24.276943795863907:24.35805620413609]> at initial value 24.305971111894756 . Fixing value.
# <Parameter 'g_OIV_258903B_Wave', value=25.875071342942046, bounds=[25.847120713809208:25.933479286190792]> at initial value 25.87509833716526 . Fixing value.
# Rerunning fit
# Iteration 3/5(max): 2023-01-06 23:36:39.710934 -----------------
# True in 5 steps
# 14.71 seconds elapsed
# <Parameter 'g_H200S17_34850N_Peak', value=0.00034717852797911764 +/- 0.00106, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S16_35470N_Peak', value=0.0006343467388757042 +/- 0.00129, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S13_38464N_Peak', value=0.0002204211580738804 +/- 0.00111, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=0.00025919197403650795 +/- 0.00117, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVII_46847N_Peak', value=0.0005527924626615719 +/- 0.00123, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_131022N_Peak', value=0.0003884360230766997 +/- 0.00345, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeIII_229250N_Peak', value=0.004817258529126895 +/- 0.0119, bounds=[0.0:inf]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# AGN
# AGN
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [1 0]
# Parameter object has 84 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [1 0] will be initialized with results from spaxel [1 1]
# Parameter object has 84 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-06 23:36:59.503061 -----------------
# True in 43 steps
# 176.01 seconds elapsed
# <Parameter 'g_KVII_31905N_Peak', value=3.452454376248338e-17 +/- 0.000692, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=2.9810062763732215e-12 +/- 0.000687, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S14_37240N_Peak', value=2.9675440953302343e-12 +/- 0.000742, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_Pfund85_37406N_Peak', value=9.499910805430373e-06 +/- 0.000708, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=5.935078639892305e-13 +/- 0.0012, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=1.224546590227889e-13 +/- 0.00122, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaVIII_51789B_Gamma', value=0.0066710887421350075 +/- 0.00183, bounds=[0.00025023237290382276:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_MgVII_55032N_Peak', value=4.959536781863647e-11 +/- 0.00103, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVII_90090N_Peak', value=1.4085230027349336e-10 +/- 0.00094, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_AlVI_91160N_Peak', value=1.63890553576128e-08 +/- 0.000964, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ClII_143678N_Peak', value=8.485396181821833e-09 +/- 0.00116, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Wave', value=24.275177485357688 +/- 0.0102, bounds=[24.274980467156926:24.356086315694032]> at lower bound, fixing to 24.274980467156926
# <Parameter 'g_NeV_243175B_Gamma', value=0.006671114076039793 +/- 0.000962, bounds=[0.000536762505574601:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'd8_PAH107_106800_Peak', value=3.426695317793351e-25 +/- 0.000223, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=2.3714685299454965e-06 +/- 0.000181, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=5.589768247719903e-20 +/- 0.000303, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=5.263669667230238e-18 +/- 0.000284, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'WRM_TAU', value=0.00019595192798535095 +/- 0.107, bounds=[0.0:inf]> unconstrained at 54542.94206226291 % error. Fixing value.
# <Parameter 'STB_TAU', value=0.2390150773183005 +/- 1.02, bounds=[0.0:inf]> unconstrained at 427.55245134697464 % error. Fixing value.
# <Parameter 'STB_010', value=0.00013940972368775315 +/- 0.00999, bounds=[0.0:1.0]> unconstrained at 7169.124441912376 % error. Fixing value.
# <Parameter 'DSK_FLX', value=2.2075856595329727e-05 +/- 0.0673, bounds=[0.0:2.0]> unconstrained at 304737.25068597187 % error. Fixing value.
# <Parameter 'DSK_TAU', value=0.005227758858774032 +/- 4.28e+03, bounds=[0.0:2.0]> unconstrained at 81935083.71080278 % error. Fixing value.
# <Parameter 'g_AlV_29052N_Peak', value=0.0001333367520105289 +/- 0.000844, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVIII_30280N_Peak', value=2.7794934788302055e-05 +/- 0.00152, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=3.452454376248338e-17 +/- 0.000692, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=3.452454376248338e-17 +/- 0.000692, bounds=[0.0:inf]> lower than uncertainty 2.5665053056540246e-05 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=0.00018438675525003204 +/- 0.000615, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=2.9810062763732215e-12 +/- 0.000687, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=2.9810062763732215e-12 +/- 0.000687, bounds=[0.0:inf]> lower than uncertainty 2.4251184625255776e-05 , fixing to 0.0
# <Parameter 'g_H200S15_36250N_Peak', value=0.0002654488966362347 +/- 0.000663, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=2.9675440953302343e-12 +/- 0.000742, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S14_37240N_Peak', value=2.9675440953302343e-12 +/- 0.000742, bounds=[0.0:inf]> lower than uncertainty 2.6471355727647166e-05 , fixing to 0.0
# <Parameter 'g_Pfund85_37406N_Peak', value=9.499910805430373e-06 +/- 0.000708, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund85_37406N_Peak', value=9.499910805430373e-06 +/- 0.000708, bounds=[0.0:inf]> lower than uncertainty 2.5053327120772228e-05 , fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=0.0003380401172286747 +/- 0.00116, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaV_41594N_Peak', value=0.00019572478418405763 +/- 0.00152, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S10_44096N_Peak', value=0.0005230229721153024 +/- 0.00113, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_44348N_Peak', value=0.0005367397175241794 +/- 0.00125, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=0.0004342192639815237 +/- 0.00141, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=0.00012376848143212505 +/- 0.00186, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=5.935078639892305e-13 +/- 0.0012, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=5.935078639892305e-13 +/- 0.0012, bounds=[0.0:inf]> lower than uncertainty 3.89013856773898e-05 , fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=1.224546590227889e-13 +/- 0.00122, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KIII_46180N_Peak', value=1.224546590227889e-13 +/- 0.00122, bounds=[0.0:inf]> lower than uncertainty 3.962045573729651e-05 , fixing to 0.0
# <Parameter 'g_FeII_46719N_Peak', value=0.0006042106189978684 +/- 0.00124, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVIII_51789N_Peak', value=0.00035610729553464394 +/- 0.00221, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_55032N_Peak', value=4.959536781863647e-11 +/- 0.00103, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_55032N_Peak', value=4.959536781863647e-11 +/- 0.00103, bounds=[0.0:inf]> lower than uncertainty 2.6790884873790705e-05 , fixing to 0.0
# <Parameter 'g_MgV_56098N_Peak', value=0.0001446783331913135 +/- 0.00141, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_56739N_Peak', value=0.00032788747329111253 +/- 0.000982, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIII_73177N_Peak', value=0.00023661931751084653 +/- 0.000953, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=0.0006881605467697586 +/- 0.00234, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_79016N_Peak', value=0.0003252248311967062 +/- 0.00128, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_90090N_Peak', value=1.4085230027349336e-10 +/- 0.00094, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_90090N_Peak', value=1.4085230027349336e-10 +/- 0.00094, bounds=[0.0:inf]> lower than uncertainty 2.8618734908049766e-05 , fixing to 0.0
# <Parameter 'g_AlVI_91160N_Peak', value=1.63890553576128e-08 +/- 0.000964, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_AlVI_91160N_Peak', value=1.63890553576128e-08 +/- 0.000964, bounds=[0.0:inf]> lower than uncertainty 2.898666172296309e-05 , fixing to 0.0
# <Parameter 'g_ClII_143678N_Peak', value=8.485396181821833e-09 +/- 0.00116, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ClII_143678N_Peak', value=8.485396181821833e-09 +/- 0.00116, bounds=[0.0:inf]> lower than uncertainty 4.1393122060774955e-05 , fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=0.0001982269711821502 +/- 0.00385, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd8_PAH107_106800_Peak', value=3.426695317793351e-25 +/- 0.000223, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd8_PAH107_106800_Peak', value=3.426695317793351e-25 +/- 0.000223, bounds=[0.0:inf]> lower than uncertainty 3.2297994800999625e-05 , fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=2.3714685299454965e-06 +/- 0.000181, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=2.3714685299454965e-06 +/- 0.000181, bounds=[0.0:inf]> lower than uncertainty 4.04214642029395e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=5.589768247719903e-20 +/- 0.000303, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=5.589768247719903e-20 +/- 0.000303, bounds=[0.0:inf]> lower than uncertainty 4.185177075074655e-05 , fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=5.263669667230238e-18 +/- 0.000284, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd14_PAH142_141900_Peak', value=5.263669667230238e-18 +/- 0.000284, bounds=[0.0:inf]> lower than uncertainty 4.027335998439693e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=0.013893789177227564 +/- 0.0537, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# AGN
# AGN
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [1 2]
# Parameter object has 80 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [1 2] will be initialized with results from spaxel [1 1]
# Parameter object has 80 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-06 23:40:01.083180 -----------------
# True in 46 steps
# 198.34 seconds elapsed
# No errors retuned
# <Parameter 'HOT_TMP', value=1027.1999999999998, bounds=[100.0:1027.2]> at upper bound, fixing to  1027.2
# <Parameter 'HOT_TMP', value=1027.1999999999998, bounds=[100.0:1027.2]> at initial value 1027.2 . Fixing value.
# <Parameter 'STB_TAU', value=2.8385270745134854e-20, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_010', value=9.504849974788642e-27, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'DSK_FLX', value=5.514952498657221e-20, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=4.352944010116446e-29, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_AlVI_36597N_Peak', value=4.550904050619649e-25, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S13_38464N_Peak', value=7.042378949342828e-27, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_40763N_Peak', value=1.0769887625686886e-27, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=1.2346952575436509e-27, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgIV_44867N_Peak', value=4.4373669172342305e-23, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=1.873987448166047e-24, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVIII_50019N_Peak', value=1.5844154603549038e-24, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SVII_52334N_Peak', value=4.546428047974437e-28, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVIII_52910N_Peak', value=1.1315104854297625e-14, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeVIII_54466B_Gamma', value=0.006671114076050699, bounds=[0.0002371829799907665:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_MgVII_55032N_Peak', value=2.8093054705584257e-11, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeVI_76524N_Peak', value=2.7343094217938917e-19, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SIV_105105N_Peak', value=1.4035953218986616e-10, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_PIII_178850N_Peak', value=2.642231917293362e-29, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_179359N_Peak', value=2.0771999944170834e-31, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Gamma', value=0.0066711140760496845, bounds=[0.000536762505574601:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_OIV_258903N_Peak', value=1.936265668379797e-17, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd4_PAH67_66900_Peak', value=2.0607151201056725e-26, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd10_PAH120_119900_Peak', value=2.2238331644319674e-23, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=1.5573514044581208e-28, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=7.388024712062974e-27, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO2ice_42736_Peak', value=7.874364981098426e-23, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'VGRAD', value=99.99999395898129, bounds=[-100.0:100.0]> at upper bound, fixing to  100.0
# Rerunning fit
# Iteration 2/5(max): 2023-01-06 23:43:19.732131 -----------------
# True in 7 steps
# 17.39 seconds elapsed
# <Parameter 'g_MgVIII_30280N_Peak', value=0.00012502322715469285 +/- 0.00114, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=1.6149800995850083e-05 +/- 0.000452, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S15_36250N_Peak', value=0.00010356765653727976 +/- 0.000534, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=5.3068997688578624e-05 +/- 0.0015, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund75_46538N_Peak', value=0.00037246271720805336 +/- 0.000906, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIX_46585N_Peak', value=2.9420206112333174e-05 +/- 0.000901, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVIII_51789N_Peak', value=0.00047960540788670084 +/- 0.00147, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgV_56098N_Peak', value=0.00033409495027251996 +/- 0.00136, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArIII_89914N_Peak', value=0.00015533991260171064 +/- 0.00148, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_131022N_Peak', value=0.0006206048687567625 +/- 0.0013, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeV_143217N_Peak', value=0.00017565018560042464 +/- 0.00243, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeIII_229250N_Peak', value=0.0010178204456224443 +/- 0.00545, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd0_PAH34_34260_Peak', value=2.845463604598572e-05 +/- 0.000101, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=0.012115126554976879 +/- 0.0353, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# AGN
# AGN
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [2 1]
# Parameter object has 79 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [2 1] will be initialized with results from spaxel [1 1]
# Parameter object has 79 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-06 23:43:42.151722 -----------------
# True in 52 steps
# 214.7 seconds elapsed
# <Parameter 'HOT_TMP', value=1027.1999999999973 +/- 871, bounds=[100.0:1027.2]> at upper bound, fixing to  1027.2
# <Parameter 'STB_FLX', value=1.3157945874790909e-08 +/- 0.388, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_TAU', value=9.41244399192067e-13 +/- 2.12e+05, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'STB_010', value=1.3456109302285611e-28 +/- 5.79e+04, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'DSK_TAU', value=1.2898183583027032e-14 +/- 0.342, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVIII_30280B_Wave', value=3.032754664731397 +/- 0.00242, bounds=[3.022655581598759:3.0327546647313977]> at upper bound, fixing to 3.0327546647313977
# <Parameter 'g_MgVIII_30280B_Gamma', value=0.006671114076050699 +/- 0.00202, bounds=[0.0002598066452992078:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_KVII_31905N_Peak', value=8.968397914523479e-33 +/- 0.000351, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=1.2498441842347048e-30 +/- 0.00039, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=6.930510845674227e-26 +/- 0.000414, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_40819N_Peak', value=5.9876246410417645e-27 +/- 0.000865, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaVII_40858N_Peak', value=1.8289926344191946e-32 +/- 0.000734, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=5.953074175139124e-32 +/- 0.00055, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CII_42988N_Peak', value=1.9570269223117255e-24 +/- 0.000564, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgIV_44867N_Peak', value=3.485709095564718e-24 +/- 0.000779, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArVI_45295N_Peak', value=1.1193894333942442e-16 +/- 0.00082, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=2.5246184453386355e-32 +/- 0.000668, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=1.4862064267297144e-34 +/- 0.000695, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SIX_46413N_Peak', value=2.1604000881668905e-34 +/- 0.000735, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SVII_50027N_Peak', value=2.3670262408543263e-33 +/- 0.00103, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SVII_50027B_Wave', value=5.0106381417301336 +/- 0.00316, bounds=[4.9939527000327315:5.010638141730134]> at upper bound, fixing to 5.010638141730134
# <Parameter 'g_SVII_50027B_Gamma', value=0.006671114076050699 +/- 0.00148, bounds=[0.0002596345135320551:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_SVII_52334N_Peak', value=9.632702272118379e-33 +/- 0.0011, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVIII_52910N_Peak', value=1.104776897285937e-22 +/- 0.00114, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeVIII_54466B_Gamma', value=0.006671114076050699 +/- 0.00223, bounds=[0.0002371829799907665:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_MgVII_55032B_Wave', value=5.5119323208605895 +/- 0.000698, bounds=[5.493577567877371:5.51193232086059]> at upper bound, fixing to 5.51193232086059
# <Parameter 'g_MgV_56098N_Peak', value=9.362084675712222e-17 +/- 0.00138, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArII_69853N_Peak', value=7.2055768137434755e-34 +/- 0.00297, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeVI_76524N_Peak', value=5.801467498570051e-28 +/- 0.00183, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=1.5717812724774663e-37 +/- 0.00126, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaIV_90410N_Peak', value=4.663453192229475e-12 +/- 0.00102, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SIV_105105N_Peak', value=2.1883014467009774e-14 +/- 0.00176, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArV_131022N_Peak', value=1.751966943254604e-16 +/- 0.00142, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_143217N_Peak', value=3.0425842006810767e-14 +/- 0.00234, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Gamma', value=0.006671114076050699 +/- 0.000551, bounds=[0.000536762505574601:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_SI_252490N_Peak', value=8.039731887640901e-28 +/- 0.00529, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_259883N_Peak', value=1.1605209599886623e-28 +/- 0.00709, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=7.128641912696676e-38 +/- 0.000168, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=4.2745153877881205e-34 +/- 0.000314, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH174_173750_Peak', value=2.7079508311453003e-11 +/- 0.000388, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=4.748539244385105e-27 +/- 0.0395, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'VGRAD', value=99.99999994417998 +/- 0.986, bounds=[-100.0:100.0]> at upper bound, fixing to  100.0
# <Parameter 'STB_FLX', value=1.3157945874790909e-08 +/- 0.388, bounds=[0.0:2.0]> unconstrained at 2949892832.2683477 % error. Fixing value.
# <Parameter 'STB_TAU', value=9.41244399192067e-13 +/- 2.12e+05, bounds=[0.0:inf]> unconstrained at 2.257565733421058e+19 % error. Fixing value.
# <Parameter 'STB_010', value=1.3456109302285611e-28 +/- 5.79e+04, bounds=[0.0:1.0]> unconstrained at 4.304208269347294e+34 % error. Fixing value.
# <Parameter 'DSK_TAU', value=1.2898183583027032e-14 +/- 0.342, bounds=[0.0:2.0]> unconstrained at 2650514636638158.0 % error. Fixing value.
# <Parameter 'g_MgVIII_30280N_Peak', value=5.225187618044644e-05 +/- 0.000563, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=8.968397914523479e-33 +/- 0.000351, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=8.968397914523479e-33 +/- 0.000351, bounds=[0.0:inf]> lower than uncertainty 1.3724933377541548e-05 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=1.2498441842347048e-30 +/- 0.00039, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=1.2498441842347048e-30 +/- 0.00039, bounds=[0.0:inf]> lower than uncertainty 1.580167245362605e-05 , fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=6.930510845674227e-26 +/- 0.000414, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=6.930510845674227e-26 +/- 0.000414, bounds=[0.0:inf]> lower than uncertainty 1.514499934066834e-05 , fixing to 0.0
# <Parameter 'g_AlVI_36597N_Peak', value=0.00016894396065708333 +/- 0.000456, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=5.9876246410417645e-27 +/- 0.000865, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=5.9876246410417645e-27 +/- 0.000865, bounds=[0.0:inf]> lower than uncertainty 2.9931784495735722e-05 , fixing to 0.0
# <Parameter 'g_CaVII_40858N_Peak', value=1.8289926344191946e-32 +/- 0.000734, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaVII_40858N_Peak', value=1.8289926344191946e-32 +/- 0.000734, bounds=[0.0:inf]> lower than uncertainty 3.036634534153775e-05 , fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=5.953074175139124e-32 +/- 0.00055, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_41150N_Peak', value=5.953074175139124e-32 +/- 0.00055, bounds=[0.0:inf]> lower than uncertainty 2.1602351167640107e-05 , fixing to 0.0
# <Parameter 'g_CII_42988N_Peak', value=1.9570269223117255e-24 +/- 0.000564, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CII_42988N_Peak', value=1.9570269223117255e-24 +/- 0.000564, bounds=[0.0:inf]> lower than uncertainty 2.2424989933143787e-05 , fixing to 0.0
# <Parameter 'g_MgIV_44867N_Peak', value=3.485709095564718e-24 +/- 0.000779, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=3.485709095564718e-24 +/- 0.000779, bounds=[0.0:inf]> lower than uncertainty 2.47608368317216e-05 , fixing to 0.0
# <Parameter 'g_ArVI_45295N_Peak', value=1.1193894333942442e-16 +/- 0.00082, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=1.1193894333942442e-16 +/- 0.00082, bounds=[0.0:inf]> lower than uncertainty 2.8728013405181184e-05 , fixing to 0.0
# <Parameter 'g_FeII_46077N_Peak', value=2.5246184453386355e-32 +/- 0.000668, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46077N_Peak', value=2.5246184453386355e-32 +/- 0.000668, bounds=[0.0:inf]> lower than uncertainty 2.638337328159319e-05 , fixing to 0.0
# <Parameter 'g_KIII_46180N_Peak', value=1.4862064267297144e-34 +/- 0.000695, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KIII_46180N_Peak', value=1.4862064267297144e-34 +/- 0.000695, bounds=[0.0:inf]> lower than uncertainty 2.6648728434940178e-05 , fixing to 0.0
# <Parameter 'g_SIX_46413N_Peak', value=2.1604000881668905e-34 +/- 0.000735, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIX_46413N_Peak', value=2.1604000881668905e-34 +/- 0.000735, bounds=[0.0:inf]> lower than uncertainty 2.8517564219412963e-05 , fixing to 0.0
# <Parameter 'g_Pfund75_46538N_Peak', value=0.0003255078584756445 +/- 0.000735, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_50027N_Peak', value=2.3670262408543263e-33 +/- 0.00103, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_50027N_Peak', value=2.3670262408543263e-33 +/- 0.00103, bounds=[0.0:inf]> lower than uncertainty 3.985027119682774e-05 , fixing to 0.0
# <Parameter 'g_SVII_52334N_Peak', value=9.632702272118379e-33 +/- 0.0011, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_52334N_Peak', value=9.632702272118379e-33 +/- 0.0011, bounds=[0.0:inf]> lower than uncertainty 3.512187435353205e-05 , fixing to 0.0
# <Parameter 'g_SiVIII_52910N_Peak', value=1.104776897285937e-22 +/- 0.00114, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_52910N_Peak', value=1.104776897285937e-22 +/- 0.00114, bounds=[0.0:inf]> lower than uncertainty 3.6902540314703874e-05 , fixing to 0.0
# <Parameter 'g_SiVIII_52910B_Gamma', value=0.003371767087107879 +/- 0.00845, bounds=[0.00024459709519623386:0.0066711140760507]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_52910B_Peak', value=0.00017354262354259264 +/- 0.0004, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeVIII_54466N_Peak', value=0.0003398191694407137 +/- 0.00114, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_55032N_Peak', value=0.00044168229270547015 +/- 0.00129, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgV_56098N_Peak', value=9.362084675712222e-17 +/- 0.00138, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgV_56098N_Peak', value=9.362084675712222e-17 +/- 0.00138, bounds=[0.0:inf]> lower than uncertainty 3.728370633305741e-05 , fixing to 0.0
# <Parameter 'g_ArII_69853N_Peak', value=7.2055768137434755e-34 +/- 0.00297, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=7.2055768137434755e-34 +/- 0.00297, bounds=[0.0:inf]> lower than uncertainty 5.662724551796268e-05 , fixing to 0.0
# <Parameter 'g_NeVI_76524N_Peak', value=5.801467498570051e-28 +/- 0.00183, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeVI_76524N_Peak', value=5.801467498570051e-28 +/- 0.00183, bounds=[0.0:inf]> lower than uncertainty 4.734791611704513e-05 , fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=1.5717812724774663e-37 +/- 0.00126, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_79016N_Peak', value=1.5717812724774663e-37 +/- 0.00126, bounds=[0.0:inf]> lower than uncertainty 4.060745852942318e-05 , fixing to 0.0
# <Parameter 'g_NaIV_90410N_Peak', value=4.663453192229475e-12 +/- 0.00102, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIV_90410N_Peak', value=4.663453192229475e-12 +/- 0.00102, bounds=[0.0:inf]> lower than uncertainty 3.526176313879763e-05 , fixing to 0.0
# <Parameter 'g_SIV_105105N_Peak', value=2.1883014467009774e-14 +/- 0.00176, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIV_105105N_Peak', value=2.1883014467009774e-14 +/- 0.00176, bounds=[0.0:inf]> lower than uncertainty 4.371237998728682e-05 , fixing to 0.0
# <Parameter 'g_ArV_131022N_Peak', value=1.751966943254604e-16 +/- 0.00142, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArV_131022N_Peak', value=1.751966943254604e-16 +/- 0.00142, bounds=[0.0:inf]> lower than uncertainty 5.0398755089003606e-05 , fixing to 0.0
# <Parameter 'g_NeV_143217N_Peak', value=3.0425842006810767e-14 +/- 0.00234, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeV_143217N_Peak', value=3.0425842006810767e-14 +/- 0.00234, bounds=[0.0:inf]> lower than uncertainty 6.527368411902778e-05 , fixing to 0.0
# <Parameter 'g_FeII_179359N_Peak', value=0.0018648044308056688 +/- 0.00376, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=8.039731887640901e-28 +/- 0.00529, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=8.039731887640901e-28 +/- 0.00529, bounds=[0.0:inf]> lower than uncertainty 0.000257932869280706 , fixing to 0.0
# <Parameter 'g_OIV_258903N_Peak', value=0.001547872453692061 +/- 0.0315, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_259883N_Peak', value=1.1605209599886623e-28 +/- 0.00709, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_259883N_Peak', value=1.1605209599886623e-28 +/- 0.00709, bounds=[0.0:inf]> lower than uncertainty 0.00033561073849526106 , fixing to 0.0
# <Parameter 'd12_PAH135_134800_Peak', value=7.128641912696676e-38 +/- 0.000168, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=7.128641912696676e-38 +/- 0.000168, bounds=[0.0:inf]> lower than uncertainty 4.674543344022686e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=4.2745153877881205e-34 +/- 0.000314, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=4.2745153877881205e-34 +/- 0.000314, bounds=[0.0:inf]> lower than uncertainty 4.565887312744971e-05 , fixing to 0.0
# <Parameter 'd16_PAH174_173750_Peak', value=2.7079508311453003e-11 +/- 0.000388, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH174_173750_Peak', value=2.7079508311453003e-11 +/- 0.000388, bounds=[0.0:inf]> lower than uncertainty 6.664020675927604e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=4.748539244385105e-27 +/- 0.0395, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=4.748539244385105e-27 +/- 0.0395, bounds=[0.0:1.0]> lower than uncertainty 3.234258971396247e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# AGN
# AGN
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [2 0]
# Parameter object has 82 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [2 0] will be initialized with results from spaxel [1 1]
# Parameter object has 82 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-06 23:47:22.650358 -----------------
# True in 95 steps
# 397.57 seconds elapsed
# <Parameter 'DSK_TAU', value=1.5519311569199693e-08 +/- 0.355, bounds=[0.0:2.0]> at lower bound, fixing to 0.0
# <Parameter 'g_CoII_29846N_Peak', value=4.7250189442460366e-20 +/- 0.000558, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVIII_30280B_Wave', value=3.032754664731397 +/- 0.0045, bounds=[3.022655581598759:3.0327546647313977]> at upper bound, fixing to 3.0327546647313977
# <Parameter 'g_MgVIII_30280B_Gamma', value=0.006671114076050699 +/- 0.00373, bounds=[0.0002598066452992078:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_KVII_31905N_Peak', value=1.8774007163074644e-32 +/- 0.000391, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=9.994382512961434e-34 +/- 0.000411, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=6.787548116489048e-06 +/- 0.000452, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVIII_50019N_Peak', value=1.3586467798376039e-25 +/- 0.00111, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_SiVIII_50019B_Wave', value=5.009836872312943 +/- 0.00536, bounds=[4.993154098845368:5.009836872312944]> at upper bound, fixing to 5.009836872312944
# <Parameter 'g_SiVIII_50019B_Gamma', value=0.006671114076050699 +/- 0.00253, bounds=[0.000259678813544634:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_NaVIII_51789B_Gamma', value=0.006671114076050699 +/- 0.00299, bounds=[0.00025023237290382276:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_FeVIII_54466B_Wave', value=5.437076536201575 +/- 0.00918, bounds=[5.437076533871365:5.45524250959429]> at lower bound, fixing to 5.437076533871365
# <Parameter 'g_FeVIII_54466B_Gamma', value=0.006671114076050699 +/- 0.00393, bounds=[0.0002371829799907665:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_MgVII_55032B_Wave', value=5.5119323208605895 +/- 0.000263, bounds=[5.493577567877371:5.51193232086059]> at upper bound, fixing to 5.51193232086059
# <Parameter 'g_ArII_69853N_Peak', value=1.6372616560339495e-25 +/- 0.00262, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVII_90090N_Peak', value=1.9843814410949965e-33 +/- 0.000742, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Gamma', value=0.006671114076050699 +/- 0.000779, bounds=[0.000536762505574601:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'd13_PAH140_140400_Peak', value=3.3378084114904784e-36 +/- 0.000242, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=5.378298031021684e-37 +/- 0.000231, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=7.262159948482823e-07 +/- 0.0722, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_FLX', value=0.05027710582176764 +/- 0.106, bounds=[0.0:2.0]> unconstrained at 210.75650181069906 % error. Fixing value.
# <Parameter 'DSK_TAU', value=1.5519311569199693e-08 +/- 0.355, bounds=[0.0:2.0]> unconstrained at 2288366858.9603724 % error. Fixing value.
# <Parameter 'g_CoII_29846N_Peak', value=4.7250189442460366e-20 +/- 0.000558, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CoII_29846N_Peak', value=4.7250189442460366e-20 +/- 0.000558, bounds=[0.0:inf]> lower than uncertainty 2.0486236761706618e-05 , fixing to 0.0
# <Parameter 'g_MgVIII_30280N_Peak', value=2.463565737180938e-05 +/- 0.000635, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=1.8774007163074644e-32 +/- 0.000391, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=1.8774007163074644e-32 +/- 0.000391, bounds=[0.0:inf]> lower than uncertainty 1.8646565537795702e-05 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=9.994382512961434e-34 +/- 0.000411, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=9.994382512961434e-34 +/- 0.000411, bounds=[0.0:inf]> lower than uncertainty 1.9519679031887465e-05 , fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=6.787548116489048e-06 +/- 0.000452, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=6.787548116489048e-06 +/- 0.000452, bounds=[0.0:inf]> lower than uncertainty 2.0599708949334202e-05 , fixing to 0.0
# <Parameter 'g_H200S14_37240N_Peak', value=0.00013775112968445114 +/- 0.00045, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NiI_39524N_Peak', value=5.504901121803784e-05 +/- 0.000539, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_41150N_Peak', value=0.0001018462154809294 +/- 0.000613, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaV_41594N_Peak', value=0.00027677736882082975 +/- 0.000592, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=0.00021610261997193536 +/- 0.000864, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=5.808478815008453e-05 +/- 0.000826, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_46719N_Peak', value=0.00010856526379151373 +/- 0.000812, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=1.7273519733190898e-05 +/- 0.000984, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=1.7273519733190898e-05 +/- 0.000984, bounds=[0.0:inf]> lower than uncertainty 4.5486274415999586e-05 , fixing to 0.0
# <Parameter 'g_SiVIII_50019N_Peak', value=1.3586467798376039e-25 +/- 0.00111, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_50019N_Peak', value=1.3586467798376039e-25 +/- 0.00111, bounds=[0.0:inf]> lower than uncertainty 5.197899646563682e-05 , fixing to 0.0
# <Parameter 'g_NaVIII_51789N_Peak', value=7.144793701318407e-05 +/- 0.00132, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SVII_52334N_Peak', value=2.124344122660046e-05 +/- 0.000737, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SiVIII_52910N_Peak', value=8.868725459460295e-05 +/- 0.000827, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeVIII_54466N_Peak', value=0.00019214170349306852 +/- 0.000774, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S7_55115N_Peak', value=0.0008131870528371797 +/- 0.00193, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgV_56098N_Peak', value=0.00012449782932249446 +/- 0.000858, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=1.6372616560339495e-25 +/- 0.00262, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=1.6372616560339495e-25 +/- 0.00262, bounds=[0.0:inf]> lower than uncertainty 5.548770170594531e-05 , fixing to 0.0
# <Parameter 'g_Pfund65_74578N_Peak', value=0.00017928612722623014 +/- 0.00157, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeVI_76524N_Peak', value=0.0001638081732539602 +/- 0.00172, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_90090N_Peak', value=1.9843814410949965e-33 +/- 0.000742, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_90090N_Peak', value=1.9843814410949965e-33 +/- 0.000742, bounds=[0.0:inf]> lower than uncertainty 3.220815364782569e-05 , fixing to 0.0
# <Parameter 'g_FeII_259883N_Peak', value=0.0021279934708244696 +/- 0.00475, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=3.3378084114904784e-36 +/- 0.000242, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=3.3378084114904784e-36 +/- 0.000242, bounds=[0.0:inf]> lower than uncertainty 4.455418614514316e-05 , fixing to 0.0
# <Parameter 'd14_PAH142_141900_Peak', value=5.378298031021684e-37 +/- 0.000231, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd14_PAH142_141900_Peak', value=5.378298031021684e-37 +/- 0.000231, bounds=[0.0:inf]> lower than uncertainty 4.439753409166604e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=7.262159948482823e-07 +/- 0.0722, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# ...
# <Parameter 'g_FeII_56739N_Peak', value=0.0002376719404974123 +/- 0.000581, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaIII_73177N_Peak', value=0.00026849527168315844 +/- 0.000543, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=6.292947490838014e-20 +/- 0.00164, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_Pfund65_74578N_Peak', value=6.292947490838014e-20 +/- 0.00164, bounds=[0.0:inf]> lower than uncertainty 3.216456190393313e-05 , fixing to 0.0
# <Parameter 'g_NeVI_76524N_Peak', value=2.7886336400169234e-31 +/- 0.00133, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeVI_76524N_Peak', value=2.7886336400169234e-31 +/- 0.00133, bounds=[0.0:inf]> lower than uncertainty 3.3885746705034466e-05 , fixing to 0.0
# <Parameter 'g_ArV_79016N_Peak', value=0.00020879472770837923 +/- 0.000801, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArIII_89914N_Peak', value=6.0628665966346005e-21 +/- 0.00113, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArIII_89914N_Peak', value=6.0628665966346005e-21 +/- 0.00113, bounds=[0.0:inf]> lower than uncertainty 2.542580999162921e-05 , fixing to 0.0
# <Parameter 'g_AlVI_91160N_Peak', value=0.00012427089087830193 +/- 0.000577, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIV_105105N_Peak', value=5.6231018343521145e-33 +/- 0.0015, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SIV_105105N_Peak', value=5.6231018343521145e-33 +/- 0.0015, bounds=[0.0:inf]> lower than uncertainty 3.2803155548096096e-05 , fixing to 0.0
# <Parameter 'g_ArV_131022N_Peak', value=0.00019875765678040473 +/- 0.000864, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeV_143217N_Peak', value=1.5320613206761657e-26 +/- 0.00204, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeV_143217N_Peak', value=1.5320613206761657e-26 +/- 0.00204, bounds=[0.0:inf]> lower than uncertainty 5.0653802526343995e-05 , fixing to 0.0
# <Parameter 'g_ArIII_218302N_Peak', value=0.001383957132148011 +/- 0.00278, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeV_243175N_Peak', value=4.2005356112469004e-20 +/- 0.00967, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeV_243175N_Peak', value=4.2005356112469004e-20 +/- 0.00967, bounds=[0.0:inf]> lower than uncertainty 0.00018144346971330763 , fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=9.562587789700934e-19 +/- 0.00415, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=9.562587789700934e-19 +/- 0.00415, bounds=[0.0:inf]> lower than uncertainty 0.00021228281316300253 , fixing to 0.0
# <Parameter 'g_OIV_258903N_Peak', value=4.4838733109063887e-17 +/- 0.0193, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_OIV_258903N_Peak', value=4.4838733109063887e-17 +/- 0.0193, bounds=[0.0:inf]> lower than uncertainty 0.00035745929753658393 , fixing to 0.0
# <Parameter 'g_FeII_259883N_Peak', value=0.002549999562940966 +/- 0.00587, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=6.261643107231891e-38 +/- 0.000126, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd12_PAH135_134800_Peak', value=6.261643107231891e-38 +/- 0.000126, bounds=[0.0:inf]> lower than uncertainty 3.314605139022769e-05 , fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=3.4430156929922638e-34 +/- 0.000204, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=3.4430156929922638e-34 +/- 0.000204, bounds=[0.0:inf]> lower than uncertainty 3.390129744575452e-05 , fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=0.004393426983722053 +/- 0.0983, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# Successful fit ----------------------------------------------------
# Regenerating continuum profiles
# AGN
# AGN
# ISRF
# ISRF
# Regenerating parameter object for current spaxel [2 2]
# Parameter object has 72 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Current spaxel [2 2] will be initialized with results from spaxel [1 1]
# Parameter object has 72 lines, 29 PAHs, 4 opacity features, and 42 continuum parameters
# Iteration 1/5(max): 2023-01-07 00:08:26.857534 -----------------
# True in 57 steps
# 219.05 seconds elapsed
# <Parameter 'g_SXIII_28926N_Peak', value=9.823027766524216e-22 +/- 0.000324, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_KVII_31905N_Peak', value=1.7652046032667202e-22 +/- 0.000236, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=1.5702712764782337e-17 +/- 0.000235, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=1.671161159375384e-10 +/- 0.000299, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_40819N_Peak', value=2.7531340616341928e-24 +/- 0.000435, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_CaVII_40858N_Peak', value=6.916116038498397e-32 +/- 0.000455, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_FeII_48891N_Peak', value=1.7190405456775388e-21 +/- 0.000624, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaVIII_51789N_Peak', value=3.5301457886360318e-22 +/- 0.000759, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NaVIII_51789B_Gamma', value=0.006671114076042497 +/- 0.00275, bounds=[0.00025023237290382276:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_FeVIII_54466B_Wave', value=5.437076544645928 +/- 0.00983, bounds=[5.437076533871365:5.45524250959429]> at lower bound, fixing to 5.437076533871365
# <Parameter 'g_FeVIII_54466B_Gamma', value=0.006671114050370986 +/- 0.00422, bounds=[0.0002371829799907665:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_MgVII_55032N_Peak', value=2.885357906802679e-18 +/- 0.000621, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVII_55032B_Wave', value=5.511932320860489 +/- 0.00118, bounds=[5.493577567877371:5.51193232086059]> at upper bound, fixing to 5.51193232086059
# <Parameter 'g_MgV_56098N_Peak', value=5.057362738608384e-24 +/- 0.000745, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_ArII_69853N_Peak', value=5.715713327751682e-18 +/- 0.00238, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeVI_76524N_Peak', value=6.274715805369222e-15 +/- 0.000999, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_MgVII_90090N_Peak', value=4.162707601525158e-22 +/- 0.00058, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_AlVI_91160N_Peak', value=7.669053674369485e-14 +/- 0.000584, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_143217N_Peak', value=2.6793794374419916e-10 +/- 0.00159, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'g_NeV_243175B_Gamma', value=0.006671114076050699 +/- 0.000971, bounds=[0.000536762505574601:0.0066711140760507]> at upper bound, fixing to 0.0066711140760507
# <Parameter 'g_SI_252490N_Peak', value=6.797698728677712e-16 +/- 0.0043, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd13_PAH140_140400_Peak', value=5.567784000896309e-17 +/- 0.000206, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=9.596427714040979e-15 +/- 0.000193, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH170_170400_Peak', value=9.406943799842023e-11 +/- 0.000224, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'd16_PAH174_173750_Peak', value=1.8018543277334154e-14 +/- 0.000248, bounds=[0.0:inf]> at lower bound, fixing to 0.0
# <Parameter 'o_CO13ice_46822_Peak', value=2.658662994451544e-09 +/- 0.0839, bounds=[0.0:1.0]> at lower bound, fixing to 0.0
# <Parameter 'STB_010', value=0.6997457881600756 +/- 54.4, bounds=[0.0:1.0]> unconstrained at 7772.417706153594 % error. Fixing value.
# <Parameter 'DSK_TAU', value=0.0006942922914078045 +/- 0.218, bounds=[0.0:2.0]> unconstrained at 31344.312978126316 % error. Fixing value.
# <Parameter 'g_SXIII_28926N_Peak', value=9.823027766524216e-22 +/- 0.000324, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SXIII_28926N_Peak', value=9.823027766524216e-22 +/- 0.000324, bounds=[0.0:inf]> lower than uncertainty 9.858530930657784e-06 , fixing to 0.0
# <Parameter 'g_MgVIII_30280N_Peak', value=1.7584142263502024e-05 +/- 0.000322, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=1.7652046032667202e-22 +/- 0.000236, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_KVII_31905N_Peak', value=1.7652046032667202e-22 +/- 0.000236, bounds=[0.0:inf]> lower than uncertainty 9.452172836443305e-06 , fixing to 0.0
# <Parameter 'g_CaIV_32067N_Peak', value=1.5702712764782337e-17 +/- 0.000235, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaIV_32067N_Peak', value=1.5702712764782337e-17 +/- 0.000235, bounds=[0.0:inf]> lower than uncertainty 9.727721671252027e-06 , fixing to 0.0
# <Parameter 'g_H200S17_34850N_Peak', value=1.671161159375384e-10 +/- 0.000299, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_H200S17_34850N_Peak', value=1.671161159375384e-10 +/- 0.000299, bounds=[0.0:inf]> lower than uncertainty 1.003916001530073e-05 , fixing to 0.0
# <Parameter 'g_H200S14_37240N_Peak', value=5.87543160298914e-05 +/- 0.000264, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=2.7531340616341928e-24 +/- 0.000435, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_40819N_Peak', value=2.7531340616341928e-24 +/- 0.000435, bounds=[0.0:inf]> lower than uncertainty 1.6363157394321926e-05 , fixing to 0.0
# <Parameter 'g_CaVII_40858N_Peak', value=6.916116038498397e-32 +/- 0.000455, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_CaVII_40858N_Peak', value=6.916116038498397e-32 +/- 0.000455, bounds=[0.0:inf]> lower than uncertainty 1.8237452404963628e-05 , fixing to 0.0
# <Parameter 'g_FeII_41150N_Peak', value=5.378514431955967e-05 +/- 0.000349, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgIV_44867N_Peak', value=5.328894618121123e-05 +/- 0.000473, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArVI_45295N_Peak', value=3.30403336589997e-05 +/- 0.000498, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVII_46847N_Peak', value=6.565087286571368e-05 +/- 0.000568, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=1.7190405456775388e-21 +/- 0.000624, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_48891N_Peak', value=1.7190405456775388e-21 +/- 0.000624, bounds=[0.0:inf]> lower than uncertainty 2.2923675168282872e-05 , fixing to 0.0
# <Parameter 'g_NaVIII_51789N_Peak', value=3.5301457886360318e-22 +/- 0.000759, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NaVIII_51789N_Peak', value=3.5301457886360318e-22 +/- 0.000759, bounds=[0.0:inf]> lower than uncertainty 2.9232014829904222e-05 , fixing to 0.0
# <Parameter 'g_SiVIII_52910N_Peak', value=3.396319038068186e-05 +/- 0.000539, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeVIII_54466N_Peak', value=1.5256752937901744e-05 +/- 0.00054, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_55032N_Peak', value=2.885357906802679e-18 +/- 0.000621, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_55032N_Peak', value=2.885357906802679e-18 +/- 0.000621, bounds=[0.0:inf]> lower than uncertainty 1.697678695302633e-05 , fixing to 0.0
# <Parameter 'g_MgV_56098N_Peak', value=5.057362738608384e-24 +/- 0.000745, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgV_56098N_Peak', value=5.057362738608384e-24 +/- 0.000745, bounds=[0.0:inf]> lower than uncertainty 1.70755567848177e-05 , fixing to 0.0
# <Parameter 'g_FeII_56739N_Peak', value=0.00013308078056534483 +/- 0.000579, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=5.715713327751682e-18 +/- 0.00238, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_ArII_69853N_Peak', value=5.715713327751682e-18 +/- 0.00238, bounds=[0.0:inf]> lower than uncertainty 2.6591239370851628e-05 , fixing to 0.0
# <Parameter 'g_NeVI_76524N_Peak', value=6.274715805369222e-15 +/- 0.000999, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeVI_76524N_Peak', value=6.274715805369222e-15 +/- 0.000999, bounds=[0.0:inf]> lower than uncertainty 2.5047021675230732e-05 , fixing to 0.0
# <Parameter 'g_MgVII_90090N_Peak', value=4.162707601525158e-22 +/- 0.00058, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_MgVII_90090N_Peak', value=4.162707601525158e-22 +/- 0.00058, bounds=[0.0:inf]> lower than uncertainty 1.9134041028310398e-05 , fixing to 0.0
# <Parameter 'g_AlVI_91160N_Peak', value=7.669053674369485e-14 +/- 0.000584, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_AlVI_91160N_Peak', value=7.669053674369485e-14 +/- 0.000584, bounds=[0.0:inf]> lower than uncertainty 1.8808386935634558e-05 , fixing to 0.0
# <Parameter 'g_NeV_143217N_Peak', value=2.6793794374419916e-10 +/- 0.00159, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_NeV_143217N_Peak', value=2.6793794374419916e-10 +/- 0.00159, bounds=[0.0:inf]> lower than uncertainty 3.743817409832838e-05 , fixing to 0.0
# <Parameter 'g_SI_252490N_Peak', value=6.797698728677712e-16 +/- 0.0043, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_SI_252490N_Peak', value=6.797698728677712e-16 +/- 0.0043, bounds=[0.0:inf]> lower than uncertainty 0.00020222889399145236 , fixing to 0.0
# <Parameter 'g_OIV_258903N_Peak', value=0.000311499405312247 +/- 0.0323, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'g_FeII_259883N_Peak', value=0.001727361903763736 +/- 0.00635, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd20_PAH30_30100_Peak', value=2.538737910706236e-05 +/- 5.74e-05, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=5.567784000896309e-17 +/- 0.000206, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd13_PAH140_140400_Peak', value=5.567784000896309e-17 +/- 0.000206, bounds=[0.0:inf]> lower than uncertainty 3.073647335330839e-05 , fixing to 0.0
# <Parameter 'd15_PAH159_159000_Peak', value=9.596427714040979e-15 +/- 0.000193, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd15_PAH159_159000_Peak', value=9.596427714040979e-15 +/- 0.000193, bounds=[0.0:inf]> lower than uncertainty 3.485380485308605e-05 , fixing to 0.0
# <Parameter 'd16_PAH170_170400_Peak', value=9.406943799842023e-11 +/- 0.000224, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH170_170400_Peak', value=9.406943799842023e-11 +/- 0.000224, bounds=[0.0:inf]> lower than uncertainty 4.112624542947946e-05 , fixing to 0.0
# <Parameter 'd16_PAH174_173750_Peak', value=1.8018543277334154e-14 +/- 0.000248, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'd16_PAH174_173750_Peak', value=1.8018543277334154e-14 +/- 0.000248, bounds=[0.0:inf]> lower than uncertainty 3.964710145959527e-05 , fixing to 0.0
# <Parameter 'd16_PAH179_178700_Peak', value=0.00012721709503424374 +/- 0.000477, bounds=[0.0:inf]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=2.658662994451544e-09 +/- 0.0839, bounds=[0.0:1.0]> unconstrained, fixing entire feature
# <Parameter 'o_CO13ice_46822_Peak', value=2.658662994451544e-09 +/- 0.0839, bounds=[0.0:1.0]> lower than uncertainty 1.9117220099030886e-05 , fixing to 0.0
# Successful fit ----------------------------------------------------

# %%
# Line and PAH averaged velocity gradient wrt z, in [km/s]
print(s.parcube['VALUE'].data[-1])
print(s.parcube['VALUE'].data[-1]/2.998e5)
# Out:
# [[ -2.15633778  10.36721807  52.9846466 ]
#  [  6.58994215 -24.24547139 100.        ]
#  [ 90.49923771 100.          99.97808252]]
# [[-7.19258765e-06  3.45804472e-05  1.76733311e-04]
#  [ 2.19811279e-05 -8.08721528e-05  3.33555704e-04]
#  [ 3.01865369e-04  3.33555704e-04  3.33482597e-04]]

# %%
s.plot_cube_fit(1, 1, inppar_fn, optpar_fn)
# Out:
# AGN
# AGN
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Load the parameter cube from drive
parcube_fd = '../CAFE/output/'+source_fnb+'/'
parcube_fn = source_fnb+'_parcube.fits'

# %%
s.read_cube(source_fn, file_dir=source_fd, z=z)
# Out:
# Filename: ./CRETA/extractions/NGC7469_GridExt_3x3_s0.5as_cube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  FLUX          1 ImageHDU        38   (3, 3, 12894)   float64
#   2  ERR           1 ImageHDU         9   (3, 3, 12894)   float64
#   3  FLUX_ST       1 ImageHDU         9   (3, 3, 12894)   float64
#   4  ERR_ST        1 ImageHDU         9   (3, 3, 12894)   float64
#   5  DQ            1 ImageHDU         9   (3, 3, 12894)   float64
#   6  WAVE          1 ImageHDU         7   (12894,)   float64
#   7  BAND_NAME     1 BinTableHDU     11   12894R x 1C   [20A]

# %%
s.read_parcube_file(parcube_fn, file_dir=parcube_fd)
# Out:
# Filename: /Users/tanio/Sync/pywork/CAFE_dev/output/NGC7469_GridExt_3x3_s05as_cube/NGC7469_GridExt_3x3_s05as_cube_parcube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1  VALUE         1 ImageHDU        38   (3, 3, 460)   float64
#   2  STDERR        1 ImageHDU        38   (3, 3, 460)   float64
#   3  VARY          1 ImageHDU        38   (3, 3, 460)   float64
#   4  MIN           1 ImageHDU        38   (3, 3, 460)   float64
#   5  MAX           1 ImageHDU        38   (3, 3, 460)   float64
#   6  EXPR          1 BinTableHDU     13   460R x 2C   [I, 24A]
#   7  PARNAME       1 BinTableHDU     13   460R x 2C   [I, 32A]

# %%
s.plot_cube_fit(1, 1, inppar_fn, optpar_fn)
# Out:
# AGN
# AGN
# ISRF
# ISRF
# /usr/local/anaconda3/lib/python3.8/site-packages/ipywidgets/widgets/widget.py:412: DeprecationWarning: Passing unrecognized arguments to super(Toolbar).__init__().
# __init__() missing 1 required positional argument: 'canvas'
# This is deprecated in traitlets 4.2.This error will be raised in a future release of traitlets.
#   super(Widget, self).__init__(**kwargs)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Generate map of feature (TBD)
#s.make_map('HOT_FLX')

# %%
from astropy.io import ascii
from astropy.table import Table
from astropy.table import QTable

# Read output PAH table
pah = cafeio.pah_table(s.parcube, 0, 0)
# Read output line table
line = cafeio.line_table(s.parcube, 0, 0)

pah62 = pah[pah.index == 'PAH62'].pah_strength.values[0]
pah62_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah77 = pah[pah.index == 'PAH77_C'].pah_strength.values[0]
pah77_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]
pah113 = pah[pah.index == 'PAH113_C'].pah_strength.values[0]
pah113_unc = pah[pah.index == 'PAH62'].pah_strength_unc.values[0]

x = pah62 / pah77 
x_unc = pah62 / pah77 * np.sqrt((pah62_unc/pah62)**2 + (pah77_unc/pah77)**2)
y = pah113 / pah77
y_unc = pah113 / pah77 * np.sqrt((pah113_unc/pah113)**2 + (pah77_unc/pah77)**2)

print('6.2/7.7 = {} +/- {}'.format(x, x_unc))
print('11.3/7.7 = {} +/- {}'.format(y, y_unc))

print(pah)

# Make an astropy table 
t = QTable([pah.index.values, pah.pah_strength, pah.pah_strength_unc],
           names = ('pah_complex', 'pah_strength', 'pah_strength_unc'),
           meta={'wavelength': 'micron',
                 'flux': 'W/m^2',
                }
          )

# Write PAH table in an .ecsv file
#t.write('./NGC7469_pah_tbl.ecsv', overwrite=False)
# Out:
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: divide by zero encountered in true_divide
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# /usr/local/anaconda3/lib/python3.8/site-packages/astropy/units/quantity.py:611: RuntimeWarning: invalid value encountered in multiply
#   result = super().__array_ufunc__(function, method, *arrays, **kwargs)
# 6.2/7.7 = 0.2694158115306601 +/- 0.006545463417734035
# 11.3/7.7 = 0.3846227736544648 +/- 0.006771473023612428
#              pah_strength  pah_strength_unc
# pah_complex
# PAH113_C     2.106990e-19      5.208565e-21
# PAH120       5.274476e-20      2.831340e-21
# PAH126_C     1.072756e-19      3.656524e-21
# PAH136       1.232616e-20      1.720379e-21
# PAH142       0.000000e+00      0.000000e+00
# PAH164       9.552297e-21      7.926729e-22
# PAH170_C     1.487757e-20      2.290471e-21
# PAH33        4.747356e-20      2.642360e-21
# PAH62        1.475878e-19      3.462199e-21
# PAH77_C      5.478069e-19      1.755303e-20
# PAH83        3.863632e-20      3.610172e-21
# PAH86        1.087322e-19      3.472195e-21
# ali34        6.032916e-21      2.734573e-21
# ali345       1.208811e-20      4.178507e-21
